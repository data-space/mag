# %%
save_load_path = '/home/eolus/Dropbox/MA755 Public/pynotes/Danny-Eole-Yuchen/Pickles'

# %%
import pickle
import pandas as pd
import numpy as np

# %%
def termThreshold(dtm_df, threshold):
    
    # Build array for the count of non-0 term-scores for each term
    sum_vec = dtm_df[ dtm_df > 0 ].count(axis=0)
    
    # Initialize list containing position of term columns to drop from dtm
    term_drop = []

    c = 0
    for column in dtm_df:
        if (len(column) < 3) or (sum_vec[c] < threshold) : 
            term_drop.append(column)
        c +=1
    
    dtm_df.drop(dtm_df.columns[term_drop], axis=1, inplace=True)
    return(dtm_df)

# %%
dtm_df = pd.read_pickle(save_load_path+'/lyrics_english_df.pkl')

# %%
sum_vec = dtm_df[ dtm_df > 0 ].count(axis=0)

threshold = 3

drop_words = []
c = 0
for column in dtm_df:
    if (len(column) < 3) or (sum_vec[c] < threshold) : 
        term_drop.append(column)
    c +=1

# %%
len(drop_words)
keep = [column for column in dtm_df if column not in drop_words]
keep
# Out:
# ['abandon',
#  'abl',
#  'aboard',
#  'abov',
#  'absenc',
#  'absolut',
#  'absurd',
#  'abus',
#  'abyss',
#  'accept',
#  'accus',
#  'ace',
#  'ach',
#  'achiev',
#  'acid',
#  'act',
#  'action',
#  'actual',
#  'adam',
#  'add',
#  'addict',
#  'admir',
#  'admit',
#  'ador',
#  'advanc',
#  'advic',
#  'afar',
#  'affair',
#  'affect',
#  'afford',
#  'afraid',
#  'afternoon',
#  'age',
#  'ago',
#  'agre',
#  'aha',
#  'ahead',
#  'ahh',
#  'ahhh',
#  'aid',
#  'aim',
#  'air',
#  'alarm',
#  'album',
#  'alcohol',
#  'alien',
#  'aliv',
#  'allah',
#  'alley',
#  'almighti',
#  'alon',
#  'alreadi',
#  'alright',
#  'altar',
#  'alter',
#  'alway',
#  'amaz',
#  'ambit',
#  'amen',
#  'america',
#  'american',
#  'amus',
#  'anchor',
#  'ancient',
#  'angel',
#  'anger',
#  'angri',
#  'anguish',
#  'ani',
#  'anim',
#  'anoth',
#  'answer',
#  'anticip',
#  'anybodi',
#  'anymor',
#  'anyon',
#  'anyth',
#  'anytim',
#  'anywher',
#  'apathi',
#  'apolog',
#  'appeal',
#  'appl',
#  'appreci',
#  'approach',
#  'april',
#  'aris',
#  'arm',
#  'armi',
#  'arrang',
#  'arriv',
#  'arrow',
#  'art',
#  'artist',
#  'ascend',
#  'ash',
#  'asham',
#  'asid',
#  'askin',
#  'asleep',
#  'ass',
#  'assassin',
#  'asshol',
#  'assum',
#  'assur',
#  'astray',
#  'ate',
#  'atom',
#  'attack',
#  'attempt',
#  'attent',
#  'attitud',
#  'attract',
#  'author',
#  'automat',
#  'autumn',
#  'ave',
#  'avenu',
#  'avoid',
#  'await',
#  'awak',
#  'awaken',
#  'awar',
#  'awhil',
#  'axe',
#  'aye',
#  'babe',
#  'babi',
#  'babylon',
#  'back',
#  'backward',
#  'bad',
#  'bag',
#  'bail',
#  'bake',
#  'balanc',
#  'bald',
#  'ball',
#  'banana',
#  'band',
#  'bang',
#  'bank',
#  'bar',
#  'bare',
#  'bark',
#  'barrel',
#  'base',
#  'basement',
#  'bass',
#  'bastard',
#  'bat',
#  'bath',
#  'bathroom',
#  'batter',
#  'battl',
#  'bay',
#  'beach',
#  'beam',
#  'bean',
#  'bear',
#  'beast',
#  'beat',
#  'beauti',
#  'becam',
#  'becaus',
#  'becom',
#  'bed',
#  'bedroom',
#  'bee',
#  'beef',
#  'beer',
#  'befor',
#  'beg',
#  'began',
#  'beggin',
#  'begin',
#  'begun',
#  'behav',
#  'behold',
#  'bein',
#  'belief',
#  'believ',
#  'bell',
#  'belli',
#  'belong',
#  'belt',
#  'bend',
#  'beneath',
#  'bent',
#  'berlin',
#  'besid',
#  'bet',
#  'betray',
#  'bewar',
#  'bibl',
#  'bid',
#  'big',
#  'bigger',
#  'biggest',
#  'bike',
#  'bill',
#  'billi',
#  'billion',
#  'bin',
#  'bind',
#  'bir',
#  'bird',
#  'birth',
#  'birthday',
#  'bit',
#  'bitch',
#  'bite',
#  'bitter',
#  'black',
#  'blacken',
#  'blade',
#  'blame',
#  'blank',
#  'blanket',
#  'blast',
#  'blaze',
#  'bled',
#  'bleed',
#  'bless',
#  'blew',
#  'blind',
#  'blink',
#  'bliss',
#  'blister',
#  'block',
#  'blond',
#  'blood',
#  'bloodi',
#  'bloom',
#  'blossom',
#  'blow',
#  'blowin',
#  'blown',
#  'blue',
#  'bluebird',
#  'blunt',
#  'blur',
#  'board',
#  'boat',
#  'bob',
#  'bobbi',
#  'bodi',
#  'boil',
#  'bold',
#  'bomb',
#  'bond',
#  'bone',
#  'bonni',
#  'boo',
#  'boogi',
#  'book',
#  'boom',
#  'boot',
#  'booti',
#  'booz',
#  'border',
#  'bore',
#  'born',
#  'borrow',
#  'boss',
#  'bother',
#  'bottl',
#  'bottom',
#  'bought',
#  'boulevard',
#  'bounc',
#  'bound',
#  'bout',
#  'bow',
#  'bowl',
#  'box',
#  'boy',
#  'boyfriend',
#  'brain',
#  'brake',
#  'branch',
#  'brand',
#  'brave',
#  'bread',
#  'break',
#  'breakfast',
#  'breakin',
#  'breast',
#  'breath',
#  'breed',
#  'breez',
#  'brick',
#  'bride',
#  'bridg',
#  'bright',
#  'brighter',
#  'bring',
#  'broad',
#  'broke',
#  'broken',
#  'brooklyn',
#  'brother',
#  'brought',
#  'brown',
#  'bruis',
#  'brush',
#  'brutal',
#  'bubbl',
#  'buck',
#  'bucket',
#  'buddi',
#  'bug',
#  'build',
#  'built',
#  'bull',
#  'bullet',
#  'bullshit',
#  'bum',
#  'bump',
#  'burden',
#  'buri',
#  'burn',
#  'burnin',
#  'burnt',
#  'burst',
#  'bus',
#  'bush',
#  'busi',
#  'bust',
#  'butcher',
#  'butt',
#  'butter',
#  'butterfli',
#  'button',
#  'buy',
#  'buzz',
#  'bye',
#  'cadillac',
#  'cafe',
#  'cage',
#  'cake',
#  'california',
#  'call',
#  'callin',
#  'calm',
#  'cancer',
#  'candi',
#  'candl',
#  'canâ\x80\x99t',
#  'can’t',
#  'cap',
#  'captain',
#  'captiv',
#  'captur',
#  'car',
#  'card',
#  'care',
#  'caress',
#  'carol',
#  'carpet',
#  'carri',
#  'carv',
#  'case',
#  'cash',
#  'cast',
#  'castl',
#  'cat',
#  'catch',
#  'caught',
#  'caus',
#  'cave',
#  'ceas',
#  'ceil',
#  'celebr',
#  'cell',
#  'cent',
#  'center',
#  'centuri',
#  'cha',
#  'chain',
#  'chair',
#  'challeng',
#  'chamber',
#  'champagn',
#  'chanc',
#  'chang',
#  'channel',
#  'chant',
#  'chao',
#  'chapter',
#  'charg',
#  'charm',
#  'chart',
#  'chase',
#  'chat',
#  'cheap',
#  'cheat',
#  'check',
#  'cheek',
#  'cheer',
#  'chees',
#  'chemic',
#  'cherish',
#  'cherri',
#  'chest',
#  'chew',
#  'chi',
#  'chicago',
#  'chick',
#  'chicken',
#  'child',
#  'children',
#  'chill',
#  'chime',
#  'chin',
#  'chip',
#  'chocol',
#  'choic',
#  'choir',
#  'choke',
#  'choos',
#  'chop',
#  'chord',
#  'chorus',
#  'chose',
#  'chosen',
#  'christ',
#  'christian',
#  'christma',
#  'chrome',
#  'church',
#  'cigarett',
#  'circl',
#  'circumst',
#  'circus',
#  'citi',
#  'civil',
#  'claim',
#  'clap',
#  'class',
#  'claus',
#  'claw',
#  'clay',
#  'clean',
#  'cleans',
#  'clear',
#  'clever',
#  'click',
#  'climb',
#  'cling',
#  'clip',
#  'clock',
#  'close',
#  'closer',
#  'closet',
#  'cloth',
#  'cloud',
#  'cloudi',
#  'clown',
#  'club',
#  'clue',
#  'clutch',
#  'coal',
#  'coast',
#  'coat',
#  'cocain',
#  'cock',
#  'code',
#  'coffe',
#  'coffin',
#  'coin',
#  'coke',
#  'cold',
#  'colder',
#  'collaps',
#  'collect',
#  'colleg',
#  'collid',
#  'color',
#  'colour',
#  'comb',
#  'combin',
#  'comfort',
#  'comin',
#  'command',
#  'comment',
#  'commit',
#  'common',
#  'communic',
#  'compani',
#  'compar',
#  'compass',
#  'complain',
#  'complet',
#  'complex',
#  'complic',
#  'comprehend',
#  'compromis',
#  'comput',
#  'con',
#  'conceal',
#  'conceiv',
#  'concentr',
#  'concern',
#  'conclus',
#  'concret',
#  'condemn',
#  'condit',
#  'confess',
#  'confid',
#  'confin',
#  'confront',
#  'confus',
#  'connect',
#  'conquer',
#  'conscienc',
#  'conscious',
#  'consequ',
#  'consid',
#  'consol',
#  'constant',
#  'consum',
#  'contact',
#  'contempl',
#  'content',
#  'continu',
#  'control',
#  'convers',
#  'convict',
#  'convinc',
#  'cook',
#  'cool',
#  'cop',
#  'cope',
#  'core',
#  'corn',
#  'corner',
#  'corpor',
#  'corps',
#  'correct',
#  'corrupt',
#  'cos',
#  'cosmic',
#  'cost',
#  'cotton',
#  'couch',
#  'count',
#  'counti',
#  'countri',
#  'coup',
#  'coupl',
#  'courag',
#  'cours',
#  'court',
#  'cousin',
#  'cover',
#  'coward',
#  'cowboy',
#  'coz',
#  'crack',
#  'cradl',
#  'crap',
#  'crash',
#  'crave',
#  'crawl',
#  'crazi',
#  'cream',
#  'creat',
#  'creation',
#  'creatur',
#  'credit',
#  'creep',
#  'crew',
#  'cri',
#  'crime',
#  'crimin',
#  'crimson',
#  'critic',
#  'crook',
#  'cross',
#  'crow',
#  'crowd',
#  'crown',
#  'crucifi',
#  'cruel',
#  'cruis',
#  'crumbl',
#  'crush',
#  'cryin',
#  'crystal',
#  'cultur',
#  'cum',
#  'cup',
#  'cure',
#  'curl',
#  'current',
#  'curs',
#  'curtain',
#  'curv',
#  'cut',
#  'cute',
#  'cuz',
#  'cycl',
#  'dad',
#  'daddi',
#  'dag',
#  'daili',
#  'dalla',
#  'damag',
#  'dame',
#  'damn',
#  'damnat',
#  'danc',
#  'dancer',
#  'dancin',
#  'danger',
#  'dare',
#  'dark',
#  'darken',
#  'darker',
#  'darkest',
#  'darl',
#  'darlin',
#  'dart',
#  'dash',
#  'dat',
#  'date',
#  'daughter',
#  'david',
#  'dawn',
#  'day',
#  'daydream',
#  'daylight',
#  'dead',
#  'deaf',
#  'deal',
#  'dear',
#  'death',
#  'decad',
#  'decay',
#  'deceit',
#  'deceiv',
#  'decemb',
#  'decept',
#  'decid',
#  'decis',
#  'deck',
#  'declar',
#  'dedic',
#  'dee',
#  'deed',
#  'deep',
#  'deeper',
#  'deepest',
#  'deepli',
#  'defeat',
#  'defend',
#  'defens',
#  'defi',
#  'defin',
#  'definit',
#  'degre',
#  'delight',
#  'deliv',
#  'delus',
#  'dem',
#  'demand',
#  'demis',
#  'demon',
#  'den',
#  'deni',
#  'denial',
#  'depart',
#  'depend',
#  'depress',
#  'depth',
#  'descend',
#  'describ',
#  'desert',
#  'deserv',
#  'design',
#  'desir',
#  'desol',
#  'despair',
#  'desper',
#  'despis',
#  'despit',
#  'destin',
#  'destini',
#  'destroy',
#  'destruct',
#  'devast',
#  'devil',
#  'devot',
#  'devour',
#  'diamond',
#  'dice',
#  'dick',
#  'die',
#  'differ',
#  'dig',
#  'digit',
#  'dim',
#  'dime',
#  'dimens',
#  'dine',
#  'ding',
#  'dinner',
#  'dip',
#  'direct',
#  'dirt',
#  'dirti',
#  'dis',
#  'disagre',
#  'disappear',
#  'disappoint',
#  'disast',
#  'disconnect',
#  'discov',
#  'diseas',
#  'disgrac',
#  'disguis',
#  'disgust',
#  'dish',
#  'display',
#  'diss',
#  'dissolv',
#  'distanc',
#  'distant',
#  'distort',
#  'distract',
#  'ditch',
#  'dive',
#  'divid',
#  'divin',
#  'dizzi',
#  'doctor',
#  'doe',
#  'dog',
#  'doin',
#  'doll',
#  'dollar',
#  'domin',
#  'donâ\x80\x99t',
#  'don’t',
#  'doom',
#  'door',
#  'doorway',
#  'dope',
#  'dot',
#  'doubl',
#  'doubt',
#  'dough',
#  'dove',
#  'downtown',
#  'drag',
#  'dragon',
#  'drain',
#  'drama',
#  'drank',
#  'draw',
#  'drawn',
#  'dread',
#  'dream',
#  'dreamer',
#  'dreamin',
#  'dress',
#  'drew',
#  'dri',
#  'drift',
#  'drink',
#  'drinkin',
#  'drip',
#  'drive',
#  'driven',
#  'drivin',
#  'drop',
#  'drove',
#  'drown',
#  'drug',
#  'drum',
#  'drunk',
#  'drunken',
#  'dub',
#  'duck',
#  'dude',
#  'due',
#  'dug',
#  'dull',
#  'dumb',
#  'dun',
#  'dure',
#  'dust',
#  'duti',
#  'dwell',
#  'dyin',
#  'dynamit',
#  'eager',
#  'eagl',
#  'ear',
#  'earli',
#  'earn',
#  'earth',
#  'eas',
#  'easi',
#  'easier',
#  'easili',
#  'east',
#  'eat',
#  'echo',
#  'ecstasi',
#  'edg',
#  'educ',
#  'effect',
#  'effort',
#  'egg',
#  'ego',
#  'electr',
#  'elev',
#  'els',
#  'elvi',
#  'ember',
#  'embrac',
#  'emerg',
#  'emot',
#  'empir',
#  'empti',
#  'end',
#  'endless',
#  'endur',
#  'enemi',
#  'energi',
#  'engin',
#  'england',
#  'english',
#  'enjoy',
#  'enter',
#  'entertain',
#  'entir',
#  'envi',
#  'equal',
#  'eras',
#  'error',
#  'escap',
#  'especi',
#  'essenc',
#  'etern',
#  'eve',
#  'eventu',
#  'everi',
#  'everlast',
#  'everybodi',
#  'everyday',
#  'everyon',
#  'everyth',
#  'everytim',
#  'everywher',
#  'evid',
#  'evil',
#  'evolut',
#  'exact',
#  'excit',
#  'excus',
#  'exist',
#  'exit',
#  'expect',
#  'experi',
#  'explain',
#  'explod',
#  'explor',
#  'explos',
#  'expos',
#  'express',
#  'extra',
#  'eye',
#  'face',
#  'fact',
#  'factori',
#  'fade',
#  'fail',
#  'failur',
#  'faint',
#  'fair',
#  'fairi',
#  'faith',
#  'fake',
#  'fall',
#  'fallen',
#  'fallin',
#  'fals',
#  'fame',
#  'famili',
#  'familiar',
#  'famous',
#  'fan',
#  'fanci',
#  'fantasi',
#  'farewel',
#  'farm',
#  'fascin',
#  'fashion',
#  'fast',
#  'faster',
#  'fat',
#  'fatal',
#  'fate',
#  'father',
#  'fault',
#  'favor',
#  'favorit',
#  'fear',
#  'fearless',
#  'feast',
#  'feat',
#  'feather',
#  'featur',
#  'fed',
#  'feed',
#  'feel',
#  'feelin',
#  'feet',
#  'fell',
#  'fella',
#  'fellow',
#  'felt',
#  'fenc',
#  'fever',
#  'fiction',
#  'fiddl',
#  'field',
#  'fiend',
#  'fifteen',
#  'fifti',
#  'fight',
#  'fighter',
#  'figur',
#  'file',
#  'fill',
#  'film',
#  'filth',
#  'filthi',
#  'final',
#  'find',
#  'fine',
#  'finest',
#  'finger',
#  'fingertip',
#  'finish',
#  'fire',
#  'firm',
#  'fish',
#  'fist',
#  'fit',
#  'fix',
#  'flag',
#  'flame',
#  'flash',
#  'flat',
#  'flavor',
#  'flaw',
#  'flee',
#  'flesh',
#  'flew',
#  'fli',
#  'flicker',
#  'flight',
#  'flip',
#  'flirt',
#  'float',
#  'flock',
#  'flood',
#  'floor',
#  'flow',
#  'flower',
#  'flyin',
#  'focus',
#  'foe',
#  'fog',
#  'fold',
#  'folk',
#  'follow',
#  'food',
#  'fool',
#  'foolish',
#  'foot',
#  'footstep',
#  'forc',
#  'fore',
#  'foreign',
#  'forest',
#  'forev',
#  'forg',
#  'forget',
#  'forgiv',
#  'forgot',
#  'forgotten',
#  'form',
#  'forsak',
#  'forsaken',
#  'forti',
#  ...]

# %%
# save cleaned dataframe as pickle file
mss_english_df = pd.read_pickle(save_load_path+'/lyrics_english_df.pkl')

# %%
mss_english_thre2_df = termThreshold(mss_english_df, 2)
mss_english_thre3_df = termThreshold(mss_english_df, 3)
mss_english_thre4_df = termThreshold(mss_english_df, 4)

# %%
# save cleaned dataframe as pickle file
mss_english_thre2_df.to_pickle(save_load_path+'/DTM/lyrics_english_thre2_df.pkl')
mss_english_thre3_df.to_pickle(save_load_path+'/DTM/lyrics_english_thre3_df.pkl')
mss_english_thre4_df.to_pickle(save_load_path+'/DTM/lyrics_english_thre4_df.pkl')
