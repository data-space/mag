# %% [markdown]
# # Project: Sentiment analysis

# %%
### Notes

- Recommend songs to a user based on the songs they listen to
- Pick the song that is closest to the geometric mean of the 
    songs which the user listens to. 
- Create the sentiment variable for each song    
    
- Looking at "profile" dataset to get the songs the user listens to

# %% [markdown]
# ## Goals:
# 1. Sentiment analysis using text mining technique on lyrics data
# 2. Cluster analysis of song sentiment using sentiment data determined in previous step

# %% [markdown]
# ## Data:
#
# ###  Opinion Lexicon: Positive & Negative
#
# `positive-words.txt` contains a list of POSITIVE opinion words (or sentiment words).
# `negative-words.txt` contains a list of NEGATIVE opinion words (or sentiment words).
#
# This file and the papers can all be downloaded from
# http://www.cs.uic.edu/~liub/FBS/sentiment-analysis.html
#
# Citation:
# Minqing Hu and Bing Liu. "Mining and Summarizing Customer Reviews."
# Proceedings of the ACM SIGKDD International Conference on Knowledge
# Discovery and Data Mining (KDD-2004), Aug 22-25, 2004, Seattle, Washington, USA.
# Bing Liu, Minqing Hu and Junsheng Cheng. "Opinion Observer: Analyzing and Comparing Opinions on the Web."
# Proceedings of the 14th International World Wide Web conference (WWW-2005), May 10-14, 2005, Chiba, Japan.
#
# ### Mapping {Stemmed word : Unstemmed word}
#
# `mxm_reverse_mapping.txt` contains the mapping for Stemmed word -> Unstemmed word
#
# This file can be downloaded from
# http://labrosa.ee.columbia.edu/millionsong/sites/default/files/mxm_reverse_mapping.txt
#
# Citation:
# musiXmatch dataset, the official lyrics collection for the Million Song Dataset
# author: Thierry Bertin-Mahieux and Daniel P.W. Ellis and Brian Whitman and Paul Lamere
# title: The Million Song Dataset

# %% [markdown]
# ## Modules and functions:

# %%
import pandas as pd
import numpy as np
import re
import pickle
import sqlite3
import itertools

# %% [markdown]
# ### 1 - Preparation of the 'mood' data using Pandas

# %%
path = '/home/eolus/Documents/MA755_data/LyricsData/'

# Put text content stemmed/unstemmed entries in list
f_1 = open(path+'mxm_reverse_mapping.txt', 'r')
lines_1 = [line.rstrip('\n').split('<SEP>') for line in f_1.readlines()]

# Put list in pandas df
df_1 = pd.DataFrame(lines_1, columns=['Stemmed', 'Unstemmed'])

# Remove non letter terms
df_stem_mapping = df_1[df_1.Stemmed.str.match("^[a-zA-Z]+$") == True]
df_stem_mapping.head()
# Out:
#   Stemmed Unstemmed
# 1    pido      pido
# 2    hatr    hatred
# 3    pide      pide
# 4  yellow    yellow
# 5    four      four

# %%
# Put text content positive & negative unstemmed entries in list
f_2 = open(path+'positive-words.txt', 'r', encoding='ISO-8859-1')
lines_2 = [line.rstrip('\n') for line in f_2.readlines()]

f_3 = open(path+'negative-words.txt', 'r', encoding='ISO-8859-1')
lines_3 = [line.rstrip('\n') for line in f_3.readlines()]

# %%
# Put list positive in pandas df
df_2 = pd.DataFrame(lines_2, columns=['Unstemmed'])
df_2['Mood'] = pd.Series([1] * len(df_2.index) )
df_2.head()
# Out:
#    Unstemmed  Mood
# 0         a+     1
# 1     abound     1
# 2    abounds     1
# 3  abundance     1
# 4   abundant     1

# %%
# Put list negative in pandas df
df_3 = pd.DataFrame(lines_3, columns=['Unstemmed'])
df_3['Mood'] = pd.Series([-1] * len(df_3.index) )
df_3.head()
# Out:
#     Unstemmed  Mood
# 0     2-faced    -1
# 1     2-faces    -1
# 2    abnormal    -1
# 3     abolish    -1
# 4  abominable    -1

# %%
# Stack the positive and negative df on top of each other
df_mood = pd.concat([df_2, df_3], axis=0)
df_mood.head()
df_mood.tail()
# Out:
#       Unstemmed  Mood
# 4778       zaps    -1
# 4779     zealot    -1
# 4780    zealous    -1
# 4781  zealously    -1
# 4782     zombie    -1

# %%
# Define outter join data.frame to JOIN stem_mapping and df_mood on `Unstemmed` column
df_outter_join = pd.merge(df_stem_mapping, df_mood, on='Unstemmed', how='outer')
df_outter_join.head()
# Out:
#   Stemmed Unstemmed  Mood
# 0    pido      pido   NaN
# 1    hatr    hatred    -1
# 2    pide      pide   NaN
# 3  yellow    yellow   NaN
# 4    four      four   NaN

# %%
# Filter out Nan values in `Stemmed` (meaning is not in Lyrics bag of word) and from `Mood`(meaning not in sentiment lexicon docs)
df_stem = df_outter_join[df_outter_join.Stemmed.notnull() & df_outter_join.Mood.notnull()]
print('Stemmed words tagged with a mood value: %d' %(len(df_stem.index)))
df_stem.head()
# Out:
# Stemmed words tagged with a mood value: 737
#    Stemmed Unstemmed  Mood
# 1     hatr    hatred    -1
# 7   thirst    thirst    -1
# 10    hate      hate    -1
# 17  pardon    pardon     1
# 20   sorri     sorry    -1

# %%
# Save `df_stem` to pickle file:
save_load_path = '/home/eolus/Documents/MA755_data/myPickles'
df_stem.to_pickle(save_load_path+'/df_stem.pkl')

# %% [markdown]
# ### 2 - Preparation of the 'lyrics' data using SQLite and Pandas

# %%
import pandas as pd
import numpy as np
import pickle
import sqlite3
import itertools

# %%
# Define path
lyrics_path = '/home/eolus/Documents/MA755_data/LyricsData'
pickle_path = '/home/eolus/Documents/MA755_data/myPickles'

# Access MXM data stored in SQLite using Python and Pandas
con = sqlite3.connect(lyrics_path +'/mxm_dataset.db')
c = con.cursor()

# Get set of track_id
c.execute('SELECT DISTINCT track_id FROM lyrics')
data_track_id = c.fetchall()
set_track_id = set(itertools.chain.from_iterable(data_track_id))

# Convert to list of track_id to use as DataFrame index
list_track_id = []
list_track_id.extend(set_track_id)

for track_id in list_track_id[0:9]:
    print(track_id)
# Out:
# TREHRKF128F423349E
# TRWGKJQ128F9347978
# TRHUJRK12903CB4638
# TRCZSUV128F42816A1
# TRFNAIW128F421F3DD
# TRKHUIZ128F934435A
# TRYYAHV128F4277393
# TRFXFMA128F42652C7
# TRPJCAN128F1459DE2

# %%
# Load df_stem from the pickle file (STEM | MOOD)
df_stem = pd.read_pickle(pickle_path+'/df_stem.pkl')# Put unique stemmed words into a set for faster look-ups
stemmed_set = set(pd.unique(df_stem.Stemmed.ravel()))

list_stemmed_set = []
list_stemmed_set.extend(stemmed_set)
for stem in list_stemmed_set[0:9]:
    print(stem)
# Out:
# skinni
# suav
# naughti
# leer
# protect
# kill
# stranger
# guilt
# beg

# %%
# Create list of `lyrics_df` column names [<WORD#1>, ... ,<WORD#N>, 'COUNT_OTHER']
column_names = []
for word in stemmed_set:
    column_names.append(word.upper())
column_names.append('COUNT_OTHER')

# TRVZPPJ12903CB5C2D       0     0       0        0       0      0            0
# TRISADH128F42178B3       0     0       0        0       0      0            0
# TRVTYFT128F9316C65       0     0       0        0       0      0            0
# ...                    ...   ...     ...      ...     ...    ...          ...
# TRXSSAG128F424E068       0     0       0        0       0      0            0
# TRELLTX12903CDDF18       0     0       0        0       0      0            0
# TRWEKFP128F423E4B8       0     0       0        0       0      0            0
# TRAEYHX128F9359E34       0     0       0        0       0      0            0
# TRBRIYH128F92DFD5D       0     0       0        0       0      0            0
# TRRLNDF128F934B164       0     0       0        0       0      0            0
# TRSLZES128F92F8A97       0     0       0        0       0      0            0
# TRYMIYP128F4259834       0     0       0        0       0      0            0
# TRQNTOJ128F426A6A0       0     0       0        0       0      0            0
# TROCTTG128F9321656       0     0       0        0       0      0            0
# TRJLLXR12903CFEC97       0     0       0        0       0      0            0
# TRDHLDM128F424377A       0     0       0        0       0      0            0
# TRRHWUW128F4249CEE       0     0       0        0       0      0            0
# TRTALMQ128F42AD439       0     0       0        0       0      0            0
# TRSXUWI128F426BDED       0     0       0        0       0      0            0
# TRRWXJX128E0785A67       0     0       0        0       0      0            0
# TRQSVPD128F427864A       0     0       0        0       0      0            0
# TRQCCRU128F426205C       0     0       0        0       0      0            0
# TRPBLJY128F93569CD       0     0       0        0       0      0            0
# TRULAOU128F42397E9       0     0       0        0       0      0            0
# TRUQPYV128F93236AD       0     0       0        0       0      0            0
# TRHNUMP128F42936EC       0     0       0        0       0      0            0
# TRWAFKY128F42676AB       0     0       0        0       0      0            0
# TRXDVSL12903CD849E       0     0       0        0       0      0            0
# TRPCWPA128F9310D7D       0     0       0        0       0      0            0
# TRAAORZ128F421CB5C       0     0       0        0       0      0            0
# TRYIXKH12903CBAC35       0     0       0        0       0      0            0
# TRPVEVA128F427BCC9       0     0       0        0       0      0            0
# TRHWNTO128F426138C       0     0       0        0       0      0            0
# TRDAJAQ128F9300B97       0     0       0        0       0      0            0
#
# [237662 rows x 738 columns]

# %% [markdown]
# ### 3 - Fill lyrics.df

# %%
import pandas as pd
import numpy as np
import pickle
import sqlite3
import itertools

# %%
lyrics_path = '/home/eolus/Documents/MA755_data/LyricsData'
pickle_path = '/home/eolus/Documents/MA755_data/myPickles'


# Open output DataFrame
try:
    # Open `full_df_lyrics.pkl` if exists
    lyrics_df = pd.read_pickle(pickle_path+'/full_df_lyrics.pkl')
    print("Retrieving work in progress, frame `full_lyrics_df`...\n")
except:
    # Open initialized `lyrics_df` otherwise
    lyrics_df = pd.read_pickle(pickle_path+'/df_lyrics.pkl')
    print("Retrieving empty frame `lyrics_df`...\n")

# %%
# Access MXM data stored in SQLite using Python and Pandas
con = sqlite3.connect(lyrics_path +'/mxm_dataset.db')
c = con.cursor()


# Get the remaining list of track_id to process
try:
    # Retrieve from pickle file if exists
    track_list = pickle.load(open(pickle_path + '/track_stack.pkl', 'rb'))
    print("Retrieving stack of tracks to process...\n")
    
except:
    # Generate from .db query otherwise
    c.execute('SELECT DISTINCT track_id FROM lyrics')
    data_track_id = c.fetchall()

    #Get set of unique track_id's
    track_set = set(itertools.chain.from_iterable(data_track_id))

    # Convert to list for slicing (create a buffer..)
    track_list = []
    track_list.extend(track_set)
    
    # Save to pickle
    pickle.dump(track_list, open(pickle_path + '/track_stack.pkl', 'wb'))
    print("Generating new stack of tracks to process...\n")
    
for track_id in track_list[0:5]:
    print(track_id)
print('...')
for track_id in track_list[-5:]:
    print(track_id)
# Out:
# Retrieving stack of tracks to process...
#
# TRMWRJM128F427611C
# TRBHHZX128F14AE20E
# TRGALDW128F92D0CDE
# TRAUTTP128F425BDEB
# TRSKWNE128F42A1FC7
# ...
# TRHUGGQ128F423844F
# TRPBTBJ128F92D4A2A
# TROEQUU128E0795673
# TRXWLNP128F933C86A
# TRIDHXQ128F9346553

# %%
iterations_count = 10
track_buffer_size = 10

for i in range(0,iterations_count-1):

    # Select a bunch of track_id for processing: track_buffer
    if (len(track_list) >= track_buffer_size):
        track_buffer = track_list[0:track_buffer_size-1]
    else:
        track_buffer = track_list

    print('')
    print('Buffering tracks:')
    [print(track) for track in track_buffer]
    print('')

    # Query for track data in track_buffer
    placeholder= '?' # For SQLite. See DBAPI paramstyle.
    placeholders= ', '.join(placeholder for unused in track_buffer)
    query= 'SELECT * FROM lyrics WHERE track_id IN (%s)' % placeholders

    # Iterate through tokenized row object (tuple)
    #   [0]          [1]         [2]         [3]       [4]
    #   track_id    |mxm_id     |word       |count     |is_test
    for row in c.execute(query, track_buffer):
        word = row[2].upper()
        track_id = row[0]
        print('ROW = {row}'.format(row = row))
        print('track_id = {track_id}'.format(track_id = track_id))
        print('word = {word}'.format(word = word))
        print('')

        try:
            lyrics_df.loc[track_id][word] += row[3]
        except:
            lyrics_df.loc[track_id]['COUNT_OTHER'] += row[3]


    # Save complete `lyrics_df` in pkl file
    lyrics_df.to_pickle(pickle_path+'/full_df_lyrics.pkl')

    # Remove buffered value from track_list
    track_list = track_list[len(track_buffer):]
    print("Updating track list to process")

    # Save to pickle
    pickle.dump(track_list, open(pickle_path + '/track_stack.pkl', 'wb'))
    print("Saving updated track stack...\n")
# Out:
# Buffering tracks:
# TRMWRJM128F427611C
# TRBHHZX128F14AE20E
# TRGALDW128F92D0CDE
# TRAUTTP128F425BDEB
# TRSKWNE128F42A1FC7
# TRUDGYR12903CCD8CE
# TREAMHV128F92DC7EA
# TRBKUIX12903CEB628
# TRDTUOK128F428D064
#
# ROW = ('TRAUTTP128F425BDEB', 707069, 'of', 11, 0)
# track_id =TRAUTTP128F425BDEB
# word =OF
#
# ROW = ('TRAUTTP128F425BDEB', 707069, 'say', 2, 0)
# track_id =TRAUTTP128F425BDEB
# word =SAY
#
# ROW = ('TRAUTTP128F425BDEB', 707069, 'littl', 11, 0)
# track_id =TRAUTTP128F425BDEB
# word =LITTL
#
# ROW = ('TRAUTTP128F425BDEB', 707069, 'bit', 11, 0)
# track_id =TRAUTTP128F425BDEB
# word =BIT
#
# ROW = ('TRAUTTP128F425BDEB', 707069, 'bass', 9, 0)
# track_id =TRAUTTP128F425BDEB
# word =BASS
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'i', 11, 0)
# track_id =TRBHHZX128F14AE20E
# word =I
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'the', 19, 0)
# track_id =TRBHHZX128F14AE20E
# word =THE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'you', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =YOU
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'to', 7, 0)
# track_id =TRBHHZX128F14AE20E
# word =TO
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'and', 16, 0)
# track_id =TRBHHZX128F14AE20E
# word =AND
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'a', 16, 0)
# track_id =TRBHHZX128F14AE20E
# word =A
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'it', 7, 0)
# track_id =TRBHHZX128F14AE20E
# word =IT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'not', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =NOT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'in', 9, 0)
# track_id =TRBHHZX128F14AE20E
# word =IN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'is', 5, 0)
# track_id =TRBHHZX128F14AE20E
# word =IS
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'of', 9, 0)
# track_id =TRBHHZX128F14AE20E
# word =OF
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'that', 6, 0)
# track_id =TRBHHZX128F14AE20E
# word =THAT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'do', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =DO
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'on', 8, 0)
# track_id =TRBHHZX128F14AE20E
# word =ON
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'we', 18, 0)
# track_id =TRBHHZX128F14AE20E
# word =WE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'am', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =AM
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'will', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =WILL
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'all', 4, 0)
# track_id =TRBHHZX128F14AE20E
# word =ALL
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'for', 8, 0)
# track_id =TRBHHZX128F14AE20E
# word =FOR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'no', 3, 0)
# track_id =TRBHHZX128F14AE20E
# word =NO
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'have', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =HAVE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'so', 3, 0)
# track_id =TRBHHZX128F14AE20E
# word =SO
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'this', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =THIS
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'but', 3, 0)
# track_id =TRBHHZX128F14AE20E
# word =BUT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'with', 4, 0)
# track_id =TRBHHZX128F14AE20E
# word =WITH
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'what', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =WHAT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'just', 4, 0)
# track_id =TRBHHZX128F14AE20E
# word =JUST
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'when', 3, 0)
# track_id =TRBHHZX128F14AE20E
# word =WHEN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'like', 5, 0)
# track_id =TRBHHZX128F14AE20E
# word =LIKE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'can', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =CAN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'up', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =UP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'one', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =ONE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'they', 5, 0)
# track_id =TRBHHZX128F14AE20E
# word =THEY
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'down', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =DOWN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'get', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =GET
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'was', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =WAS
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'see', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SEE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'from', 4, 0)
# track_id =TRBHHZX128F14AE20E
# word =FROM
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'feel', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =FEEL
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'make', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =MAKE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'take', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =TAKE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'day', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =DAY
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'at', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =AT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'her', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =HER
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'heart', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =HEART
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'need', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =NEED
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'our', 8, 0)
# track_id =TRBHHZX128F14AE20E
# word =OUR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'world', 4, 0)
# track_id =TRBHHZX128F14AE20E
# word =WORLD
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'die', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =DIE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'think', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =THINK
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'man', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =MAN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'too', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =TOO
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'onli', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =ONLI
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'tri', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =TRI
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'or', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =OR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'whi', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =WHI
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'mind', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =MIND
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'an', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =AN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'us', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =US
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'girl', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =GIRL
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'wanna', 3, 0)
# track_id =TRBHHZX128F14AE20E
# word =WANNA
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'find', 3, 0)
# track_id =TRBHHZX128F14AE20E
# word =FIND
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'over', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =OVER
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'littl', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =LITTL
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'light', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =LIGHT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'did', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =DID
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'home', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =HOME
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'walk', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =WALK
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'ever', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =EVER
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'them', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =THEM
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'face', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =FACE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'their', 3, 0)
# track_id =TRBHHZX128F14AE20E
# word =THEIR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'chang', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =CHANG
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'god', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =GOD
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'stop', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =STOP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'thought', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =THOUGHT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'peopl', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =PEOPL
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'sky', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SKY
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'care', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =CARE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'watch', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =WATCH
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'pain', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =PAIN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'name', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =NAME
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'blue', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =BLUE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'talk', 3, 0)
# track_id =TRBHHZX128F14AE20E
# word =TALK
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'mine', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =MINE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'sleep', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SLEEP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'kill', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =KILL
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'two', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =TWO
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'done', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =DONE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'black', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =BLACK
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'line', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =LINE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'rock', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =ROCK
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'lose', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =LOSE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'wonder', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =WONDER
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'togeth', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =TOGETH
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'shine', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SHINE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'mani', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =MANI
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'work', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =WORK
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'behind', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =BEHIND
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'big', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =BIG
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'hate', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =HATE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'save', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SAVE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'arm', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =ARM
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'bodi', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =BODI
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'best', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =BEST
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'war', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =WAR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'sea', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SEA
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'road', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =ROAD
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'rise', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =RISE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'grow', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =GROW
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'game', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =GAME
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'follow', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =FOLLOW
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'water', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =WATER
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'wast', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =WAST
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'earth', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =EARTH
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 's', 6, 0)
# track_id =TRBHHZX128F14AE20E
# word =S
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'guess', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =GUESS
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'drive', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =DRIVE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'car', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =CAR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'shadow', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SHADOW
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'drink', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =DRINK
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 't', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =T
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'peac', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =PEAC
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'mother', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =MOTHER
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'tire', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =TIRE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'speak', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SPEAK
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'kid', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =KID
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'throw', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =THROW
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'within', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =WITHIN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'worri', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =WORRI
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'bout', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =BOUT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'wear', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =WEAR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'blame', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =BLAME
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'catch', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =CATCH
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'caught', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =CAUGHT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'warm', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =WARM
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'top', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =TOP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'bit', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =BIT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'gold', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =GOLD
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'build', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =BUILD
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'cos', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =COS
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'worth', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =WORTH
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'dri', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =DRI
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'everywher', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =EVERYWHER
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'feed', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =FEED
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'vers', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =VERS
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'wide', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =WIDE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'natur', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =NATUR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'shoe', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SHOE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'bar', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =BAR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'destroy', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =DESTROY
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'treat', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =TREAT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'stranger', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =STRANGER
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'machin', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =MACHIN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'cloth', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =CLOTH
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'ignor', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =IGNOR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'nation', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =NATION
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 're', 4, 0)
# track_id =TRBHHZX128F14AE20E
# word =RE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'middl', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =MIDDL
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'pop', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =POP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'comfort', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =COMFORT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'swallow', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SWALLOW
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'swim', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SWIM
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'person', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =PERSON
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'west', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =WEST
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'spit', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SPIT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'gather', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =GATHER
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'dollar', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =DOLLAR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'action', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =ACTION
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'test', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =TEST
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'trace', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =TRACE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'prison', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =PRISON
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'paid', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =PAID
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'daughter', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =DAUGHTER
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'hip', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =HIP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'pressur', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =PRESSUR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'east', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =EAST
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'cop', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =COP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'imag', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =IMAG
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'enjoy', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =ENJOY
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'consum', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =CONSUM
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'connect', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =CONNECT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'cheap', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =CHEAP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'flag', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =FLAG
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'sue', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SUE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'restless', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =RESTLESS
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'forest', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =FOREST
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'mankind', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =MANKIND
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'hop', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =HOP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'affect', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =AFFECT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'squar', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SQUAR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'obsess', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =OBSESS
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'sheep', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SHEEP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'slaughter', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SLAUGHTER
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'secur', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SECUR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'stress', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =STRESS
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'ceas', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =CEAS
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'border', 3, 0)
# track_id =TRBHHZX128F14AE20E
# word =BORDER
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'reaction', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =REACTION
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'palm', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =PALM
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'stray', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =STRAY
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'yell', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =YELL
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'attitud', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =ATTITUD
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'sleev', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SLEEV
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'progress', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =PROGRESS
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'rag', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =RAG
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'slap', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =SLAP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'chip', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =CHIP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'foreign', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =FOREIGN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'crimin', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =CRIMIN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'aussi', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =AUSSI
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'opinion', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =OPINION
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'nuclear', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =NUCLEAR
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'usa', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =USA
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'georg', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =GEORG
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'wolv', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =WOLV
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'stock', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =STOCK
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'bush', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =BUSH
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'pawn', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =PAWN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'peep', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =PEEP
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'politician', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =POLITICIAN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'ain', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =AIN
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'pollut', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =POLLUT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'phrase', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =PHRASE
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'subject', 2, 0)
# track_id =TRBHHZX128F14AE20E
# word =SUBJECT
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'issu', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =ISSU
#
# ROW = ('TRBHHZX128F14AE20E', 3706327, 'nurs', 1, 0)
# track_id =TRBHHZX128F14AE20E
# word =NURS
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'the', 11, 1)
# track_id =TRBKUIX12903CEB628
# word =THE
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'and', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =AND
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'in', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =IN
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'is', 9, 1)
# track_id =TRBKUIX12903CEB628
# word =IS
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'of', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =OF
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'are', 3, 1)
# track_id =TRBKUIX12903CEB628
# word =ARE
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'we', 5, 1)
# track_id =TRBKUIX12903CEB628
# word =WE
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'will', 3, 1)
# track_id =TRBKUIX12903CEB628
# word =WILL
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'all', 4, 1)
# track_id =TRBKUIX12903CEB628
# word =ALL
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'this', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =THIS
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'when', 2, 1)
# track_id =TRBKUIX12903CEB628
# word =WHEN
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'time', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =TIME
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'go', 6, 1)
# track_id =TRBKUIX12903CEB628
# word =GO
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'see', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =SEE
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'as', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =AS
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'day', 6, 1)
# track_id =TRBKUIX12903CEB628
# word =DAY
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'away', 10, 1)
# track_id =TRBKUIX12903CEB628
# word =AWAY
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'life', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =LIFE
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'our', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =OUR
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'world', 3, 1)
# track_id =TRBKUIX12903CEB628
# word =WORLD
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'dream', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =DREAM
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'us', 3, 1)
# track_id =TRBKUIX12903CEB628
# word =US
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'turn', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =TURN
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'face', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =FACE
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'end', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =END
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'last', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =LAST
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'dead', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =DEAD
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'cold', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =COLD
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'year', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =YEAR
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'today', 6, 1)
# track_id =TRBKUIX12903CEB628
# word =TODAY
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'sad', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =SAD
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'eat', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =EAT
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'flower', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =FLOWER
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'grey', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =GREY
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'ray', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =RAY
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'sweep', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =SWEEP
#
# ROW = ('TRBKUIX12903CEB628', 2227259, 'wither', 1, 1)
# track_id =TRBKUIX12903CEB628
# word =WITHER
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'a', 4, 1)
# track_id =TRDTUOK128F428D064
# word =A
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'me', 1, 1)
# track_id =TRDTUOK128F428D064
# word =ME
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'no', 7, 1)
# track_id =TRDTUOK128F428D064
# word =NO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'que', 27, 1)
# track_id =TRDTUOK128F428D064
# word =QUE
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'de', 15, 1)
# track_id =TRDTUOK128F428D064
# word =DE
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'la', 23, 1)
# track_id =TRDTUOK128F428D064
# word =LA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'y', 13, 1)
# track_id =TRDTUOK128F428D064
# word =Y
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'en', 4, 1)
# track_id =TRDTUOK128F428D064
# word =EN
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'un', 1, 1)
# track_id =TRDTUOK128F428D064
# word =UN
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'el', 12, 1)
# track_id =TRDTUOK128F428D064
# word =EL
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'tu', 4, 1)
# track_id =TRDTUOK128F428D064
# word =TU
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'se', 5, 1)
# track_id =TRDTUOK128F428D064
# word =SE
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'mi', 12, 1)
# track_id =TRDTUOK128F428D064
# word =MI
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'es', 12, 1)
# track_id =TRDTUOK128F428D064
# word =ES
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'ya', 1, 1)
# track_id =TRDTUOK128F428D064
# word =YA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'yo', 6, 1)
# track_id =TRDTUOK128F428D064
# word =YO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'le', 3, 1)
# track_id =TRDTUOK128F428D064
# word =LE
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'si', 2, 1)
# track_id =TRDTUOK128F428D064
# word =SI
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'por', 9, 1)
# track_id =TRDTUOK128F428D064
# word =POR
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'lo', 8, 1)
# track_id =TRDTUOK128F428D064
# word =LO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'da', 4, 1)
# track_id =TRDTUOK128F428D064
# word =DA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'con', 12, 1)
# track_id =TRDTUOK128F428D064
# word =CON
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'na', 1, 1)
# track_id =TRDTUOK128F428D064
# word =NA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'sin', 9, 1)
# track_id =TRDTUOK128F428D064
# word =SIN
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'una', 4, 1)
# track_id =TRDTUOK128F428D064
# word =UNA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'como', 5, 1)
# track_id =TRDTUOK128F428D064
# word =COMO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'los', 6, 1)
# track_id =TRDTUOK128F428D064
# word =LOS
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'las', 2, 1)
# track_id =TRDTUOK128F428D064
# word =LAS
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'del', 2, 1)
# track_id =TRDTUOK128F428D064
# word =DEL
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'ja', 1, 1)
# track_id =TRDTUOK128F428D064
# word =JA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'mas', 1, 1)
# track_id =TRDTUOK128F428D064
# word =MAS
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'su', 5, 1)
# track_id =TRDTUOK128F428D064
# word =SU
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'hay', 5, 1)
# track_id =TRDTUOK128F428D064
# word =HAY
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'cuando', 1, 1)
# track_id =TRDTUOK128F428D064
# word =CUANDO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'nos', 1, 1)
# track_id =TRDTUOK128F428D064
# word =NOS
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'porqu', 8, 1)
# track_id =TRDTUOK128F428D064
# word =PORQU
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'vez', 1, 1)
# track_id =TRDTUOK128F428D064
# word =VEZ
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'siempr', 1, 1)
# track_id =TRDTUOK128F428D064
# word =SIEMPR
#
# ROW = ('TRDTUOK128F428D064', 1670852, '&', 2, 1)
# track_id =TRDTUOK128F428D064
# word =&
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'daddi', 2, 1)
# track_id =TRDTUOK128F428D064
# word =DADDI
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'pa', 3, 1)
# track_id =TRDTUOK128F428D064
# word =PA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'tien', 3, 1)
# track_id =TRDTUOK128F428D064
# word =TIEN
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'don', 11, 1)
# track_id =TRDTUOK128F428D064
# word =DON
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'sabe', 9, 1)
# track_id =TRDTUOK128F428D064
# word =SABE
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'nadi', 1, 1)
# track_id =TRDTUOK128F428D064
# word =NADI
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'ella', 9, 1)
# track_id =TRDTUOK128F428D064
# word =ELLA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'ojo', 1, 1)
# track_id =TRDTUOK128F428D064
# word =OJO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'mia', 4, 1)
# track_id =TRDTUOK128F428D064
# word =MIA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'verdad', 1, 1)
# track_id =TRDTUOK128F428D064
# word =VERDAD
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'saber', 1, 1)
# track_id =TRDTUOK128F428D064
# word =SABER
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'hora', 1, 1)
# track_id =TRDTUOK128F428D064
# word =HORA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'junto', 1, 1)
# track_id =TRDTUOK128F428D064
# word =JUNTO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'ven', 1, 1)
# track_id =TRDTUOK128F428D064
# word =VEN
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'miedo', 8, 1)
# track_id =TRDTUOK128F428D064
# word =MIEDO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'esto', 1, 1)
# track_id =TRDTUOK128F428D064
# word =ESTO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'conmigo', 8, 1)
# track_id =TRDTUOK128F428D064
# word =CONMIGO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'sola', 1, 1)
# track_id =TRDTUOK128F428D064
# word =SOLA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'viento', 1, 1)
# track_id =TRDTUOK128F428D064
# word =VIENTO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'loco', 3, 1)
# track_id =TRDTUOK128F428D064
# word =LOCO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'decir', 1, 1)
# track_id =TRDTUOK128F428D064
# word =DECIR
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'buscando', 1, 1)
# track_id =TRDTUOK128F428D064
# word =BUSCANDO
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'anda', 1, 1)
# track_id =TRDTUOK128F428D064
# word =ANDA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'dale', 1, 1)
# track_id =TRDTUOK128F428D064
# word =DALE
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'tas', 1, 1)
# track_id =TRDTUOK128F428D064
# word =TAS
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'pein', 1, 1)
# track_id =TRDTUOK128F428D064
# word =PEIN
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'loca', 9, 1)
# track_id =TRDTUOK128F428D064
# word =LOCA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'verd', 1, 1)
# track_id =TRDTUOK128F428D064
# word =VERD
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'problema', 1, 1)
# track_id =TRDTUOK128F428D064
# word =PROBLEMA
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'correr', 1, 1)
# track_id =TRDTUOK128F428D064
# word =CORRER
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'pal', 1, 1)
# track_id =TRDTUOK128F428D064
# word =PAL
#
# ROW = ('TRDTUOK128F428D064', 1670852, 'cambia', 1, 1)
# track_id =TRDTUOK128F428D064
# word =CAMBIA
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'i', 27, 0)
# track_id =TREAMHV128F92DC7EA
# word =I
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'the', 7, 0)
# track_id =TREAMHV128F92DC7EA
# word =THE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'you', 5, 0)
# track_id =TREAMHV128F92DC7EA
# word =YOU
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'to', 10, 0)
# track_id =TREAMHV128F92DC7EA
# word =TO
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'and', 11, 0)
# track_id =TREAMHV128F92DC7EA
# word =AND
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'a', 7, 0)
# track_id =TREAMHV128F92DC7EA
# word =A
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'me', 4, 0)
# track_id =TREAMHV128F92DC7EA
# word =ME
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'it', 7, 0)
# track_id =TREAMHV128F92DC7EA
# word =IT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'not', 7, 0)
# track_id =TREAMHV128F92DC7EA
# word =NOT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'in', 3, 0)
# track_id =TREAMHV128F92DC7EA
# word =IN
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'my', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =MY
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'is', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =IS
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'of', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =OF
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'your', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =YOUR
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'that', 4, 0)
# track_id =TREAMHV128F92DC7EA
# word =THAT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'on', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =ON
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'we', 8, 0)
# track_id =TREAMHV128F92DC7EA
# word =WE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'am', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =AM
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'will', 3, 0)
# track_id =TREAMHV128F92DC7EA
# word =WILL
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'for', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =FOR
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'be', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =BE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'have', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =HAVE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'love', 3, 0)
# track_id =TREAMHV128F92DC7EA
# word =LOVE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'so', 6, 0)
# track_id =TREAMHV128F92DC7EA
# word =SO
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'know', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =KNOW
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'this', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =THIS
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'but', 5, 0)
# track_id =TREAMHV128F92DC7EA
# word =BUT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'just', 6, 0)
# track_id =TREAMHV128F92DC7EA
# word =JUST
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'when', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =WHEN
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'now', 3, 0)
# track_id =TREAMHV128F92DC7EA
# word =NOW
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'time', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =TIME
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'can', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =CAN
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'come', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =COME
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'there', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =THERE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'go', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =GO
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'up', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =UP
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'one', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =ONE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'they', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =THEY
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'out', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =OUT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'get', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =GET
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'she', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =SHE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'was', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =WAS
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'see', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =SEE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'never', 3, 0)
# track_id =TREAMHV128F92DC7EA
# word =NEVER
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'from', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =FROM
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'feel', 4, 0)
# track_id =TREAMHV128F92DC7EA
# word =FEEL
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'let', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =LET
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'make', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =MAKE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'take', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =TAKE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'would', 4, 0)
# track_id =TREAMHV128F92DC7EA
# word =WOULD
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'as', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =AS
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'ca', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =CA
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'day', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =DAY
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'at', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =AT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'away', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =AWAY
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'life', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =LIFE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'back', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =BACK
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'by', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =BY
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'her', 9, 0)
# track_id =TREAMHV128F92DC7EA
# word =HER
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'how', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =HOW
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'could', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =COULD
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'need', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =NEED
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'our', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =OUR
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'look', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =LOOK
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'where', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =WHERE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'eye', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =EYE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'thing', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =THING
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'die', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =DIE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'tell', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =TELL
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'think', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =THINK
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'who', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =WHO
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'through', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =THROUGH
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'too', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =TOO
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'onli', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =ONLI
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'tri', 3, 0)
# track_id =TREAMHV128F92DC7EA
# word =TRI
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'dream', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =DREAM
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'still', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =STILL
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'us', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =US
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'girl', 3, 0)
# track_id =TREAMHV128F92DC7EA
# word =GIRL
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'around', 3, 0)
# track_id =TREAMHV128F92DC7EA
# word =AROUND
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'good', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =GOOD
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'about', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =ABOUT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'over', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =OVER
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'said', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =SAID
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'everi', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =EVERI
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'were', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =WERE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'did', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =DID
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'into', 3, 0)
# track_id =TREAMHV128F92DC7EA
# word =INTO
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'wait', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =WAIT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'home', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =HOME
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'had', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =HAD
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'cri', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =CRI
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'alon', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =ALON
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'insid', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =INSID
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'place', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =PLACE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'much', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =MUCH
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'stand', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =STAND
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'him', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =HIM
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'thought', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =THOUGHT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'made', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =MADE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'should', 3, 0)
# track_id =TREAMHV128F92DC7EA
# word =SHOULD
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'realli', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =REALLI
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'without', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =WITHOUT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'fire', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =FIRE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'dead', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =DEAD
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'myself', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =MYSELF
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'sleep', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =SLEEP
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'those', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =THOSE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'while', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =WHILE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'kill', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =KILL
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'fli', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =FLI
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'rock', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =ROCK
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'blood', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =BLOOD
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'found', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =FOUND
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'onc', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =ONC
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'help', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =HELP
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'becaus', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =BECAUS
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'street', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =STREET
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'hide', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =HIDE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'save', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =SAVE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'bodi', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =BODI
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'until', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =UNTIL
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'hurt', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =HURT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'knew', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =KNEW
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'saw', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =SAW
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'fill', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =FILL
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'though', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =THOUGH
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'step', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =STEP
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'abov', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =ABOV
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'moment', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =MOMENT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'guess', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =GUESS
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'sad', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =SAD
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'lead', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =LEAD
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'cut', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =CUT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'hang', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =HANG
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'felt', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =FELT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'knee', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =KNEE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'which', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =WHICH
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'both', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =BOTH
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'warm', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =WARM
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'quit', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =QUIT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'space', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =SPACE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'act', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =ACT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'doubt', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =DOUBT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'dress', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =DRESS
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'bless', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =BLESS
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'slowli', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =SLOWLI
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'almost', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =ALMOST
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'glad', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =GLAD
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'stick', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =STICK
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'sink', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =SINK
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'choic', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =CHOIC
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'glow', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =GLOW
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'person', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =PERSON
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'desert', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =DESERT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'betray', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =BETRAY
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'pill', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =PILL
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'dad', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =DAD
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'freez', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =FREEZ
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'savior', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =SAVIOR
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'truli', 2, 0)
# track_id =TREAMHV128F92DC7EA
# word =TRULI
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'drove', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =DROVE
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'weed', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =WEED
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'parent', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =PARENT
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'veil', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =VEIL
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'sharp', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =SHARP
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'deed', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =DEED
#
# ROW = ('TREAMHV128F92DC7EA', 2493526, 'slap', 1, 0)
# track_id =TREAMHV128F92DC7EA
# word =SLAP
#
# ROW = ('TRGALDW128F92D0CDE', 1538430, 'i', 1, 0)
# track_id =TRGALDW128F92D0CDE
# word =I
#
# ROW = ('TRGALDW128F92D0CDE', 1538430, 'the', 5, 0)
# track_id =TRGALDW128F92D0CDE
# word =THE
#
# ROW = ('TRGALDW128F92D0CDE', 1538430, 'you', 4, 0)
# track_id =TRGALDW128F92D0CDE
# word =YOU
#
# ROW = ('TRGALDW128F92D0CDE', 1538430, 'and', 2, 0)
# track_id =TRGALDW128F92D0CDE
# word =AND
#
# ROW = ('TRGALDW128F92D0CDE', 1538430, 'me', 2, 0)
# track_id =TRGALDW128F92D0CDE
# word =ME
#
# ROW = ('TRGALDW128F92D0CDE', 1538430, 'not', 4, 0)
# track_id =TRGALDW128F92D0CDE
# word =NOT
#
# ...
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'in', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =IN
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'is', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =IS
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'of', 6, 0)
# track_id =TRLAJXB128F9337DA1
# word =OF
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'your', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =YOUR
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'are', 9, 0)
# track_id =TRLAJXB128F9337DA1
# word =ARE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'we', 12, 0)
# track_id =TRLAJXB128F9337DA1
# word =WE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'am', 10, 0)
# track_id =TRLAJXB128F9337DA1
# word =AM
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'for', 3, 0)
# track_id =TRLAJXB128F9337DA1
# word =FOR
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'be', 3, 0)
# track_id =TRLAJXB128F9337DA1
# word =BE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'have', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =HAVE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'this', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =THIS
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'but', 2, 0)
# track_id =TRLAJXB128F9337DA1
# word =BUT
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'time', 4, 0)
# track_id =TRLAJXB128F9337DA1
# word =TIME
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'go', 8, 0)
# track_id =TRLAJXB128F9337DA1
# word =GO
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'up', 22, 0)
# track_id =TRLAJXB128F9337DA1
# word =UP
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'they', 6, 0)
# track_id =TRLAJXB128F9337DA1
# word =THEY
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'out', 2, 0)
# track_id =TRLAJXB128F9337DA1
# word =OUT
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'down', 9, 0)
# track_id =TRLAJXB128F9337DA1
# word =DOWN
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'feel', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =FEEL
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'let', 6, 0)
# track_id =TRLAJXB128F9337DA1
# word =LET
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'way', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =WAY
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'day', 2, 0)
# track_id =TRLAJXB128F9337DA1
# word =DAY
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'life', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =LIFE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'back', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =BACK
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'our', 9, 0)
# track_id =TRLAJXB128F9337DA1
# word =OUR
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'where', 2, 0)
# track_id =TRLAJXB128F9337DA1
# word =WHERE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'caus', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =CAUS
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'gonna', 10, 0)
# track_id =TRLAJXB128F9337DA1
# word =GONNA
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'live', 2, 0)
# track_id =TRLAJXB128F9337DA1
# word =LIVE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'give', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =GIVE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'tri', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =TRI
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'whi', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =WHI
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'mind', 2, 0)
# track_id =TRLAJXB128F9337DA1
# word =MIND
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'us', 7, 0)
# track_id =TRLAJXB128F9337DA1
# word =US
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'wanna', 2, 0)
# track_id =TRLAJXB128F9337DA1
# word =WANNA
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'turn', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =TURN
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'into', 5, 0)
# track_id =TRLAJXB128F9337DA1
# word =INTO
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'lie', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =LIE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'cri', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =CRI
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'someth', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =SOMETH
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'stand', 2, 0)
# track_id =TRLAJXB128F9337DA1
# word =STAND
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'break', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =BREAK
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'pain', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =PAIN
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'tear', 7, 0)
# track_id =TRLAJXB128F9337DA1
# word =TEAR
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'doe', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =DOE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'line', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =LINE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'death', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =DEATH
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'set', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =SET
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'broken', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =BROKEN
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'rise', 16, 0)
# track_id =TRLAJXB128F9337DA1
# word =RISE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'wake', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =WAKE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'white', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =WHITE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'king', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =KING
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'til', 8, 0)
# track_id =TRLAJXB128F9337DA1
# word =TIL
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'knee', 8, 0)
# track_id =TRLAJXB128F9337DA1
# word =KNEE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'flame', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =FLAME
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'wave', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =WAVE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'bit', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =BIT
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'build', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =BUILD
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'drown', 6, 0)
# track_id =TRLAJXB128F9337DA1
# word =DROWN
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'fate', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =FATE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'suffer', 8, 0)
# track_id =TRLAJXB128F9337DA1
# word =SUFFER
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'age', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =AGE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'cast', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =CAST
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'mark', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =MARK
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'bottl', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =BOTTL
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'attent', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =ATTENT
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'wise', 6, 0)
# track_id =TRLAJXB128F9337DA1
# word =WISE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'numb', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =NUMB
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'wipe', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =WIPE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'limit', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =LIMIT
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'tower', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =TOWER
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'modern', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =MODERN
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'infect', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =INFECT
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'mention', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =MENTION
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'stack', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =STACK
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'alien', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =ALIEN
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'factori', 7, 0)
# track_id =TRLAJXB128F9337DA1
# word =FACTORI
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'redempt', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =REDEMPT
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'explos', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =EXPLOS
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'wage', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =WAGE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'rate', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =RATE
#
# ROW = ('TRLAJXB128F9337DA1', 1008376, 'revers', 1, 0)
# track_id =TRLAJXB128F9337DA1
# word =REVERS
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'i', 10, 0)
# track_id =TRRSXUL128F1462CA7
# word =I
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'the', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =THE
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'you', 11, 0)
# track_id =TRRSXUL128F1462CA7
# word =YOU
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'to', 5, 0)
# track_id =TRRSXUL128F1462CA7
# word =TO
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'a', 5, 0)
# track_id =TRRSXUL128F1462CA7
# word =A
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'me', 5, 0)
# track_id =TRRSXUL128F1462CA7
# word =ME
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'it', 3, 0)
# track_id =TRRSXUL128F1462CA7
# word =IT
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'not', 3, 0)
# track_id =TRRSXUL128F1462CA7
# word =NOT
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'my', 5, 0)
# track_id =TRRSXUL128F1462CA7
# word =MY
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'is', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =IS
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'your', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =YOUR
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'that', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =THAT
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'do', 5, 0)
# track_id =TRRSXUL128F1462CA7
# word =DO
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'on', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =ON
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'am', 4, 0)
# track_id =TRRSXUL128F1462CA7
# word =AM
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'all', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =ALL
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'be', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =BE
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'have', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =HAVE
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'know', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =KNOW
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'this', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =THIS
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'what', 4, 0)
# track_id =TRRSXUL128F1462CA7
# word =WHAT
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'just', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =JUST
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'like', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =LIKE
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'now', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =NOW
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'can', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =CAN
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'up', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =UP
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'get', 3, 0)
# track_id =TRRSXUL128F1462CA7
# word =GET
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'was', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =WAS
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'if', 3, 0)
# track_id =TRRSXUL128F1462CA7
# word =IF
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'got', 3, 0)
# track_id =TRRSXUL128F1462CA7
# word =GOT
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'from', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =FROM
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'he', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =HE
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'want', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =WANT
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'make', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =MAKE
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'would', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =WOULD
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'day', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =DAY
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'how', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =HOW
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'caus', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =CAUS
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'gonna', 4, 0)
# track_id =TRRSXUL128F1462CA7
# word =GONNA
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'been', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =BEEN
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'think', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =THINK
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'keep', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =KEEP
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'well', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =WELL
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'mind', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =MIND
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'an', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =AN
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'good', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =GOOD
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'about', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =ABOUT
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'turn', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =TURN
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'said', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =SAID
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'call', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =CALL
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'did', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =DID
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'leav', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =LEAV
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'face', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =FACE
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'end', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =END
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'hey', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =HEY
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'friend', 5, 0)
# track_id =TRRSXUL128F1462CA7
# word =FRIEND
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'old', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =OLD
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'boy', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =BOY
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'blue', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =BLUE
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'other', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =OTHER
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'high', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =HIGH
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'real', 3, 0)
# track_id =TRRSXUL128F1462CA7
# word =REAL
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'behind', 4, 0)
# track_id =TRRSXUL128F1462CA7
# word =BEHIND
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'ask', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =ASK
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'till', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =TILL
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'sure', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =SURE
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'ai', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =AI
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'saw', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =SAW
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'nobodi', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =NOBODI
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'young', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =YOUNG
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'somebodi', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =SOMEBODI
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'veri', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =VERI
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'pay', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =PAY
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'yet', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =YET
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'trust', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =TRUST
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'mama', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =MAMA
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'school', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =SCHOOL
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'tryin', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =TRYIN
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'cmon', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =CMON
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'talkin', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =TALKIN
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'woah', 7, 0)
# track_id =TRRSXUL128F1462CA7
# word =WOAH
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'judg', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =JUDG
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'toy', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =TOY
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'bread', 2, 0)
# track_id =TRRSXUL128F1462CA7
# word =BREAD
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'tip', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =TIP
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'friendship', 1, 0)
# track_id =TRRSXUL128F1462CA7
# word =FRIENDSHIP
#
# ROW = ('TRRSXUL128F1462CA7', 1069571, 'yah', 9, 0)
# track_id =TRRSXUL128F1462CA7
# word =YAH
#
# ROW = ('TRWJKJN128F930C65C', 1027542, 'i', 2, 0)
# track_id =TRWJKJN128F930C65C
# word =I
#
# ROW = ('TRWJKJN128F930C65C', 1027542, 'the', 14, 0)
# track_id =TRWJKJN128F930C65C
# word =THE
#
# ROW = ('TRWJKJN128F930C65C', 1027542, 'me', 3, 0)

# %% [markdown]
# ### TESTING : ONE - TWO...

# %%
import pandas as pd
import numpy as np
import pickle

# %%
lyrics_path = '/home/eolus/Documents/MA755_data/LyricsData'
pickle_path = '/home/eolus/Documents/MA755_data/myPickles'

# Retrieve `lyrics_df`
lyrics_df = pd.read_pickle(pickle_path+'/full_df_lyrics.pkl')

# Deactivate Pandas warning on chained assignment
pd.options.mode.chained_assignment = None

# Create filtered version of the lyrics DataFrame for reporting purpose
lyrics_df_filtered = lyrics_df[(lyrics_df.COUNT_OTHER > 0)]
lyrics_df_filtered['COUNT_MOOD_RATED'] = ''
lyrics_df_filtered['%_MOOD_RATED'] = ''

# Create `count_mood` and `count_no_mood` for reporting purpose.
sum_columns = lyrics_df.columns[:(len(lyrics_df.columns)-2)]

for index, row in lyrics_df_filtered.iterrows():

    count_mood = sum([lyrics_df_filtered.get_value(index, col) for col in sum_columns])
    count_no_mood = lyrics_df_filtered.get_value(index, 'COUNT_OTHER')

    lyrics_df_filtered['COUNT_MOOD_RATED'][index] = count_mood
    lyrics_df_filtered['%_MOOD_RATED'][index] =
    '{percent}%'.format(percent = round((count_mood / (count_mood + count_no_mood) * 100),2))

lyrics_df_reporting = lyrics_df_filtered[['COUNT_OTHER', 'COUNT_MOOD_RATED', '%_MOOD_RATED']]
lyrics_df_reporting.columns = ['NOT_MOOD_RATED', 'MOOD_RATED', '%_MOOD_RATED']

print(lyrics_df_reporting)
