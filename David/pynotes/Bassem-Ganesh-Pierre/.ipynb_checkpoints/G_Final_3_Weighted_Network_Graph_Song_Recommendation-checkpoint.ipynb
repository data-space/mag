# %% [markdown]
# # About the notebook
#
# In this notebook, the dataframes representing the relationships between different combinations of fields from the notebook __`G_Final_2_Graph_Relationship_Data.ipynb`__ are used to recommend songs based on network graph theory and an appropriate shortest-path algorithm. The `networkx` library will be used for the graph analysis and `pyplot` module of `matplotlib` library will be used for the visualization.

# %% [markdown]
# ### Import the libraries and set random seed

# %%
# %matplotlib inline
import os
import re
import itertools as it
import pandas as pd
import numpy as np
import operator 
import functools
import pickle as pk
import networkx as nx
import matplotlib as mplot
import matplotlib.colors as colors
import matplotlib.pyplot as pyplot
import random

# %%
# Set the seed for the random number generator - to be consistent in different notebooks
a = random.randint(0,9)
random.seed(4)
a
# Out:
# 3

# %% [markdown]
# ### Set the desired plot style for `pyplot`

# %%
# Change the styles of the pyplot plots
print(pyplot.style.available) # shows available styles
pyplot.style.use('classic')
pyplot.rcParams['figure.figsize'] = (10.0, 8.0)
# Out:
# ['seaborn-muted', 'seaborn-paper', 'bmh', 'seaborn-bright', 'seaborn-whitegrid', 'seaborn-dark-palette', 'seaborn-talk', 'seaborn-deep', 'seaborn-poster', 'grayscale', 'seaborn-notebook', 'seaborn-ticks', 'seaborn-colorblind', 'ggplot', 'seaborn-darkgrid', 'seaborn-dark', 'classic', 'dark_background', 'seaborn-pastel', 'seaborn-white', 'fivethirtyeight']

# %% [markdown]
# ## Weighted Network Graph 1: represent all node types
#
# In the first network graph, all the three node types `track`, `artist_id` and `artist_terms` are represented using different colors. Also, the weights between an `artist_id` node and `artist_terms` node are computed from the group aggregates. The `networkx` and the `matplotlib` libraries will be used in conjunction with the `pandas` library for this analysis.
#
# ### Read the pickled data frames that hold the relationships and nodes

# %%
path = "C:/Users/ganes_000/Documents/MSBA/Spring 2016/MA 755/Pickle Files"
# Get the track-artist relationship dataframe
df_ta = pd.read_pickle(path+"/MSS_METADATA_SUBSET_500_TRACK_ARTIST.pkl")

# Get the artist-artist_terms relationship dataframe
df_aat = pd.read_pickle(path+"/MSS_METADATA_SUBSET_500_ARTIST_ARTIST_TERMS.pkl")

# Get the artist-artist relationship dataframe
df_aa = pd.read_pickle(path+"/MSS_METADATA_SUBSET_500_ARTIST_ARTIST.pkl")

# %%
print('TRACK-ARTIST Relationship \n ======================== \n',len(df_ta),'rows \n ----------------------\n',
      df_ta.columns)
print('\n ######################################## \n')
print('ARTIST-ARTIST TERMS Relationship \n ======================== \n',len(df_aat),'rows \n ----------------------\n',
      df_aat.columns)
print('\n ######################################## \n')
print('ARTIST-ARTIST Relationship \n ======================== \n', len(df_aa), 'rows \n ----------------------\n',
      df_aa.columns)
# Out:
# TRACK-ARTIST Relationship
#  ========================
#  500 rows
#  ----------------------
#  Index(['track', 'artist_id', 'title', 'artist_name', 'artist_familiarity',
#        'artist_hotttnesss', 'song_hotttnesss'],
#       dtype='object')
#
#  ########################################
#
# ARTIST-ARTIST TERMS Relationship
#  ========================
#  12575 rows
#  ----------------------
#  Index(['artist_id', 'artist_terms', 'artist_name', 'artist_familiarity',
#        'artist_hotttnesss', 'at_wt', 'at_freq'],
#       dtype='object')
#
#  ########################################
#
# ARTIST-ARTIST Relationship
#  ========================
#  198774 rows
#  ----------------------
#  Index(['artist_id_l', 'artist_id_r', 'artist_name_l', 'artist_name_r',
#        'wt_l_sum', 'wt_r_sum', 'fam_l', 'fam_r', 'hot_l', 'hot_r'],
#       dtype='object')

# %% [markdown]
# ### Create the Nodes - with attributes
#
# An empty undirected graph is created and then the nodes and edges are added. Refer to the comments for greater details.

# %%
# Create an empty graph
G_1 = nx.Graph()

# Add nodes
G_1.add_nodes_from(df_ta['track'], type = 'track', color = 'red', hot = 0, name = 'NaN')
G_1.add_nodes_from(df_ta['artist_id'], type = 'artist', color = 'deepskyblue', hot = 0, name = 'NaN')
G_1.add_nodes_from(df_aat['artist_terms'], type = 'artist_terms', color = 'greenyellow', name = 'NaN')

print(type(G_1.nodes()))
print('No. of nodes:', G_1.number_of_nodes())
# Out:
# <class 'list'>
# No. of nodes: 2530

# %%
# Get the number of nodes per node type
node_type_dict = {}

for node,data in G_1.nodes_iter(data = True):
    if data['type'] not in node_type_dict:
        node_type_dict[data['type']] = 1
    else:
        node_type_dict[data['type']] +=1
             
print(node_type_dict)
# Out:
# {'artist_terms': 1561, 'track': 500, 'artist': 469}

# %% [markdown]
# So, there are __500__ `track` nodes, __469__ `artist_id` nodes and __1561__ `artist_terms` nodes to total up to __2530__ nodes.

# %%
print(type(G_1.nodes())) # list of dictionaries
print(type(G_1.node['new wave']))
print(G_1.node['new wave'])
print(G_1.node['new wave']['type'])
# Out:
# <class 'list'>
# <class 'dict'>
# {'name': 'NaN', 'type': 'artist_terms', 'color': 'greenyellow'}
# artist_terms

# %% [markdown]
# #### Add node attributes
#
# The different attributes are added for each node type as described below.

# %%
# Include song and artist hotttnesss as attributes for each node
for node,data in G_1.nodes_iter(data = True):
    if data['type'] == 'track':
        data['hot'] = df_ta[df_ta['track'] == node]['song_hotttnesss'].values[0] # if [0] is missed, it will be an array (cell)
        data['name'] = df_ta[df_ta['track'] == node]['title'].values[0] 
    else:
        if data['type'] == 'artist' :
            data['hot'] = df_ta[df_ta['artist_id'] == node]['artist_hotttnesss'].values[0]
            data['name'] = df_ta[df_ta['artist_id'] == node]['artist_name'].values[0]
        else:
            data['name'] = df_aat[df_aat['artist_terms'] == node]['artist_terms'].values[0]
    
G_1.nodes(data = True)
# Out:
# [('ARTAIYM11F50C4E159',
#   {'color': 'deepskyblue',
#    'hot': 0.32454508944470478,
#    'name': 'The Capitol Years',
#    'type': 'artist'}),
#  ('TRAXYGX128F93158FC',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'That Old Gang Of Mine',
#    'type': 'track'}),
#  ('brazil',
#   {'color': 'greenyellow', 'name': 'brazil', 'type': 'artist_terms'}),
#  ('TRBDMBY12903CE84AF',
#   {'color': 'red',
#    'hot': 0.26801031558477889,
#    'name': 'Fly Again (The Scumfrog Radio Edit)',
#    'type': 'track'}),
#  ('TRAAENP128F147BF32',
#   {'color': 'red',
#    'hot': 0.22655531395553141,
#    'name': 'Movement 4 [from Kiss] (Album Version)',
#    'type': 'track'}),
#  ('ska', {'color': 'greenyellow', 'name': 'ska', 'type': 'artist_terms'}),
#  ('black metal from germany',
#   {'color': 'greenyellow',
#    'name': 'black metal from germany',
#    'type': 'artist_terms'}),
#  ('dark metal',
#   {'color': 'greenyellow', 'name': 'dark metal', 'type': 'artist_terms'}),
#  ('electro ambient',
#   {'color': 'greenyellow', 'name': 'electro ambient', 'type': 'artist_terms'}),
#  ('ARAMIDF1187FB3D8D4',
#   {'color': 'deepskyblue',
#    'hot': 0.3615879415321665,
#    'name': 'Alejandro Lerner',
#    'type': 'artist'}),
#  ('TRAQHMP128F932D69C',
#   {'color': 'red',
#    'hot': 0.0,
#    'name': 'Everything Has Changed',
#    'type': 'track'}),
#  ('hk-pop',
#   {'color': 'greenyellow', 'name': 'hk-pop', 'type': 'artist_terms'}),
#  ('drummer',
#   {'color': 'greenyellow', 'name': 'drummer', 'type': 'artist_terms'}),
#  ('alternative folk',
#   {'color': 'greenyellow',
#    'name': 'alternative folk',
#    'type': 'artist_terms'}),
#  ('calypso',
#   {'color': 'greenyellow', 'name': 'calypso', 'type': 'artist_terms'}),
#  ('trip rock',
#   {'color': 'greenyellow', 'name': 'trip rock', 'type': 'artist_terms'}),
#  ('TRASOQY128F92FEC9F',
#   {'color': 'red', 'hot': nan, 'name': 'En La Soledad', 'type': 'track'}),
#  ('TRBGULR128F145DA35',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Dale Darrell Waltrip Richard Petty Rusty Awesome Bill Irvin Gordon Earnhardt Smith...Johnson_ Jr. (Live)',
#    'type': 'track'}),
#  ('latino',
#   {'color': 'greenyellow', 'name': 'latino', 'type': 'artist_terms'}),
#  ('swamp pop',
#   {'color': 'greenyellow', 'name': 'swamp pop', 'type': 'artist_terms'}),
#  ('bongo', {'color': 'greenyellow', 'name': 'bongo', 'type': 'artist_terms'}),
#  ('ethno pop',
#   {'color': 'greenyellow', 'name': 'ethno pop', 'type': 'artist_terms'}),
#  ('mestizaje',
#   {'color': 'greenyellow', 'name': 'mestizaje', 'type': 'artist_terms'}),
#  ('TRBBVPM12903CDB094',
#   {'color': 'red', 'hot': nan, 'name': 'Kiss the Sky', 'type': 'track'}),
#  ('tejano',
#   {'color': 'greenyellow', 'name': 'tejano', 'type': 'artist_terms'}),
#  ('TRAPYML128F423DF98',
#   {'color': 'red',
#    'hot': 0.68408877539809787,
#    'name': 'Ability To Create A War',
#    'type': 'track'}),
#  ('old school thrash metal',
#   {'color': 'greenyellow',
#    'name': 'old school thrash metal',
#    'type': 'artist_terms'}),
#  ('anthemic',
#   {'color': 'greenyellow', 'name': 'anthemic', 'type': 'artist_terms'}),
#  ('bagpipe',
#   {'color': 'greenyellow', 'name': 'bagpipe', 'type': 'artist_terms'}),
#  ('cinematic',
#   {'color': 'greenyellow', 'name': 'cinematic', 'type': 'artist_terms'}),
#  ('TRAGWPR128F426BDC3',
#   {'color': 'red',
#    'hot': 0.0,
#    'name': 'The Saga Of Rita Joe',
#    'type': 'track'}),
#  ('guitar',
#   {'color': 'greenyellow', 'name': 'guitar', 'type': 'artist_terms'}),
#  ('peaceful',
#   {'color': 'greenyellow', 'name': 'peaceful', 'type': 'artist_terms'}),
#  ('regional mexican',
#   {'color': 'greenyellow',
#    'name': 'regional mexican',
#    'type': 'artist_terms'}),
#  ('TRALLVR12903C9E514',
#   {'color': 'red',
#    'hot': 0.0,
#    'name': "Don't Mess With Cupid (1972 demo)",
#    'type': 'track'}),
#  ('rastafari',
#   {'color': 'greenyellow', 'name': 'rastafari', 'type': 'artist_terms'}),
#  ('psychedelia',
#   {'color': 'greenyellow', 'name': 'psychedelia', 'type': 'artist_terms'}),
#  ('traditional pop',
#   {'color': 'greenyellow', 'name': 'traditional pop', 'type': 'artist_terms'}),
#  ('nordic folk',
#   {'color': 'greenyellow', 'name': 'nordic folk', 'type': 'artist_terms'}),
#  ('mellotron',
#   {'color': 'greenyellow', 'name': 'mellotron', 'type': 'artist_terms'}),
#  ('TRBEXHU128F93390C5',
#   {'color': 'red',
#    'hot': 0.33470654906922059,
#    'name': 'Monologue With the Sky',
#    'type': 'track'}),
#  ('free', {'color': 'greenyellow', 'name': 'free', 'type': 'artist_terms'}),
#  ('TRAKAFU12903CB4234',
#   {'color': 'red',
#    'hot': 0.52165925804846114,
#    'name': 'We Do It For the Money_ OBVIOUSLY! (Demo)',
#    'type': 'track'}),
#  ('holiday',
#   {'color': 'greenyellow', 'name': 'holiday', 'type': 'artist_terms'}),
#  ('ARI2JSK1187FB496EF',
#   {'color': 'deepskyblue',
#    'hot': 0.31853602993581781,
#    'name': 'Nick Ingman',
#    'type': 'artist'}),
#  ('shaman',
#   {'color': 'greenyellow', 'name': 'shaman', 'type': 'artist_terms'}),
#  ('mambo', {'color': 'greenyellow', 'name': 'mambo', 'type': 'artist_terms'}),
#  ('60s garage',
#   {'color': 'greenyellow', 'name': '60s garage', 'type': 'artist_terms'}),
#  ('country male',
#   {'color': 'greenyellow', 'name': 'country male', 'type': 'artist_terms'}),
#  ('TRBDBVP128F428EA51',
#   {'color': 'red',
#    'hot': 0.26156931157725732,
#    'name': 'Encouraged',
#    'type': 'track'}),
#  ('acoustic blues',
#   {'color': 'greenyellow', 'name': 'acoustic blues', 'type': 'artist_terms'}),
#  ('haunting',
#   {'color': 'greenyellow', 'name': 'haunting', 'type': 'artist_terms'}),
#  ('oriental metal',
#   {'color': 'greenyellow', 'name': 'oriental metal', 'type': 'artist_terms'}),
#  ('harmonica',
#   {'color': 'greenyellow', 'name': 'harmonica', 'type': 'artist_terms'}),
#  ('horn', {'color': 'greenyellow', 'name': 'horn', 'type': 'artist_terms'}),
#  ('technical death metal',
#   {'color': 'greenyellow',
#    'name': 'technical death metal',
#    'type': 'artist_terms'}),
#  ('power ballad',
#   {'color': 'greenyellow', 'name': 'power ballad', 'type': 'artist_terms'}),
#  ('TRAKYNP128F427FB32',
#   {'color': 'red', 'hot': nan, 'name': 'The Name Is...', 'type': 'track'}),
#  ('authentic',
#   {'color': 'greenyellow', 'name': 'authentic', 'type': 'artist_terms'}),
#  ('baila latina',
#   {'color': 'greenyellow', 'name': 'baila latina', 'type': 'artist_terms'}),
#  ('TRANNXH128F933A6B3',
#   {'color': 'red',
#    'hot': 0.3231121208952123,
#    'name': 'Aguas Claras De Olimpos',
#    'type': 'track'}),
#  ('jazz rock',
#   {'color': 'greenyellow', 'name': 'jazz rock', 'type': 'artist_terms'}),
#  ('TRAGJPA128F92F9665',
#   {'color': 'red',
#    'hot': 0.67443680390108729,
#    'name': 'FEZ-Being Born',
#    'type': 'track'}),
#  ('united states',
#   {'color': 'greenyellow', 'name': 'united states', 'type': 'artist_terms'}),
#  ('power pop',
#   {'color': 'greenyellow', 'name': 'power pop', 'type': 'artist_terms'}),
#  ('cartoon music',
#   {'color': 'greenyellow', 'name': 'cartoon music', 'type': 'artist_terms'}),
#  ('arkansas',
#   {'color': 'greenyellow', 'name': 'arkansas', 'type': 'artist_terms'}),
#  ('fast', {'color': 'greenyellow', 'name': 'fast', 'type': 'artist_terms'}),
#  ('TRBCNWM128F92D50EC',
#   {'color': 'red', 'hot': nan, 'name': 'U Not Like Me', 'type': 'track'}),
#  ('modern rock',
#   {'color': 'greenyellow', 'name': 'modern rock', 'type': 'artist_terms'}),
#  ('troll metal',
#   {'color': 'greenyellow', 'name': 'troll metal', 'type': 'artist_terms'}),
#  ('80s pop',
#   {'color': 'greenyellow', 'name': '80s pop', 'type': 'artist_terms'}),
#  ('relaxation',
#   {'color': 'greenyellow', 'name': 'relaxation', 'type': 'artist_terms'}),
#  ('chanson francaise',
#   {'color': 'greenyellow',
#    'name': 'chanson francaise',
#    'type': 'artist_terms'}),
#  ('doo-wop',
#   {'color': 'greenyellow', 'name': 'doo-wop', 'type': 'artist_terms'}),
#  ('ARRESZG1187B9A3FBF',
#   {'color': 'deepskyblue',
#    'hot': 0.11615613420763671,
#    'name': 'Les Hou-Lops',
#    'type': 'artist'}),
#  ('latin rock',
#   {'color': 'greenyellow', 'name': 'latin rock', 'type': 'artist_terms'}),
#  ('ARBH0MS1187FB36311',
#   {'color': 'deepskyblue',
#    'hot': 0.35303405577540575,
#    'name': 'Sir Neville Marriner',
#    'type': 'artist'}),
#  ('TRBHECY128F930A474',
#   {'color': 'red',
#    'hot': nan,
#    'name': "Freezin' From The Inside Out",
#    'type': 'track'}),
#  ('alternative urban',
#   {'color': 'greenyellow',
#    'name': 'alternative urban',
#    'type': 'artist_terms'}),
#  ('rasta', {'color': 'greenyellow', 'name': 'rasta', 'type': 'artist_terms'}),
#  ('jazz pianist',
#   {'color': 'greenyellow', 'name': 'jazz pianist', 'type': 'artist_terms'}),
#  ('TRBDFUU128F92EF5BC',
#   {'color': 'red',
#    'hot': 0.74644197927874023,
#    'name': 'Execution',
#    'type': 'track'}),
#  ('electro-jazz',
#   {'color': 'greenyellow', 'name': 'electro-jazz', 'type': 'artist_terms'}),
#  ('jungle music',
#   {'color': 'greenyellow', 'name': 'jungle music', 'type': 'artist_terms'}),
#  ('fir', {'color': 'greenyellow', 'name': 'fir', 'type': 'artist_terms'}),
#  ('catalonia',
#   {'color': 'greenyellow', 'name': 'catalonia', 'type': 'artist_terms'}),
#  ('lucerne',
#   {'color': 'greenyellow', 'name': 'lucerne', 'type': 'artist_terms'}),
#  ('irish trad folk',
#   {'color': 'greenyellow', 'name': 'irish trad folk', 'type': 'artist_terms'}),
#  ('60s', {'color': 'greenyellow', 'name': '60s', 'type': 'artist_terms'}),
#  ('belgium',
#   {'color': 'greenyellow', 'name': 'belgium', 'type': 'artist_terms'}),
#  ('old fashioned',
#   {'color': 'greenyellow', 'name': 'old fashioned', 'type': 'artist_terms'}),
#  ('epic', {'color': 'greenyellow', 'name': 'epic', 'type': 'artist_terms'}),
#  ('oriental',
#   {'color': 'greenyellow', 'name': 'oriental', 'type': 'artist_terms'}),
#  ('salsa colombiana',
#   {'color': 'greenyellow',
#    'name': 'salsa colombiana',
#    'type': 'artist_terms'}),
#  ('ARPCEWC11F4C83EEA7',
#   {'color': 'deepskyblue',
#    'hot': 0.3555029950198822,
#    'name': 'Eddie Palmieri',
#    'type': 'artist'}),
#  ('japan', {'color': 'greenyellow', 'name': 'japan', 'type': 'artist_terms'}),
#  ('alternative metal',
#   {'color': 'greenyellow',
#    'name': 'alternative metal',
#    'type': 'artist_terms'}),
#  ('AR84SHT1187FB4687A',
#   {'color': 'deepskyblue', 'hot': 0.0, 'name': 'Wade Ray', 'type': 'artist'}),
#  ('ARLCEUJ11F4C842D6A',
#   {'color': 'deepskyblue',
#    'hot': 0.30643862922766407,
#    'name': 'Screaming Jay Hawkins',
#    'type': 'artist'}),
#  ('TRAQMBA12903CD57EA',
#   {'color': 'red',
#    'hot': nan,
#    'name': "Breezin' Along With the Breeze",
#    'type': 'track'}),
#  ('suomi rock',
#   {'color': 'greenyellow', 'name': 'suomi rock', 'type': 'artist_terms'}),
#  ('banda', {'color': 'greenyellow', 'name': 'banda', 'type': 'artist_terms'}),
#  ('terrorcore',
#   {'color': 'greenyellow', 'name': 'terrorcore', 'type': 'artist_terms'}),
#  ('TRBHNVI128F92F0EC7',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'I Remember/Great Is Thy Faithfulness',
#    'type': 'track'}),
#  ('chicago blues',
#   {'color': 'greenyellow', 'name': 'chicago blues', 'type': 'artist_terms'}),
#  ('dance', {'color': 'greenyellow', 'name': 'dance', 'type': 'artist_terms'}),
#  ('77 style punk',
#   {'color': 'greenyellow', 'name': '77 style punk', 'type': 'artist_terms'}),
#  ('psychedelic chill',
#   {'color': 'greenyellow',
#    'name': 'psychedelic chill',
#    'type': 'artist_terms'}),
#  ('ARLYUP11187B98B92B',
#   {'color': 'deepskyblue',
#    'hot': 0.26556176518180369,
#    'name': "Corey / Shaquille O'Neal",
#    'type': 'artist'}),
#  ('ARGWFMR1187B98D0E7',
#   {'color': 'deepskyblue',
#    'hot': 0.34901349777131224,
#    'name': 'C\\xc3\\xb3mplices',
#    'type': 'artist'}),
#  ('dance-punk',
#   {'color': 'greenyellow', 'name': 'dance-punk', 'type': 'artist_terms'}),
#  ('ARKR75V1187FB3D4D5',
#   {'color': 'deepskyblue',
#    'hot': 0.76607616441978266,
#    'name': 'My Chemical Romance',
#    'type': 'artist'}),
#  ('electro',
#   {'color': 'greenyellow', 'name': 'electro', 'type': 'artist_terms'}),
#  ('ARMLEY51187FB5BF8F',
#   {'color': 'deepskyblue',
#    'hot': 0.41687176615175431,
#    'name': 'Havok',
#    'type': 'artist'}),
#  ('new orleans',
#   {'color': 'greenyellow', 'name': 'new orleans', 'type': 'artist_terms'}),
#  ('AR3Q3QT1187FB396E7',
#   {'color': 'deepskyblue',
#    'hot': 0.40173498558744702,
#    'name': 'Sanna Nielsen',
#    'type': 'artist'}),
#  ('mestizo',
#   {'color': 'greenyellow', 'name': 'mestizo', 'type': 'artist_terms'}),
#  ('TRAUGWE128F42670DB',
#   {'color': 'red',
#    'hot': 0.37253003936607959,
#    'name': 'What If I Forget The Champagne',
#    'type': 'track'}),
#  ('TRAIXEO128F424AD97',
#   {'color': 'red',
#    'hot': 0.21204540548371908,
#    'name': 'Communication (More Mix)',
#    'type': 'track'}),
#  ('AROSI8L1187B9ACD43',
#   {'color': 'deepskyblue',
#    'hot': 0.55775567477850985,
#    'name': 'Ice Cube',
#    'type': 'artist'}),
#  ('humppa',
#   {'color': 'greenyellow', 'name': 'humppa', 'type': 'artist_terms'}),
#  ('introspective',
#   {'color': 'greenyellow', 'name': 'introspective', 'type': 'artist_terms'}),
#  ('new rave',
#   {'color': 'greenyellow', 'name': 'new rave', 'type': 'artist_terms'}),
#  ('pop espanol',
#   {'color': 'greenyellow', 'name': 'pop espanol', 'type': 'artist_terms'}),
#  ('ARFFFFY122988EDE49',
#   {'color': 'deepskyblue',
#    'hot': 0.0,
#    'name': 'Carlos Embales - Cutumba',
#    'type': 'artist'}),
#  ('TRAUGRD128F425E997',
#   {'color': 'red',
#    'hot': 0.47872628848033488,
#    'name': 'Shame',
#    'type': 'track'}),
#  ('melody',
#   {'color': 'greenyellow', 'name': 'melody', 'type': 'artist_terms'}),
#  ('protopunk',
#   {'color': 'greenyellow', 'name': 'protopunk', 'type': 'artist_terms'}),
#  ('TRABWUW128F93214D6',
#   {'color': 'red', 'hot': 0.0, 'name': 'Allein', 'type': 'track'}),
#  ('AR3EABF1187B98AD35',
#   {'color': 'deepskyblue',
#    'hot': 0.36091623001463918,
#    'name': 'Sophie Tucker',
#    'type': 'artist'}),
#  ('madrigal',
#   {'color': 'greenyellow', 'name': 'madrigal', 'type': 'artist_terms'}),
#  ('old school punk',
#   {'color': 'greenyellow', 'name': 'old school punk', 'type': 'artist_terms'}),
#  ('TRAUMBG12903CF0D68',
#   {'color': 'red',
#    'hot': 0.26586104921065007,
#    'name': 'Never Alone',
#    'type': 'track'}),
#  ('TRAJLIV128F42882D8',
#   {'color': 'red', 'hot': nan, 'name': 'A Night in Tunisia', 'type': 'track'}),
#  ('latin jazz',
#   {'color': 'greenyellow', 'name': 'latin jazz', 'type': 'artist_terms'}),
#  ('free improvisation',
#   {'color': 'greenyellow',
#    'name': 'free improvisation',
#    'type': 'artist_terms'}),
#  ('ARJJKAA1187B9ADAF1',
#   {'color': 'deepskyblue',
#    'hot': 0.37666410585810928,
#    'name': 'Rolfe Kent',
#    'type': 'artist'}),
#  ('new jazz',
#   {'color': 'greenyellow', 'name': 'new jazz', 'type': 'artist_terms'}),
#  ('soft rock',
#   {'color': 'greenyellow', 'name': 'soft rock', 'type': 'artist_terms'}),
#  ('TRAQNMM12903D00407',
#   {'color': 'red', 'hot': 0.0, 'name': 'Party Favours', 'type': 'track'}),
#  ('comedian',
#   {'color': 'greenyellow', 'name': 'comedian', 'type': 'artist_terms'}),
#  ('reflective',
#   {'color': 'greenyellow', 'name': 'reflective', 'type': 'artist_terms'}),
#  ('TRATFJI128F4252046',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Oedipus Rex_ Atto Primo: Liberi_ Vos Liberabo (Oedipus) (Stravinsky)',
#    'type': 'track'}),
#  ('TRALDCM128F4222464',
#   {'color': 'red', 'hot': nan, 'name': 'Intro', 'type': 'track'}),
#  ('ARELA4P1187B991507',
#   {'color': 'deepskyblue',
#    'hot': 0.28773146783742498,
#    'name': 'Charles Williams',
#    'type': 'artist'}),
#  ('TRBIERO12903CC4BF5',
#   {'color': 'red', 'hot': nan, 'name': 'La Bambola', 'type': 'track'}),
#  ('TRATNIZ128F42414D2',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Ai Ji Mei Gui 1000 Da',
#    'type': 'track'}),
#  ('no wave',
#   {'color': 'greenyellow', 'name': 'no wave', 'type': 'artist_terms'}),
#  ('AR2HXXS1187B9AF3E2',
#   {'color': 'deepskyblue',
#    'hot': 0.42062740133562165,
#    'name': 'Jesus Jones',
#    'type': 'artist'}),
#  ('underground hip hop',
#   {'color': 'greenyellow',
#    'name': 'underground hip hop',
#    'type': 'artist_terms'}),
#  ('guitar virtuoso',
#   {'color': 'greenyellow', 'name': 'guitar virtuoso', 'type': 'artist_terms'}),
#  ('ARWSMC91187B9AD369',
#   {'color': 'deepskyblue',
#    'hot': 0.34700692093040558,
#    'name': 'Helen Love',
#    'type': 'artist'}),
#  ('ARFM7OI1187B990C49',
#   {'color': 'deepskyblue',
#    'hot': 0.52431892047024631,
#    'name': 'Tonic',
#    'type': 'artist'}),
#  ('flute', {'color': 'greenyellow', 'name': 'flute', 'type': 'artist_terms'}),
#  ('modern electric blues',
#   {'color': 'greenyellow',
#    'name': 'modern electric blues',
#    'type': 'artist_terms'}),
#  ('instrumental post rock',
#   {'color': 'greenyellow',
#    'name': 'instrumental post rock',
#    'type': 'artist_terms'}),
#  ('TRADJGI128F148B0F6',
#   {'color': 'red',
#    'hot': 0.60303014479359129,
#    'name': 'The One I Got',
#    'type': 'track'}),
#  ('TRABFQC128F4265349',
#   {'color': 'red', 'hot': nan, 'name': 'Quiet Time', 'type': 'track'}),
#  ('quebec',
#   {'color': 'greenyellow', 'name': 'quebec', 'type': 'artist_terms'}),
#  ('grime', {'color': 'greenyellow', 'name': 'grime', 'type': 'artist_terms'}),
#  ('melodic power metal',
#   {'color': 'greenyellow',
#    'name': 'melodic power metal',
#    'type': 'artist_terms'}),
#  ('west coast rap',
#   {'color': 'greenyellow', 'name': 'west coast rap', 'type': 'artist_terms'}),
#  ('TRBDGRU128F934D684',
#   {'color': 'red',
#    'hot': nan,
#    'name': "Il a suffit d'une chanson d'amour",
#    'type': 'track'}),
#  ('evil', {'color': 'greenyellow', 'name': 'evil', 'type': 'artist_terms'}),
#  ('heartland rock',
#   {'color': 'greenyellow', 'name': 'heartland rock', 'type': 'artist_terms'}),
#  ('german rap',
#   {'color': 'greenyellow', 'name': 'german rap', 'type': 'artist_terms'}),
#  ('icelandic',
#   {'color': 'greenyellow', 'name': 'icelandic', 'type': 'artist_terms'}),
#  ('cock rock',
#   {'color': 'greenyellow', 'name': 'cock rock', 'type': 'artist_terms'}),
#  ('contemporary country',
#   {'color': 'greenyellow',
#    'name': 'contemporary country',
#    'type': 'artist_terms'}),
#  ('progressive black metal',
#   {'color': 'greenyellow',
#    'name': 'progressive black metal',
#    'type': 'artist_terms'}),
#  ('ARORFIN1187FB3BE5C',
#   {'color': 'deepskyblue',
#    'hot': 0.0,
#    'name': 'Danielle Bollinger',
#    'type': 'artist'}),
#  ('midwest rap',
#   {'color': 'greenyellow', 'name': 'midwest rap', 'type': 'artist_terms'}),
#  ('AR8U8G41187B9A833B',
#   {'color': 'deepskyblue',
#    'hot': 0.30184709481113642,
#    'name': 'Tim Exile',
#    'type': 'artist'}),
#  ('TRABPHE128F42A1E65',
#   {'color': 'red',
#    'hot': 0.56545101217369831,
#    'name': 'Ojos Gitanos',
#    'type': 'track'}),
#  ('mexican',
#   {'color': 'greenyellow', 'name': 'mexican', 'type': 'artist_terms'}),
#  ('chamber music',
#   {'color': 'greenyellow', 'name': 'chamber music', 'type': 'artist_terms'}),
#  ('la punk',
#   {'color': 'greenyellow', 'name': 'la punk', 'type': 'artist_terms'}),
#  ('horror rock',
#   {'color': 'greenyellow', 'name': 'horror rock', 'type': 'artist_terms'}),
#  ('club house',
#   {'color': 'greenyellow', 'name': 'club house', 'type': 'artist_terms'}),
#  ('ARD9THI1187B98EAD0',
#   {'color': 'deepskyblue',
#    'hot': 0.23381943778669392,
#    'name': 'Larissa',
#    'type': 'artist'}),
#  ('ARN0DMU1187FB5B63A',
#   {'color': 'deepskyblue',
#    'hot': 0.49638114568159253,
#    'name': 'Hall & Oates',
#    'type': 'artist'}),
#  ('TRARHXX128F93477A0',
#   {'color': 'red',
#    'hot': 0.0,
#    'name': 'Faithkeeper_ Part 1',
#    'type': 'track'}),
#  ('spanish indie rock',
#   {'color': 'greenyellow',
#    'name': 'spanish indie rock',
#    'type': 'artist_terms'}),
#  ('milonga',
#   {'color': 'greenyellow', 'name': 'milonga', 'type': 'artist_terms'}),
#  ('german metal',
#   {'color': 'greenyellow', 'name': 'german metal', 'type': 'artist_terms'}),
#  ('fusion jazz',
#   {'color': 'greenyellow', 'name': 'fusion jazz', 'type': 'artist_terms'}),
#  ('choro', {'color': 'greenyellow', 'name': 'choro', 'type': 'artist_terms'}),
#  ('ARBXODO1241B9C6C6F',
#   {'color': 'deepskyblue',
#    'hot': 0.0,
#    'name': 'Ismael Due\\xc3\\xb1as',
#    'type': 'artist'}),
#  ('louisiana',
#   {'color': 'greenyellow', 'name': 'louisiana', 'type': 'artist_terms'}),
#  ('AR57WGF1187FB41F11',
#   {'color': 'deepskyblue',
#    'hot': 0.25181562228446863,
#    'name': 'Alan Feinberg',
#    'type': 'artist'}),
#  ('TRARYDZ128F9355209',
#   {'color': 'red', 'hot': nan, 'name': 'Rant Kanaria', 'type': 'track'}),
#  ('TRAOBUI128E078E073',
#   {'color': 'red', 'hot': nan, 'name': 'Autobahn (Live)', 'type': 'track'}),
#  ('AR7DFJP1187B992F13',
#   {'color': 'deepskyblue',
#    'hot': 0.44822358922684985,
#    'name': 'Juana Molina',
#    'type': 'artist'}),
#  ('industrial',
#   {'color': 'greenyellow', 'name': 'industrial', 'type': 'artist_terms'}),
#  ('group', {'color': 'greenyellow', 'name': 'group', 'type': 'artist_terms'}),
#  ('cha cha cha',
#   {'color': 'greenyellow', 'name': 'cha cha cha', 'type': 'artist_terms'}),
#  ('TRANXPU128F428CE4A',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'D\\xc3\\xa5 \\xc3\\xa4r det jul',
#    'type': 'track'}),
#  ('yodel', {'color': 'greenyellow', 'name': 'yodel', 'type': 'artist_terms'}),
#  ('TRAPMTM128F425B4E5',
#   {'color': 'red', 'hot': nan, 'name': 'Georgia', 'type': 'track'}),
#  ('arabic',
#   {'color': 'greenyellow', 'name': 'arabic', 'type': 'artist_terms'}),
#  ('us punk',
#   {'color': 'greenyellow', 'name': 'us punk', 'type': 'artist_terms'}),
#  ('greece',
#   {'color': 'greenyellow', 'name': 'greece', 'type': 'artist_terms'}),
#  ('AR0OEYB1187FB4A81E',
#   {'color': 'deepskyblue',
#    'hot': 0.31920972076720344,
#    'name': 'Catherine Howe & Vo Fletcher',
#    'type': 'artist'}),
#  ('TRAIIWZ128F933E996',
#   {'color': 'red',
#    'hot': 0.4454545254934259,
#    'name': 'Gonna Take a Miracle',
#    'type': 'track'}),
#  ('TRARZIV128F147AADB',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Cavaleiro De Aruanda',
#    'type': 'track'}),
#  ('TRACXUW128F93093F5',
#   {'color': 'red',
#    'hot': 0.23376270577652303,
#    'name': 'Faithful and True (Collectors Version)',
#    'type': 'track'}),
#  ('taiwanese pop',
#   {'color': 'greenyellow', 'name': 'taiwanese pop', 'type': 'artist_terms'}),
#  ('brazilian pop music',
#   {'color': 'greenyellow',
#    'name': 'brazilian pop music',
#    'type': 'artist_terms'}),
#  ('southern',
#   {'color': 'greenyellow', 'name': 'southern', 'type': 'artist_terms'}),
#  ('AR7OEB71187B995A17',
#   {'color': 'deepskyblue',
#    'hot': 0.25751540347437846,
#    'name': 'Henri Pousseur',
#    'type': 'artist'}),
#  ('ARI8GY11187B988DF4',
#   {'color': 'deepskyblue',
#    'hot': 0.32443479443924456,
#    'name': 'Hemdale',
#    'type': 'artist'}),
#  ('AROCBZZ11E2835D652',
#   {'color': 'deepskyblue',
#    'hot': 0.44905257515374747,
#    'name': 'Small Faces',
#    'type': 'artist'}),
#  ('contemporary reggae',
#   {'color': 'greenyellow',
#    'name': 'contemporary reggae',
#    'type': 'artist_terms'}),
#  ('indie power pop',
#   {'color': 'greenyellow', 'name': 'indie power pop', 'type': 'artist_terms'}),
#  ('norteno',
#   {'color': 'greenyellow', 'name': 'norteno', 'type': 'artist_terms'}),
#  ('TRACFQB12903D06042',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Big Guys Throw Cones',
#    'type': 'track'}),
#  ('dixieland',
#   {'color': 'greenyellow', 'name': 'dixieland', 'type': 'artist_terms'}),
#  ('ARV3IN31187FB4AAAE',
#   {'color': 'deepskyblue',
#    'hot': 0.32684529983300464,
#    'name': 'Till West & DJ Delicious',
#    'type': 'artist'}),
#  ('instrumental pop',
#   {'color': 'greenyellow',
#    'name': 'instrumental pop',
#    'type': 'artist_terms'}),
#  ('acoustic guitar',
#   {'color': 'greenyellow', 'name': 'acoustic guitar', 'type': 'artist_terms'}),
#  ('TRAQSWR128F92F1357',
#   {'color': 'red',
#    'hot': 0.0,
#    'name': 'Waiting For A Train [Live]',
#    'type': 'track'}),
#  ('male vocalist',
#   {'color': 'greenyellow', 'name': 'male vocalist', 'type': 'artist_terms'}),
#  ('TRANALJ128F9318BAF',
#   {'color': 'red', 'hot': 0.0, 'name': 'Ooh Wee Baby', 'type': 'track'}),
#  ('TRAJABU128F4239037',
#   {'color': 'red',
#    'hot': 0.46492399418071773,
#    'name': 'Grow Proper',
#    'type': 'track'}),
#  ('anti-folk',
#   {'color': 'greenyellow', 'name': 'anti-folk', 'type': 'artist_terms'}),
#  ('TRAWAWH128F934C8E4',
#   {'color': 'red',
#    'hot': 0.37598430150044215,
#    'name': "Since I've Been Loving You",
#    'type': 'track'}),
#  ('ARQXAUH1187B9BA010',
#   {'color': 'deepskyblue',
#    'hot': 0.38479890996490645,
#    'name': 'Bobbie Gentry',
#    'type': 'artist'}),
#  ('ARDPTGD1187B9AD361',
#   {'color': 'deepskyblue',
#    'hot': 0.36367567705114168,
#    'name': 'Brand X',
#    'type': 'artist'}),
#  ('TRAEMAA128F428E58F',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'El Te Daba Mala Vida',
#    'type': 'track'}),
#  ('AR508LN1187B996F4E',
#   {'color': 'deepskyblue',
#    'hot': 0.41498528243888683,
#    'name': 'Lole y Manuel',
#    'type': 'artist'}),
#  ('ART3O5Z1187B9AB043',
#   {'color': 'deepskyblue',
#    'hot': 0.54425750572452603,
#    'name': 'Stevie Ray Vaughan And Double Trouble',
#    'type': 'artist'}),
#  ('norway',
#   {'color': 'greenyellow', 'name': 'norway', 'type': 'artist_terms'}),
#  ('russian heavy metal',
#   {'color': 'greenyellow',
#    'name': 'russian heavy metal',
#    'type': 'artist_terms'}),
#  ('pop rock nacional',
#   {'color': 'greenyellow',
#    'name': 'pop rock nacional',
#    'type': 'artist_terms'}),
#  ('ARMAEYS1187B990F2F',
#   {'color': 'deepskyblue',
#    'hot': 0.31762454603358753,
#    'name': 'Tree',
#    'type': 'artist'}),
#  ('TRBCSZQ128F92F9043',
#   {'color': 'red',
#    'hot': 0.26173330837465286,
#    'name': 'Speed Of Sound (Emergency Broadcast Album Version)',
#    'type': 'track'}),
#  ('TRAGMTY128F4260063',
#   {'color': 'red', 'hot': 0.0, 'name': 'Pray On', 'type': 'track'}),
#  ('contemporary folk',
#   {'color': 'greenyellow',
#    'name': 'contemporary folk',
#    'type': 'artist_terms'}),
#  ('country and western',
#   {'color': 'greenyellow',
#    'name': 'country and western',
#    'type': 'artist_terms'}),
#  ('glam', {'color': 'greenyellow', 'name': 'glam', 'type': 'artist_terms'}),
#  ('TRALUNR128EF3425DE',
#   {'color': 'red',
#    'hot': 0.44791544314592491,
#    'name': 'Did You Get My Message?  (Live From Shubas)',
#    'type': 'track'}),
#  ('chinese pop',
#   {'color': 'greenyellow', 'name': 'chinese pop', 'type': 'artist_terms'}),
#  ('ARD5SR21187B9B5F4A',
#   {'color': 'deepskyblue',
#    'hot': 0.4328043103024764,
#    'name': 'Irwin Goodman',
#    'type': 'artist'}),
#  ('pop rock',
#   {'color': 'greenyellow', 'name': 'pop rock', 'type': 'artist_terms'}),
#  ('AROBQ0B1187FB404F6',
#   {'color': 'deepskyblue',
#    'hot': 0.31615598739703837,
#    'name': 'Walter Jackson',
#    'type': 'artist'}),
#  ('AR58SJE1187B9A8E4C',
#   {'color': 'deepskyblue',
#    'hot': 0.35597435894657803,
#    'name': 'J.B. Lenoir',
#    'type': 'artist'}),
#  ('british punk rock',
#   {'color': 'greenyellow',
#    'name': 'british punk rock',
#    'type': 'artist_terms'}),
#  ('ARTDUXM1187B9899ED',
#   {'color': 'deepskyblue',
#    'hot': 0.37559358258517289,
#    'name': 'Charley Patton',
#    'type': 'artist'}),
#  ('portugese',
#   {'color': 'greenyellow', 'name': 'portugese', 'type': 'artist_terms'}),
#  ('new york punk',
#   {'color': 'greenyellow', 'name': 'new york punk', 'type': 'artist_terms'}),
#  ('gospel choir',
#   {'color': 'greenyellow', 'name': 'gospel choir', 'type': 'artist_terms'}),
#  ('TRAKUNC128F147C549',
#   {'color': 'red',
#    'hot': 0.37253003936607959,
#    'name': 'Freaks (Album Version)',
#    'type': 'track'}),
#  ('fingerstyle',
#   {'color': 'greenyellow', 'name': 'fingerstyle', 'type': 'artist_terms'}),
#  ('zxzw 2006',
#   {'color': 'greenyellow', 'name': 'zxzw 2006', 'type': 'artist_terms'}),
#  ('hit', {'color': 'greenyellow', 'name': 'hit', 'type': 'artist_terms'}),
#  ('lounge music',
#   {'color': 'greenyellow', 'name': 'lounge music', 'type': 'artist_terms'}),
#  ('TRBBJBO128F92EB2C5',
#   {'color': 'red',
#    'hot': 0.52973060722890153,
#    'name': 'Your Touch Versus Death',
#    'type': 'track'}),
#  ('suomipop',
#   {'color': 'greenyellow', 'name': 'suomipop', 'type': 'artist_terms'}),
#  ('post-grunge',
#   {'color': 'greenyellow', 'name': 'post-grunge', 'type': 'artist_terms'}),
#  ('rumba', {'color': 'greenyellow', 'name': 'rumba', 'type': 'artist_terms'}),
#  ('AR9OLFX1187B9A5762',
#   {'color': 'deepskyblue',
#    'hot': 0.37996076697507797,
#    'name': 'Bob Willis',
#    'type': 'artist'}),
#  ('TRBIACJ128F93087A9',
#   {'color': 'red',
#    'hot': 0.0,
#    'name': 'I Got My Discharge Papers',
#    'type': 'track'}),
#  ('power metal',
#   {'color': 'greenyellow', 'name': 'power metal', 'type': 'artist_terms'}),
#  ('TRBBDAH128F92E625E',
#   {'color': 'red', 'hot': nan, 'name': 'What Would You Do?', 'type': 'track'}),
#  ('TRBHUDB128F429A663',
#   {'color': 'red', 'hot': nan, 'name': 'Slipping Away', 'type': 'track'}),
#  ('TRAOGLL128F931FAEB',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Te Parto el Alma (inter. El Tariacuri)',
#    'type': 'track'}),
#  ('deutschsprachig',
#   {'color': 'greenyellow', 'name': 'deutschsprachig', 'type': 'artist_terms'}),
#  ('jazz fusion',
#   {'color': 'greenyellow', 'name': 'jazz fusion', 'type': 'artist_terms'}),
#  ('j pop', {'color': 'greenyellow', 'name': 'j pop', 'type': 'artist_terms'}),
#  ('60s rock',
#   {'color': 'greenyellow', 'name': '60s rock', 'type': 'artist_terms'}),
#  ('electro bass',
#   {'color': 'greenyellow', 'name': 'electro bass', 'type': 'artist_terms'}),
#  ('ARMPRI31187FB4F7D9',
#   {'color': 'deepskyblue',
#    'hot': 0.47370050129677771,
#    'name': 'Vangelis',
#    'type': 'artist'}),
#  ('TRAHKEG12903CDB829',
#   {'color': 'red',
#    'hot': 0.31356211424793418,
#    'name': 'Sleeping My Day Away [Live]',
#    'type': 'track'}),
#  ('funk rock',
#   {'color': 'greenyellow', 'name': 'funk rock', 'type': 'artist_terms'}),
#  ('territorios sevilla',
#   {'color': 'greenyellow',
#    'name': 'territorios sevilla',
#    'type': 'artist_terms'}),
#  ('depressive',
#   {'color': 'greenyellow', 'name': 'depressive', 'type': 'artist_terms'}),
#  ('church',
#   {'color': 'greenyellow', 'name': 'church', 'type': 'artist_terms'}),
#  ('ART8F8O1187B9A538D',
#   {'color': 'deepskyblue',
#    'hot': 0.4641524390532526,
#    'name': 'Herbert  von Karajan',
#    'type': 'artist'}),
#  ('indie dance',
#   {'color': 'greenyellow', 'name': 'indie dance', 'type': 'artist_terms'}),
#  ('swamp blues',
#   {'color': 'greenyellow', 'name': 'swamp blues', 'type': 'artist_terms'}),
#  ('hillbilly',
#   {'color': 'greenyellow', 'name': 'hillbilly', 'type': 'artist_terms'}),
#  ('TRAFSSU128EF344074',
#   {'color': 'red',
#    'hot': 0.255070001544072,
#    'name': 'A Little Tear',
#    'type': 'track'}),
#  ('TRAYLQL128F92F0A86',
#   {'color': 'red', 'hot': nan, 'name': 'Break My Mind', 'type': 'track'}),
#  ('french caribbean',
#   {'color': 'greenyellow',
#    'name': 'french caribbean',
#    'type': 'artist_terms'}),
#  ('TRBBDIU128F1496C52',
#   {'color': 'red', 'hot': 0.0, 'name': 'Gamble Calypso', 'type': 'track'}),
#  ('TRASDMK128F4243937',
#   {'color': 'red', 'hot': nan, 'name': 'Susan Said', 'type': 'track'}),
#  ('soundtrack',
#   {'color': 'greenyellow', 'name': 'soundtrack', 'type': 'artist_terms'}),
#  ('ARKJJZN1187B9AFC88',
#   {'color': 'deepskyblue',
#    'hot': 0.35329028976873145,
#    'name': 'Taal',
#    'type': 'artist'}),
#  ('ARS26BQ1187B99466D',
#   {'color': 'deepskyblue',
#    'hot': 0.37810696510421971,
#    'name': 'Vilma Palma e Vampiros',
#    'type': 'artist'}),
#  ('indie rock',
#   {'color': 'greenyellow', 'name': 'indie rock', 'type': 'artist_terms'}),
#  ('sensual',
#   {'color': 'greenyellow', 'name': 'sensual', 'type': 'artist_terms'}),
#  ('hymns', {'color': 'greenyellow', 'name': 'hymns', 'type': 'artist_terms'}),
#  ('folk rock',
#   {'color': 'greenyellow', 'name': 'folk rock', 'type': 'artist_terms'}),
#  ('cuban', {'color': 'greenyellow', 'name': 'cuban', 'type': 'artist_terms'}),
#  ('ARPNDSH1187B9B942F',
#   {'color': 'deepskyblue',
#    'hot': 0.45054667427270134,
#    'name': 'Sui Generis',
#    'type': 'artist'}),
#  ('traditional folk',
#   {'color': 'greenyellow',
#    'name': 'traditional folk',
#    'type': 'artist_terms'}),
#  ('old school',
#   {'color': 'greenyellow', 'name': 'old school', 'type': 'artist_terms'}),
#  ('canton music',
#   {'color': 'greenyellow', 'name': 'canton music', 'type': 'artist_terms'}),
#  ('alabama',
#   {'color': 'greenyellow', 'name': 'alabama', 'type': 'artist_terms'}),
#  ('scandinavian folk',
#   {'color': 'greenyellow',
#    'name': 'scandinavian folk',
#    'type': 'artist_terms'}),
#  ('20th century',
#   {'color': 'greenyellow', 'name': '20th century', 'type': 'artist_terms'}),
#  ('ARCEEC91187B9AC4FB',
#   {'color': 'deepskyblue',
#    'hot': 0.46236783998692382,
#    'name': "Alexander O'Neal",
#    'type': 'artist'}),
#  ('nashville',
#   {'color': 'greenyellow', 'name': 'nashville', 'type': 'artist_terms'}),
#  ('pop country',
#   {'color': 'greenyellow', 'name': 'pop country', 'type': 'artist_terms'}),
#  ('TRAOSFC128F42618F6',
#   {'color': 'red',
#    'hot': 0.50221122055080214,
#    'name': 'Here Comes The Big Parade',
#    'type': 'track'}),
#  ('polka', {'color': 'greenyellow', 'name': 'polka', 'type': 'artist_terms'}),
#  ('TRBASEK128F9338E0F',
#   {'color': 'red', 'hot': nan, 'name': 'Tracy', 'type': 'track'}),
#  ('blues guitar',
#   {'color': 'greenyellow', 'name': 'blues guitar', 'type': 'artist_terms'}),
#  ('greek music',
#   {'color': 'greenyellow', 'name': 'greek music', 'type': 'artist_terms'}),
#  ('AR1XE381187FB4C685',
#   {'color': 'deepskyblue',
#    'hot': 0.37796153231672769,
#    'name': 'Kane',
#    'type': 'artist'}),
#  ('rostock',
#   {'color': 'greenyellow', 'name': 'rostock', 'type': 'artist_terms'}),
#  ('AROGHQQ1187B9890E3',
#   {'color': 'deepskyblue',
#    'hot': 0.0,
#    'name': 'Mil featuring Memphis Bleek',
#    'type': 'artist'}),
#  ('eurobeat',
#   {'color': 'greenyellow', 'name': 'eurobeat', 'type': 'artist_terms'}),
#  ('conscious',
#   {'color': 'greenyellow', 'name': 'conscious', 'type': 'artist_terms'}),
#  ('ARRXPRY1187B9A8B34',
#   {'color': 'deepskyblue',
#    'hot': 0.36652780195544032,
#    'name': 'Gran Coquivacoa',
#    'type': 'artist'}),
#  ('modern country',
#   {'color': 'greenyellow', 'name': 'modern country', 'type': 'artist_terms'}),
#  ('uk pop',
#   {'color': 'greenyellow', 'name': 'uk pop', 'type': 'artist_terms'}),
#  ('90s', {'color': 'greenyellow', 'name': '90s', 'type': 'artist_terms'}),
#  ('album rock',
#   {'color': 'greenyellow', 'name': 'album rock', 'type': 'artist_terms'}),
#  ('ARQOC971187B9910FA',
#   {'color': 'deepskyblue',
#    'hot': 0.4983953383497739,
#    'name': 'The Verve Pipe',
#    'type': 'artist'}),
#  ('stoner metal',
#   {'color': 'greenyellow', 'name': 'stoner metal', 'type': 'artist_terms'}),
#  ('ARMOHN71187FB3959F',
#   {'color': 'deepskyblue',
#    'hot': 0.59243948552780912,
#    'name': 'Atreyu',
#    'type': 'artist'}),
#  ('TRAEFDB128E0783952',
#   {'color': 'red',
#    'hot': 0.5763999812554107,
#    'name': 'Say How I Feel',
#    'type': 'track'}),
#  ('ruhrpott',
#   {'color': 'greenyellow', 'name': 'ruhrpott', 'type': 'artist_terms'}),
#  ('tennessee',
#   {'color': 'greenyellow', 'name': 'tennessee', 'type': 'artist_terms'}),
#  ('samba rock',
#   {'color': 'greenyellow', 'name': 'samba rock', 'type': 'artist_terms'}),
#  ('TRAIHPX128F428081B',
#   {'color': 'red',
#    'hot': 0.70969928993332021,
#    'name': 'Just A Phase',
#    'type': 'track'}),
#  ('ARKSB7X1187B99BA5C',
#   {'color': 'deepskyblue', 'hot': 0.0, 'name': 'Nouvelle', 'type': 'artist'}),
#  ('TRBGLBW12903D03B68',
#   {'color': 'red',
#    'hot': 0.0,
#    'name': 'Les D\\xc3\\xa9penaill\\xc3\\xa9s',
#    'type': 'track'}),
#  ('turnablism',
#   {'color': 'greenyellow', 'name': 'turnablism', 'type': 'artist_terms'}),
#  ('vienna',
#   {'color': 'greenyellow', 'name': 'vienna', 'type': 'artist_terms'}),
#  ('galego',
#   {'color': 'greenyellow', 'name': 'galego', 'type': 'artist_terms'}),
#  ('TRATIRE128F42A667F',
#   {'color': 'red',
#    'hot': 0.71321769226344411,
#    'name': 'She Will Love You (Album Version)',
#    'type': 'track'}),
#  ('norwegian',
#   {'color': 'greenyellow', 'name': 'norwegian', 'type': 'artist_terms'}),
#  ('chanson',
#   {'color': 'greenyellow', 'name': 'chanson', 'type': 'artist_terms'}),
#  ('contemporary',
#   {'color': 'greenyellow', 'name': 'contemporary', 'type': 'artist_terms'}),
#  ('ARJD6I01187FB50347',
#   {'color': 'deepskyblue',
#    'hot': 0.41574847553610206,
#    'name': 'Anna Abreu',
#    'type': 'artist'}),
#  ('TRAPYBS128F9309278',
#   {'color': 'red', 'hot': nan, 'name': 'Street Sh***', 'type': 'track'}),
#  ('durham',
#   {'color': 'greenyellow', 'name': 'durham', 'type': 'artist_terms'}),
#  ('TRATSNE128F427EDB6',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'African Typic Collection',
#    'type': 'track'}),
#  ('moshcore',
#   {'color': 'greenyellow', 'name': 'moshcore', 'type': 'artist_terms'}),
#  ('ARQAXT91187B99103A',
#   {'color': 'deepskyblue',
#    'hot': 0.32502293284522349,
#    'name': 'UKW',
#    'type': 'artist'}),
#  ('TRAIZRI128F1466316',
#   {'color': 'red', 'hot': nan, 'name': 'Sex', 'type': 'track'}),
#  ('rusbeh',
#   {'color': 'greenyellow', 'name': 'rusbeh', 'type': 'artist_terms'}),
#  ('TRAUAHG128F931C55F',
#   {'color': 'red',
#    'hot': 0.0,
#    'name': 'Heal (The Separation) [PM Dawn Alt. Lead Mix]',
#    'type': 'track'}),
#  ('harsh noise',
#   {'color': 'greenyellow', 'name': 'harsh noise', 'type': 'artist_terms'}),
#  ('motown',
#   {'color': 'greenyellow', 'name': 'motown', 'type': 'artist_terms'}),
#  ('soul blues',
#   {'color': 'greenyellow', 'name': 'soul blues', 'type': 'artist_terms'}),
#  ('TRALBKB12903C95C86',
#   {'color': 'red', 'hot': nan, 'name': 'Midnight Hour', 'type': 'track'}),
#  ('ARMBYRO1187FB57419',
#   {'color': 'deepskyblue',
#    'hot': 0.13924739387110993,
#    'name': 'Nadine Renee',
#    'type': 'artist'}),
#  ('TRASUBB12903CE6546',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Valokeilojen vampyyri',
#    'type': 'track'}),
#  ('TRAFELG128F427C373',
#   {'color': 'red',
#    'hot': 0.49529362129216348,
#    'name': 'Special',
#    'type': 'track'}),
#  ('master',
#   {'color': 'greenyellow', 'name': 'master', 'type': 'artist_terms'}),
#  ('TRADWHL128F933E397',
#   {'color': 'red', 'hot': nan, 'name': 'Heart Of Dixie', 'type': 'track'}),
#  ('TRAAMSO128EF348DCC',
#   {'color': 'red', 'hot': nan, 'name': 'Bitch Is Back', 'type': 'track'}),
#  ('ARNPPTH1187B9AD429',
#   {'color': 'deepskyblue',
#    'hot': 0.4249403308027947,
#    'name': 'Jimmy Page',
#    'type': 'artist'}),
#  ('TRAQLOT12903CE025B',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Enclosed_ One Broken Heart',
#    'type': 'track'}),
#  ('ARZ3U0K1187B999BF4',
#   {'color': 'deepskyblue',
#    'hot': 0.39741466337671016,
#    'name': 'Cabas',
#    'type': 'artist'}),
#  ('chant', {'color': 'greenyellow', 'name': 'chant', 'type': 'artist_terms'}),
#  ('ARBQ5TQ1187B992B8A',
#   {'color': 'deepskyblue',
#    'hot': 0.35926026411845985,
#    'name': 'Vivian',
#    'type': 'artist'}),
#  ('innovative',
#   {'color': 'greenyellow', 'name': 'innovative', 'type': 'artist_terms'}),
#  ('soul jazz',
#   {'color': 'greenyellow', 'name': 'soul jazz', 'type': 'artist_terms'}),
#  ('castellano',
#   {'color': 'greenyellow', 'name': 'castellano', 'type': 'artist_terms'}),
#  ('crossover jazz',
#   {'color': 'greenyellow', 'name': 'crossover jazz', 'type': 'artist_terms'}),
#  ('swamp rock',
#   {'color': 'greenyellow', 'name': 'swamp rock', 'type': 'artist_terms'}),
#  ('grind', {'color': 'greenyellow', 'name': 'grind', 'type': 'artist_terms'}),
#  ('AR9XEVF1187B99D017',
#   {'color': 'deepskyblue',
#    'hot': 0.42141510254240711,
#    'name': 'Borialis',
#    'type': 'artist'}),
#  ('ARPBNLO1187FB3D52F',
#   {'color': 'deepskyblue',
#    'hot': 0.40489733548011109,
#    'name': 'Tiny Tim',
#    'type': 'artist'}),
#  ('old school rap',
#   {'color': 'greenyellow', 'name': 'old school rap', 'type': 'artist_terms'}),
#  ('TRABSXW128F4233422',
#   {'color': 'red',
#    'hot': 0.59024059758241698,
#    'name': 'Into A Swan',
#    'type': 'track'}),
#  ('piano blues',
#   {'color': 'greenyellow', 'name': 'piano blues', 'type': 'artist_terms'}),
#  ('german rock',
#   {'color': 'greenyellow', 'name': 'german rock', 'type': 'artist_terms'}),
#  ('TRARTHV128F429B77A',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Woh\\xc3\\xa4r dr Wind w\\xc3\\xa4iht',
#    'type': 'track'}),
#  ('ARU230L1187FB4642F',
#   {'color': 'deepskyblue',
#    'hot': 0.31400816731809039,
#    'name': 'Walter Hawkins',
#    'type': 'artist'}),
#  ('AROW3XO1187B989E72',
#   {'color': 'deepskyblue',
#    'hot': 0.33532212992924409,
#    'name': 'The Motors',
#    'type': 'artist'}),
#  ('harmony',
#   {'color': 'greenyellow', 'name': 'harmony', 'type': 'artist_terms'}),
#  ('minnesota',
#   {'color': 'greenyellow', 'name': 'minnesota', 'type': 'artist_terms'}),
#  ('ethno', {'color': 'greenyellow', 'name': 'ethno', 'type': 'artist_terms'}),
#  ('progressive country',
#   {'color': 'greenyellow',
#    'name': 'progressive country',
#    'type': 'artist_terms'}),
#  ('kazakh pop',
#   {'color': 'greenyellow', 'name': 'kazakh pop', 'type': 'artist_terms'}),
#  ('native american',
#   {'color': 'greenyellow', 'name': 'native american', 'type': 'artist_terms'}),
#  ('TRAAMXP128F4264F6A',
#   {'color': 'red', 'hot': 0.0, 'name': 'Naked Albino', 'type': 'track'}),
#  ('ARX9YIP1187B98A656',
#   {'color': 'deepskyblue',
#    'hot': 0.60663015172918533,
#    'name': 'RUN-DMC',
#    'type': 'artist'}),
#  ('sunshine pop',
#   {'color': 'greenyellow', 'name': 'sunshine pop', 'type': 'artist_terms'}),
#  ('oldies',
#   {'color': 'greenyellow', 'name': 'oldies', 'type': 'artist_terms'}),
#  ('TRANAZC128F9344921',
#   {'color': 'red', 'hot': nan, 'name': "Bartholdi's Dream", 'type': 'track'}),
#  ('rumba flamenca',
#   {'color': 'greenyellow', 'name': 'rumba flamenca', 'type': 'artist_terms'}),
#  ('baroque',
#   {'color': 'greenyellow', 'name': 'baroque', 'type': 'artist_terms'}),
#  ('desi', {'color': 'greenyellow', 'name': 'desi', 'type': 'artist_terms'}),
#  ('death/thrash metal',
#   {'color': 'greenyellow',
#    'name': 'death/thrash metal',
#    'type': 'artist_terms'}),
#  ('ARNSTES1187FB4FC9B',
#   {'color': 'deepskyblue',
#    'hot': 0.41136413214629225,
#    'name': 'Shinehead',
#    'type': 'artist'}),
#  ('sludge metal',
#   {'color': 'greenyellow', 'name': 'sludge metal', 'type': 'artist_terms'}),
#  ('new wave',
#   {'color': 'greenyellow', 'name': 'new wave', 'type': 'artist_terms'}),
#  ('AR7JPF81187B988D23',
#   {'color': 'deepskyblue',
#    'hot': 0.28598980826770681,
#    'name': 'Charlie McCoy',
#    'type': 'artist'}),
#  ('contemporary flamenco',
#   {'color': 'greenyellow',
#    'name': 'contemporary flamenco',
#    'type': 'artist_terms'}),
#  ('vocal group',
#   {'color': 'greenyellow', 'name': 'vocal group', 'type': 'artist_terms'}),
#  ('texas', {'color': 'greenyellow', 'name': 'texas', 'type': 'artist_terms'}),
#  ('hippie',
#   {'color': 'greenyellow', 'name': 'hippie', 'type': 'artist_terms'}),
#  ('energy',
#   {'color': 'greenyellow', 'name': 'energy', 'type': 'artist_terms'}),
#  ('sludge',
#   {'color': 'greenyellow', 'name': 'sludge', 'type': 'artist_terms'}),
#  ('waltz', {'color': 'greenyellow', 'name': 'waltz', 'type': 'artist_terms'}),
#  ('ARIMZQZ1187B9AD541',
#   {'color': 'deepskyblue',
#    'hot': 0.51996547928675652,
#    'name': 'Thrice',
#    'type': 'artist'}),
#  ('latin artists',
#   {'color': 'greenyellow', 'name': 'latin artists', 'type': 'artist_terms'}),
#  ('maryland',
#   {'color': 'greenyellow', 'name': 'maryland', 'type': 'artist_terms'}),
#  ('string',
#   {'color': 'greenyellow', 'name': 'string', 'type': 'artist_terms'}),
#  ('kraut rock',
#   {'color': 'greenyellow', 'name': 'kraut rock', 'type': 'artist_terms'}),
#  ('trip hop',
#   {'color': 'greenyellow', 'name': 'trip hop', 'type': 'artist_terms'}),
#  ('quiet storm',
#   {'color': 'greenyellow', 'name': 'quiet storm', 'type': 'artist_terms'}),
#  ('brutal death grind',
#   {'color': 'greenyellow',
#    'name': 'brutal death grind',
#    'type': 'artist_terms'}),
#  ('ARYORUX11F4C846890',
#   {'color': 'deepskyblue',
#    'hot': 0.30672097559350214,
#    'name': 'Perfection',
#    'type': 'artist'}),
#  ('TRBHDTL128F1468F7D',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Dancing The Night Away',
#    'type': 'track'}),
#  ('argentinian rock',
#   {'color': 'greenyellow',
#    'name': 'argentinian rock',
#    'type': 'artist_terms'}),
#  ('modern classical',
#   {'color': 'greenyellow',
#    'name': 'modern classical',
#    'type': 'artist_terms'}),
#  ('TRAYKCV128F9341943',
#   {'color': 'red',
#    'hot': nan,
#    'name': "I'm Thinking Tonight Of My Blue Eyes",
#    'type': 'track'}),
#  ('hardcore rap',
#   {'color': 'greenyellow', 'name': 'hardcore rap', 'type': 'artist_terms'}),
#  ('zouk', {'color': 'greenyellow', 'name': 'zouk', 'type': 'artist_terms'}),
#  ('jazzdance',
#   {'color': 'greenyellow', 'name': 'jazzdance', 'type': 'artist_terms'}),
#  ('variationen',
#   {'color': 'greenyellow', 'name': 'variationen', 'type': 'artist_terms'}),
#  ('epic viking metal',
#   {'color': 'greenyellow',
#    'name': 'epic viking metal',
#    'type': 'artist_terms'}),
#  ('TRAVOFJ128F933DEA1',
#   {'color': 'red',
#    'hot': 0.26586104921065007,
#    'name': 'Missing You',
#    'type': 'track'}),
#  ('soft', {'color': 'greenyellow', 'name': 'soft', 'type': 'artist_terms'}),
#  ('detroit',
#   {'color': 'greenyellow', 'name': 'detroit', 'type': 'artist_terms'}),
#  ('ARRXADQ1187FB38F22',
#   {'color': 'deepskyblue',
#    'hot': 0.44273927881605984,
#    'name': 'The Business',
#    'type': 'artist'}),
#  ('TRADWAU128F145622F',
#   {'color': 'red',
#    'hot': 0.38293509007501925,
#    'name': 'Long Summer Days',
#    'type': 'track'}),
#  ('congo', {'color': 'greenyellow', 'name': 'congo', 'type': 'artist_terms'}),
#  ('ARL3HJZ1187B9A35EB',
#   {'color': 'deepskyblue',
#    'hot': 0.2543565004184033,
#    'name': 'Johnny Daye',
#    'type': 'artist'}),
#  ('hellfest 2008',
#   {'color': 'greenyellow', 'name': 'hellfest 2008', 'type': 'artist_terms'}),
#  ('vibrations 2007',
#   {'color': 'greenyellow', 'name': 'vibrations 2007', 'type': 'artist_terms'}),
#  ('slow core',
#   {'color': 'greenyellow', 'name': 'slow core', 'type': 'artist_terms'}),
#  ('TRAPVDC128F422C711',
#   {'color': 'red',
#    'hot': 0.61017454047701514,
#    'name': 'Guardians Of The Forest',
#    'type': 'track'}),
#  ('TRAPGAG128F42ADAF7',
#   {'color': 'red', 'hot': nan, 'name': 'All I Can Do', 'type': 'track'}),
#  ('charanga',
#   {'color': 'greenyellow', 'name': 'charanga', 'type': 'artist_terms'}),
#  ('TRASQHA128F4280A1D',
#   {'color': 'red', 'hot': nan, 'name': 'The Attitude Song', 'type': 'track'}),
#  ('electric blues',
#   {'color': 'greenyellow', 'name': 'electric blues', 'type': 'artist_terms'}),
#  ('TRBHKSA128F92FDBEA',
#   {'color': 'red', 'hot': nan, 'name': 'Ida Red', 'type': 'track'}),
#  ('hardcore hip hop',
#   {'color': 'greenyellow',
#    'name': 'hardcore hip hop',
#    'type': 'artist_terms'}),
#  ('german hip hop',
#   {'color': 'greenyellow', 'name': 'german hip hop', 'type': 'artist_terms'}),
#  ('proto-metal',
#   {'color': 'greenyellow', 'name': 'proto-metal', 'type': 'artist_terms'}),
#  ('desi artist',
#   {'color': 'greenyellow', 'name': 'desi artist', 'type': 'artist_terms'}),
#  ('musette',
#   {'color': 'greenyellow', 'name': 'musette', 'type': 'artist_terms'}),
#  ('TRAPWTX128F428FE47',
#   {'color': 'red',
#    'hot': 0.23528047821920517,
#    'name': 'The Marquis and the Scaffold (From "Quills")',
#    'type': 'track'}),
#  ('new mexico',
#   {'color': 'greenyellow', 'name': 'new mexico', 'type': 'artist_terms'}),
#  ('new orleans funk',
#   {'color': 'greenyellow',
#    'name': 'new orleans funk',
#    'type': 'artist_terms'}),
#  ('hair and glam metal',
#   {'color': 'greenyellow',
#    'name': 'hair and glam metal',
#    'type': 'artist_terms'}),
#  ('TRAWNSM12903CA71FC',
#   {'color': 'red',
#    'hot': 0.439202489315343,
#    'name': 'What Is Light? Where Is Laughter? (Acoustic Version)',
#    'type': 'track'}),
#  ('ARV57NY1187FB3C1DC',
#   {'color': 'deepskyblue',
#    'hot': 0.41558288068042459,
#    'name': 'Tommy Castro',
#    'type': 'artist'}),
#  ('TRAQNXY128EF35D3CB',
#   {'color': 'red', 'hot': 0.0, 'name': 'Gemini', 'type': 'track'}),
#  ('acid jazz',
#   {'color': 'greenyellow', 'name': 'acid jazz', 'type': 'artist_terms'}),
#  ('mellow',
#   {'color': 'greenyellow', 'name': 'mellow', 'type': 'artist_terms'}),
#  ('soul music',
#   {'color': 'greenyellow', 'name': 'soul music', 'type': 'artist_terms'}),
#  ('ARQVLQJ1187B98F11F',
#   {'color': 'deepskyblue',
#    'hot': 0.31155917564728197,
#    'name': 'Mau Mau',
#    'type': 'artist'}),
#  ('ARJ87C21187B99B9D4',
#   {'color': 'deepskyblue',
#    'hot': 0.32375539455153141,
#    'name': 'Nino Nardini',
#    'type': 'artist'}),
#  ('ARW45YR1187FB3DE95',
#   {'color': 'deepskyblue',
#    'hot': 0.35297647202000682,
#    'name': 'Pierre Perret',
#    'type': 'artist'}),
#  ('uruguay',
#   {'color': 'greenyellow', 'name': 'uruguay', 'type': 'artist_terms'}),
#  ('cleveland',
#   {'color': 'greenyellow', 'name': 'cleveland', 'type': 'artist_terms'}),
#  ('posi', {'color': 'greenyellow', 'name': 'posi', 'type': 'artist_terms'}),
#  ('TRALETZ12903D0355E',
#   {'color': 'red',
#    'hot': 0.24047374606428715,
#    'name': "Don't Let Go",
#    'type': 'track'}),
#  ('political punk',
#   {'color': 'greenyellow', 'name': 'political punk', 'type': 'artist_terms'}),
#  ('spain', {'color': 'greenyellow', 'name': 'spain', 'type': 'artist_terms'}),
#  ('children music',
# ...
#  ('roots and culture',
#   {'color': 'greenyellow',
#    'name': 'roots and culture',
#    'type': 'artist_terms'}),
#  ('TRAADLR12903CF8D7E',
#   {'color': 'red', 'hot': 0.0, 'name': 'Sabor Guajiro', 'type': 'track'}),
#  ('TRAGQLG128F9351109',
#   {'color': 'red', 'hot': nan, 'name': 'The Jezebel Spirit', 'type': 'track'}),
#  ('dancehall jamaica',
#   {'color': 'greenyellow',
#    'name': 'dancehall jamaica',
#    'type': 'artist_terms'}),
#  ('00s pop',
#   {'color': 'greenyellow', 'name': '00s pop', 'type': 'artist_terms'}),
#  ('bhangra',
#   {'color': 'greenyellow', 'name': 'bhangra', 'type': 'artist_terms'}),
#  ('ARC5Q0L1187B98D463',
#   {'color': 'deepskyblue',
#    'hot': 0.40738682964593709,
#    'name': 'Enter the Haggis',
#    'type': 'artist'}),
#  ('oregon',
#   {'color': 'greenyellow', 'name': 'oregon', 'type': 'artist_terms'}),
#  ('ARANIJI11F4C83EFD2',
#   {'color': 'deepskyblue',
#    'hot': 0.51799022135951145,
#    'name': 'Toots & The Maytals',
#    'type': 'artist'}),
#  ('bayern',
#   {'color': 'greenyellow', 'name': 'bayern', 'type': 'artist_terms'}),
#  ('vinyl', {'color': 'greenyellow', 'name': 'vinyl', 'type': 'artist_terms'}),
#  ('ARYF20K1187B9B76BD',
#   {'color': 'deepskyblue',
#    'hot': 0.51696373073834112,
#    'name': 'George Lopez',
#    'type': 'artist'}),
#  ('switzerland',
#   {'color': 'greenyellow', 'name': 'switzerland', 'type': 'artist_terms'}),
#  ('cuban jazz',
#   {'color': 'greenyellow', 'name': 'cuban jazz', 'type': 'artist_terms'}),
#  ('ARWF1KM1187B9908CA',
#   {'color': 'deepskyblue',
#    'hot': 0.35868566623376791,
#    'name': 'Spliff',
#    'type': 'artist'}),
#  ('60s soul',
#   {'color': 'greenyellow', 'name': '60s soul', 'type': 'artist_terms'}),
#  ('german progressive rock',
#   {'color': 'greenyellow',
#    'name': 'german progressive rock',
#    'type': 'artist_terms'}),
#  ('electropop',
#   {'color': 'greenyellow', 'name': 'electropop', 'type': 'artist_terms'}),
#  ('creative commons',
#   {'color': 'greenyellow',
#    'name': 'creative commons',
#    'type': 'artist_terms'}),
#  ('TRAXULE128F9320132',
#   {'color': 'red', 'hot': nan, 'name': 'Rescue Me', 'type': 'track'}),
#  ('cowboy',
#   {'color': 'greenyellow', 'name': 'cowboy', 'type': 'artist_terms'}),
#  ('TRABZKU12903CBFE15',
#   {'color': 'red',
#    'hot': 0.3005928806392878,
#    'name': 'Wasted Love',
#    'type': 'track'}),
#  ('classic soul',
#   {'color': 'greenyellow', 'name': 'classic soul', 'type': 'artist_terms'}),
#  ('drone', {'color': 'greenyellow', 'name': 'drone', 'type': 'artist_terms'}),
#  ('TRAOVDM128F42BAA66',
#   {'color': 'red',
#    'hot': 0.23962909777363708,
#    'name': 'Si Tu Me Dices Ven',
#    'type': 'track'}),
#  ('mixt', {'color': 'greenyellow', 'name': 'mixt', 'type': 'artist_terms'}),
#  ('ARR575U1187B98FB97',
#   {'color': 'deepskyblue',
#    'hot': 0.38067987361328043,
#    'name': 'The Perrys',
#    'type': 'artist'}),
#  ('intellectual',
#   {'color': 'greenyellow', 'name': 'intellectual', 'type': 'artist_terms'}),
#  ('ARHB1961187B9B1732',
#   {'color': 'deepskyblue',
#    'hot': 0.39488108337774364,
#    'name': 'Kofi',
#    'type': 'artist'}),
#  ('TRAUIYH128E078DA2F',
#   {'color': 'red', 'hot': nan, 'name': 'So Many Reasons', 'type': 'track'}),
#  ('washington',
#   {'color': 'greenyellow', 'name': 'washington', 'type': 'artist_terms'}),
#  ('bel canto',
#   {'color': 'greenyellow', 'name': 'bel canto', 'type': 'artist_terms'}),
#  ('ostrock',
#   {'color': 'greenyellow', 'name': 'ostrock', 'type': 'artist_terms'}),
#  ('bounce',
#   {'color': 'greenyellow', 'name': 'bounce', 'type': 'artist_terms'}),
#  ('female singer-songwriter',
#   {'color': 'greenyellow',
#    'name': 'female singer-songwriter',
#    'type': 'artist_terms'}),
#  ('TRBDDTD12903CA7AA9',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'My Tribute (to God Be The Glory)',
#    'type': 'track'}),
#  ('madrid',
#   {'color': 'greenyellow', 'name': 'madrid', 'type': 'artist_terms'}),
#  ('TRAUDNM12903CDEF32',
#   {'color': 'red',
#    'hot': 0.43483809026085618,
#    'name': 'Let It All Go',
#    'type': 'track'}),
#  ('sympho black metal',
#   {'color': 'greenyellow',
#    'name': 'sympho black metal',
#    'type': 'artist_terms'}),
#  ('china', {'color': 'greenyellow', 'name': 'china', 'type': 'artist_terms'}),
#  ('TRALZXZ128F92E26EF',
#   {'color': 'red',
#    'hot': 0.67816110894165516,
#    'name': 'My Little Girl',
#    'type': 'track'}),
#  ('moody', {'color': 'greenyellow', 'name': 'moody', 'type': 'artist_terms'}),
#  ('cloud', {'color': 'greenyellow', 'name': 'cloud', 'type': 'artist_terms'}),
#  ('TRABLLK128F428FFAF',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Hear Me Lord (2001 Digital Remaster)',
#    'type': 'track'}),
#  ('ARVUN5F1187FB4CCC7',
#   {'color': 'deepskyblue',
#    'hot': 0.48133930857423185,
#    'name': 'Beenie Man',
#    'type': 'artist'}),
#  ('ARTXS851187FB411C7',
#   {'color': 'deepskyblue',
#    'hot': 0.33857502645721227,
#    'name': 'Chris Farlowe',
#    'type': 'artist'}),
#  ('ARDL03L1187B997FBE',
#   {'color': 'deepskyblue',
#    'hot': 0.3241574928410268,
#    'name': 'Fl\\xc3\\xa4skkvartetten / Daniel Bellqvist',
#    'type': 'artist'}),
#  ('indian',
#   {'color': 'greenyellow', 'name': 'indian', 'type': 'artist_terms'}),
#  ('african soul',
#   {'color': 'greenyellow', 'name': 'african soul', 'type': 'artist_terms'}),
#  ('southern rap',
#   {'color': 'greenyellow', 'name': 'southern rap', 'type': 'artist_terms'}),
#  ('ARUJZFJ1187B9B135F',
#   {'color': 'deepskyblue',
#    'hot': 0.54632611955194066,
#    'name': 'Shania Twain',
#    'type': 'artist'}),
#  ('noise rock',
#   {'color': 'greenyellow', 'name': 'noise rock', 'type': 'artist_terms'}),
#  ('reggaeton',
#   {'color': 'greenyellow', 'name': 'reggaeton', 'type': 'artist_terms'}),
#  ('cameroon',
#   {'color': 'greenyellow', 'name': 'cameroon', 'type': 'artist_terms'}),
#  ('ARQGNEN1187FB4494C',
#   {'color': 'deepskyblue',
#    'hot': 0.326430852787923,
#    'name': 'Gabinete Caligari',
#    'type': 'artist'}),
#  ('balkan',
#   {'color': 'greenyellow', 'name': 'balkan', 'type': 'artist_terms'}),
#  ('african',
#   {'color': 'greenyellow', 'name': 'african', 'type': 'artist_terms'}),
#  ('bashment',
#   {'color': 'greenyellow', 'name': 'bashment', 'type': 'artist_terms'}),
#  ('TRACMPZ12903CF150B',
#   {'color': 'red', 'hot': nan, 'name': 'Moon Going Down', 'type': 'track'}),
#  ('ambient',
#   {'color': 'greenyellow', 'name': 'ambient', 'type': 'artist_terms'}),
#  ('ARW70HR1187B9A358C',
#   {'color': 'deepskyblue',
#    'hot': 0.39943154431106781,
#    'name': 'Aleks Syntek',
#    'type': 'artist'}),
#  ('timba', {'color': 'greenyellow', 'name': 'timba', 'type': 'artist_terms'}),
#  ('TRAVASN128F9361074',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Earrings on the Table',
#    'type': 'track'}),
#  ('symphonic power metal',
#   {'color': 'greenyellow',
#    'name': 'symphonic power metal',
#    'type': 'artist_terms'}),
#  ('urban folk',
#   {'color': 'greenyellow', 'name': 'urban folk', 'type': 'artist_terms'}),
#  ('shred', {'color': 'greenyellow', 'name': 'shred', 'type': 'artist_terms'}),
#  ('abstract',
#   {'color': 'greenyellow', 'name': 'abstract', 'type': 'artist_terms'}),
#  ('ARIRD6J1187FB5A98C',
#   {'color': 'deepskyblue',
#    'hot': 0.38628965124618425,
#    'name': 'Sugar Minott',
#    'type': 'artist'}),
#  ('trippy',
#   {'color': 'greenyellow', 'name': 'trippy', 'type': 'artist_terms'}),
#  ('movie score composer',
#   {'color': 'greenyellow',
#    'name': 'movie score composer',
#    'type': 'artist_terms'}),
#  ('melodic black metal',
#   {'color': 'greenyellow',
#    'name': 'melodic black metal',
#    'type': 'artist_terms'}),
#  ('new zealand',
#   {'color': 'greenyellow', 'name': 'new zealand', 'type': 'artist_terms'}),
#  ('ARUTP601187FB388AC',
#   {'color': 'deepskyblue',
#    'hot': 0.41530364258122732,
#    'name': 'The Elders',
#    'type': 'artist'}),
#  ('TRAJLKH128F422C613',
#   {'color': 'red',
#    'hot': 0.50338123620631914,
#    'name': 'Nothing But The Best',
#    'type': 'track'}),
#  ('AR8I87E1187FB57E2E',
#   {'color': 'deepskyblue',
#    'hot': 0.40146205320734124,
#    'name': 'Andra\\xc3\\xa9 Crouch & Solid Gospel',
#    'type': 'artist'}),
#  ('cantonese',
#   {'color': 'greenyellow', 'name': 'cantonese', 'type': 'artist_terms'}),
#  ('ARQKBSH1187B9B4B99',
#   {'color': 'deepskyblue',
#    'hot': 0.29533281954469626,
#    'name': 'Francis Dhomont',
#    'type': 'artist'}),
#  ('ARX8PZU1187B9AA7E2',
#   {'color': 'deepskyblue',
#    'hot': 0.31426824061355829,
#    'name': 'Mighty Joe Young',
#    'type': 'artist'}),
#  ('TRAAYGH128F92ECD16',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Will You Love Me Tomorrow',
#    'type': 'track'}),
#  ('AR8QHU51187B9A3341',
#   {'color': 'deepskyblue',
#    'hot': 0.36062871613623815,
#    'name': 'Leo Ku',
#    'type': 'artist'}),
#  ('beach music',
#   {'color': 'greenyellow', 'name': 'beach music', 'type': 'artist_terms'}),
#  ('joululaulut',
#   {'color': 'greenyellow', 'name': 'joululaulut', 'type': 'artist_terms'}),
#  ('ARH4N0N1187FB3E1F1',
#   {'color': 'deepskyblue',
#    'hot': 0.32443089199258551,
#    'name': 'Malkit Singh',
#    'type': 'artist'}),
#  ('breakbeat',
#   {'color': 'greenyellow', 'name': 'breakbeat', 'type': 'artist_terms'}),
#  ('voice', {'color': 'greenyellow', 'name': 'voice', 'type': 'artist_terms'}),
#  ('film score composer',
#   {'color': 'greenyellow',
#    'name': 'film score composer',
#    'type': 'artist_terms'}),
#  ('ARCP94M1187B9B0F56',
#   {'color': 'deepskyblue',
#    'hot': 0.56485575047668202,
#    'name': 'Every Time I Die',
#    'type': 'artist'}),
#  ('deutsch hiphop',
#   {'color': 'greenyellow', 'name': 'deutsch hiphop', 'type': 'artist_terms'}),
#  ('latin electronica',
#   {'color': 'greenyellow',
#    'name': 'latin electronica',
#    'type': 'artist_terms'}),
#  ('alternative rap',
#   {'color': 'greenyellow', 'name': 'alternative rap', 'type': 'artist_terms'}),
#  ('ARLGUTA1187B9B605F',
#   {'color': 'deepskyblue',
#    'hot': 0.39507381874006531,
#    'name': 'Terror Squad / Remy / Prospect / Armageddon',
#    'type': 'artist'}),
#  ('TRAGGHA128F4262D55',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'I WANNA HEAR IT FROM YOU',
#    'type': 'track'}),
#  ('AR6IJ6U1187B99FC7C',
#   {'color': 'deepskyblue',
#    'hot': 0.32841373787793265,
#    'name': 'Alberto Cortez',
#    'type': 'artist'}),
#  ('TRBDUAQ128F427154D',
#   {'color': 'red', 'hot': 0.0, 'name': 'Joaquin Torres Jr.', 'type': 'track'}),
#  ('concerto',
#   {'color': 'greenyellow', 'name': 'concerto', 'type': 'artist_terms'}),
#  ('psychedelic trance',
#   {'color': 'greenyellow',
#    'name': 'psychedelic trance',
#    'type': 'artist_terms'}),
#  ('AR1WDRJ1187B9BA4B8',
#   {'color': 'deepskyblue',
#    'hot': 0.30150587751163294,
#    'name': 'Buzzov\\xc2\\xac"en',
#    'type': 'artist'}),
#  ('progressive metal',
#   {'color': 'greenyellow',
#    'name': 'progressive metal',
#    'type': 'artist_terms'}),
#  ('tribal',
#   {'color': 'greenyellow', 'name': 'tribal', 'type': 'artist_terms'}),
#  ('happy music',
#   {'color': 'greenyellow', 'name': 'happy music', 'type': 'artist_terms'}),
#  ('easy listening',
#   {'color': 'greenyellow', 'name': 'easy listening', 'type': 'artist_terms'}),
#  ('chinese diva',
#   {'color': 'greenyellow', 'name': 'chinese diva', 'type': 'artist_terms'}),
#  ('ARMUCXW11F50C4BFEC',
#   {'color': 'deepskyblue',
#    'hot': 0.18614164293301078,
#    'name': 'Bionikworld',
#    'type': 'artist'}),
#  ('ARRHZLW11E2835E799',
#   {'color': 'deepskyblue',
#    'hot': 0.38528564261478293,
#    'name': 'Sofi Marinova',
#    'type': 'artist'}),
#  ('TRAGOEW128F427A209',
#   {'color': 'red', 'hot': nan, 'name': 'Choro II', 'type': 'track'}),
#  ('canadian rock',
#   {'color': 'greenyellow', 'name': 'canadian rock', 'type': 'artist_terms'}),
#  ('ARLTWXK1187FB5A3F8',
#   {'color': 'deepskyblue',
#    'hot': 0.36682078763979759,
#    'name': 'King Curtis',
#    'type': 'artist'}),
#  ('TRAHRPF128F4252CB3',
#   {'color': 'red',
#    'hot': 0.0,
#    'name': 'Punjabian Di Chale Glassi',
#    'type': 'track'}),
#  ('greek rock',
#   {'color': 'greenyellow', 'name': 'greek rock', 'type': 'artist_terms'}),
#  ('epic trance',
#   {'color': 'greenyellow', 'name': 'epic trance', 'type': 'artist_terms'}),
#  ('inspirational',
#   {'color': 'greenyellow', 'name': 'inspirational', 'type': 'artist_terms'}),
#  ('TRAQBTT128F427AE7D',
#   {'color': 'red', 'hot': nan, 'name': 'Pu**y Pop', 'type': 'track'}),
#  ('symphony',
#   {'color': 'greenyellow', 'name': 'symphony', 'type': 'artist_terms'}),
#  ('ARY1VGA1187FB5A39E',
#   {'color': 'deepskyblue',
#    'hot': 0.37178673345688029,
#    'name': 'Tom Cochrane',
#    'type': 'artist'}),
#  ('vocal jazz',
#   {'color': 'greenyellow', 'name': 'vocal jazz', 'type': 'artist_terms'}),
#  ('male lead',
#   {'color': 'greenyellow', 'name': 'male lead', 'type': 'artist_terms'}),
#  ('sentimental',
#   {'color': 'greenyellow', 'name': 'sentimental', 'type': 'artist_terms'}),
#  ('TRAMAKK128F9301EE4',
#   {'color': 'red',
#    'hot': 0.44713579628617778,
#    'name': 'Digital [Live at Birmingham University] [2007 Re-mastered]',
#    'type': 'track'}),
#  ('TRBIBSS128F14A205E',
#   {'color': 'red',
#    'hot': 0.58892216755590654,
#    'name': 'Two Elegiac Melodies Op. 34: 2. The Last Spring',
#    'type': 'track'}),
#  ('rock castellano',
#   {'color': 'greenyellow', 'name': 'rock castellano', 'type': 'artist_terms'}),
#  ('punjabi',
#   {'color': 'greenyellow', 'name': 'punjabi', 'type': 'artist_terms'}),
#  ('TRAJIDY128F931C89D',
#   {'color': 'red',
#    'hot': 0.38293509007501925,
#    'name': 'Another Djemba Djemba',
#    'type': 'track'}),
#  ('north east',
#   {'color': 'greenyellow', 'name': 'north east', 'type': 'artist_terms'}),
#  ('experimental music',
#   {'color': 'greenyellow',
#    'name': 'experimental music',
#    'type': 'artist_terms'}),
#  ('ARW2I321187B9A9F87',
#   {'color': 'deepskyblue',
#    'hot': 0.27175744842936628,
#    'name': 'Xose Manuel Budi\\xc3\\xb1o',
#    'type': 'artist'}),
#  ('chiptune',
#   {'color': 'greenyellow', 'name': 'chiptune', 'type': 'artist_terms'}),
#  ('black gospel',
#   {'color': 'greenyellow', 'name': 'black gospel', 'type': 'artist_terms'}),
#  ('new traditionalist country',
#   {'color': 'greenyellow',
#    'name': 'new traditionalist country',
#    'type': 'artist_terms'}),
#  ('ARRWAD71187FB3FE44',
#   {'color': 'deepskyblue',
#    'hot': 0.49756873428189957,
#    'name': 'Martha Wainwright',
#    'type': 'artist'}),
#  ('voodoo',
#   {'color': 'greenyellow', 'name': 'voodoo', 'type': 'artist_terms'}),
#  ('old', {'color': 'greenyellow', 'name': 'old', 'type': 'artist_terms'}),
#  ('ARVWNTI1269FB34C59',
#   {'color': 'deepskyblue',
#    'hot': 0.43678294949471058,
#    'name': 'SOJA',
#    'type': 'artist'}),
#  ('TRAYDZS128F4288459',
#   {'color': 'red',
#    'hot': 0.29987748827397781,
#    'name': 'Seni Unuturum',
#    'type': 'track'}),
#  ('ARK82DC1187B9A1FEB',
#   {'color': 'deepskyblue',
#    'hot': 0.33075388875142681,
#    'name': 'Gordon Jenkins',
#    'type': 'artist'}),
#  ('TRBGGRK128F422CA7F',
#   {'color': 'red', 'hot': nan, 'name': 'Laakista humppa', 'type': 'track'}),
#  ('big band',
#   {'color': 'greenyellow', 'name': 'big band', 'type': 'artist_terms'}),
#  ('stand-up comedy',
#   {'color': 'greenyellow', 'name': 'stand-up comedy', 'type': 'artist_terms'}),
#  ('girl power',
#   {'color': 'greenyellow', 'name': 'girl power', 'type': 'artist_terms'}),
#  ('minneapolis sound',
#   {'color': 'greenyellow',
#    'name': 'minneapolis sound',
#    'type': 'artist_terms'}),
#  ('marimba',
#   {'color': 'greenyellow', 'name': 'marimba', 'type': 'artist_terms'}),
#  ('early reggae',
#   {'color': 'greenyellow', 'name': 'early reggae', 'type': 'artist_terms'}),
#  ('TRBHJZX128F1495DAE',
#   {'color': 'red',
#    'hot': nan,
#    'name': 'Lil Brother (LP Version)',
#    'type': 'track'}),
#  ('modern rnb',
#   {'color': 'greenyellow', 'name': 'modern rnb', 'type': 'artist_terms'}),
#  ('TRAHKND128F935E15F',
#   {'color': 'red',
#    'hot': 0.22914410371660274,
#    'name': 'Sentimental Journey',
#    'type': 'track'}),
#  ('TRAETWP128F421AD6A',
#   {'color': 'red',
#    'hot': 0.42512465831305757,
#    'name': "Sho' Enough",
#    'type': 'track'}),
#  ('lyrics',
#   {'color': 'greenyellow', 'name': 'lyrics', 'type': 'artist_terms'}),
#  ('california',
#   {'color': 'greenyellow', 'name': 'california', 'type': 'artist_terms'}),
#  ('bolero',
#   {'color': 'greenyellow', 'name': 'bolero', 'type': 'artist_terms'}),
#  ('mexico',
#   {'color': 'greenyellow', 'name': 'mexico', 'type': 'artist_terms'}),
#  ('classic jazz',
#   {'color': 'greenyellow', 'name': 'classic jazz', 'type': 'artist_terms'}),
#  ...]

# %% [markdown]
# ### Add the Edges - with attributes and weight
#
# There will be two types of edges
# + `track` to `artist_id`
# + `artist_id` to `artist_terms`
#
# First, the `track` to `artist_id` edges are added.

# %%
# using from pandas dataframe ()
# create a weight column in the df_ta dataframe and set it as 1. This will be the weight.
df_ta1 = df_ta
df_ta1['weight'] = 1
# track - artist edges
graph_edge_1_pd = nx.from_pandas_dataframe(df_ta1, 'track', 'artist_id', 
                                           edge_attr=['weight','song_hotttnesss','artist_hotttnesss','artist_familiarity'], 
                                           create_using=nx.Graph())

print(type(graph_edge_1_pd))

# create an edge list
edges_1 = nx.to_edgelist(graph_edge_1_pd)
print(type(edges_1))

# add edges to graph
G_1.add_edges_from(edges_1)

print('No. of track to artist edges:', G_1.number_of_edges())
# Out:
# <class 'networkx.classes.graph.Graph'>
# <class 'list'>
# No. of track to artist edges: 500

# %% [markdown]
# There are 500 `track` to `artist_id` edges. Now, the `artist_id` to `artist_terms` edges are added.

# %%
# rename at_wt column as weight in the df_aat dataframe. This i to ensure consistency of weight attribute for all edge types.
df_aat1 = df_aat
df_aat1['weight'] = df_aat['at_wt']

# artist - artist_terms edges
graph_edge_2_pd = nx.from_pandas_dataframe(df_aat1, 'artist_terms', 'artist_id', 
                                           edge_attr=['weight','artist_hotttnesss','artist_familiarity'], 
                                           create_using=nx.Graph())

print(type(graph_edge_2_pd))
edges_2 = nx.to_edgelist(graph_edge_2_pd)
print(type(edges_2))

# add edges to graph
G_1.add_edges_from(edges_2)

print('No. of artist - artist_terms edges:', G_1.number_of_edges()-500)
# Out:
# <class 'networkx.classes.graph.Graph'>
# <class 'list'>
# No. of artist - artist_terms edges: 12428

# %%
# Look at each of the edge lists with data
G_1.edges(data = True)
# Out:
# [('AR2DKN01187FB3AA39',
#   'guitar',
#   {'artist_familiarity': 0.3004990465562955,
#    'artist_hotttnesss': 0.11241786757300369,
#    'weight': 0.36152517991705674}),
#  ('AR2DKN01187FB3AA39',
#   'traditional country',
#   {'artist_familiarity': 0.3004990465562955,
#    'artist_hotttnesss': 0.11241786757300369,
#    'weight': 0.6655481371159804}),
#  ('AR2DKN01187FB3AA39',
#   'country',
#   {'artist_familiarity': 0.3004990465562955,
#    'artist_hotttnesss': 0.11241786757300369,
#    'weight': 0.5507469775270242}),
#  ('AR2DKN01187FB3AA39',
#   'cowboy',
#   {'artist_familiarity': 0.3004990465562955,
#    'artist_hotttnesss': 0.11241786757300369,
#    'weight': 0.6309211941647311}),
#  ('AR2DKN01187FB3AA39',
#   'western swing',
#   {'artist_familiarity': 0.3004990465562955,
#    'artist_hotttnesss': 0.11241786757300369,
#    'weight': 1.0}),
#  ('AR2DKN01187FB3AA39',
#   'TRAMFIU128F426B004',
#   {'artist_familiarity': 0.3004990465562955,
#    'artist_hotttnesss': 0.11241786757300369,
#    'song_hotttnesss': 0.26586104921065007,
#    'weight': 1}),
#  ('AR2DKN01187FB3AA39',
#   'gospel',
#   {'artist_familiarity': 0.3004990465562955,
#    'artist_hotttnesss': 0.11241786757300369,
#    'weight': 0.3295636671304903}),
#  ('TRASNTF128F426C3E6',
#   'AR1PCLK1187FB5BBFF',
#   {'artist_familiarity': 0.6987704777958721,
#    'artist_hotttnesss': 0.39945172400502926,
#    'song_hotttnesss': 0.5947794446625645,
#    'weight': 1}),
#  ('harp',
#   'AR7JPF81187B988D23',
#   {'artist_familiarity': 0.37019116502419075,
#    'artist_hotttnesss': 0.2859898082677068,
#    'weight': 0.5798052813698727}),
#  ('harp',
#   'ARW4AGO1187FB4F107',
#   {'artist_familiarity': 0.36280014168093827,
#    'artist_hotttnesss': 0.28228640563265106,
#    'weight': 0.4379015706646092}),
#  ('boogie',
#   'AR8ACFK1187B9B4063',
#   {'artist_familiarity': 0.5380848292044943,
#    'artist_hotttnesss': 0.3135007553703385,
#    'weight': 0.537494022891317}),
#  ('maryland',
#   'ARR575U1187B98FB97',
#   {'artist_familiarity': 0.5013371622205839,
#    'artist_hotttnesss': 0.38067987361328043,
#    'weight': 0.5609747583486996}),
#  ('ARYQ8281187FB58C34',
#   'hardcore',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.6182957029686876}),
#  ('ARYQ8281187FB58C34',
#   'alternative',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.5830697236319331}),
#  ('ARYQ8281187FB58C34',
#   'rock steady',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.8989007284965572}),
#  ('ARYQ8281187FB58C34',
#   'soul',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.7171893667728332}),
#  ('ARYQ8281187FB58C34',
#   'skinhead',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.5723354081499661}),
#  ('ARYQ8281187FB58C34',
#   'ska',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.807986782573588}),
#  ('ARYQ8281187FB58C34',
#   'psychedelic rock',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.7553356176003172}),
#  ('ARYQ8281187FB58C34',
#   'progressive',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.6389024020297234}),
#  ('ARYQ8281187FB58C34',
#   'funk soul',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.41472175265726086}),
#  ('ARYQ8281187FB58C34',
#   'skinhead reaggae',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.5296657216367449}),
#  ('ARYQ8281187FB58C34',
#   'indie',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.5830697349007515}),
#  ('ARYQ8281187FB58C34',
#   'jazz',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.662243891545245}),
#  ('ARYQ8281187FB58C34',
#   'rock',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.7724227525823713}),
#  ('ARYQ8281187FB58C34',
#   'early reggae',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.502789589812568}),
#  ('ARYQ8281187FB58C34',
#   'pop',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.5830701202880657}),
#  ('ARYQ8281187FB58C34',
#   'punk',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.5830694539983956}),
#  ('ARYQ8281187FB58C34',
#   'blues',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.802299698679819}),
#  ('ARYQ8281187FB58C34',
#   'soft rock',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.7841423812292277}),
#  ('ARYQ8281187FB58C34',
#   'reggae',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.8916811106432228}),
#  ('ARYQ8281187FB58C34',
#   'jamaica',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.5830646753783613}),
#  ('ARYQ8281187FB58C34',
#   'dub',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.8269977615349134}),
#  ('ARYQ8281187FB58C34',
#   'acoustic',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.5830658646485862}),
#  ('ARYQ8281187FB58C34',
#   'finish',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.7110925156858775}),
#  ('ARYQ8281187FB58C34',
#   'reggae pop',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.5389061824875625}),
#  ('ARYQ8281187FB58C34',
#   'classic rock',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.8325105699927657}),
#  ('ARYQ8281187FB58C34',
#   'blues-rock',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.9227865557154742}),
#  ('ARYQ8281187FB58C34',
#   'folk rock',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.752236915122712}),
#  ('ARYQ8281187FB58C34',
#   'jazz rock',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.5703369652192825}),
#  ('ARYQ8281187FB58C34',
#   'pop rock',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.7743722520617845}),
#  ('ARYQ8281187FB58C34',
#   'alternative rock',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.31450244816962775}),
#  ('ARYQ8281187FB58C34',
#   'electric blues',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.9160004213665772}),
#  ('ARYQ8281187FB58C34',
#   'progressive rock',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.7055481776566941}),
#  ('ARYQ8281187FB58C34',
#   'roots reggae',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 1.0}),
#  ('ARYQ8281187FB58C34',
#   'switzerland',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.5452967012892733}),
#  ('ARYQ8281187FB58C34',
#   'winterthur',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'weight': 0.3510556914828852}),
#  ('ARYQ8281187FB58C34',
#   'TRAIFJE128F933046A',
#   {'artist_familiarity': 0.49500978750410507,
#    'artist_hotttnesss': 0.38866990102322235,
#    'song_hotttnesss': nan,
#    'weight': 1}),
#  ('77 style punk',
#   'ARJNRA61187FB57724',
#   {'artist_familiarity': 0.5075509061827213,
#    'artist_hotttnesss': 0.4121303265420695,
#    'weight': 0.724019740138456}),
#  ('77 style punk',
#   'AROW3XO1187B989E72',
#   {'artist_familiarity': 0.4913702787170684,
#    'artist_hotttnesss': 0.3353221299292441,
#    'weight': 0.6058296298134789}),
#  ('drama',
#   'ARQ3VBJ1187FB3FE55',
#   {'artist_familiarity': 0.6134649321348336,
#    'artist_hotttnesss': 0.4121155534594195,
#    'weight': 0.5824164238461903}),
#  ('modern classical',
#   'ARMMKRK1187B996E31',
#   {'artist_familiarity': 0.3518151232337846,
#    'artist_hotttnesss': 0.27094070676741144,
#    'weight': 0.6685583444984954}),
#  ('modern classical',
#   'ARN3O411187FB4D859',
#   {'artist_familiarity': 0.5613709072283409,
#    'artist_hotttnesss': 0.36553375619798023,
#    'weight': 0.7342388056206436}),
#  ('modern classical',
#   'ARQKBSH1187B9B4B99',
#   {'artist_familiarity': 0.44437243088957856,
#    'artist_hotttnesss': 0.29533281954469626,
#    'weight': 0.7129925567095153}),
#  ('modern classical',
#   'ARI2JSK1187FB496EF',
#   {'artist_familiarity': 0.407430399749988,
#    'artist_hotttnesss': 0.3185360299358178,
#    'weight': 0.6662208789188535}),
#  ('modern classical',
#   'ARC4O5Z1187B9AE91F',
#   {'artist_familiarity': 0.3949625000942707,
#    'artist_hotttnesss': 0.310087326212534,
#    'weight': 0.88062762013823}),
#  ('modern classical',
#   'AROLZEM1187B9A805E',
#   {'artist_familiarity': 0.566157341575077,
#    'artist_hotttnesss': 0.3588450251644818,
#    'weight': 0.6383839993773068}),
#  ('modern classical',
#   'ARPK1CM1187B9B6B9C',
#   {'artist_familiarity': 0.3156924102499128,
#    'artist_hotttnesss': 0.2635090972993376,
#    'weight': 0.715692710120137}),
#  ('modern classical',
#   'AR9ILJF1187B9B80ED',
#   {'artist_familiarity': 0.6118014714600088,
#    'artist_hotttnesss': 0.39904208143240477,
#    'weight': 0.7936890241561323}),
#  ('modern classical',
#   'ARHFIXK1187B99D6A9',
#   {'artist_familiarity': 0.5441034694527811,
#    'artist_hotttnesss': 0.3958356539933544,
#    'weight': 0.6337067474091863}),
#  ('modern classical',
#   'ARHY20W1187B9B8262',
#   {'artist_familiarity': 0.46191743086070425,
#    'artist_hotttnesss': 0.3606256705962805,
#    'weight': 0.7093507948827699}),
#  ('modern classical',
#   'ARSZIBW1187B994053',
#   {'artist_familiarity': 0.6113815948790435,
#    'artist_hotttnesss': 0.4453218782746221,
#    'weight': 0.8046185933415978}),
#  ('ARUSOMY1187FB4D3B4',
#   'punk',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 0.791860736977742}),
#  ('ARUSOMY1187FB4D3B4',
#   'aggressive',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 0.2828080484125568}),
#  ('ARUSOMY1187FB4D3B4',
#   'melodic',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 0.4232473493805455}),
#  ('ARUSOMY1187FB4D3B4',
#   'emo',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 0.5012130727990949}),
#  ('ARUSOMY1187FB4D3B4',
#   'indie',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 0.325353615753198}),
#  ('ARUSOMY1187FB4D3B4',
#   'TRASDGG128F933EDE2',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'song_hotttnesss': 0.6038604709100711,
#    'weight': 1}),
#  ('ARUSOMY1187FB4D3B4',
#   'punk revival',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 0.6579829749348461}),
#  ('ARUSOMY1187FB4D3B4',
#   'political',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 0.49097786597110965}),
#  ('ARUSOMY1187FB4D3B4',
#   'oi',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 1.0}),
#  ('ARUSOMY1187FB4D3B4',
#   'metal',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 0.32472061911839656}),
#  ('ARUSOMY1187FB4D3B4',
#   'rock',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 0.7828296153481855}),
#  ('ARUSOMY1187FB4D3B4',
#   'political punk',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 0.2828080484125568}),
#  ('ARUSOMY1187FB4D3B4',
#   'hardcore punk',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 0.9432931085417625}),
#  ('ARUSOMY1187FB4D3B4',
#   'pop',
#   {'artist_familiarity': 0.8440395322273969,
#    'artist_hotttnesss': 0.5243789875148084,
#    'weight': 0.3249601765531201}),
#  ('nueva cancion',
#   'AR6IJ6U1187B99FC7C',
#   {'artist_familiarity': 0.5067789283762791,
#    'artist_hotttnesss': 0.32841373787793265,
#    'weight': 0.5126892966106039}),
#  ('ARG51IA1187B9B143A',
#   'glasgow',
#   {'artist_familiarity': 0.44780805706814564,
#    'artist_hotttnesss': 0.29191313037941863,
#    'weight': 0.38790188196973685}),
#  ('ARG51IA1187B9B143A',
#   'california',
#   {'artist_familiarity': 0.44780805706814564,
#    'artist_hotttnesss': 0.29191313037941863,
#    'weight': 0.46782946052267327}),
#  ('ARG51IA1187B9B143A',
#   'original',
#   {'artist_familiarity': 0.44780805706814564,
#    'artist_hotttnesss': 0.29191313037941863,
#    'weight': 0.38790188196973685}),
#  ('ARG51IA1187B9B143A',
#   'TRAYHSH128F92E4A6F',
#   {'artist_familiarity': 0.44780805706814564,
#    'artist_hotttnesss': 0.29191313037941863,
#    'song_hotttnesss': nan,
#    'weight': 1}),
#  ('ARG51IA1187B9B143A',
#   'soundtrack',
#   {'artist_familiarity': 0.44780805706814564,
#    'artist_hotttnesss': 0.29191313037941863,
#    'weight': 0.7280656101398147}),
#  ('ARG51IA1187B9B143A',
#   'composer',
#   {'artist_familiarity': 0.44780805706814564,
#    'artist_hotttnesss': 0.29191313037941863,
#    'weight': 0.8970884544951091}),
#  ('ARG51IA1187B9B143A',
#   'film music',
#   {'artist_familiarity': 0.44780805706814564,
#    'artist_hotttnesss': 0.29191313037941863,
#    'weight': 0.7925533343621348}),
#  ('ARG51IA1187B9B143A',
#   'contemporary classical music',
#   {'artist_familiarity': 0.44780805706814564,
#    'artist_hotttnesss': 0.29191313037941863,
#    'weight': 1.0}),
#  ('ARG51IA1187B9B143A',
#   'san francisco',
#   {'artist_familiarity': 0.44780805706814564,
#    'artist_hotttnesss': 0.29191313037941863,
#    'weight': 0.38790188196973685}),
#  ('ARG51IA1187B9B143A',
#   'master',
#   {'artist_familiarity': 0.44780805706814564,
#    'artist_hotttnesss': 0.29191313037941863,
#    'weight': 0.38790188196973685}),
#  ('ARG51IA1187B9B143A',
#   'original score',
#   {'artist_familiarity': 0.44780805706814564,
#    'artist_hotttnesss': 0.29191313037941863,
#    'weight': 0.6443475583717295}),
#  ('ARG51IA1187B9B143A',
#   'cartoon music',
#   {'artist_familiarity': 0.44780805706814564,
#    'artist_hotttnesss': 0.29191313037941863,
#    'weight': 0.5046719838171367}),
#  ('voice',
#   'ARB1KC91187FB38B13',
#   {'artist_familiarity': 0.551502069088444,
#    'artist_hotttnesss': 0.3517177511209014,
#    'weight': 0.26833183710538644}),
#  ('voice',
#   'ARSX6IX1187B9B640C',
#   {'artist_familiarity': 0.7410404327961191,
#    'artist_hotttnesss': 0.4965081187205733,
#    'weight': 0.2775865718416983}),
#  ('voice',
#   'ARF3PG41187FB4B0B4',
#   {'artist_familiarity': 0.4182825139804495,
#    'artist_hotttnesss': 0.3203456288328348,
#    'weight': 0.348878764016325}),
#  ('voice',
#   'AR7N7MI1187FB46935',
#   {'artist_familiarity': 0.7714921495221693,
#    'artist_hotttnesss': 0.5173422859533258,
#    'weight': 0.3006847414729582}),
#  ('voice',
#   'AR2FSX31187B98E3EF',
#   {'artist_familiarity': 0.7309590855000573,
#    'artist_hotttnesss': 0.4814269364777582,
#    'weight': 0.34933002146819075}),
#  ('voice',
#   'ARJD6I01187FB50347',
#   {'artist_familiarity': 0.6125761417994826,
#    'artist_hotttnesss': 0.41574847553610206,
#    'weight': 0.6508193512269413}),
#  ('voice',
#   'ARGVJPK1187B9909EA',
#   {'artist_familiarity': 0.7653570130635742,
#    'artist_hotttnesss': 0.7551499130578622,
#    'weight': 0.377812712119534}),
#  ('voice',
#   'AREB9421187FB458EF',
#   {'artist_familiarity': 0.441586733214394,
#    'artist_hotttnesss': 0.2795154797568439,
#    'weight': 0.3423649570549284}),
#  ('voice',
#   'AR9HQ6Y1187FB3C2CB',
#   {'artist_familiarity': 0.3672550107574772,
#    'artist_hotttnesss': 0.3116155449734521,
#    'weight': 0.3361303507456479}),
#  ('TRAHTDA128F147A055',
#   'ARIQZ2V1187B98E546',
#   {'artist_familiarity': 0.4401582935385169,
#    'artist_hotttnesss': 0.36257249427757804,
#    'song_hotttnesss': nan,
#    'weight': 1}),
#  ('AR9K6SJ1187B989A32',
#   'louisville',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.5895844552817491}),
#  ('AR9K6SJ1187B989A32',
#   'r&b',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.356375099599777}),
#  ('AR9K6SJ1187B989A32',
#   'funk soul',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.5411284518621801}),
#  ('AR9K6SJ1187B989A32',
#   'mondiovision',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.723395749674015}),
#  ('AR9K6SJ1187B989A32',
#   'vocal',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.7233777267260317}),
#  ('AR9K6SJ1187B989A32',
#   'new jersey',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.6505323077187276}),
#  ('AR9K6SJ1187B989A32',
#   'male vocalist',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.8914652670943765}),
#  ('AR9K6SJ1187B989A32',
#   'rock',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.8742212141662115}),
#  ('AR9K6SJ1187B989A32',
#   'pop',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.8203237117270074}),
#  ('AR9K6SJ1187B989A32',
#   'disco',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.9533954616774333}),
#  ('AR9K6SJ1187B989A32',
#   'hip hop',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.8721426331953708}),
#  ('AR9K6SJ1187B989A32',
#   'soft rock',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 1.0}),
#  ('AR9K6SJ1187B989A32',
#   'stand-up comedy',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.8048367956271225}),
#  ('AR9K6SJ1187B989A32',
#   'united states',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.6849599775055086}),
#  ('AR9K6SJ1187B989A32',
#   'world reggae',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.398735666605682}),
#  ('AR9K6SJ1187B989A32',
#   '60s',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.8002011095002787}),
#  ('AR9K6SJ1187B989A32',
#   'classic rock',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.8989036541650954}),
#  ('AR9K6SJ1187B989A32',
#   'TRBBXXC128F427044F',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'song_hotttnesss': 0.22096654906218638,
#    'weight': 1}),
#  ('AR9K6SJ1187B989A32',
#   'spoken word',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.8971133825151143}),
#  ('AR9K6SJ1187B989A32',
#   'soul',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.7718585711990672}),
#  ('AR9K6SJ1187B989A32',
#   'poetry',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.9127217596921702}),
#  ('AR9K6SJ1187B989A32',
#   'funk',
#   {'artist_familiarity': 0.4858832058048417,
#    'artist_hotttnesss': 0.2822214801855799,
#    'weight': 0.8789864773873013}),
#  ('jazz blues',
#   'AR97EHA1187B98AD5F',
#   {'artist_familiarity': 0.5217122143644578,
#    'artist_hotttnesss': 0.3513450770925733,
#    'weight': 0.47651811694001284}),
#  ('jazz blues',
#   'ARGY96L1187FB410ED',
#   {'artist_familiarity': 0.5902437967911479,
#    'artist_hotttnesss': 0.3874232710097214,
#    'weight': 0.902886603782694}),
#  ('jazz blues',
#   'ARWIMT21187B9B5AEC',
#   {'artist_familiarity': 0.594464632807191,
#    'artist_hotttnesss': 0.3645865754085436,
#    'weight': 0.9373482017947902}),
#  ('jazz blues',
#   'ARUP17W1187B98CAB9',
#   {'artist_familiarity': 0.5273391834991505,
#    'artist_hotttnesss': 0.31055608317952577,
#    'weight': 0.8033923340196559}),
#  ('ARKZJ301187FB521B2',
#   'alternative',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.33928888529399354}),
#  ('ARKZJ301187FB521B2',
#   'piano',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.40427130794877786}),
#  ('ARKZJ301187FB521B2',
#   'pop',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.8737341099929277}),
#  ('ARKZJ301187FB521B2',
#   'ska',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 1.0}),
#  ('ARKZJ301187FB521B2',
#   'electropop',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.5921506768386369}),
#  ('ARKZJ301187FB521B2',
#   'smooth',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.35328654075315197}),
#  ('ARKZJ301187FB521B2',
#   'vocal',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.35582743698640956}),
#  ('ARKZJ301187FB521B2',
#   'electro',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.46712340853216033}),
#  ('ARKZJ301187FB521B2',
#   'england',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.8323913982162262}),
#  ('ARKZJ301187FB521B2',
#   'guitar',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.313079900572596}),
#  ('ARKZJ301187FB521B2',
#   'party music',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.33933785976011843}),
#  ('ARKZJ301187FB521B2',
#   'jazz',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.40789960444551926}),
#  ('ARKZJ301187FB521B2',
#   'rock',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.38904570344402645}),
#  ('ARKZJ301187FB521B2',
#   'london',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.8323889961932935}),
#  ('ARKZJ301187FB521B2',
#   'female',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.43033210112781006}),
#  ('ARKZJ301187FB521B2',
#   'country',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.3802266602541828}),
#  ('ARKZJ301187FB521B2',
#   'retro',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.3296928454818658}),
#  ('ARKZJ301187FB521B2',
#   'TRAWAQB128F930D7F7',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'song_hotttnesss': nan,
#    'weight': 1}),
#  ('ARKZJ301187FB521B2',
#   'punk',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.3141929450859515}),
#  ('ARKZJ301187FB521B2',
#   'funk',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.4717369600443661}),
#  ('ARKZJ301187FB521B2',
#   'funny',
#   {'artist_familiarity': 0.6768859314057637,
#    'artist_hotttnesss': 0.5354083792298137,
#    'weight': 0.36855052582082914}),
#  ('eastern europe rock',
#   'AREUYDJ1187B9BA040',
#   {'artist_familiarity': 0.5086362291338029,
#    'artist_hotttnesss': 0.3721191186306522,
#    'weight': 0.5168256863022391}),
#  ('female singer-songwriter',
#   'ARSTSEH121318C5B01',
#   {'artist_familiarity': 0.6344417131498283,
#    'artist_hotttnesss': 0.42311794435199923,
#    'weight': 0.657521372297322}),
#  ('AROBSHL1187B9AFB01',
#   'emo',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.9896878606183378}),
#  ('AROBSHL1187B9AFB01',
#   'punk',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.8038307333724968}),
#  ('AROBSHL1187B9AFB01',
#   'hard rock',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.7950986774887095}),
#  ('AROBSHL1187B9AFB01',
#   'death metal',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.8030790963823431}),
#  ('AROBSHL1187B9AFB01',
#   'experimental',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.6747216012856204}),
#  ('AROBSHL1187B9AFB01',
#   'happy hardcore',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.9209057177750206}),
#  ('AROBSHL1187B9AFB01',
#   'heavy metal',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 1.0}),
#  ('AROBSHL1187B9AFB01',
#   'instrumental',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.6376649667371347}),
#  ('AROBSHL1187B9AFB01',
#   'pop punk',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.9669634550703797}),
#  ('AROBSHL1187B9AFB01',
#   'nu metal',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.841920983575545}),
#  ('AROBSHL1187B9AFB01',
#   'rock',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.7781167731314799}),
#  ('AROBSHL1187B9AFB01',
#   'alternative',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.7117759298615567}),
#  ('AROBSHL1187B9AFB01',
#   'hardcore punk',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.9549082292617379}),
#  ('AROBSHL1187B9AFB01',
#   'pop',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.6963970725052343}),
#  ('AROBSHL1187B9AFB01',
#   'indie rock',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.7314515865986588}),
#  ('AROBSHL1187B9AFB01',
#   'metalcore',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.9287409963064249}),
#  ('AROBSHL1187B9AFB01',
#   'beautiful',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.6963970880205087}),
#  ('AROBSHL1187B9AFB01',
#   'american',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.696396593651173}),
#  ('AROBSHL1187B9AFB01',
#   'alternative metal',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.8471455631524135}),
#  ('AROBSHL1187B9AFB01',
#   'acoustic',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.6963967310968103}),
#  ('AROBSHL1187B9AFB01',
#   'TRBEEEP128F426C17D',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'song_hotttnesss': 0.7471817957067781,
#    'weight': 1}),
#  ('AROBSHL1187B9AFB01',
#   'grindcore',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.8472398100543335}),
#  ('AROBSHL1187B9AFB01',
#   'indie',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.6747215392309156}),
#  ('AROBSHL1187B9AFB01',
#   'metal',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.7334513525370653}),
#  ('AROBSHL1187B9AFB01',
#   'screamo',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.9933735101182043}),
#  ('AROBSHL1187B9AFB01',
#   'alternative rock',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.8139789218791119}),
#  ('AROBSHL1187B9AFB01',
#   'melodic hardcore',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.9341880086773856}),
#  ('AROBSHL1187B9AFB01',
#   'emocore',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.7787454492487891}),
#  ('AROBSHL1187B9AFB01',
#   'melodic metalcore',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.9209057177750206}),
#  ('AROBSHL1187B9AFB01',
#   'pop rock',
#   {'artist_familiarity': 0.8302362167035976,
#    'artist_hotttnesss': 0.5692399537354433,
#    'weight': 0.8605726876225122}),
#  ('ethnic fusion',
#   'ARN3O411187FB4D859',
#   {'artist_familiarity': 0.5613709072283409,
#    'artist_hotttnesss': 0.36553375619798023,
#    'weight': 0.6969042935824343}),
#  ('ethnic fusion',
#   'AR9O0LF1187B99D0D1',
#   {'artist_familiarity': 0.6380733763602572,
#    'artist_hotttnesss': 0.4179673472629846,
#    'weight': 0.6281607924356386}),
#  ('ethnic fusion',
#   'ARQZRQ11187B9A5918',
#   {'artist_familiarity': 0.6087016157203143,
#    'artist_hotttnesss': 0.4413715986716032,
#    'weight': 0.6383857764576764}),
#  ('ethnic fusion',
#   'ARJ3TAF1187FB4AAB1',
#   {'artist_familiarity': 0.3872425947084871,
#    'artist_hotttnesss': 0.18767630092926466,
#    'weight': 0.6180930446662802}),
#  ('ethno',
#   'ARRHZLW11E2835E799',
#   {'artist_familiarity': 0.4485305418592766,
#    'artist_hotttnesss': 0.38528564261478293,
#    'weight': 0.6032065852612064}),
#  ('ARHZCG01187B99E4DE',
#   'urban',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.6789940005359874}),
#  ('ARHZCG01187B99E4DE',
#   'nu jazz',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7772315427921958}),
#  ('ARHZCG01187B99E4DE',
#   'instrumental',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.5704084297985133}),
#  ('ARHZCG01187B99E4DE',
#   'rock',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7497096859491377}),
#  ('ARHZCG01187B99E4DE',
#   'contemporary jazz',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.8019345899057995}),
#  ('ARHZCG01187B99E4DE',
#   'french',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.563898677002287}),
#  ('ARHZCG01187B99E4DE',
#   'pop',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.6407380379494343}),
#  ('ARHZCG01187B99E4DE',
#   'ambient',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.6006979715138293}),
#  ('ARHZCG01187B99E4DE',
#   'guitar',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.5704079690426618}),
#  ('ARHZCG01187B99E4DE',
#   'experimental',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.6006978374640838}),
#  ('ARHZCG01187B99E4DE',
#   'american',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.5704083050878012}),
#  ('ARHZCG01187B99E4DE',
#   'united states',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.704561638981721}),
#  ('ARHZCG01187B99E4DE',
#   'jazz rock',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7432319809379091}),
#  ('ARHZCG01187B99E4DE',
#   'acoustic',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.6006977066406124}),
#  ('ARHZCG01187B99E4DE',
#   'acid jazz',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.727887784200554}),
#  ('ARHZCG01187B99E4DE',
#   'pop rap',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.8196526097749813}),
#  ('ARHZCG01187B99E4DE',
#   'latin',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.5704080465992009}),
#  ('ARHZCG01187B99E4DE',
#   'fusion jazz',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7716454840927232}),
#  ('ARHZCG01187B99E4DE',
#   'fusion',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.8160090011614046}),
#  ('ARHZCG01187B99E4DE',
#   'funk rock',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7716454840927232}),
#  ('ARHZCG01187B99E4DE',
#   'reggae',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.6816720783038885}),
#  ('ARHZCG01187B99E4DE',
#   'electronic',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7013163059698315}),
#  ('ARHZCG01187B99E4DE',
#   'soul jazz',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.9086602129945748}),
#  ('ARHZCG01187B99E4DE',
#   'soul',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7281986626907674}),
#  ('ARHZCG01187B99E4DE',
#   'progressive rock',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.6746898023931529}),
#  ('ARHZCG01187B99E4DE',
#   'funk',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.8358996898988555}),
#  ('ARHZCG01187B99E4DE',
#   'germany',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.6309869967817576}),
#  ('ARHZCG01187B99E4DE',
#   'quiet storm',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.8869669293490106}),
#  ('ARHZCG01187B99E4DE',
#   'easy listening',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7444571281818394}),
#  ('ARHZCG01187B99E4DE',
#   'bass',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.618414664215021}),
#  ('ARHZCG01187B99E4DE',
#   'psychedelic rock',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7488194628641753}),
#  ('ARHZCG01187B99E4DE',
#   'downtempo',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.718297696090099}),
#  ('ARHZCG01187B99E4DE',
#   'electro',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7425636549052863}),
#  ('ARHZCG01187B99E4DE',
#   'jazz funk',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 1.0}),
#  ('ARHZCG01187B99E4DE',
#   'smooth jazz',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.9247163287322154}),
#  ('ARHZCG01187B99E4DE',
#   '70s',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.570408470366152}),
#  ('ARHZCG01187B99E4DE',
#   'disco',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.8548263400660295}),
#  ('ARHZCG01187B99E4DE',
#   'hip hop',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.748410396030908}),
#  ('ARHZCG01187B99E4DE',
#   'soundtrack',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7062322079403732}),
#  ('ARHZCG01187B99E4DE',
#   'TRAUGWE128F42670DB',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'song_hotttnesss': 0.3725300393660796,
#    'weight': 1}),
#  ('ARHZCG01187B99E4DE',
#   'synthpop',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.612366808733878}),
#  ('ARHZCG01187B99E4DE',
#   'classic rock',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7103951132206193}),
#  ('ARHZCG01187B99E4DE',
#   'jazz',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.8550450907648569}),
#  ('ARHZCG01187B99E4DE',
#   'nederland',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.6734077541467401}),
#  ('ARHZCG01187B99E4DE',
#   'post-bop',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.6646990062363327}),
#  ('ARHZCG01187B99E4DE',
#   'jazz fusion',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.8283138559924892}),
#  ('ARHZCG01187B99E4DE',
#   'latin jazz',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7716454840927232}),
#  ('ARHZCG01187B99E4DE',
#   'pop rock',
#   {'artist_familiarity': 0.6578831163450102,
#    'artist_hotttnesss': 0.4648862571321493,
#    'weight': 0.7749390134291149}),
#  ('TRASKOZ128F42ADA15',
#   'ARXTM8U1187B99F200',
#   {'artist_familiarity': 0.5463104236993335,
#    'artist_hotttnesss': 0.3099193396540712,
#    'song_hotttnesss': nan,
#    'weight': 1}),
#  ('christian acoustic',
#   'ARLQ5EV1187FB4491D',
#   {'artist_familiarity': 0.5080586129066689,
#    'artist_hotttnesss': 0.3722985729468398,
#    'weight': 0.3792744099491056}),
#  ('ARJRF841187B9B7F9A',
#   'world',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.7147479629547632}),
#  ('ARJRF841187B9B7F9A',
#   'european',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.6764654296077024}),
#  ('ARJRF841187B9B7F9A',
#   'soundtrack',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 1.0}),
#  ('ARJRF841187B9B7F9A',
#   'composer',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.7668895640259153}),
#  ('ARJRF841187B9B7F9A',
#   'contemporary classical music',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.7864803201416055}),
#  ('ARJRF841187B9B7F9A',
#   'chanson',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.9542099648007851}),
#  ('ARJRF841187B9B7F9A',
#   'beautiful',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.6764685103519186}),
#  ('ARJRF841187B9B7F9A',
#   'avant-garde',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.6764746187820384}),
#  ('ARJRF841187B9B7F9A',
#   'movie score composer',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.6207812847827688}),
#  ('ARJRF841187B9B7F9A',
#   'instrumental',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.6764730692270202}),
#  ('ARJRF841187B9B7F9A',
#   'jazz',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.7624979813879392}),
#  ('ARJRF841187B9B7F9A',
#   'neoclassical',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.6308707574720887}),
#  ('ARJRF841187B9B7F9A',
#   'modern',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.6364852135850664}),
#  ('ARJRF841187B9B7F9A',
#   'united states',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.7453319324718898}),
#  ('ARJRF841187B9B7F9A',
#   'pop',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.7147485708767805}),
#  ('ARJRF841187B9B7F9A',
#   'original score',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.7544365415994226}),
#  ('ARJRF841187B9B7F9A',
#   'vienna',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.5955334571447796}),
#  ('ARJRF841187B9B7F9A',
#   'film score composer',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.6419752787508618}),
#  ('ARJRF841187B9B7F9A',
#   'big band',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.7315599265123085}),
#  ('ARJRF841187B9B7F9A',
#   'classical',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.7653438922485959}),
#  ('ARJRF841187B9B7F9A',
#   'TRAKOYE128F4229B67',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'song_hotttnesss': 0.0,
#    'weight': 1}),
#  ('ARJRF841187B9B7F9A',
#   'german pop',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.9690358821240733}),
#  ('ARJRF841187B9B7F9A',
#   'film music',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.8215585566907618}),
#  ('ARJRF841187B9B7F9A',
#   'movie score',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.5788421957571164}),
#  ('ARJRF841187B9B7F9A',
#   'folk',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.7530226988972664}),
#  ('ARJRF841187B9B7F9A',
#   'easy listening',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.8964060636895543}),
#  ('ARJRF841187B9B7F9A',
#   'country',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.7147470191044181}),
#  ('ARJRF841187B9B7F9A',
#   'romantic',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.6764656643319349}),
#  ('ARJRF841187B9B7F9A',
#   'film score',
#   {'artist_familiarity': 0.471894875514916,
#    'artist_hotttnesss': 0.35549113602485716,
#    'weight': 0.594494848666894}),
#  ('original score',
#   'ARQ3VBJ1187FB3FE55',
#   {'artist_familiarity': 0.6134649321348336,
#    'artist_hotttnesss': 0.4121155534594195,
#    'weight': 0.6191500739978584}),
#  ('original score',
#   'ARMMKRK1187B996E31',
#   {'artist_familiarity': 0.3518151232337846,
#    'artist_hotttnesss': 0.27094070676741144,
#    'weight': 0.5359578215086427}),
#  ('original score',
#   'AR1PCLK1187FB5BBFF',
#   {'artist_familiarity': 0.6987704777958721,
#    'artist_hotttnesss': 0.39945172400502926,
#    'weight': 0.7982938178486796}),
#  ('original score',
#   'ARJJKAA1187B9ADAF1',
#   {'artist_familiarity': 0.549033905412002,
#    'artist_hotttnesss': 0.3766641058581093,
#    'weight': 0.598113925249473}),
#  ('original score',
#   'ARSZIBW1187B994053',
#   {'artist_familiarity': 0.6113815948790435,
#    'artist_hotttnesss': 0.4453218782746221,
#    'weight': 0.7701904458618793}),
#  ('original score',
#   'AR9ILJF1187B9B80ED',
#   {'artist_familiarity': 0.6118014714600088,
#    'artist_hotttnesss': 0.39904208143240477,
#    'weight': 0.7496970551258466}),
#  ('original score',
#   'ARLIIVS1187FB5583B',
#   {'artist_familiarity': 0.7113800959726605,
#    'artist_hotttnesss': 0.4662243003452983,
#    'weight': 0.5193794439153596}),
#  ('AR74Q3R1187B9B24C3',
#   'female vocalist',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.31497459091101926}),
#  ('AR74Q3R1187B9B24C3',
#   'melodic',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.41347661853344986}),
#  ('AR74Q3R1187B9B24C3',
#   'soundtrack',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.4627523300996565}),
#  ('AR74Q3R1187B9B24C3',
#   'progressive',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.3591164075555074}),
#  ('AR74Q3R1187B9B24C3',
#   'sympho black metal',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 1.0}),
#  ('AR74Q3R1187B9B24C3',
#   'orchestra',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.4529260070994428}),
#  ('AR74Q3R1187B9B24C3',
#   'heavy metal',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.8765367403227835}),
#  ('AR74Q3R1187B9B24C3',
#   'instrumental',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.3832184432679326}),
#  ('AR74Q3R1187B9B24C3',
#   'emotional',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.3837729534140406}),
#  ('AR74Q3R1187B9B24C3',
#   'rock',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.7566562352362483}),
#  ('AR74Q3R1187B9B24C3',
#   'female vocals',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.35501606504531985}),
#  ('AR74Q3R1187B9B24C3',
#   'pop',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.3174584203678251}),
#  ('AR74Q3R1187B9B24C3',
#   'progressive metal',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.9105707169843499}),
#  ('AR74Q3R1187B9B24C3',
#   'guitar',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.4585679524585746}),
#  ('AR74Q3R1187B9B24C3',
#   'power metal',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.6217927696583166}),
#  ('AR74Q3R1187B9B24C3',
#   'classical',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.4345200942024737}),
#  ('AR74Q3R1187B9B24C3',
#   'symphonic metal',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.691666106576533}),
#  ('AR74Q3R1187B9B24C3',
#   'cover',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.35944776141851353}),
#  ('AR74Q3R1187B9B24C3',
#   'finish',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.7420596806834482}),
#  ('AR74Q3R1187B9B24C3',
#   'classic',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.35750441498058577}),
#  ('AR74Q3R1187B9B24C3',
#   'vocal',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.4247262576926975}),
#  ('AR74Q3R1187B9B24C3',
#   'folk',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.3728027499401829}),
#  ('AR74Q3R1187B9B24C3',
#   'gothic',
#   {'artist_familiarity': 0.8019892159693104,
#    'artist_hotttnesss': 0.5803452713778326,
#    'weight': 0.44485130845501386}),
#  ('AR74Q3R1187B9B24C3',
#   'heavy',
# ...
#    'artist_hotttnesss': 0.5608197692618571,
#    'weight': 0.2807285052996006}),
#  ('united states',
#   'ARF3PG41187FB4B0B4',
#   {'artist_familiarity': 0.4182825139804495,
#    'artist_hotttnesss': 0.3203456288328348,
#    'weight': 0.6824728945580693}),
#  ('united states',
#   'ARDY3451187B9A0226',
#   {'artist_familiarity': 0.6038391696904002,
#    'artist_hotttnesss': 0.39579127377388607,
#    'weight': 0.6699971304594543}),
#  ('united states',
#   'ARLCEUJ11F4C842D6A',
#   {'artist_familiarity': 0.5375871451231229,
#    'artist_hotttnesss': 0.30643862922766407,
#    'weight': 0.7696373062562528}),
#  ('united states',
#   'ARQKBSH1187B9B4B99',
#   {'artist_familiarity': 0.44437243088957856,
#    'artist_hotttnesss': 0.29533281954469626,
#    'weight': 0.6380580345576901}),
#  ('united states',
#   'AR0S7TA1187FB4D024',
#   {'artist_familiarity': 0.831240276991066,
#    'artist_hotttnesss': 0.7257460818523215,
#    'weight': 0.7480348904766891}),
#  ('united states',
#   'AR0FGL21187FB56301',
#   {'artist_familiarity': 0.4221030433845711,
#    'artist_hotttnesss': 0.3405238268004334,
#    'weight': 0.625972939203789}),
#  ('united states',
#   'AR0RCMP1187FB3F427',
#   {'artist_familiarity': 0.5237146369702328,
#    'artist_hotttnesss': 0.3846110839616365,
#    'weight': 0.8093024046282956}),
#  ('united states',
#   'ARHONG11187FB3B120',
#   {'artist_familiarity': 0.6657283364248289,
#    'artist_hotttnesss': 0.45694055844157816,
#    'weight': 0.6655254192696093}),
#  ('united states',
#   'ARPBNLO1187FB3D52F',
#   {'artist_familiarity': 0.5934960438312681,
#    'artist_hotttnesss': 0.4048973354801111,
#    'weight': 0.7471956460398571}),
#  ('united states',
#   'ARFSPOV1187B9B2363',
#   {'artist_familiarity': 0.8036192618435595,
#    'artist_hotttnesss': 0.5312132868052581,
#    'weight': 0.268835666100189}),
#  ('united states',
#   'ARZH0R61187FB422AE',
#   {'artist_familiarity': 0.5589162440267129,
#    'artist_hotttnesss': 0.3925798777553678,
#    'weight': 0.625487955283489}),
#  ('united states',
#   'AR97EHA1187B98AD5F',
#   {'artist_familiarity': 0.5217122143644578,
#    'artist_hotttnesss': 0.3513450770925733,
#    'weight': 0.5821577810871145}),
#  ('united states',
#   'ARPCEWC11F4C83EEA7',
#   {'artist_familiarity': 0.5228218177630841,
#    'artist_hotttnesss': 0.3555029950198822,
#    'weight': 0.7458341272300792}),
#  ('united states',
#   'AR0B3RS1187FB48F5D',
#   {'artist_familiarity': 0.8220349621993864,
#    'artist_hotttnesss': 0.4770197895144525,
#    'weight': 0.3317669311495081}),
#  ('united states',
#   'ARUBDQW1187B98D775',
#   {'artist_familiarity': 0.5261270332019164,
#    'artist_hotttnesss': 0.37231499597754764,
#    'weight': 0.7839163661530302}),
#  ('united states',
#   'ARH3S5S1187FB4F76B',
#   {'artist_familiarity': 0.8258053861924912,
#    'artist_hotttnesss': 0.6613829243380245,
#    'weight': 0.3706035765687649}),
#  ('united states',
#   'ARUBX2Y1187B99CD25',
#   {'artist_familiarity': 0.4320747960152752,
#    'artist_hotttnesss': 0.29939278719775364,
#    'weight': 0.5552694396900948}),
#  ('united states',
#   'ARYF20K1187B9B76BD',
#   {'artist_familiarity': 0.6680202487233046,
#    'artist_hotttnesss': 0.5169637307383411,
#    'weight': 0.4909254758599178}),
#  ('united states',
#   'ARMBYRO1187FB57419',
#   {'artist_familiarity': 0.4083890223759677,
#    'artist_hotttnesss': 0.13924739387110993,
#    'weight': 0.6299763324604651}),
#  ('united states',
#   'AR8U8G41187B9A833B',
#   {'artist_familiarity': 0.6205019249164577,
#    'artist_hotttnesss': 0.3018470948111364,
#    'weight': 0.5642627950959811}),
#  ('united states',
#   'ARHT0B11187B993CB3',
#   {'artist_familiarity': 0.464994319368088,
#    'artist_hotttnesss': 0.3447211111720015,
#    'weight': 0.5684706661183716}),
#  ('united states',
#   'ARLLANI1187FB5116F',
#   {'artist_familiarity': 0.39076083985338955,
#    'artist_hotttnesss': 0.2076758378001374,
#    'weight': 0.6522089172209993}),
#  ('united states',
#   'ARE2QID1187B98FA19',
#   {'artist_familiarity': 0.5190000723734253,
#    'artist_hotttnesss': 0.35303574014515915,
#    'weight': 0.5720417910300543}),
#  ('united states',
#   'ARR2BHS1187B9B8FA7',
#   {'artist_familiarity': 0.6528604657461411,
#    'artist_hotttnesss': 0.3835574697768149,
#    'weight': 0.7617696451155176}),
#  ('united states',
#   'ARALP6I1187B989E27',
#   {'artist_familiarity': 0.66229870965635,
#    'artist_hotttnesss': 0.379137555624937,
#    'weight': 0.7140010516158569}),
#  ('united states',
#   'ARHB1961187B9B1732',
#   {'artist_familiarity': 0.5693296873667095,
#    'artist_hotttnesss': 0.39488108337774364,
#    'weight': 0.5753724717922882}),
#  ('united states',
#   'ARLNSD41187FB4D9A0',
#   {'artist_familiarity': 0.42196043731099453,
#    'artist_hotttnesss': 0.23274867834736324,
#    'weight': 0.673665835349959}),
#  ('united states',
#   'ARWIMT21187B9B5AEC',
#   {'artist_familiarity': 0.594464632807191,
#    'artist_hotttnesss': 0.3645865754085436,
#    'weight': 0.6830247410577266}),
#  ('united states',
#   'AREENKN1187B98F35D',
#   {'artist_familiarity': 0.5578751684218033,
#    'artist_hotttnesss': 0.3593247265042633,
#    'weight': 0.766513886730421}),
#  ('united states',
#   'AR3N2H11187B98AFBA',
#   {'artist_familiarity': 0.4796207472295076,
#    'artist_hotttnesss': 0.3243342048085304,
#    'weight': 0.5946380926067985}),
#  ('united states',
#   'ARCEEC91187B9AC4FB',
#   {'artist_familiarity': 0.6091238748175969,
#    'artist_hotttnesss': 0.4623678399869238,
#    'weight': 0.7911389442569713}),
#  ('united states',
#   'ARVML4B1187FB52324',
#   {'artist_familiarity': 0.5303556678749041,
#    'artist_hotttnesss': 0.39717904259160935,
#    'weight': 0.7413805733312}),
#  ('united states',
#   'ARUAKAN1187FB48204',
#   {'artist_familiarity': 0.589995161887244,
#    'artist_hotttnesss': 0.30771167908554087,
#    'weight': 0.6407059479232693}),
#  ('united states',
#   'ARUJZFJ1187B9B135F',
#   {'artist_familiarity': 0.8700337966178991,
#    'artist_hotttnesss': 0.5463261195519407,
#    'weight': 0.2742718808522977}),
#  ('united states',
#   'AR6YDKV1187B989230',
#   {'artist_familiarity': 0.4823560425909108,
#    'artist_hotttnesss': 0.3500785789894733,
#    'weight': 0.7095523511770031}),
#  ('united states',
#   'AR1X2H01187B98CCF2',
#   {'artist_familiarity': 0.5024531765214763,
#    'artist_hotttnesss': 0.3915853290262099,
#    'weight': 0.5713149485661325}),
#  ('united states',
#   'AR7AOEJ1187FB3D279',
#   {'artist_familiarity': 0.5794241084560094,
#    'artist_hotttnesss': 0.3864410971038427,
#    'weight': 0.7208230987818908}),
#  ('united states',
#   'ARD0S291187B9B7BF5',
#   {'artist_familiarity': 0.5564956019129572,
#    'artist_hotttnesss': 0.2619411773808474,
#    'weight': 0.7002748096879295}),
#  ('united states',
#   'ARZAHDN1187B9B4BED',
#   {'artist_familiarity': 0.6491557735314687,
#    'artist_hotttnesss': 0.34593570218633163,
#    'weight': 0.7017780815248317}),
#  ('united states',
#   'ARJDUON1187B989F69',
#   {'artist_familiarity': 0.40799723925500914,
#    'artist_hotttnesss': 0.3331088294667733,
#    'weight': 0.5194300963760999}),
#  ('united states',
#   'ARB8H82119B34032E1',
#   {'artist_familiarity': 0.6793950514218868,
#    'artist_hotttnesss': 0.3909636117315853,
#    'weight': 0.6845424201973198}),
#  ('united states',
#   'ARLQ5EV1187FB4491D',
#   {'artist_familiarity': 0.5080586129066689,
#    'artist_hotttnesss': 0.3722985729468398,
#    'weight': 0.5718767715905466}),
#  ('united states',
#   'ARZ3BA51187B998A3E',
#   {'artist_familiarity': 0.35969351113356596,
#    'artist_hotttnesss': 0.0,
#    'weight': 0.6096689069262653}),
#  ('united states',
#   'AROUOZZ1187B9ABE51',
#   {'artist_familiarity': 0.5888271005018058,
#    'artist_hotttnesss': 0.3796711247498673,
#    'weight': 0.6756799899364814}),
#  ('united states',
#   'ARRXADQ1187FB38F22',
#   {'artist_familiarity': 0.6251657623913732,
#    'artist_hotttnesss': 0.44273927881605984,
#    'weight': 0.6226438160617529}),
#  ('united states',
#   'ARD9THI1187B98EAD0',
#   {'artist_familiarity': 0.44592627458772754,
#    'artist_hotttnesss': 0.23381943778669392,
#    'weight': 0.666369966128709}),
#  ('united states',
#   'ARQOC971187B9910FA',
#   {'artist_familiarity': 0.7033494404116145,
#    'artist_hotttnesss': 0.4983953383497739,
#    'weight': 0.7250799011476872}),
#  ('united states',
#   'ARPFHN61187FB575F6',
#   {'artist_familiarity': 0.9020629269028733,
#    'artist_hotttnesss': 0.5546332305741549,
#    'weight': 0.2861931659970793}),
#  ('united states',
#   'ARWQQYJ1187B9ADC4C',
#   {'artist_familiarity': 0.7752687687216739,
#    'artist_hotttnesss': 0.41501140026139904,
#    'weight': 0.43885760308563054}),
#  ('united states',
#   'ARNVH8S1187FB52F86',
#   {'artist_familiarity': 0.6178701163443497,
#    'artist_hotttnesss': 0.36366811024462387,
#    'weight': 0.6871306076909016}),
#  ('united states',
#   'ARBU6D71187B9B5319',
#   {'artist_familiarity': 0.5756865010660667,
#    'artist_hotttnesss': 0.3829764579671415,
#    'weight': 0.5746517714244925}),
#  ('united states',
#   'ARCEAJY1187FB4DF61',
#   {'artist_familiarity': 0.7704939626476507,
#    'artist_hotttnesss': 0.5199530010138332,
#    'weight': 0.7168034814639599}),
#  ('united states',
#   'ARDVZTE1187FB5A0A1',
#   {'artist_familiarity': 0.8392976775681696,
#    'artist_hotttnesss': 0.7188914556702095,
#    'weight': 0.3031594637858174}),
#  ('united states',
#   'ARBE5BJ1187B98BCFD',
#   {'artist_familiarity': 0.41008203986183206,
#    'artist_hotttnesss': 0.2788650405012439,
#    'weight': 0.6890321081792894}),
#  ('united states',
#   'ARNVM131187B990D2B',
#   {'artist_familiarity': 0.6282744489330068,
#    'artist_hotttnesss': 0.42883453621653383,
#    'weight': 0.8255651228177392}),
#  ('united states',
#   'AREP8KM1187B9A3A7B',
#   {'artist_familiarity': 0.5749843939258663,
#    'artist_hotttnesss': 0.31701649456707315,
#    'weight': 0.8125261074383864}),
#  ('united states',
#   'AR3EABF1187B98AD35',
#   {'artist_familiarity': 0.45178440595419245,
#    'artist_hotttnesss': 0.3609162300146392,
#    'weight': 0.6840816567817565}),
#  ('united states',
#   'AREEUJE1241B9C773F',
#   {'artist_familiarity': 0.26289641216909604,
#    'artist_hotttnesss': 0.3075702943770519,
#    'weight': 0.6922087618204585}),
#  ('united states',
#   'ARCZ20M1187FB49687',
#   {'artist_familiarity': 0.6247237675785525,
#    'artist_hotttnesss': 0.4035096733630853,
#    'weight': 0.6323280682115071}),
#  ('united states',
#   'ARMLEY51187FB5BF8F',
#   {'artist_familiarity': 0.6256343816115406,
#    'artist_hotttnesss': 0.4168717661517543,
#    'weight': 0.6726105279920188}),
#  ('united states',
#   'AR9OLFX1187B9A5762',
#   {'artist_familiarity': 0.49883497525793824,
#    'artist_hotttnesss': 0.37996076697507797,
#    'weight': 0.5606556415919214}),
#  ('united states',
#   'ARQXR6R1187FB46FD6',
#   {'artist_familiarity': 0.6900801237874965,
#    'artist_hotttnesss': 0.4667756219262354,
#    'weight': 0.8042696988618281}),
#  ('united states',
#   'AR65OLD1187FB5C103',
#   {'artist_familiarity': 0.8598733119890262,
#    'artist_hotttnesss': 0.5330853751571502,
#    'weight': 0.2519915290166694}),
#  ('united states',
#   'ARSZIBW1187B994053',
#   {'artist_familiarity': 0.6113815948790435,
#    'artist_hotttnesss': 0.4453218782746221,
#    'weight': 0.7374202974524212}),
#  ('united states',
#   'ARM5JLS1187FB3615B',
#   {'artist_familiarity': 0.6061186456969245,
#    'artist_hotttnesss': 0.4091960356545295,
#    'weight': 0.691624877976522}),
#  ('united states',
#   'ARYBUAO1187FB3F4EB',
#   {'artist_familiarity': 0.5700167028852964,
#    'artist_hotttnesss': 0.39376269898655997,
#    'weight': 0.5778794951759187}),
#  ('united states',
#   'AR8I87E1187FB57E2E',
#   {'artist_familiarity': 0.45240058187088594,
#    'artist_hotttnesss': 0.40146205320734124,
#    'weight': 0.8091648743605074}),
#  ('united states',
#   'ARWIN9D1187B98E544',
#   {'artist_familiarity': 0.500510256360053,
#    'artist_hotttnesss': 0.41478386309228343,
#    'weight': 0.5530464809206689}),
#  ('united states',
#   'AR52QY11187B99FC59',
#   {'artist_familiarity': 0.5344436024147244,
#    'artist_hotttnesss': 0.3335846278352391,
#    'weight': 0.5917087375084166}),
#  ('united states',
#   'ARUT60Q1187B9B90E9',
#   {'artist_familiarity': 0.39885871321158833,
#    'artist_hotttnesss': 0.3410613992194141,
#    'weight': 0.3215164230300067}),
#  ('united states',
#   'ARY1VGA1187FB5A39E',
#   {'artist_familiarity': 0.5903603253945124,
#    'artist_hotttnesss': 0.3717867334568803,
#    'weight': 0.5965339286877649}),
#  ('united states',
#   'ARUP17W1187B98CAB9',
#   {'artist_familiarity': 0.5273391834991505,
#    'artist_hotttnesss': 0.31055608317952577,
#    'weight': 0.6584851719134859}),
#  ('united states',
#   'ARJ4B7V1187FB4CB90',
#   {'artist_familiarity': 0.4912562094922859,
#    'artist_hotttnesss': 0.3262082546201735,
#    'weight': 0.7997433687915967}),
#  ('united states',
#   'AR681HS1187FB5BBFE',
#   {'artist_familiarity': 0.5668139099960331,
#    'artist_hotttnesss': 0.46302507599424003,
#    'weight': 0.776879549847894}),
#  ('united states',
#   'ARJ87C21187B99B9D4',
#   {'artist_familiarity': 0.3995103920704494,
#    'artist_hotttnesss': 0.3237553945515314,
#    'weight': 0.6131452462658858}),
#  ('united states',
#   'ARMMKRK1187B996E31',
#   {'artist_familiarity': 0.3518151232337846,
#    'artist_hotttnesss': 0.27094070676741144,
#    'weight': 0.70363945642812}),
#  ('united states',
#   'ARB1KC91187FB38B13',
#   {'artist_familiarity': 0.551502069088444,
#    'artist_hotttnesss': 0.3517177511209014,
#    'weight': 0.28886650685313}),
#  ('united states',
#   'ARJVTRE1187B9959C0',
#   {'artist_familiarity': 0.7142014472093124,
#    'artist_hotttnesss': 0.49612334604345754,
#    'weight': 0.6566703693905424}),
#  ('united states',
#   'ARVLMSG1187B98E07E',
#   {'artist_familiarity': 0.5460127843008569,
#    'artist_hotttnesss': 0.3805567282061756,
#    'weight': 0.6182620399793279}),
#  ('united states',
#   'AR0WV4Y1187B99B806',
#   {'artist_familiarity': 0.4918359590583831,
#    'artist_hotttnesss': 0.38941401403392173,
#    'weight': 0.6307636838569393}),
#  ('united states',
#   'AR1WDRJ1187B9BA4B8',
#   {'artist_familiarity': 0.5033546141595812,
#    'artist_hotttnesss': 0.30150587751163294,
#    'weight': 0.720675627058753}),
#  ('united states',
#   'ARZM53A1187B9A1AE7',
#   {'artist_familiarity': 0.5886080865488486,
#    'artist_hotttnesss': 0.37361111191126956,
#    'weight': 0.6626085380591147}),
#  ('united states',
#   'ARS1DCR1187B9A4A56',
#   {'artist_familiarity': 0.43350762637871326,
#    'artist_hotttnesss': 0.2899029316087479,
#    'weight': 0.25241690874505474}),
#  ('united states',
#   'ARXGICZ1187FB444DD',
#   {'artist_familiarity': 0.35449610815774923,
#    'artist_hotttnesss': 0.24945364941116577,
#    'weight': 0.8378201168002379}),
#  ('united states',
#   'ARBFDJW1187B9AD27A',
#   {'artist_familiarity': 0.6231542839712871,
#    'artist_hotttnesss': 0.42935351499935154,
#    'weight': 0.6370940390562201}),
#  ('united states',
#   'ARVWNTI1269FB34C59',
#   {'artist_familiarity': 0.6126405242364219,
#    'artist_hotttnesss': 0.4367829494947106,
#    'weight': 0.33575562490769306}),
#  ('united states',
#   'ARUG6DV1187B992475',
#   {'artist_familiarity': 0.46705418466605936,
#    'artist_hotttnesss': 0.37455792647989944,
#    'weight': 0.6787430047858348}),
#  ('united states',
#   'ARS1OWB1187B99EEAD',
#   {'artist_familiarity': 0.717670524728552,
#    'artist_hotttnesss': 0.4793084593382274,
#    'weight': 0.737235592248315}),
#  ('united states',
#   'ARVQZNK11E2835CDAC',
#   {'artist_familiarity': 0.5493533768111833,
#    'artist_hotttnesss': 0.41712458371887273,
#    'weight': 0.7488022241195287}),
#  ('united states',
#   'AR7DFJP1187B992F13',
#   {'artist_familiarity': 0.7036648899166419,
#    'artist_hotttnesss': 0.44822358922684985,
#    'weight': 0.8153172293769602}),
#  ('united states',
#   'ARI8GY11187B988DF4',
#   {'artist_familiarity': 0.4478639288699045,
#    'artist_hotttnesss': 0.32443479443924456,
#    'weight': 0.6384567557607308}),
#  ('united states',
#   'ARFNXFR1187B98F6C1',
#   {'artist_familiarity': 0.3073761670859222,
#    'artist_hotttnesss': 0.2344886544537336,
#    'weight': 0.3411550038604266}),
#  ('united states',
#   'ARF4V431187FB3AA41',
#   {'artist_familiarity': 0.5164437797727629,
#    'artist_hotttnesss': 0.38666909170602387,
#    'weight': 0.6071111813701979}),
#  ('united states',
#   'ARXOKNT1187B9AA521',
#   {'artist_familiarity': 0.5433500129660529,
#    'artist_hotttnesss': 0.399265149721187,
#    'weight': 0.72879919204667}),
#  ('united states',
#   'ARIHI8H1187B9B0058',
#   {'artist_familiarity': 0.5037387899485233,
#    'artist_hotttnesss': 0.35929084897032304,
#    'weight': 0.6176857980973732}),
#  ...]

# %% [markdown]
# Notice the different attributes for the two different edge types in the above output.
#
# ### Draw the weighted network graph
#
# The weights will be used only for the `artist_id` and `artist_terms` connection. The `at_wt`, which are normalized across each `artist_id` will be used as the weights for the edges. For the `track` - `artist_id` edges, a standard weight of 1 is used. The weights will be represented by the `width` of the edges in the graph. The thicker the edge, the stronger the relationship. Also, a `spring_layout` is used which will ensure that the nodes are distributed so as to create an equilibrium state. In simpler terms, more connected (weight based) nodes will be at the centre while the lesser connected ones will be farther from the centre.

# %%
nx.draw(G_1,
        pos=nx.spring_layout(G_1), # Or spectral_layout, random_layout, shell_layout , spring_layout     
        with_labels = False, # True will have labels
        node_size=50, 
        alpha=0.8, 
        node_color = [G_1.node[node]['color'] for node in G_1],#node_color_values['color'],
        font_size = 7,
        font_color = 'black',
        font_family = 'arial',
        width = [edge[2]['weight'] for edge in G_1.edges(data = True)],
        edge_color = 'gray')

pyplot.show()

# %% [markdown]
# As can be seen from the network graph, the `artist_id` nodes (in sky blue) and many `artist_terms` nodes (in green yellow) are the most central in this weighted graph. This is as expected since the `artist_id` along with the `artist_terms` primarily define relationships and also have a higher degree, on an average, than the `track` nodes (in red) which have a degree of 1 (connected to a single artist with weight 1). The less important `artist_terms` and a handful of `artist_id` that are farther, from the centre, than the `track` nodes are less important to this network graph of the 500 songs subset of the MSS data.

# %%
print('The density of the graph: ',nx.density(G_1))
# Out:
# The density of the graph:  0.00404102919962428

# %% [markdown]
# However, this graph, although weighted, is not easy to work with for recommendation purposes. This is because of the three different node types that requires the modification of the inbuilt shortest-distance algorithms in `networkx`. After some failed attempts, it made sense to use the `track` - `track` relationship dataframe to create a weighted `track` - `track` network graph.
#
# ## Weighted Network Graph 2: only `track` - `track` relationship
#
# In the second network graph, only the `track` node will be represented. The weights between two `track` nodes are computed from the group aggregates of the `track` - `track` relationship data created in the notebook __`G_Final_2_Graph_Relationship_Data.ipynb`__ , using the rationale below.

# %% [markdown]
# ### The math behind the weights between two `track` nodes
#
#
# + A `track` node is always connected to an `artist_id` node.
# + Following which two `artist_id` nodes will be connected, if at all they are connected, via `n` `artist_terms` node. In other words,there will be `n` paths between the two artists (and also between the two tracks).
# + The next step is to logically define a mathematical formula to compute the weights between the two `track` nodes.
#     - Since the artist term weights are normalized for every artist, the weights will be different for the two paths reaching an `artist_terms` node from the two `artist_id` nodes. Considering that this is a path between two artists, we can add them up to compute the weight.
#     - But, there are two other attributes pertinent to each artist that could help make the weights even more effective for recommendation purposes. These are the `artist_hotttnesss` and `artist_familiarity`. These two attributes are normalized across all artists.
#     - Therefore, the most logical way to define the weight of a path between an `artist_id` node and an `artist_terms` node, that is reasonably normalized across the entire graph, would be to multiply the artist term weight (`at_wt`) by a factor that is representative of the normalized recognizability of an artist. This factor is defined to be the sum of the `artist_hotttnesss` and `artist_familiarity`.
#     - Thus, the mathematical formula for the weights between two `artist_id` nodes, and hence two `track` nodes, that are connected by `n` common terms, will be given by the formula below.
#
# \begin{equation}
# \sum_{i = 1}^{n}([(atw_{l})(i)*(familiarity_{l} + hotness_{l})(i) + (atw_{r})(i)*(familiarity_{r} + hotness_{r})(i)])
# \end{equation}
#
# which reduces to
#
# \begin{equation}
# (familiarity_{l} + hotness_{l})\sum_{i = 1}^{n}[(atw_l)(i)] + (familiarity_{r} + hotness_{r})\sum_{i = 1}^{n}[(atw_r)(i)],
# \end{equation}
#
# where the subscripts _r and _l denote the path to the artist_term from either direction.
#
# The term under summation is nothing but the aggregated sum of each `track` - `track` group weights, which we already have computed.
#
#
# + The key point to note here is that, the formula, in general, provides a higher weight if the two `artist_id` nodes that connect the two `track` nodes is the same. This would be true if the artist enjoys a reasonably high familarity and hotness. This means that, for recommendation, songs performed by the same artist has a higher probability of being recommended. However, in the event that the artist has a pretty poor rating, then there can be other artists with a much improved rating and connected to this artist through the artist terms, whose songs might be recommended.

# %% [markdown]
# ### Read the pickled data frames that hold the relationships and nodes

# %%
path = "C:/Users/ganes_000/Documents/MSBA/Spring 2016/MA 755/Pickle Files"
df_ss = pd.read_pickle(path+"/MSS_METADATA_SUBSET_500_TRACK_TRACK.pkl")

# %%
print('TRACK-TRACK Relationship \n ======================== \n',len(df_ss),'rows \n ----------------------\n',
      df_ss.columns)
print('\n ######################################## \n')
# Out:
# TRACK-TRACK Relationship
#  ========================
#  198840 rows
#  ----------------------
#  Index(['track_l', 'track_r', 'wt_l_sum', 'wt_r_sum', 'fam_l', 'fam_r', 'hot_l',
#        'hot_r', 'song_hot_l', 'song_hot_r', 'cnt_at', 'title_l', 'artist_id_l',
#        'artist_name_l', 'title_r', 'artist_id_r', 'artist_name_r',
#        'same_artist_flag'],
#       dtype='object')
#
#  ########################################

# %%
df_ss.head(10)
# Out:
#               track_l             track_r  wt_l_sum  wt_r_sum     fam_l  \
# 0  TRAAAVG12903CFA543  TRAACTB12903CAAF15  0.734100  0.724350  0.550514
# 1  TRAABJV128F1460C49  TRAACTB12903CAAF15  1.804455  2.608040  0.776676
# 2  TRAADLN128F14832E9  TRAACTB12903CAAF15  3.067252  4.877071  0.814830
# 3  TRAADLR12903CF8D7E  TRAACTB12903CAAF15  1.949940  2.312114  0.482356
# 4  TRAAENP128F147BF32  TRAACTB12903CAAF15  1.250377  2.040589  0.749318
# 5  TRAAGHM128EF35CF8E  TRAACTB12903CAAF15  3.283752  3.739735  0.408389
# 6  TRAAGOH128F42593CE  TRAACTB12903CAAF15  4.317186  4.545478  0.449324
# 7  TRAAGZU128EF360F47  TRAACTB12903CAAF15  0.706473  0.691292  0.420546
# 8  TRAAHEH128F427FCEF  TRAACTB12903CAAF15  2.292019  2.194105  0.138188
# 9  TRAAJJG128F4284B27  TRAACTB12903CAAF15  5.544593  5.923369  0.703349
#
#       fam_r     hot_l     hot_r  song_hot_l  song_hot_r  cnt_at  \
# 0  0.523715  0.422706  0.384611         NaN         0.0       1
# 1  0.523715  0.553072  0.384611         NaN         0.0       4
# 2  0.523715  0.735766  0.384611    0.834493         0.0       7
# 3  0.523715  0.350079  0.384611    0.000000         0.0       3
# 4  0.523715  0.481656  0.384611    0.226555         0.0       3
# 5  0.523715  0.139247  0.384611    0.198785         0.0       5
# 6  0.523715  0.343282  0.384611    0.382723         0.0       6
# 7  0.523715  0.313569  0.384611         NaN         0.0       1
# 8  0.523715  0.317811  0.384611         NaN         0.0       3
# 9  0.523715  0.498395  0.384611    0.466305         0.0       8
#
#                                   title_l         artist_id_l  \
# 0       Insatiable (Instrumental Version)  ARNTLGG11E2835DDB9
# 1                 Tonight Will Be Alright  ARIK43K1187B9AE54C
# 2           Angie (1993 Digital Remaster)  ARFCUN31187B9AD578
# 3                           Sabor Guajiro  AR6YDKV1187B989230
# 4  Movement 4 [from Kiss] (Album Version)  ARUI8651187B9ACF52
# 5                               Next Time  ARMBYRO1187FB57419
# 6                  You Feel Good All Over  ARLWR721187B9A03C9
# 7                        Caricia Y Herida  ARHFEBO11F50C4825A
# 8                       Ter\xc3\xa4slintu  ARL6XZC1187FB3936E
# 9                         Medicate Myself  ARQOC971187B9910FA
#
#         artist_name_l                     title_r         artist_id_r  \
# 0                 Clp  It Makes No Difference Now  AR0RCMP1187FB3F427
# 1       Lionel Richie  It Makes No Difference Now  AR0RCMP1187FB3F427
# 2  The Rolling Stones  It Makes No Difference Now  AR0RCMP1187FB3F427
# 3      Roberto Torres  It Makes No Difference Now  AR0RCMP1187FB3F427
# 4           John Cale  It Makes No Difference Now  AR0RCMP1187FB3F427
# 5        Nadine Renee  It Makes No Difference Now  AR0RCMP1187FB3F427
# 6       T.G. Sheppard  It Makes No Difference Now  AR0RCMP1187FB3F427
# 7      Flor Silvestre  It Makes No Difference Now  AR0RCMP1187FB3F427
# 8  Solistiyhtye Suomi  It Makes No Difference Now  AR0RCMP1187FB3F427
# 9      The Verve Pipe  It Makes No Difference Now  AR0RCMP1187FB3F427
#
#       artist_name_r  same_artist_flag
# 0  Billie Jo Spears                 0
# 1  Billie Jo Spears                 0
# 2  Billie Jo Spears                 0
# 3  Billie Jo Spears                 0
# 4  Billie Jo Spears                 0
# 5  Billie Jo Spears                 0
# 6  Billie Jo Spears                 0
# 7  Billie Jo Spears                 0
# 8  Billie Jo Spears                 0
# 9  Billie Jo Spears                 0

# %% [markdown]
# ### Compute the weights and inverse weights for the `track` - `track` relationship
#
# The formula discussed above is used to compute the weights. Although weights relate directly to the strength of the relationship and it is necessary for visualization purposes, for shortest-distance algorithms the distance between nodes must be represented as inverse weights.

# %%
# Calculate the weights for each connection
df_ss['weight'] = df_ss['wt_l_sum']*(df_ss['fam_l'] + df_ss['hot_l']) + df_ss['wt_r_sum']*(df_ss['fam_r'] + df_ss['hot_r'])

# Inverse weights
df_ss['inv_weight'] = 1/df_ss['weight']

df_ss.head(10)
# Out:
#               track_l             track_r  wt_l_sum  wt_r_sum     fam_l  \
# 0  TRAAAVG12903CFA543  TRAACTB12903CAAF15  0.734100  0.724350  0.550514
# 1  TRAABJV128F1460C49  TRAACTB12903CAAF15  1.804455  2.608040  0.776676
# 2  TRAADLN128F14832E9  TRAACTB12903CAAF15  3.067252  4.877071  0.814830
# 3  TRAADLR12903CF8D7E  TRAACTB12903CAAF15  1.949940  2.312114  0.482356
# 4  TRAAENP128F147BF32  TRAACTB12903CAAF15  1.250377  2.040589  0.749318
# 5  TRAAGHM128EF35CF8E  TRAACTB12903CAAF15  3.283752  3.739735  0.408389
# 6  TRAAGOH128F42593CE  TRAACTB12903CAAF15  4.317186  4.545478  0.449324
# 7  TRAAGZU128EF360F47  TRAACTB12903CAAF15  0.706473  0.691292  0.420546
# 8  TRAAHEH128F427FCEF  TRAACTB12903CAAF15  2.292019  2.194105  0.138188
# 9  TRAAJJG128F4284B27  TRAACTB12903CAAF15  5.544593  5.923369  0.703349
#
#       fam_r     hot_l     hot_r  song_hot_l  song_hot_r  cnt_at  \
# 0  0.523715  0.422706  0.384611         NaN         0.0       1
# 1  0.523715  0.553072  0.384611         NaN         0.0       4
# 2  0.523715  0.735766  0.384611    0.834493         0.0       7
# 3  0.523715  0.350079  0.384611    0.000000         0.0       3
# 4  0.523715  0.481656  0.384611    0.226555         0.0       3
# 5  0.523715  0.139247  0.384611    0.198785         0.0       5
# 6  0.523715  0.343282  0.384611    0.382723         0.0       6
# 7  0.523715  0.313569  0.384611         NaN         0.0       1
# 8  0.523715  0.317811  0.384611         NaN         0.0       3
# 9  0.523715  0.498395  0.384611    0.466305         0.0       8
#
#                                   title_l         artist_id_l  \
# 0       Insatiable (Instrumental Version)  ARNTLGG11E2835DDB9
# 1                 Tonight Will Be Alright  ARIK43K1187B9AE54C
# 2           Angie (1993 Digital Remaster)  ARFCUN31187B9AD578
# 3                           Sabor Guajiro  AR6YDKV1187B989230
# 4  Movement 4 [from Kiss] (Album Version)  ARUI8651187B9ACF52
# 5                               Next Time  ARMBYRO1187FB57419
# 6                  You Feel Good All Over  ARLWR721187B9A03C9
# 7                        Caricia Y Herida  ARHFEBO11F50C4825A
# 8                       Ter\xc3\xa4slintu  ARL6XZC1187FB3936E
# 9                         Medicate Myself  ARQOC971187B9910FA
#
#         artist_name_l                     title_r         artist_id_r  \
# 0                 Clp  It Makes No Difference Now  AR0RCMP1187FB3F427
# 1       Lionel Richie  It Makes No Difference Now  AR0RCMP1187FB3F427
# 2  The Rolling Stones  It Makes No Difference Now  AR0RCMP1187FB3F427
# 3      Roberto Torres  It Makes No Difference Now  AR0RCMP1187FB3F427
# 4           John Cale  It Makes No Difference Now  AR0RCMP1187FB3F427
# 5        Nadine Renee  It Makes No Difference Now  AR0RCMP1187FB3F427
# 6       T.G. Sheppard  It Makes No Difference Now  AR0RCMP1187FB3F427
# 7      Flor Silvestre  It Makes No Difference Now  AR0RCMP1187FB3F427
# 8  Solistiyhtye Suomi  It Makes No Difference Now  AR0RCMP1187FB3F427
# 9      The Verve Pipe  It Makes No Difference Now  AR0RCMP1187FB3F427
#
#       artist_name_r  same_artist_flag     weight  inv_weight
# 0  Billie Jo Spears                 0   1.372386    0.728658
# 1  Billie Jo Spears                 0   4.768420    0.209713
# 2  Billie Jo Spears                 0   9.186036    0.108861
# 3  Billie Jo Spears                 0   3.723351    0.268575
# 4  Billie Jo Spears                 0   3.392701    0.294750
# 5  Billie Jo Spears                 0   5.195200    0.192485
# 6  Billie Jo Spears                 0   7.550600    0.132440
# 7  Billie Jo Spears                 0   1.146552    0.872181
# 8  Billie Jo Spears                 0   3.038119    0.329151
# 9  Billie Jo Spears                 0  12.043534    0.083032

# %% [markdown]
# ### Create the Nodes - with attributes
#
# An empty undirected graph is created and then the nodes and edges are added. The track title will be used as the key for the graph, as opposed to the track id, purely for better visualization. Refer to the comments for greater details.

# %%
# Create an empty graph
G_2 = nx.Graph()

# Add nodes
# Using the title as the node key instead of track
G_2.add_nodes_from(df_ss['title_l'], type = 'track', color = 'crimson',s_hot = 0, track_id = 'NaN', 
                   artist_name = 'NaN', artist_id = 'NaN', a_hot = 0, a_fam = 0)
G_2.add_nodes_from(df_ss['title_r'], type = 'track', color = 'crimson',s_hot = 0, track_id = 'NaN', 
                   artist_name = 'NaN', artist_id = 'NaN', a_hot = 0, a_fam = 0)


print(type(G_2.nodes()))
print('No. of nodes:', G_2.number_of_nodes())
# Out:
# <class 'list'>
# No. of nodes: 500

# %% [markdown]
# #### Add node attributes
#
# The different attributes are added for the `track` node as described below.

# %%
for node,data in G_2.nodes_iter(data = True):
    if data['type'] == 'track':
        data['s_hot'] = df_ss[df_ss['title_l'] == node]['song_hot_l'].values[0] # if [0] is missed, it will be an array (cell)
        data['track_id'] = df_ss[df_ss['title_l'] == node]['track_l'].values[0] 
        data['artist_name'] = df_ss[df_ss['title_l'] == node]['artist_name_l'].values[0]
        data['artist_id'] = df_ss[df_ss['title_l'] == node]['artist_id_l'].values[0]
        data['a_hot'] = df_ss[df_ss['title_l'] == node]['hot_l'].values[0]
        data['a_fam'] = df_ss[df_ss['title_l'] == node]['fam_l'].values[0]
        
G_2.nodes(data = True)
# Out:
# [('Earrings on the Table',
#   {'a_fam': 0.58999516188724399,
#    'a_hot': 0.30771167908554087,
#    'artist_id': 'ARUAKAN1187FB48204',
#    'artist_name': 'Walter Trout',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAVASN128F9361074',
#    'type': 'track'}),
#  ('Larger Than Life',
#   {'a_fam': 0.85141762884736549,
#    'a_hot': 0.59261492735183441,
#    'artist_id': 'AR3JMC51187B9AE49D',
#    'artist_name': 'Backstreet Boys',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRABAFJ128F42AF24E',
#    'type': 'track'}),
#  ('Spotlight',
#   {'a_fam': 0.57880832741868693,
#    'a_hot': 0.38626683684330476,
#    'artist_id': 'ARQ0TN01187FB4A19E',
#    'artist_name': 'Future Leaders of the World',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAVRTO128F4280C14',
#    'type': 'track'}),
#  ('Rescue Me',
#   {'a_fam': 0.55891624402671281,
#    'a_hot': 0.39257987775536779,
#    'artist_id': 'ARZH0R61187FB422AE',
#    'artist_name': 'Fontella Bass',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAXULE128F9320132',
#    'type': 'track'}),
#  ('Wo Ai Ni_ Zai Jian!',
#   {'a_fam': 0.49061141418249271,
#    'a_hot': 0.39157416411599666,
#    'artist_id': 'ARG1UAO1187FB55E50',
#    'artist_name': 'Sammi Cheng',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBFLQW128F1483D44',
#    'type': 'track'}),
#  ('Somewhere',
#   {'a_fam': 0.56358358625781679,
#    'a_hot': 0.38852729330596053,
#    'artist_id': 'ARTCO131187B9B9ADB',
#    'artist_name': 'Bob Carlisle',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAFUTE128F930F510',
#    'type': 'track'}),
#  ("A Poor Man's Roses",
#   {'a_fam': 0.65672890324761102,
#    'a_hot': 0.46851146647636349,
#    'artist_id': 'ARA7YDA1187B9A5776',
#    'artist_name': 'Patsy Cline',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAPQNA128F93000EB',
#    'type': 'track'}),
#  ('Ask The Angels',
#   {'a_fam': 0.68109069174255943,
#    'a_hot': 0.48853612540190205,
#    'artist_id': 'ARN2ZKL1187FB3972B',
#    'artist_name': 'The Distillers',
#    'color': 'crimson',
#    's_hot': 0.6251065614685144,
#    'track_id': 'TRBAOJU128F42621E6',
#    'type': 'track'}),
#  ('Jesus',
#   {'a_fam': 0.42137606022327562,
#    'a_hot': 0.36652780195544032,
#    'artist_id': 'ARRXPRY1187B9A8B34',
#    'artist_name': 'Gran Coquivacoa',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAYCRC128F932CB4E',
#    'type': 'track'}),
#  ('Iron-head: Palestine',
#   {'a_fam': 0.42694781240559931,
#    'a_hot': 0.29472687611398141,
#    'artist_id': 'ARDGALJ1187FB55592',
#    'artist_name': 'Asterisk*',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAETPY12903CF4D2F',
#    'type': 'track'}),
#  ('Speed Of Sound (Emergency Broadcast Album Version)',
#   {'a_fam': 0.47736475248353516,
#    'a_hot': 0.33750728916593725,
#    'artist_id': 'ARCCRTI11F4C845308',
#    'artist_name': 'White Heart',
#    'color': 'crimson',
#    's_hot': 0.26173330837465286,
#    'track_id': 'TRBCSZQ128F92F9043',
#    'type': 'track'}),
#  ('Hiekkaa (polvere)',
#   {'a_fam': 0.30875363352326018,
#    'a_hot': 0.20728595283543555,
#    'artist_id': 'ARVJSJY1250940FA2B',
#    'artist_name': 'Tulipunaruusut',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBDNQI128F42831EE',
#    'type': 'track'}),
#  ('Contessa Entellina',
#   {'a_fam': 0.56137090722834093,
#    'a_hot': 0.36553375619798018,
#    'artist_id': 'ARN3O411187FB4D859',
#    'artist_name': 'Stephan Micus',
#    'color': 'crimson',
#    's_hot': 0.36727341580934564,
#    'track_id': 'TRAHTZF128F4229377',
#    'type': 'track'}),
#  ('Them No Care',
#   {'a_fam': 0.54703573416789919,
#    'a_hot': 0.36568660603464831,
#    'artist_id': 'ARTM0RS1187B9A0BE6',
#    'artist_name': 'Super Cat',
#    'color': 'crimson',
#    's_hot': 0.48456252996792964,
#    'track_id': 'TRAYMYA128F4262C9D',
#    'type': 'track'}),
#  ('Tides Of Time',
#   {'a_fam': 0.57553241169139013,
#    'a_hot': 0.37453002882015307,
#    'artist_id': 'ARIRBO11187FB4B219',
#    'artist_name': 'Donna The Buffalo',
#    'color': 'crimson',
#    's_hot': 0.46048484498641545,
#    'track_id': 'TRADJJZ128F9341B40',
#    'type': 'track'}),
#  ('What If I Forget The Champagne',
#   {'a_fam': 0.65788311634501018,
#    'a_hot': 0.46488625713214932,
#    'artist_id': 'ARHZCG01187B99E4DE',
#    'artist_name': 'Stanley Clarke',
#    'color': 'crimson',
#    's_hot': 0.37253003936607959,
#    'track_id': 'TRAUGWE128F42670DB',
#    'type': 'track'}),
#  ('18 De Noviembre',
#   {'a_fam': 0.43395399516683558,
#    'a_hot': 0.31470046977659827,
#    'artist_id': 'ARJTAZU1187B990051',
#    'artist_name': 'Maracaibo 15',
#    'color': 'crimson',
#    's_hot': 0.29987748827397781,
#    'track_id': 'TRBGGOT128F932DC65',
#    'type': 'track'}),
#  ('Immigrant Song (Album Version)',
#   {'a_fam': 0.78709835548093887,
#    'a_hot': 0.63441238493030083,
#    'artist_id': 'ARDIBRT1187B9AF176',
#    'artist_name': 'Led Zeppelin',
#    'color': 'crimson',
#    's_hot': 1.0,
#    'track_id': 'TRBFNSL128F42776F9',
#    'type': 'track'}),
#  ("Freezin' From The Inside Out",
#   {'a_fam': 0.51874395857987465,
#    'a_hot': 0.34128872330078414,
#    'artist_id': 'ARY4M3J1187B9AC94C',
#    'artist_name': 'John Sebastian',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBHECY128F930A474',
#    'type': 'track'}),
#  ('Cai dentro',
#   {'a_fam': 0.43351711555557576,
#    'a_hot': 0.0,
#    'artist_id': 'ARJJPQP1241B9CA062',
#    'artist_name': 'Gabriel Grossi',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAUWIE128F92F6064',
#    'type': 'track'}),
#  ('Packed Up And Took My Mind',
#   {'a_fam': 0.57942410845600956,
#    'a_hot': 0.38644109710384272,
#    'artist_id': 'AR7AOEJ1187FB3D279',
#    'artist_name': 'Little Milton',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAWBVW128F932A39F',
#    'type': 'track'}),
#  ('Cuore Appassionato',
#   {'a_fam': 0.42196043731099453,
#    'a_hot': 0.23274867834736321,
#    'artist_id': 'ARLNSD41187FB4D9A0',
#    'artist_name': 'Sergio Franchi',
#    'color': 'crimson',
#    's_hot': 0.25092141608523022,
#    'track_id': 'TRAQRAM128F4296694',
#    'type': 'track'}),
#  ('D\\xc3\\xa5 \\xc3\\xa4r det jul',
#   {'a_fam': 0.50821888552059491,
#    'a_hot': 0.40173498558744702,
#    'artist_id': 'AR3Q3QT1187FB396E7',
#    'artist_name': 'Sanna Nielsen',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRANXPU128F428CE4A',
#    'type': 'track'}),
#  ("You Can't Hurry Love  (LP Version)",
#   {'a_fam': 0.81450622359933456,
#    'a_hot': 0.58483688871941653,
#    'artist_id': 'AR9W3X91187FB3994C',
#    'artist_name': 'Phil Collins',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAKPND128F42389EA',
#    'type': 'track'}),
#  ('Next Time',
#   {'a_fam': 0.40838902237596769,
#    'a_hot': 0.13924739387110993,
#    'artist_id': 'ARMBYRO1187FB57419',
#    'artist_name': 'Nadine Renee',
#    'color': 'crimson',
#    's_hot': 0.19878534876524423,
#    'track_id': 'TRAAGHM128EF35CF8E',
#    'type': 'track'}),
#  ('Far Beyond The Endless',
#   {'a_fam': 0.59833250036193897,
#    'a_hot': 0.32050791841776138,
#    'artist_id': 'ARYSHWJ1187B9AD2D0',
#    'artist_name': 'Moist',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAZHMT12903C9D27E',
#    'type': 'track'}),
#  ('Big Woman',
#   {'a_fam': 0.50578476272709694,
#    'a_hot': 0.32675033397379771,
#    'artist_id': 'AR84AQE1187B98AD9C',
#    'artist_name': 'Washboard Sam',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAZOGI128F429F7C1',
#    'type': 'track'}),
#  ("Il a suffit d'une chanson d'amour",
#   {'a_fam': 0.34950747840381585,
#    'a_hot': 0.23683207788107569,
#    'artist_id': 'AR7GYNZ1187FB44803',
#    'artist_name': 'Christian adam',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBDGRU128F934D684',
#    'type': 'track'}),
#  ('Into A Swan',
#   {'a_fam': 0.63444171314982833,
#    'a_hot': 0.42311794435199923,
#    'artist_id': 'ARSTSEH121318C5B01',
#    'artist_name': 'Siouxsie',
#    'color': 'crimson',
#    's_hot': 0.59024059758241698,
#    'track_id': 'TRABSXW128F4233422',
#    'type': 'track'}),
#  ('Oedipus Rex_ Atto Primo: Liberi_ Vos Liberabo (Oedipus) (Stravinsky)',
#   {'a_fam': 0.66805568685841976,
#    'a_hot': 0.4641524390532526,
#    'artist_id': 'ART8F8O1187B9A538D',
#    'artist_name': 'Herbert  von Karajan',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRATFJI128F4252046',
#    'type': 'track'}),
#  ('Pu**y Pop',
#   {'a_fam': 0.74755658111977841,
#    'a_hot': 0.55021224357166709,
#    'artist_id': 'AR49IQD1187FB37EA7',
#    'artist_name': 'Xzibit featuring Jayo Felony and Method Man',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAQBTT128F427AE7D',
#    'type': 'track'}),
#  ('Movement 4 [from Kiss] (Album Version)',
#   {'a_fam': 0.74931780096145328,
#    'a_hot': 0.48165586241245567,
#    'artist_id': 'ARUI8651187B9ACF52',
#    'artist_name': 'John Cale',
#    'color': 'crimson',
#    's_hot': 0.22655531395553141,
#    'track_id': 'TRAAENP128F147BF32',
#    'type': 'track'}),
#  ("I Don't Like You",
#   {'a_fam': 0.50335461415958116,
#    'a_hot': 0.30150587751163294,
#    'artist_id': 'AR1WDRJ1187B9BA4B8',
#    'artist_name': 'Buzzov\\xc2\\xac"en',
#    'color': 'crimson',
#    's_hot': 0.54128054670962344,
#    'track_id': 'TRBGWSR128F4286574',
#    'type': 'track'}),
#  ('Coma',
#   {'a_fam': 0.83453858559027194,
#    'a_hot': 0.47731088106700248,
#    'artist_id': 'AR6F6I21187FB5A3AA',
#    'artist_name': 'Aesop Rock',
#    'color': 'crimson',
#    's_hot': 0.63100805881809108,
#    'track_id': 'TRBGTPK128F429E5D5',
#    'type': 'track'}),
#  ('Grow Proper',
#   {'a_fam': 0.68206784769305129,
#    'a_hot': 0.43771129121014735,
#    'artist_id': 'ARLFUII1187FB565E5',
#    'artist_name': 'I Wayne',
#    'color': 'crimson',
#    's_hot': 0.46492399418071773,
#    'track_id': 'TRAJABU128F4239037',
#    'type': 'track'}),
#  ('Thank You Mama',
#   {'a_fam': 0.32300899095323227,
#    'a_hot': 0.31143764032728327,
#    'artist_id': 'AREWQSE1187B9AEC6C',
#    'artist_name': 'The Jackson Southernaires',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAHVBC12903CEF90F',
#    'type': 'track'}),
#  ('Studen plamuk',
#   {'a_fam': 0.4485305418592766,
#    'a_hot': 0.38528564261478299,
#    'artist_id': 'ARRHZLW11E2835E799',
#    'artist_name': 'Sofi Marinova',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAIMXG12903CDEE2A',
#    'type': 'track'}),
#  ('Angie (1993 Digital Remaster)',
#   {'a_fam': 0.81482965613311209,
#    'a_hot': 0.73576569295064143,
#    'artist_id': 'ARFCUN31187B9AD578',
#    'artist_name': 'The Rolling Stones',
#    'color': 'crimson',
#    's_hot': 0.83449261989090551,
#    'track_id': 'TRAADLN128F14832E9',
#    'type': 'track'}),
#  ('Intro',
#   {'a_fam': 0.49125620949228588,
#    'a_hot': 0.3262082546201735,
#    'artist_id': 'ARJ4B7V1187FB4CB90',
#    'artist_name': 'DJ Godfather',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRALDCM128F4222464',
#    'type': 'track'}),
#  ('Un Tipo Como Yo',
#   {'a_fam': 0.55596678943342537,
#    'a_hot': 0.33811038811226163,
#    'artist_id': 'AR9KWJK1187FB4A531',
#    'artist_name': 'Willie Rosario',
#    'color': 'crimson',
#    's_hot': 0.56927565067547881,
#    'track_id': 'TRABVAR128F421CFCB',
#    'type': 'track'}),
#  ('La Mam\\xc3\\xa1 De Jimmy',
#   {'a_fam': 0.56261476754774975,
#    'a_hot': 0.35843536424426514,
#    'artist_id': 'AR2S6UD1187B9B944F',
#    'artist_name': 'Le\\xc3\\xb3n Gieco',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAQAPL12903CB18F0',
#    'type': 'track'}),
#  ('Under Attack',
#   {'a_fam': 0.64915577353146869,
#    'a_hot': 0.34593570218633163,
#    'artist_id': 'ARZAHDN1187B9B4BED',
#    'artist_name': 'Ice',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRASZDW128F4269894',
#    'type': 'track'}),
#  ('Fall in Philadelphia',
#   {'a_fam': 0.66492436244412767,
#    'a_hot': 0.49638114568159253,
#    'artist_id': 'ARN0DMU1187FB5B63A',
#    'artist_name': 'Hall & Oates',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBHBGB128F931E4CF',
#    'type': 'track'}),
#  ('Punjabian Di Chale Glassi',
#   {'a_fam': 0.58097150995660296,
#    'a_hot': 0.34873592978406104,
#    'artist_id': 'ARELFAE1187FB40D0A',
#    'artist_name': 'Bally Sagoo',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAHRPF128F4252CB3',
#    'type': 'track'}),
#  ('Soldiers At War feat. Kon Juan_ Big Scoob_ Short Nutty_ L.V.',
#   {'a_fam': 0.76027010602881928,
#    'a_hot': 0.49607134662408603,
#    'artist_id': 'ARGXIE31187FB55B48',
#    'artist_name': 'Tech N9ne',
#    'color': 'crimson',
#    's_hot': 0.34580223396532944,
#    'track_id': 'TRATKVK128F93668B8',
#    'type': 'track'}),
#  ('Writes Of Winter',
#   {'a_fam': 0.73182221865142949,
#    'a_hot': 0.42494033080279475,
#    'artist_id': 'ARNPPTH1187B9AD429',
#    'artist_name': 'Jimmy Page',
#    'color': 'crimson',
#    's_hot': 0.57427987706758632,
#    'track_id': 'TRBFXQT128F148D15B',
#    'type': 'track'}),
#  ('Directions to my special place',
#   {'a_fam': 0.62827444893300677,
#    'a_hot': 0.42883453621653383,
#    'artist_id': 'ARNVM131187B990D2B',
#    'artist_name': 'themselves',
#    'color': 'crimson',
#    's_hot': 0.54989534491339531,
#    'track_id': 'TRBAZMR128F423395F',
#    'type': 'track'}),
#  ('Bigbigkiss',
#   {'a_fam': 0.58188435889129331,
#    'a_hot': 0.34700692093040558,
#    'artist_id': 'ARWSMC91187B9AD369',
#    'artist_name': 'Helen Love',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAUCVY12903CF2B1E',
#    'type': 'track'}),
#  ('El Aranero',
#   {'a_fam': 0.41241030283703678,
#    'a_hot': 0.3028397596569658,
#    'artist_id': 'AR6OPE31187B9B9CB7',
#    'artist_name': 'Los Hispanos',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRADMZH12903CE4AD0',
#    'type': 'track'}),
#  ('WHEN I AM YOU',
#   {'a_fam': 0.58860808654884855,
#    'a_hot': 0.37361111191126956,
#    'artist_id': 'ARZM53A1187B9A1AE7',
#    'artist_name': 'Panzer AG',
#    'color': 'crimson',
#    's_hot': 0.51351702853713854,
#    'track_id': 'TRAETZJ128F422B208',
#    'type': 'track'}),
#  ('Anyone Who Had A Heart',
#   {'a_fam': 0.62420032763510125,
#    'a_hot': 0.36907687054899069,
#    'artist_id': 'AR9ST641187B99B4DE',
#    'artist_name': 'Cal Tjader',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAUJEB128F4240FD4',
#    'type': 'track'}),
#  ('A una mamita',
#   {'a_fam': 0.075282883976161646,
#    'a_hot': 0.0,
#    'artist_id': 'ARFFFFY122988EDE49',
#    'artist_name': 'Carlos Embales - Cutumba',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAYRPF12903CAB6FB',
#    'type': 'track'}),
#  ('Posledny Buntar`',
#   {'a_fam': 0.53284530255958451,
#    'a_hot': 0.35051213183803731,
#    'artist_id': 'AR16NGV1187FB5B8BC',
#    'artist_name': 'Kruger',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAPTYS12903CD191F',
#    'type': 'track'}),
#  ('No Pienses Asi',
#   {'a_fam': 0.571926730797233,
#    'a_hot': 0.36844621167949099,
#    'artist_id': 'ARM7UY51187B993E17',
#    'artist_name': 'Eddie Palmieri',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRARZBQ128F42649A6',
#    'type': 'track'}),
#  ('I WANNA HEAR IT FROM YOU',
#   {'a_fam': 0.46499431936808794,
#    'a_hot': 0.34472111117200155,
#    'artist_id': 'ARHT0B11187B993CB3',
#    'artist_name': 'Eddy Raven',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAGGHA128F4262D55',
#    'type': 'track'}),
#  ('Ojos Gitanos',
#   {'a_fam': 0.51078384559843526,
#    'a_hot': 0.34901349777131224,
#    'artist_id': 'ARGWFMR1187B98D0E7',
#    'artist_name': 'C\\xc3\\xb3mplices',
#    'color': 'crimson',
#    's_hot': 0.56545101217369831,
#    'track_id': 'TRABPHE128F42A1E65',
#    'type': 'track'}),
#  ('Nada De Ti',
#   {'a_fam': 0.52282181776308412,
#    'a_hot': 0.3555029950198822,
#    'artist_id': 'ARPCEWC11F4C83EEA7',
#    'artist_name': 'Eddie Palmieri',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBDIKL128F42649B0',
#    'type': 'track'}),
#  ('Heal (The Separation) [PM Dawn Alt. Lead Mix]',
#   {'a_fam': 0.60588047106563059,
#    'a_hot': 0.3936608679237098,
#    'artist_id': 'ARK8EHO1187B9B71D1',
#    'artist_name': 'The Shamen',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAUAHG128F931C55F',
#    'type': 'track'}),
#  ("C'est Toujours la M\\xc3\\xaame Histoire",
#   {'a_fam': 0.70424476603767505,
#    'a_hot': 0.49756873428189963,
#    'artist_id': 'ARRWAD71187FB3FE44',
#    'artist_name': 'Martha Wainwright',
#    'color': 'crimson',
#    's_hot': 0.59711670292271968,
#    'track_id': 'TRBDUMD128F9327534',
#    'type': 'track'}),
#  ('Careless Talk',
#   {'a_fam': 0.69877047779587209,
#    'a_hot': 0.39945172400502926,
#    'artist_id': 'AR1PCLK1187FB5BBFF',
#    'artist_name': 'Angelo Badalamenti / Patrick Wolf',
#    'color': 'crimson',
#    's_hot': 0.59477944466256449,
#    'track_id': 'TRASNTF128F426C3E6',
#    'type': 'track'}),
#  ('Raining On Our Love',
#   {'a_fam': 0.87003379661789915,
#    'a_hot': 0.54632611955194055,
#    'artist_id': 'ARUJZFJ1187B9B135F',
#    'artist_name': 'Shania Twain',
#    'color': 'crimson',
#    's_hot': 0.48512236410182069,
#    'track_id': 'TRAGJQL128E078E840',
#    'type': 'track'}),
#  ('Old Memory',
#   {'a_fam': 0.67939505142188683,
#    'a_hot': 0.39096361173158523,
#    'artist_id': 'ARB8H82119B34032E1',
#    'artist_name': 'Ashton Shepherd',
#    'color': 'crimson',
#    's_hot': 0.52549711888017014,
#    'track_id': 'TRAIZWI128F4247EFD',
#    'type': 'track'}),
#  ('An Old Fashioned Christmas',
#   {'a_fam': 0.64196352348550212,
#    'a_hot': 0.53720953902002266,
#    'artist_id': 'AR58JT11187B9AF4CC',
#    'artist_name': 'Carpenters',
#    'color': 'crimson',
#    's_hot': 0.38293509007501925,
#    'track_id': 'TRAXIPO128F14923B2',
#    'type': 'track'}),
#  ('Packing Up',
#   {'a_fam': 0.41828251398044952,
#    'a_hot': 0.32034562883283479,
#    'artist_id': 'ARF3PG41187FB4B0B4',
#    'artist_name': 'Dorothy Norwood',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAKCRM128F42542F3',
#    'type': 'track'}),
#  ('Watermelon Man',
#   {'a_fam': 0.54003774897977885,
#    'a_hot': 0.36005330653898399,
#    'artist_id': 'AR1N6N61187FB4E25E',
#    'artist_name': 'Mongo Santamaria',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAVFOA128F92F2B38',
#    'type': 'track'}),
#  ('Bitch Is Back',
#   {'a_fam': 0.66572833642482887,
#    'a_hot': 0.45694055844157816,
#    'artist_id': 'ARHONG11187FB3B120',
#    'artist_name': 'L.A. Guns',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAAMSO128EF348DCC',
#    'type': 'track'}),
#  ('Never After',
#   {'a_fam': 0.62117046950606514,
#    'a_hot': 0.21893641516044704,
#    'artist_id': 'AR9M9XY1187B98B2F8',
#    'artist_name': 'Abbott & Chambers',
#    'color': 'crimson',
#    's_hot': 0.54831270410807487,
#    'track_id': 'TRAVAUF128F93033E5',
#    'type': 'track'}),
#  ('The Saga Of Rita Joe',
#   {'a_fam': 0.33187414645692209,
#    'a_hot': 0.27711951346727021,
#    'artist_id': 'AR0IAWL1187B9A96D0',
#    'artist_name': 'Danilo Perez / Claus Ogerman',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAGWPR128F426BDC3',
#    'type': 'track'}),
#  ('Long Summer Days',
#   {'a_fam': 0.63589871018012734,
#    'a_hot': 0.53026281342742188,
#    'artist_id': 'ARZKUQF11F4C8456E8',
#    'artist_name': 'The Moody Blues',
#    'color': 'crimson',
#    's_hot': 0.38293509007501925,
#    'track_id': 'TRADWAU128F145622F',
#    'type': 'track'}),
#  ('Everything Has Changed',
#   {'a_fam': 0.4299232145947216,
#    'a_hot': 0.31184234121943055,
#    'artist_id': 'AR4NTMG1187B9B5C17',
#    'artist_name': 'Patric C',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAQHMP128F932D69C',
#    'type': 'track'}),
#  ('Distancia',
#   {'a_fam': 0.50677892837627914,
#    'a_hot': 0.32841373787793265,
#    'artist_id': 'AR6IJ6U1187B99FC7C',
#    'artist_name': 'Alberto Cortez',
#    'color': 'crimson',
#    's_hot': 0.33470654906922059,
#    'track_id': 'TRADJVN128F42AC93D',
#    'type': 'track'}),
#  ('No. 284',
#   {'a_fam': 0.5433500129660529,
#    'a_hot': 0.39926514972118698,
#    'artist_id': 'ARXOKNT1187B9AA521',
#    'artist_name': 'Kali',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRALJAH12903CB00F5',
#    'type': 'track'}),
#  ('El Jamaiquino',
#   {'a_fam': 0.57722850277798732,
#    'a_hot': 0.37355239101415616,
#    'artist_id': 'ARYFXQ21187FB4DAEF',
#    'artist_name': 'Poncho Sanchez',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAVPYA128F92D944F',
#    'type': 'track'}),
#  ("Like It's Hot",
#   {'a_fam': 0.51531023323055125,
#    'a_hot': 0.2607967782533836,
#    'artist_id': 'ARPOPBQ11F4C83D36D',
#    'artist_name': 'DJ Spinn and DJ Rashad',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAKFZB12903CAE89D',
#    'type': 'track'}),
#  ('Nothing But The Best',
#   {'a_fam': 0.47736475248353516,
#    'a_hot': 0.33750728916593725,
#    'artist_id': 'ARCCRTI11F4C845308',
#    'artist_name': 'White Heart',
#    'color': 'crimson',
#    's_hot': 0.50338123620631914,
#    'track_id': 'TRAJLKH128F422C613',
#    'type': 'track'}),
#  ('Rossignol Montmartrois (Polka)',
#   {'a_fam': 0.39145406405090427,
#    'a_hot': 0.32085012955443049,
#    'artist_id': 'ARQC4R31187B9A0D88',
#    'artist_name': 'Jo Privat',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAIVHI128F145CC6F',
#    'type': 'track'}),
#  ('Enclosed_ One Broken Heart',
#   {'a_fam': 0.56412895014674547,
#    'a_hot': 0.39777565432262169,
#    'artist_id': 'AR14CJ91187FB3A994',
#    'artist_name': 'Eddy Arnold',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAQLOT12903CE025B',
#    'type': 'track'}),
#  ('New Love',
#   {'a_fam': 0.75047981714181877,
#    'a_hot': 0.53849112750406791,
#    'artist_id': 'ARLUAK21187B9B785A',
#    'artist_name': 'Ziggy Marley And The Melody Makers',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBGHFZ128F146984C',
#    'type': 'track'}),
#  ('Flipside',
#   {'a_fam': 0.52968067326793378,
#    'a_hot': 0.35085673038961279,
#    'artist_id': 'ARQHJLT11F50C4C101',
#    'artist_name': 'Bomb Squad',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRATHDF128F92FCD1A',
#    'type': 'track'}),
#  ('On Independence Day',
#   {'a_fam': 0.84403953222739692,
#    'a_hot': 0.52437898751480838,
#    'artist_id': 'ARUSOMY1187FB4D3B4',
#    'artist_name': 'Anti-Flag',
#    'color': 'crimson',
#    's_hot': 0.60386047091007111,
#    'track_id': 'TRASDGG128F933EDE2',
#    'type': 'track'}),
#  ('Try',
#   {'a_fam': 0.58051777655574033,
#    'a_hot': 0.31762454603358753,
#    'artist_id': 'ARMAEYS1187B990F2F',
#    'artist_name': 'Tree',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAKXLR128F9308F5A',
#    'type': 'track'}),
#  ('Quiet Time',
#   {'a_fam': 0.56602430215953659,
#    'a_hot': 0.38460168554782642,
#    'artist_id': 'AR0AVIB1187FB37D01',
#    'artist_name': 'Regina Belle',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRABFQC128F4265349',
#    'type': 'track'}),
#  ('Kids Now',
#   {'a_fam': 0.66802024872330457,
#    'a_hot': 0.51696373073834112,
#    'artist_id': 'ARYF20K1187B9B76BD',
#    'artist_name': 'George Lopez',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRALGQH12903CD4922',
#    'type': 'track'}),
#  ('Where Do I Fit',
#   {'a_fam': 0.70152170644090894,
#    'a_hot': 0.52431892047024631,
#    'artist_id': 'ARFM7OI1187B990C49',
#    'artist_name': 'Tonic',
#    'color': 'crimson',
#    's_hot': 0.63874563990040667,
#    'track_id': 'TRAEHBW12903CE1045',
#    'type': 'track'}),
#  ('Edge Of The Dream (Emergency Broadcast Album Version)',
#   {'a_fam': 0.47736475248353516,
#    'a_hot': 0.33750728916593725,
#    'artist_id': 'ARCCRTI11F4C845308',
#    'artist_name': 'White Heart',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAJSKN128F92F9046',
#    'type': 'track'}),
#  ('Only Lonely',
#   {'a_fam': 0.83929767756816964,
#    'a_hot': 0.71889145567020951,
#    'artist_id': 'ARDVZTE1187FB5A0A1',
#    'artist_name': 'Bon Jovi',
#    'color': 'crimson',
#    's_hot': 0.71720644076103934,
#    'track_id': 'TRBEATE128E078F0D8',
#    'type': 'track'}),
#  ('All Rise',
#   {'a_fam': 0.4973075122753628,
#    'a_hot': 0.34240639110484233,
#    'artist_id': 'AR9AN471187B99E0DA',
#    'artist_name': 'Scott Wesley Brown',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAAOTT128F14AE002',
#    'type': 'track'}),
#  ('Kuolema Tekee Taiteilijan',
#   {'a_fam': 0.80198921596931039,
#    'a_hot': 0.58034527137783265,
#    'artist_id': 'AR74Q3R1187B9B24C3',
#    'artist_name': 'Nightwish',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBFNZT128F429201E',
#    'type': 'track'}),
#  ('Vollmond',
#   {'a_fam': 0.74907777915737817,
#    'a_hot': 0.44733048717187751,
#    'artist_id': 'ARHKQGH1187B9A4DB4',
#    'artist_name': 'In Extremo',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAHMLW128F92D9D82',
#    'type': 'track'}),
#  ('Amigo m\\xc3\\xado',
#   {'a_fam': 0.47224776943668401,
#    'a_hot': 0.3167245506978163,
#    'artist_id': 'ARJ3VRY1187B9A3058',
#    'artist_name': 'Memphis La Blusera',
#    'color': 'crimson',
#    's_hot': 0.21204540548371908,
#    'track_id': 'TRALXYQ128F1470E15',
#    'type': 'track'}),
#  ('The One I Got',
#   {'a_fam': 0.69896992526448398,
#    'a_hot': 0.48678302492271036,
#    'artist_id': 'ARBHBE91187B9A1F58',
#    'artist_name': 'Jonny Lang',
#    'color': 'crimson',
#    's_hot': 0.60303014479359129,
#    'track_id': 'TRADJGI128F148B0F6',
#    'type': 'track'}),
#  ('She Will Love You (Album Version)',
#   {'a_fam': 0.77349132449836888,
#    'a_hot': 0.50045915065893321,
#    'artist_id': 'ARJ8PZJ1187B99314F',
#    'artist_name': 'Aiden',
#    'color': 'crimson',
#    's_hot': 0.71321769226344411,
#    'track_id': 'TRATIRE128F42A667F',
#    'type': 'track'}),
#  ('I Feel So Good',
#   {'a_fam': 0.52055374571161639,
#    'a_hot': 0.35597435894657803,
#    'artist_id': 'AR58SJE1187B9A8E4C',
#    'artist_name': 'J.B. Lenoir',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAKABH128F14A0747',
#    'type': 'track'}),
#  ('Gamble Calypso',
#   {'a_fam': 0.43990765814330768,
#    'a_hot': 0.31155917564728197,
#    'artist_id': 'ARQVLQJ1187B98F11F',
#    'artist_name': 'Mau Mau',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRBBDIU128F1496C52',
#    'type': 'track'}),
#  ('Sleeping My Day Away [Live]',
#   {'a_fam': 0.50039930969711877,
#    'a_hot': 0.43324383372351277,
#    'artist_id': 'AR9OTFC11C8A415220',
#    'artist_name': 'D.A.D.',
#    'color': 'crimson',
#    's_hot': 0.31356211424793418,
#    'track_id': 'TRAHKEG12903CDB829',
#    'type': 'track'}),
#  ('Petticoat',
#   {'a_fam': 0.46756996642993431,
#    'a_hot': 0.0,
#    'artist_id': 'ARBWFER11C8A42BA94',
#    'artist_name': 'The Weegs',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAMXIQ128F4246FAF',
#    'type': 'track'}),
#  ('Chinz Ninja (Rui Da Silva mix)',
#   {'a_fam': 0.6251867974682902,
#    'a_hot': 0.38880031291510264,
#    'artist_id': 'ARE17W51187FB5381B',
#    'artist_name': 'Smart Alex',
#    'color': 'crimson',
#    's_hot': 0.349166902124596,
#    'track_id': 'TRAJDCS128F92F9236',
#    'type': 'track'}),
#  ('Ability To Create A War',
#   {'a_fam': 0.8411364060109523,
#    'a_hot': 0.55691056761795354,
#    'artist_id': 'ARN6M7I1187FB4DEAF',
#    'artist_name': 'A Skylit Drive',
#    'color': 'crimson',
#    's_hot': 0.68408877539809787,
#    'track_id': 'TRAPYML128F423DF98',
#    'type': 'track'}),
#  ('Ego is the drug/3am',
#   {'a_fam': 0.56842734729834965,
#    'a_hot': 0.33504177703727017,
#    'artist_id': 'ARCRSUM1187FB52AB0',
#    'artist_name': 'The Frequency',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAFJKG128F9332800',
#    'type': 'track'}),
#  ('Noises',
#   {'a_fam': 0.41254462993117569,
#    'a_hot': 0.35329028976873145,
#    'artist_id': 'ARKJJZN1187B9AFC88',
#    'artist_name': 'Taal',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBDXLZ12903CC8988',
#    'type': 'track'}),
#  ('Blaue Matrosen (live)',
#   {'a_fam': 0.419034024131271,
#    'a_hot': 0.29398439015383726,
#    'artist_id': 'ARFY8NV1187B9B1961',
#    'artist_name': 'Der Moderne Man',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRACBMH128F93291A4',
#    'type': 'track'}),
#  ('Loud And Clear',
#   {'a_fam': 0.74781536931395343,
#    'a_hot': 0.45918919468022701,
#    'artist_id': 'ARTWPGO1187FB52DC3',
#    'artist_name': 'Elephant Man',
#    'color': 'crimson',
#    's_hot': 0.23962909777363708,
#    'track_id': 'TRADHUE128EF34DAF5',
#    'type': 'track'}),
#  ('Beyond The Reef',
#   {'a_fam': 0.41614717642534665,
#    'a_hot': 0.28744675323008828,
#    'artist_id': 'ARI945I1187FB4CC22',
#    'artist_name': 'The King Sisters',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRBHQBW12903CAC57B',
#    'type': 'track'}),
#  ('Susan Said',
#   {'a_fam': 0.4820069985698382,
#    'a_hot': 0.4158971284574865,
#    'artist_id': 'ARJA5XT1187B9B89AA',
#    'artist_name': 'David Tao',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRASDMK128F4243937',
#    'type': 'track'}),
#  ('Red is the Rose',
#   {'a_fam': 0.40132798622497184,
#    'a_hot': 0.28857861572516413,
#    'artist_id': 'AR5J8N51187FB54ED9',
#    'artist_name': 'Joe Heaney',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBDFWV128F93027EE',
#    'type': 'track'}),
#  ('2HB (1999 Digital Remaster)',
#   {'a_fam': 0.69480251978168484,
#    'a_hot': 0.56183053793921367,
#    'artist_id': 'ARIZODP1187B9AD272',
#    'artist_name': 'Bryan Ferry',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBCSMH128F146A146',
#    'type': 'track'}),
#  ('Streets On Fire (Explicit Album Version)',
#   {'a_fam': 0.90206292690287326,
#    'a_hot': 0.55463323057415492,
#    'artist_id': 'ARPFHN61187FB575F6',
#    'artist_name': 'Lupe Fiasco',
#    'color': 'crimson',
#    's_hot': 0.88881353789424966,
#    'track_id': 'TRABCKL128F423A778',
#    'type': 'track'}),
#  ('The Harbour',
#   {'a_fam': 0.61346493213483355,
#    'a_hot': 0.41211555345941953,
#    'artist_id': 'ARQ3VBJ1187FB3FE55',
#    'artist_name': 'Dario Marianelli',
#    'color': 'crimson',
#    's_hot': 0.35528553642308941,
#    'track_id': 'TRBGMHU128EF356CB8',
#    'type': 'track'}),
#  ('Peaches (Fear of Theydon remix)',
#   {'a_fam': 0.68761966623458892,
#    'a_hot': 0.41706891249515204,
#    'artist_id': 'ARXK4YK1187FB4D0C4',
#    'artist_name': 'Dub Pistols feat. Rodney P & Terry Hall',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBHXRQ128F42A713F',
#    'type': 'track'}),
#  ('Straight Coats',
#   {'a_fam': 0.49722157614337387,
#    'a_hot': 0.37382188109552611,
#    'artist_id': 'AROI2SN1187B98E9FD',
#    'artist_name': 'Kokane',
#    'color': 'crimson',
#    's_hot': 0.21204540548371908,
#    'track_id': 'TRAWEUP128F92E72BD',
#    'type': 'track'}),
#  ('For Me And My Gal',
#   {'a_fam': 0.47168268643925954,
#    'a_hot': 0.38459812040625513,
#    'artist_id': 'ARYT3BY1187B98C20E',
#    'artist_name': 'Ed Ames',
#    'color': 'crimson',
#    's_hot': 0.2331663339689613,
#    'track_id': 'TRAHULL128F92DDBFB',
#    'type': 'track'}),
#  ('Apertura in jazz',
#   {'a_fam': 0.58881188081714986,
#    'a_hot': 0.38254579460118709,
#    'artist_id': 'AR8TCLH1187B9A85E4',
#    'artist_name': 'Piero Umiliani',
#    'color': 'crimson',
#    's_hot': 0.21204540548371908,
#    'track_id': 'TRADXEB12903CEAC5B',
#    'type': 'track'}),
#  ('Tracy',
#   {'a_fam': 0.58917487587753492,
#    'a_hot': 0.4422857823914656,
#    'artist_id': 'AR813LR1187FB3F83A',
#    'artist_name': 'Goldfish',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBASEK128F9338E0F',
#    'type': 'track'}),
#  ('Here Comes The Big Parade',
#   {'a_fam': 0.69113372864361933,
#    'a_hot': 0.53105019317972735,
#    'artist_id': 'AR9I1L41187FB37F0E',
#    'artist_name': 'Harry Connick_ Jr.',
#    'color': 'crimson',
#    's_hot': 0.50221122055080214,
#    'track_id': 'TRAOSFC128F42618F6',
#    'type': 'track'}),
#  ('Les Trois Orf\\xc3\\xa8vres',
#   {'a_fam': 0.51030132319154164,
#    'a_hot': 0.35297647202000682,
#    'artist_id': 'ARW45YR1187FB3DE95',
#    'artist_name': 'Pierre Perret',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAORCM12903CDEC46',
#    'type': 'track'}),
#  ('Never Alone',
#   {'a_fam': 0.47582793450484695,
#    'a_hot': 0.31400816731809039,
#    'artist_id': 'ARU230L1187FB4642F',
#    'artist_name': 'Walter Hawkins',
#    'color': 'crimson',
#    's_hot': 0.26586104921065007,
#    'track_id': 'TRAUMBG12903CF0D68',
#    'type': 'track'}),
#  ('Close Up',
#   {'a_fam': 0.38980296682759785,
#    'a_hot': 0.28773146783742498,
#    'artist_id': 'ARELA4P1187B991507',
#    'artist_name': 'Charles Williams',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRACHOZ12903CCA8B3',
#    'type': 'track'}),
#  ('You Feel Good All Over',
#   {'a_fam': 0.44932361520766179,
#    'a_hot': 0.34328188178708335,
#    'artist_id': 'ARLWR721187B9A03C9',
#    'artist_name': 'T.G. Sheppard',
#    'color': 'crimson',
#    's_hot': 0.38272328078919765,
#    'track_id': 'TRAAGOH128F42593CE',
#    'type': 'track'}),
#  ('As You Take A  Walk Through My Mind',
#   {'a_fam': 0.51644377977276279,
#    'a_hot': 0.38666909170602387,
#    'artist_id': 'ARF4V431187FB3AA41',
#    'artist_name': 'Slim Whitman',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAEKCR128F14593A5',
#    'type': 'track'}),
#  ('White Winter Hymnal',
#   {'a_fam': 0.42179225302761642,
#    'a_hot': 0.31920972076720344,
#    'artist_id': 'AR0OEYB1187FB4A81E',
#    'artist_name': 'Catherine Howe & Vo Fletcher',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAPBPB12903D1553B',
#    'type': 'track'}),
#  ('Andra sidan',
#   {'a_fam': 0.5666616579558601,
#    'a_hot': 0.41835668077407862,
#    'artist_id': 'ARGE4J31187B9B41EE',
#    'artist_name': 'Sofia Karlsson',
#    'color': 'crimson',
#    's_hot': 0.46630483075728629,
#    'track_id': 'TRAZSIN128F9352D39',
#    'type': 'track'}),
#  ('Jokers and Thieves',
#   {'a_fam': 0.16485330120346647,
#    'a_hot': 0.0,
#    'artist_id': 'ARKKTIY11F4C845817',
#    'artist_name': 'Chris Vickery',
#    'color': 'crimson',
#    's_hot': 0.34092275586437804,
#    'track_id': 'TRAHZVZ128F9322915',
#    'type': 'track'}),
#  ('Have It Your Way',
#   {'a_fam': 0.59311927210277915,
#    'a_hot': 0.37300073957592578,
#    'artist_id': 'ARZHUJU1187FB51176',
#    'artist_name': 'Leigh Jones',
#    'color': 'crimson',
#    's_hot': 0.51001872463594766,
#    'track_id': 'TRAFJUG128F92C77B1',
#    'type': 'track'}),
#  ('Hold On (LP Version)',
#   {'a_fam': 0.61291257290047707,
#    'a_hot': 0.39599952273493794,
#    'artist_id': 'ARHTRR71187B98F305',
#    'artist_name': 'Michelle Tumes',
#    'color': 'crimson',
#    's_hot': 0.26586104921065007,
#    'track_id': 'TRAGOUB128F42369BA',
#    'type': 'track'}),
#  ('When He Was On The Cross [I Was On His Mind]',
#   {'a_fam': 0.43402636790250576,
#    'a_hot': 0.23451976036910782,
#    'artist_id': 'ARDW74M1187B98DA34',
#    'artist_name': 'The Florida Boys',
#    'color': 'crimson',
#    's_hot': 0.31956598688286503,
#    'track_id': 'TRAYJXO128F4228ECC',
#    'type': 'track'}),
#  ('Your Love Takes Good Care Of Me',
#   {'a_fam': 0.38230828283667867,
#    'a_hot': 0.28356259598084455,
#    'artist_id': 'AR358YS1187FB44A29',
#    'artist_name': 'The Jordanaires',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBBAKQ128F92F0A8E',
#    'type': 'track'}),
#  ("Maybe You'll Love Me Too",
#   {'a_fam': 0.36280014168093827,
#    'a_hot': 0.28228640563265106,
#    'artist_id': 'ARW4AGO1187FB4F107',
#    'artist_name': 'Jazz Gillum',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBICFZ128F429F9E1',
#    'type': 'track'}),
#  ('Test 72',
#   {'a_fam': 0.49833708190459858,
#    'a_hot': 0.29822756089072461,
#    'artist_id': 'ARQ0BG21187B99ED8F',
#    'artist_name': 'Mush',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBHUPK12903CA5C21',
#    'type': 'track'}),
#  ('I Wonder Where You Are Tonight',
#   {'a_fam': 0.55150206908844424,
#    'a_hot': 0.35171775112090137,
#    'artist_id': 'ARB1KC91187FB38B13',
#    'artist_name': 'Carl Smith',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRBENNA12903D0411A',
#    'type': 'track'}),
#  ('The Lakes Of Pontchartrain',
#   {'a_fam': 0.54818009312682936,
#    'a_hot': 0.38259163809553404,
#    'artist_id': 'AR2XBPG1187B98FCBE',
#    'artist_name': 'Planxty',
#    'color': 'crimson',
#    's_hot': 0.45972498833129383,
#    'track_id': 'TRBFHFG128F930B5F9',
#    'type': 'track'}),
#  ('Seni Unuturum',
#   {'a_fam': 0.51404680462837105,
#    'a_hot': 0.38928238052412889,
#    'artist_id': 'ARU0XZY1187FB4002B',
#    'artist_name': 'Ebru G\\xc3\\xbcndes',
#    'color': 'crimson',
#    's_hot': 0.29987748827397781,
#    'track_id': 'TRAYDZS128F4288459',
#    'type': 'track'}),
#  ('Be Stiff (Live)',
#   {'a_fam': 0.70783996844159047,
#    'a_hot': 0.53244587095940743,
#    'artist_id': 'ARYML1P1187B9AF39B',
#    'artist_name': 'Devo',
#    'color': 'crimson',
#    's_hot': 0.44329131190539756,
#    'track_id': 'TRBENDH128F1467D62',
#    'type': 'track'}),
#  ('But You Are',
#   {'a_fam': 0.49191077140417266,
#    'a_hot': 0.38347032753511862,
#    'artist_id': 'AR1SFKQ1187B98AF13',
#    'artist_name': 'Lauren Wood',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRBDDET12903CBD912',
#    'type': 'track'}),
#  ('Two Wheels In the Ditch',
#   {'a_fam': 0.20176491815410058,
#    'a_hot': 0.0,
#    'artist_id': 'ARIBTOJ11F4C83E8DD',
#    'artist_name': "Undertakin' Daddies",
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAKVAS128F92FC385',
#    'type': 'track'}),
#  ("Pop A Cap In Yo' Ass",
#   {'a_fam': 0.61223527088626428,
#    'a_hot': 0.38520942741331538,
#    'artist_id': 'AR3P1NA1187FB44B9E',
#    'artist_name': 'Ben Watt feat. Estelle',
#    'color': 'crimson',
#    's_hot': 0.26586104921065007,
#    'track_id': 'TRADCQI128F42664A8',
#    'type': 'track'}),
#  ('Machuca',
#   {'a_fam': 0.60626792694207221,
#    'a_hot': 0.39741466337671016,
#    'artist_id': 'ARZ3U0K1187B999BF4',
#    'artist_name': 'Cabas',
#    'color': 'crimson',
#    's_hot': 0.3759843015004421,
#    'track_id': 'TRBDQVN128F425CF6D',
#    'type': 'track'}),
#  ('Use Me',
#   {'a_fam': 0.41717042790271391,
#    'a_hot': 0.27272937762388677,
#    'artist_id': 'ARM578G1187B989000',
#    'artist_name': 'Far Too Jones',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRADCYH128F931532A',
#    'type': 'track'}),
#  ('The Plot To Bomb The Panhandle (Album Version)',
#   {'a_fam': 0.8302362167035976,
#    'a_hot': 0.56923995373544334,
#    'artist_id': 'AROBSHL1187B9AFB01',
#    'artist_name': 'A Day To Remember',
#    'color': 'crimson',
#    's_hot': 0.74718179570677812,
#    'track_id': 'TRBEEEP128F426C17D',
#    'type': 'track'}),
#  ('Heart Of Dixie',
#   {'a_fam': 0.44158673321439401,
#    'a_hot': 0.27951547975684393,
#    'artist_id': 'AREB9421187FB458EF',
#    'artist_name': 'Tommy Overstreet',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRADWHL128F933E397',
#    'type': 'track'}),
#  ('Bahama Lullaby',
#   {'a_fam': 0.5217122143644578,
#    'a_hot': 0.35134507709257329,
#    'artist_id': 'AR97EHA1187B98AD5F',
#    'artist_name': 'Blind Blake & The Royal Victoria Hotel Calypsos',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAFIKF128F92FD338',
#    'type': 'track'}),
#  ("It Has Been A Long Time_ Hasn't It",
#   {'a_fam': 0.77526876872167394,
#    'a_hot': 0.41501140026139904,
#    'artist_id': 'ARWQQYJ1187B9ADC4C',
#    'artist_name': 'Anubis Spire',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRACWSJ128F42739DE',
#    'type': 'track'}),
#  ('Sou Vazo Diskola',
#   {'a_fam': 0.34416504941451576,
#    'a_hot': 0.30318955663217473,
#    'artist_id': 'AR15O341187B9B182C',
#    'artist_name': 'Natassa Theodoridou',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBGJXW128F42AE7D8',
#    'type': 'track'}),
#  ('We Blame Love',
#   {'a_fam': 0.63092860767879988,
#    'a_hot': 0.46155845195981815,
#    'artist_id': 'AR5MK521187B98E0B8',
#    'artist_name': 'Heaven 17',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBAPPF128F4243DA5',
#    'type': 'track'}),
#  ('Let It All Go',
#   {'a_fam': 0.68742981080619403,
#    'a_hot': 0.44071511458391005,
#    'artist_id': 'ARZ2DHF1187FB3F2EA',
#    'artist_name': 'Krayzie Bone',
#    'color': 'crimson',
#    's_hot': 0.43483809026085618,
#    'track_id': 'TRAUDNM12903CDEF32',
#    'type': 'track'}),
#  ('The One Who Lives Inside Your Heart',
#   {'a_fam': 0.47746703723921385,
#    'a_hot': 0.34198173597362663,
#    'artist_id': 'ARO2PB81187B98EB4A',
#    'artist_name': 'Lari White',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBBSZN128F930E4E7',
#    'type': 'track'}),
#  ('Wow',
#   {'a_fam': 0.81831935913889431,
#    'a_hot': 0.66729459564346905,
#    'artist_id': 'ARVN9FZ1187FB393F1',
#    'artist_name': 'Snow Patrol',
#    'color': 'crimson',
#    's_hot': 0.7714739235051018,
#    'track_id': 'TRANQQZ128E079224E',
#    'type': 'track'}),
#  ('Nothing To Hold Me',
#   {'a_fam': 0.59247207295597504,
#    'a_hot': 0.42062740133562165,
#    'artist_id': 'AR2HXXS1187B9AF3E2',
#    'artist_name': 'Jesus Jones',
#    'color': 'crimson',
#    's_hot': 0.45694954353714434,
#    'track_id': 'TRBGTZD128EF34B6C3',
#    'type': 'track'}),
#  ('Sabor Guajiro',
#   {'a_fam': 0.48235604259091081,
#    'a_hot': 0.35007857898947331,
#    'artist_id': 'AR6YDKV1187B989230',
#    'artist_name': 'Roberto Torres',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAADLR12903CF8D7E',
#    'type': 'track'}),
#  ("Don't Cry_ Joe",
#   {'a_fam': 0.49640625856618142,
#    'a_hot': 0.33075388875142681,
#    'artist_id': 'ARK82DC1187B9A1FEB',
#    'artist_name': 'Gordon Jenkins',
#    'color': 'crimson',
#    's_hot': 0.26586104921065007,
#    'track_id': 'TRABSNL128F92E2872',
#    'type': 'track'}),
#  ('Sinnloz/ Anakonda (live)',
#   {'a_fam': 0.419034024131271,
#    'a_hot': 0.29398439015383726,
#    'artist_id': 'ARFY8NV1187B9B1961',
#    'artist_name': 'Der Moderne Man',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAMQKQ128F93291A3',
#    'type': 'track'}),
#  ('Amor Bonito',
#   {'a_fam': 0.54631042369933347,
#    'a_hot': 0.3099193396540712,
#    'artist_id': 'ARXTM8U1187B99F200',
#    'artist_name': 'Pablo Montero',
#    'color': 'crimson',
#    's_hot': 0.23621627901094303,
#    'track_id': 'TRAWLRK128F930F89B',
#    'type': 'track'}),
#  ('Just Say Yes',
#   {'a_fam': 0.81831935913889431,
#    'a_hot': 0.66729459564346905,
#    'artist_id': 'ARVN9FZ1187FB393F1',
#    'artist_name': 'Snow Patrol',
#    'color': 'crimson',
#    's_hot': 0.94599467982204033,
#    'track_id': 'TRALDUE128F9312AF2',
#    'type': 'track'}),
#  ('Cry_ Cry_ Cry',
#   {'a_fam': 0.35342955022197026,
#    'a_hot': 0.36551400326265299,
#    'artist_id': 'ARBMHBC11F4C8403A2',
#    'artist_name': 'Hushabye Baby',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRBAIUY128F92FF7F0',
#    'type': 'track'}),
#  ('Maracaia',
#   {'a_fam': 0.54192835966604558,
#    'a_hot': 0.37385634452162525,
#    'artist_id': 'ARAENPX1187B990DDA',
#    'artist_name': 'Timbalada',
#    'color': 'crimson',
#    's_hot': 0.40109529658516824,
#    'track_id': 'TRAUKGN128F1499A8D',
#    'type': 'track'}),
#  ("Sho' Enough",
#   {'a_fam': 0.5726162458211238,
#    'a_hot': 0.41558288068042459,
#    'artist_id': 'ARV57NY1187FB3C1DC',
#    'artist_name': 'Tommy Castro',
#    'color': 'crimson',
#    's_hot': 0.42512465831305757,
#    'track_id': 'TRAETWP128F421AD6A',
#    'type': 'track'}),
#  ('Rant Kanaria',
#   {'a_fam': 0.4643625908988418,
#    'a_hot': 0.41784614771379464,
#    'artist_id': 'ARW1WST1187FB384DA',
#    'artist_name': 'Jope Ruonansuu',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRARYDZ128F9355209',
#    'type': 'track'}),
#  ("Can't Break This Man",
#   {'a_fam': 0.45404399500343795,
#    'a_hot': 0.42141510254240711,
#    'artist_id': 'AR9XEVF1187B99D017',
#    'artist_name': 'Borialis',
#    'color': 'crimson',
#    's_hot': 0.55280766203543397,
#    'track_id': 'TRADMCH128E0784D99',
#    'type': 'track'}),
#  ('This Christmas (LP Version)',
#   {'a_fam': 0.65740676529844899,
#    'a_hot': 0.42247242324321971,
#    'artist_id': 'ARTB5PP1187FB523B7',
#    'artist_name': 'Donny Hathaway',
#    'color': 'crimson',
#    's_hot': 0.99775839634026842,
#    'track_id': 'TRABUDK128F14943F3',
#    'type': 'track'}),
#  ('Mark Practices',
#   {'a_fam': 0.54903390541200203,
#    'a_hot': 0.37666410585810928,
#    'artist_id': 'ARJJKAA1187B9ADAF1',
#    'artist_name': 'Rolfe Kent',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBCNTP128F93530CF',
#    'type': 'track'}),
#  ('Kiss the Sky',
#   {'a_fam': 0.50526939552243411,
#    'a_hot': 0.0,
#    'artist_id': 'ARORFIN1187FB3BE5C',
#    'artist_name': 'Danielle Bollinger',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBBVPM12903CDB094',
#    'type': 'track'}),
#  ('El Perro',
#   {'a_fam': 0.70366488991664178,
#    'a_hot': 0.44822358922684991,
#    'artist_id': 'AR7DFJP1187B992F13',
#    'artist_name': 'Juana Molina',
#    'color': 'crimson',
#    's_hot': 0.64998975550559746,
#    'track_id': 'TRBCRDS128F426018C',
#    'type': 'track'}),
#  ('Scrimmage',
#   {'a_fam': 0.47135797835015031,
#    'a_hot': 0.28302708862330006,
#    'artist_id': 'ARJMGMP124BAE72D46',
#    'artist_name': 'Gerald Clayton',
#    'color': 'crimson',
#    's_hot': 0.31956598688286503,
#    'track_id': 'TRAZDHN12903CB7532',
#    'type': 'track'}),
#  ('Anfang Vom Ende',
#   {'a_fam': 0.54867243574098246,
#    'a_hot': 0.35850092274043266,
#    'artist_id': 'ARGDY4Y1187B9A334F',
#    'artist_name': 'Pyranja',
#    'color': 'crimson',
#    's_hot': 0.21508031850922793,
#    'track_id': 'TRAUVAR12903CBD9A4',
#    'type': 'track'}),
#  ('In Pursuit of the Implicate Order of Cultural Chaos',
#   {'a_fam': 0.54511095082138372,
#    'a_hot': 0.34575124701970272,
#    'artist_id': 'ARJGNV61187B98F3B5',
#    'artist_name': 'Mira',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRATGDZ128F9314B6C',
#    'type': 'track'}),
#  ('Comfortable',
#   {'a_fam': 0.83794790918938877,
#    'a_hot': 0.78813775828340926,
#    'artist_id': 'ARZENOX1187B98A645',
#    'artist_name': 'John Mayer',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAPRQZ128F427E188',
#    'type': 'track'}),
#  ('La cl\\xc3\\xa9 parfum\\xc3\\xa9e',
#   {'a_fam': 0.61180147146000885,
#    'a_hot': 0.39904208143240477,
#    'artist_id': 'AR9ILJF1187B9B80ED',
#    'artist_name': 'Gabriel Yared',
#    'color': 'crimson',
#    's_hot': 0.21204540548371908,
#    'track_id': 'TRAFPLF12903CD8AE1',
#    'type': 'track'}),
#  ('Sentimental Journey',
#   {'a_fam': 0.35449610815774918,
#    'a_hot': 0.24945364941116574,
#    'artist_id': 'ARXGICZ1187FB444DD',
#    'artist_name': 'The Merry Macs',
#    'color': 'crimson',
#    's_hot': 0.22914410371660274,
#    'track_id': 'TRAHKND128F935E15F',
#    'type': 'track'}),
#  ('Main Title / The Searchers',
#   {'a_fam': 0.47189487551491599,
#    'a_hot': 0.35549113602485716,
#    'artist_id': 'ARJRF841187B9B7F9A',
#    'artist_name': 'Max Steiner',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAKOYE128F4229B67',
#    'type': 'track'}),
#  ('Skyline',
#   {'a_fam': 0.29191244121150878,
#    'a_hot': 0.0,
#    'artist_id': 'ARN5MQ11187B98A12D',
#    'artist_name': 'Sean Quinn',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAKYKW12903CCBD27',
#    'type': 'track'}),
#  ('Church Hangover',
#   {'a_fam': 0.66802024872330457,
#    'a_hot': 0.51696373073834112,
#    'artist_id': 'ARYF20K1187B9B76BD',
#    'artist_name': 'George Lopez',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRACJDX12903CD4917',
#    'type': 'track'}),
#  ('So Many Reasons',
#   {'a_fam': 0.37455343568216087,
#    'a_hot': 0.32754381337812372,
#    'artist_id': 'ARDFZE61187FB45994',
#    'artist_name': 'Jake Hess',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAUIYH128E078DA2F',
#    'type': 'track'}),
#  ('Two Elegiac Melodies Op. 34: 2. The Last Spring',
#   {'a_fam': 0.43002498682970675,
#    'a_hot': 0.35303405577540575,
#    'artist_id': 'ARBH0MS1187FB36311',
#    'artist_name': 'Sir Neville Marriner',
#    'color': 'crimson',
#    's_hot': 0.58892216755590654,
#    'track_id': 'TRBIBSS128F14A205E',
#    'type': 'track'}),
#  ('Fly Again (The Scumfrog Radio Edit)',
#   {'a_fam': 0.62037947928465598,
#    'a_hot': 0.40789846645794431,
#    'artist_id': 'ARUME5Q1187B9B1AA7',
#    'artist_name': 'Kristine W.',
#    'color': 'crimson',
#    's_hot': 0.26801031558477889,
#    'track_id': 'TRBDMBY12903CE84AF',
#    'type': 'track'}),
#  ("Don't Let Go",
#   {'a_fam': 0.56932968736670952,
#    'a_hot': 0.39488108337774364,
#    'artist_id': 'ARHB1961187B9B1732',
#    'artist_name': 'Kofi',
#    'color': 'crimson',
#    's_hot': 0.24047374606428715,
#    'track_id': 'TRALETZ12903D0355E',
#    'type': 'track'}),
#  ('Outside The Law',
#   {'a_fam': 0.70836820370739695,
#    'a_hot': 0.45980942246281409,
#    'artist_id': 'ARORFTD1187B99F7D4',
#    'artist_name': 'Epitaph',
#    'color': 'crimson',
#    's_hot': 0.26695518627553855,
#    'track_id': 'TRASCGS128F426C1AF',
#    'type': 'track'}),
#  ("I'm Thinking Tonight Of My Blue Eyes",
#   {'a_fam': 0.70733568125740143,
#    'a_hot': 0.60387648691816243,
#    'artist_id': 'ARYJSY01187B9B7C65',
#    'artist_name': 'Dolly Parton',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAYKCV128F9341943',
#    'type': 'track'}),
#  ('School',
#   {'a_fam': 0.82580538619249122,
#    'a_hot': 0.66138292433802448,
#    'artist_id': 'ARH3S5S1187FB4F76B',
#    'artist_name': 'Nirvana',
#    'color': 'crimson',
#    's_hot': 0.80770523566171526,
#    'track_id': 'TRANWZE128E078EE09',
#    'type': 'track'}),
#  ('The Kangaroo Theory',
#   {'a_fam': 0.4908047553265712,
#    'a_hot': 0.37205113225041059,
#    'artist_id': 'ARDCIH31187B98B241',
#    'artist_name': 'Edelweiss',
#    'color': 'crimson',
#    's_hot': 0.38330805475797713,
#    'track_id': 'TRBEVND128F93429DD',
#    'type': 'track'}),
#  ('The Christmas Song  (LP Version)',
#   {'a_fam': 0.61464295415917725,
# ...
#    'artist_name': 'Spliff',
#    'color': 'crimson',
#    's_hot': 0.57531968809532352,
#    'track_id': 'TRBGLCC128F427FE7D',
#    'type': 'track'}),
#  ('Say How I Feel',
#   {'a_fam': 0.49183595905838312,
#    'a_hot': 0.38941401403392173,
#    'artist_id': 'AR0WV4Y1187B99B806',
#    'artist_name': 'Rhian Benson',
#    'color': 'crimson',
#    's_hot': 0.5763999812554107,
#    'track_id': 'TRAEFDB128E0783952',
#    'type': 'track'}),
#  ('Hush',
#   {'a_fam': 0.54003774897977885,
#    'a_hot': 0.36005330653898399,
#    'artist_id': 'AR1N6N61187FB4E25E',
#    'artist_name': 'Mongo Santamaria',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAFUWS128F9320678',
#    'type': 'track'}),
#  ('Guardians Of The Forest',
#   {'a_fam': 0.60054656469004286,
#    'a_hot': 0.37957424750292335,
#    'artist_id': 'AREC9D21187FB3A3D5',
#    'artist_name': 'Wolfchant',
#    'color': 'crimson',
#    's_hot': 0.61017454047701514,
#    'track_id': 'TRAPVDC128F422C711',
#    'type': 'track'}),
#  ('The Bravest Kids (Acoustic)',
#   {'a_fam': 0.85072826585840089,
#    'a_hot': 0.54205463146377253,
#    'artist_id': 'ARF84A41187B9A34E7',
#    'artist_name': 'Rancid',
#    'color': 'crimson',
#    's_hot': 0.46630483075728635,
#    'track_id': 'TRAYZXR128F934858F',
#    'type': 'track'}),
#  ('Medicate Myself',
#   {'a_fam': 0.70334944041161451,
#    'a_hot': 0.4983953383497739,
#    'artist_id': 'ARQOC971187B9910FA',
#    'artist_name': 'The Verve Pipe',
#    'color': 'crimson',
#    's_hot': 0.46630483075728624,
#    'track_id': 'TRAAJJG128F4284B27',
#    'type': 'track'}),
#  ('Ooh Wee Baby',
#   {'a_fam': 0.62856015593589454,
#    'a_hot': 0.29296817047544627,
#    'artist_id': 'AREV0ZO1187B997221',
#    'artist_name': 'Doyle Bramhall',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRANALJ128F9318BAF',
#    'type': 'track'}),
#  ('Be Aware',
#   {'a_fam': 0.6126405242364219,
#    'a_hot': 0.43678294949471058,
#    'artist_id': 'ARVWNTI1269FB34C59',
#    'artist_name': 'SOJA',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRARPTJ12903CE2898',
#    'type': 'track'}),
#  ('What Would You Do',
#   {'a_fam': 0.43719377693850187,
#    'a_hot': 0.31615598739703837,
#    'artist_id': 'AROBQ0B1187FB404F6',
#    'artist_name': 'Walter Jackson',
#    'color': 'crimson',
#    's_hot': 0.35326135426498734,
#    'track_id': 'TRACIEF128F4270573',
#    'type': 'track'}),
#  ('Joaquin Torres Jr.',
#   {'a_fam': 0.64890258200687401,
#    'a_hot': 0.44083500671309339,
#    'artist_id': 'ARP07GD1187B9B9DA4',
#    'artist_name': 'Los Originales De San Juan',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRBDUAQ128F427154D',
#    'type': 'track'}),
#  ('African Typic Collection',
#   {'a_fam': 0.3601872937264462,
#    'a_hot': 0.24306454234167216,
#    'artist_id': 'AR41B9G1187B990D63',
#    'artist_name': 'Sam Fan Thomas',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRATSNE128F427EDB6',
#    'type': 'track'}),
#  ('Sheng Li Hu Huan',
#   {'a_fam': 0.42288755669041922,
#    'a_hot': 0.29624881058023994,
#    'artist_id': 'AR9E43L1187FB566FA',
#    'artist_name': 'Steve Chou',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAYMPF128F92F3362',
#    'type': 'track'}),
#  ('Whispering Grass',
#   {'a_fam': 0.12118729834524621,
#    'a_hot': 0.0,
#    'artist_id': 'ARLJK1O1187B9B0FC4',
#    'artist_name': 'The Knightsbridge Strings',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRANUPI12903CA6A4F',
#    'type': 'track'}),
#  ('Ai Ji Mei Gui 1000 Da',
#   {'a_fam': 0.49867683039709543,
#    'a_hot': 0.35416895482890376,
#    'artist_id': 'AR0QS8F1187B9ADC96',
#    'artist_name': 'Sandy Lam',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRATNIZ128F42414D2',
#    'type': 'track'}),
#  ('Tonight Will Be Alright',
#   {'a_fam': 0.77667585568455411,
#    'a_hot': 0.55307199146197528,
#    'artist_id': 'ARIK43K1187B9AE54C',
#    'artist_name': 'Lionel Richie',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAABJV128F1460C49',
#    'type': 'track'}),
#  ('Break My Mind',
#   {'a_fam': 0.38230828283667867,
#    'a_hot': 0.28356259598084455,
#    'artist_id': 'AR358YS1187FB44A29',
#    'artist_name': 'The Jordanaires',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAYLQL128F92F0A86',
#    'type': 'track'}),
#  ('The 23rd Psalm',
#   {'a_fam': 0.4619174308607043,
#    'a_hot': 0.36062567059628048,
#    'artist_id': 'ARHY20W1187B9B8262',
#    'artist_name': 'Steve Erquiaga',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRBBRVT128F428EA7A',
#    'type': 'track'}),
#  ('Rewind',
#   {'a_fam': 0.53753296749082857,
#    'a_hot': 0.3698701070312031,
#    'artist_id': 'ARID1TK1187FB4CFB8',
#    'artist_name': 'All Girl Summer Fun Band',
#    'color': 'crimson',
#    's_hot': 0.44713579628617778,
#    'track_id': 'TRALODZ128F931FA34',
#    'type': 'track'}),
#  ('Caricia Y Herida',
#   {'a_fam': 0.4205458495228202,
#    'a_hot': 0.31356934268380171,
#    'artist_id': 'ARHFEBO11F50C4825A',
#    'artist_name': 'Flor Silvestre',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAAGZU128EF360F47',
#    'type': 'track'}),
#  ('Faithful and True (Collectors Version)',
#   {'a_fam': 0.49030398037367301,
#    'a_hot': 0.33441527067536053,
#    'artist_id': 'ARRPCKN1187FB5BA2F',
#    'artist_name': 'Z.Z. Hill',
#    'color': 'crimson',
#    's_hot': 0.23376270577652303,
#    'track_id': 'TRACXUW128F93093F5',
#    'type': 'track'}),
#  ('Stereophonic Presentation - Process And Passion_ Pt. 4',
#   {'a_fam': 0.31569241024991279,
#    'a_hot': 0.26350909729933758,
#    'artist_id': 'ARPK1CM1187B9B6B9C',
#    'artist_name': 'Roger Reynolds',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAYGWA128F421FFD5',
#    'type': 'track'}),
#  ('Need More Blues',
#   {'a_fam': 0.51900007237342527,
#    'a_hot': 0.35303574014515915,
#    'artist_id': 'ARE2QID1187B98FA19',
#    'artist_name': 'Sleepy John Estes',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAIRHS128F4287576',
#    'type': 'track'}),
#  ('Banana Split Republic',
#   {'a_fam': 0.43980978276720928,
#    'a_hot': 0.27159725083436387,
#    'artist_id': 'ARYZFGE1187FB39A8C',
#    'artist_name': 'False Prophets',
#    'color': 'crimson',
#    's_hot': 0.38289336427502196,
#    'track_id': 'TRAWWTR128F93593BF',
#    'type': 'track'}),
#  ('Just A Phase',
#   {'a_fam': 0.8992795990782162,
#    'a_hot': 0.57944193788574494,
#    'artist_id': 'AR1RMYB1187FB5A59E',
#    'artist_name': 'Incubus',
#    'color': 'crimson',
#    's_hot': 0.70969928993332021,
#    'track_id': 'TRAIHPX128F428081B',
#    'type': 'track'}),
#  ('Yesterdays',
#   {'a_fam': 0.53439229410017874,
#    'a_hot': 0.34517431863973785,
#    'artist_id': 'ARDE7I31187FB43352',
#    'artist_name': 'Gonzalo Rubalcaba',
#    'color': 'crimson',
#    's_hot': 0.33470654906922065,
#    'track_id': 'TRAROHB128F145CD83',
#    'type': 'track'}),
#  ("Since I've Been Loving You",
#   {'a_fam': 0.5134675221364372,
#    'a_hot': 0.38367798246092433,
#    'artist_id': 'ARON0YP1187FB4B465',
#    'artist_name': 'Fiona',
#    'color': 'crimson',
#    's_hot': 0.37598430150044215,
#    'track_id': 'TRAWAWH128F934C8E4',
#    'type': 'track'}),
#  ('Incide',
#   {'a_fam': 0.63393272577853665,
#    'a_hot': 0.41652939963732327,
#    'artist_id': 'ARB4ZRM1187B993147',
#    'artist_name': 'Dark Fortress',
#    'color': 'crimson',
#    's_hot': 0.66833866486032756,
#    'track_id': 'TRASJRH12903CF2689',
#    'type': 'track'}),
#  ('Hear Me Lord (2001 Digital Remaster)',
#   {'a_fam': 0.73904742374508536,
#    'a_hot': 0.54160250251528919,
#    'artist_id': 'ARW9QSZ1187FB4B93E',
#    'artist_name': 'George Harrison',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRABLLK128F428FFAF',
#    'type': 'track'}),
#  ('Antes Que Seja Tarde',
#   {'a_fam': 0.49866364857789747,
#    'a_hot': 0.32188268994567615,
#    'artist_id': 'AR6C8EJ1187FB3F473',
#    'artist_name': 'Nelson Ned',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAWTJS128F1494751',
#    'type': 'track'}),
#  ('Das Geheimrezept',
#   {'a_fam': 0.44592627458772754,
#    'a_hot': 0.23381943778669392,
#    'artist_id': 'ARD9THI1187B98EAD0',
#    'artist_name': 'Larissa',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAVUYL128F934A9C5',
#    'type': 'track'}),
#  ('The World In My Hands (We Are One)',
#   {'a_fam': 0.71881020996457767,
#    'a_hot': 0.46390009479233241,
#    'artist_id': 'AR5O6W51187FB46984',
#    'artist_name': 'SNAP!',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBEMJC128F14A6E0D',
#    'type': 'track'}),
#  ('2StepN',
#   {'a_fam': 0.74621385680889607,
#    'a_hot': 0.47695504629068791,
#    'artist_id': 'ARGLOWN1187B99C06D',
#    'artist_name': 'North Mississippi Allstars',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBBZFO128F932CD27',
#    'type': 'track'}),
#  ('That you fool ed me',
#   {'a_fam': 0.35118245388301211,
#    'a_hot': 0.080166938664249995,
#    'artist_id': 'AR051KA1187B98B2FF',
#    'artist_name': 'Wilks',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBCORX128F4275BEB',
#    'type': 'track'}),
#  ('Street Sh***',
#   {'a_fam': 0.64097168257816317,
#    'a_hot': 0.0,
#    'artist_id': 'AROGHQQ1187B9890E3',
#    'artist_name': 'Mil featuring Memphis Bleek',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAPYBS128F9309278',
#    'type': 'track'}),
#  ('A Girls Oath',
#   {'a_fam': 0.76456608430512463,
#    'a_hot': 0.52749298101614384,
#    'artist_id': 'ARPNY981187B9ACB75',
#    'artist_name': 'Eluveitie',
#    'color': 'crimson',
#    's_hot': 0.65067696898203597,
#    'track_id': 'TRAIVFK128F932C825',
#    'type': 'track'}),
#  ('Who Cares',
#   {'a_fam': 0.54075015143582295,
#    'a_hot': 0.3796512190020615,
#    'artist_id': 'AR7CCCC1187FB578FF',
#    'artist_name': 'Don Gibson',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAOPAR128F92EFD17',
#    'type': 'track'}),
#  ('I Want What I Want',
#   {'a_fam': 0.50755090618272125,
#    'a_hot': 0.41213032654206949,
#    'artist_id': 'ARJNRA61187FB57724',
#    'artist_name': 'Weirdos_ The',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAKXJS12903CE0434',
#    'type': 'track'}),
#  ('To Pouli',
#   {'a_fam': 0.26471398656972184,
#    'a_hot': 0.0,
#    'artist_id': 'AR4OHL91187B9B2EB9',
#    'artist_name': 'Angela Dimitriou',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBGJGI128F427CA73',
#    'type': 'track'}),
#  ('Duck And Run',
#   {'a_fam': 0.84043242174227284,
#    'a_hot': 0.60884901857065343,
#    'artist_id': 'ARW1MUW1187FB4D5A1',
#    'artist_name': '3 Doors Down',
#    'color': 'crimson',
#    's_hot': 0.52781813655648746,
#    'track_id': 'TRASZUN128F148B165',
#    'type': 'track'}),
#  ('Missing You',
#   {'a_fam': 0.53444360241472444,
#    'a_hot': 0.33358462783523912,
#    'artist_id': 'AR52QY11187B99FC59',
#    'artist_name': 'Anthony Cruz',
#    'color': 'crimson',
#    's_hot': 0.26586104921065007,
#    'track_id': 'TRAVOFJ128F933DEA1',
#    'type': 'track'}),
#  ('Skin Ticket (Live version) (Album Version)',
#   {'a_fam': 0.92893692618856438,
#    'a_hot': 0.59855541189439554,
#    'artist_id': 'AR0KBXO1187B996460',
#    'artist_name': 'Slipknot',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBAUBI128F424142E',
#    'type': 'track'}),
#  ('Naked Albino',
#   {'a_fam': 0.53938059021068641,
#    'a_hot': 0.36058358215167524,
#    'artist_id': 'ARRA2F91187B9B4061',
#    'artist_name': 'Bare Jr.',
#    'color': 'crimson',
#    's_hot': 0.0,
#    'track_id': 'TRAAMXP128F4264F6A',
#    'type': 'track'}),
#  ('Yesss Lord...',
#   {'a_fam': 0.4871408009458939,
#    'a_hot': 0.30672097559350214,
#    'artist_id': 'ARYORUX11F4C846890',
#    'artist_name': 'Perfection',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAWRLA128F93061F0',
#    'type': 'track'}),
#  ('San Cristobal',
#   {'a_fam': 0.54678871665432371,
#    'a_hot': 0.37082898997298236,
#    'artist_id': 'AR0693R1187FB59D32',
#    'artist_name': 'Dusminguet',
#    'color': 'crimson',
#    's_hot': 0.28848164265602888,
#    'track_id': 'TRABTSM128F426AF07',
#    'type': 'track'}),
#  ('Give Me That Touch (The Touch Up Mix)',
#   {'a_fam': 0.3738899787956248,
#    'a_hot': 0.24761331863249805,
#    'artist_id': 'ARJ7HBI1187B993719',
#    'artist_name': 'Deborahe Glasgow',
#    'color': 'crimson',
#    's_hot': 0.22689469123221734,
#    'track_id': 'TRALUSV128F42515D8',
#    'type': 'track'}),
#  ('Wasted Days And Wasted Nights',
#   {'a_fam': 0.37834796858643616,
#    'a_hot': 0.30651860003807457,
#    'artist_id': 'AR059HI1187B9A14D7',
#    'artist_name': 'Roy Drusky',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAORLG12903CB578A',
#    'type': 'track'}),
#  ('Laying Down My Will (The Plan Album Version)',
#   {'a_fam': 0.55030337888410075,
#    'a_hot': 0.40737314928722795,
#    'artist_id': 'ARI4NXX1187FB59DF2',
#    'artist_name': 'Raze',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAFKMJ128F14661D8',
#    'type': 'track'}),
#  ('Your Touch Versus Death',
#   {'a_fam': 0.84242331806690451,
#    'a_hot': 0.56485575047668202,
#    'artist_id': 'ARCP94M1187B9B0F56',
#    'artist_name': 'Every Time I Die',
#    'color': 'crimson',
#    's_hot': 0.52973060722890153,
#    'track_id': 'TRBBJBO128F92EB2C5',
#    'type': 'track'}),
#  ('Choro II',
#   {'a_fam': 0.52733918349915054,
#    'a_hot': 0.31055608317952577,
#    'artist_id': 'ARUP17W1187B98CAB9',
#    'artist_name': 'Charlie Byrd / Laurindo Almeida',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAGOEW128F427A209',
#    'type': 'track'}),
#  ("Widow's Walk",
#   {'a_fam': 0.6197471466593556,
#    'a_hot': 0.40738682964593709,
#    'artist_id': 'ARC5Q0L1187B98D463',
#    'artist_name': 'Enter the Haggis',
#    'color': 'crimson',
#    's_hot': 0.44859049865724998,
#    'track_id': 'TRAJSCN12903D0CBAA',
#    'type': 'track'}),
#  ('Onni',
#   {'a_fam': 0.51748057192659047,
#    'a_hot': 0.4328043103024764,
#    'artist_id': 'ARD5SR21187B9B5F4A',
#    'artist_name': 'Irwin Goodman',
#    'color': 'crimson',
#    's_hot': 0.2150803185092279,
#    'track_id': 'TRAQQEE128EF342942',
#    'type': 'track'}),
#  ('I Know That Car',
#   {'a_fam': 0.46499431936808794,
#    'a_hot': 0.34472111117200155,
#    'artist_id': 'ARHT0B11187B993CB3',
#    'artist_name': 'Eddy Raven',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAKFQV128F145C912',
#    'type': 'track'}),
#  ('Another Djemba Djemba',
#   {'a_fam': 0.52053044405528481,
#    'a_hot': 0.27481627558840205,
#    'artist_id': 'ARGNQED1241B9C4237',
#    'artist_name': 'Youves',
#    'color': 'crimson',
#    's_hot': 0.38293509007501925,
#    'track_id': 'TRAJIDY128F931C89D',
#    'type': 'track'}),
#  ('Bull Dog',
#   {'a_fam': 0.64080710196367285,
#    'a_hot': 0.41821651819493683,
#    'artist_id': 'ARAJPHH1187FB5566A',
#    'artist_name': 'The Shangri-Las',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAUPEE128F425943A',
#    'type': 'track'}),
#  ('What Is Light? Where Is Laughter? (Acoustic Version)',
#   {'a_fam': 0.69025759625879046,
#    'a_hot': 0.41902804640879043,
#    'artist_id': 'ARJGRNY11F4C847277',
#    'artist_name': 'Twin Atlantic',
#    'color': 'crimson',
#    's_hot': 0.439202489315343,
#    'track_id': 'TRAWNSM12903CA71FC',
#    'type': 'track'}),
#  ('All I Want',
#   {'a_fam': 0.52482139287038265,
#    'a_hot': 0.36216215900153731,
#    'artist_id': 'AR19JS91187B98CB66',
#    'artist_name': 'Captain Hollywood Project',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAPRDY128F930DBA5',
#    'type': 'track'}),
#  ('Jetstream - Arthur Baker Remix',
#   {'a_fam': 0.7207110575919069,
#    'a_hot': 0.52204795519161296,
#    'artist_id': 'ARNHHIV1187FB4EA23',
#    'artist_name': 'New Order',
#    'color': 'crimson',
#    's_hot': 0.36037058271214062,
#    'track_id': 'TRADZYD128E078BE45',
#    'type': 'track'}),
#  ('The Attitude Song',
#   {'a_fam': 0.64572002333601042,
#    'a_hot': 0.54395441705583902,
#    'artist_id': 'AROY6XW1187B991121',
#    'artist_name': 'Steve Vai',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRASQHA128F4280A1D',
#    'type': 'track'}),
#  ('Lil Brother (LP Version)',
#   {'a_fam': 0.57567421848105338,
#    'a_hot': 0.36682078763979759,
#    'artist_id': 'ARLTWXK1187FB5A3F8',
#    'artist_name': 'King Curtis',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRBHJZX128F1495DAE',
#    'type': 'track'}),
#  ('22 (Vingt Deux) (Feat. Ours)',
#   {'a_fam': 0.6768859314057637,
#    'a_hot': 0.53540837922981366,
#    'artist_id': 'ARKZJ301187FB521B2',
#    'artist_name': 'Lily Allen Featuring Ours',
#    'color': 'crimson',
#    's_hot': nan,
#    'track_id': 'TRAWAQB128F930D7F7',
#    'type': 'track'})]

# %% [markdown]
# ### Add the Edges - with attributes and weight
#
# First, the `track` to `track` edges are added, with the computed weights and the inverse weights along with the other attributes.

# %%
# Adding the Edges
# using from pandas dataframe ()
graph_edge_pd = nx.from_pandas_dataframe(df_ss, 'title_l', 'title_r', 
                                           edge_attr=['artist_name_l','artist_name_r',
                                                      'hot_l','hot_r','fam_l','fam_r',
                                                      'wt_l_sum','wt_r_sum',
                                                      'cnt_at','weight','inv_weight'], 
                                           create_using=nx.Graph())
print(type(graph_edge_pd))
edges = nx.to_edgelist(graph_edge_pd)

print(type(edges))
G_2.add_edges_from(edges)

print('No. of track to track edges:', G_2.number_of_edges())
# Out:
# <class 'networkx.classes.graph.Graph'>
# <class 'list'>
# No. of track to track edges: 99420

# %% [markdown]
# The `df_ss` dataframe contained __198,840__ rows indicating that there are those many number of direct connections between `track` - `track` nodes. But since there are reverse paths too, it was pointed to earlier that these will be ignored by `networkx` and that the number of edges will be halved. Note that __99,420__ edges above. It would have been halved even if a `MultiGraph` was used since the edge attributes are the same for both the forward and reverse paths.
#
# ### Draw the weighted network graph
#
# The computed weights will be used as the weights for the edges. The weights will be represented by the `width` of the edges in the graph. The thicker the edge, the stronger the relationship. To reduce the effect, a multiplicative factor of 0.25 is used, owing to the larger absolute weights. Also, a `spring_layout` is used which will ensure that the nodes are distributed so as to create an equilibrium state. In simpler terms, more connected (weight based) nodes will be at the centre while the lesser connected ones will be farther from the centre.

# %%
# Draw the network graph
nx.draw(G_2,
        pos=nx.spring_layout(G_2), # Or spectral_layout, random_layout, shell_layout , spring_layout     
        with_labels = False,
        node_size=100, 
        alpha=0.8, 
        node_color = [G_2.node[node]['color'] for node in G_2],#node_color_values['color'],
        font_size = 7,
        font_color = 'black',
        font_family = 'arial',
        edge_color = 'gray',
        width = [0.25*edge[2]['weight'] for edge in G_2.edges(data=True)])
        
pyplot.show()

# %% [markdown]
# As can be seen from the network graph, almost all the `track` nodes form one big cluster. This is probably because, all the connections between `track` nodes have been considered. In other words, all ranges of weights have been included as a valid relationship. Maybe if edges that have weights below a threshold are dropped, the graph might present a different picture. In order to do this, let us look at the distribution of the computed weights (`weight`) in the dataframe.

# %%
# Distribution of weights
print(df_ss.weight.describe())
# Out:
# count    198840.000000
# mean          5.486316
# std           5.322947
# min           0.099538
# 25%           1.890026
# 50%           3.824369
# 75%           7.128170
# max          71.351698
# Name: weight, dtype: float64

# %% [markdown]
# Based on the numbers above, the mean weight of an edge in the graph is __5.486__,25% of the edges have weights less than __1.89__ and 50% of the edges have weights less than __3.82__.
#
# #### Remove edges with weights less than Q1 and draw
#
# If we were to drop all edges that have weights less than the first quartile of 1.89, then we would be reducing the number of edges by 25%.

# %%
remove_edge_list = [] #define empty list
for edge in G_2.edges_iter(data = True):
    if edge[2]['weight'] < 1.89:
        # append edge to list
        remove_edge_list.append((edge[0],edge[1]))

print(len(remove_edge_list))
remove_edge_list
# Out:
# 24853
# [('Earrings on the Table', 'Have U Own Things'),
#  ('Earrings on the Table', "Hang 'm High"),
#  ('Earrings on the Table', 'Contessa Entellina'),
#  ('Earrings on the Table', '18 De Noviembre'),
#  ('Earrings on the Table', 'Heart Of Dixie'),
#  ('Earrings on the Table', 'All Rise'),
#  ('Earrings on the Table', 'So Many Reasons'),
#  ('Earrings on the Table', 'Thank You Mama'),
#  ('Earrings on the Table', 'Studen plamuk'),
#  ('Earrings on the Table', 'Bigbigkiss'),
#  ('Earrings on the Table', 'El Aranero'),
#  ('Earrings on the Table', 'Ojos Gitanos'),
#  ('Earrings on the Table', 'Old Memory'),
#  ('Earrings on the Table', 'The Saga Of Rita Joe'),
#  ('Earrings on the Table', 'No. 284'),
#  ('Earrings on the Table', "Like It's Hot"),
#  ('Earrings on the Table', 'Rossignol Montmartrois (Polka)'),
#  ('Earrings on the Table', 'Flipside'),
#  ('Earrings on the Table', 'Vollmond'),
#  ('Earrings on the Table', 'Quand on est amoureux'),
#  ('Earrings on the Table', 'She Will Love You (Album Version)'),
#  ('Earrings on the Table', 'Petticoat'),
#  ('Earrings on the Table', 'Ability To Create A War'),
#  ('Earrings on the Table', 'Ego is the drug/3am'),
#  ('Earrings on the Table', 'Blaue Matrosen (live)'),
#  ('Earrings on the Table', 'For Me And My Gal'),
#  ('Earrings on the Table', 'Les Trois Orf\\xc3\\xa8vres'),
#  ('Earrings on the Table', 'Have It Your Way'),
#  ('Earrings on the Table', 'Them No Care'),
#  ('Earrings on the Table', 'Te Fuiste En Abril'),
#  ('Earrings on the Table', "Pop A Cap In Yo' Ass"),
#  ('Earrings on the Table', 'Apoliome Re Giorgi (Feat. Etsi De)'),
#  ('Earrings on the Table', 'Sabor Guajiro'),
#  ('Earrings on the Table', 'Sinnloz/ Anakonda (live)'),
#  ('Earrings on the Table', 'Maracaia'),
#  ('Earrings on the Table', 'Meteores mouvement de Chroniques de la lumier'),
#  ('Earrings on the Table', 'Rant Kanaria'),
#  ('Earrings on the Table', 'Scrimmage'),
#  ('Earrings on the Table', 'La cl\\xc3\\xa9 parfum\\xc3\\xa9e'),
#  ('Earrings on the Table', 'Main Title / The Searchers'),
#  ('Earrings on the Table', "Don't Let Go"),
#  ('Earrings on the Table', 'Hispaniola A'),
#  ('Earrings on the Table', 'Twerk (feat. Yo Majesty)'),
#  ('Earrings on the Table', 'Sunset Manifesto'),
#  ('Earrings on the Table', 'As The Terror Dances Your Way'),
#  ('Earrings on the Table',
#   'In The Name Of God (Gentle Revolution Album Version)'),
#  ('Earrings on the Table', 'Special'),
#  ('Earrings on the Table', "I Can't"),
#  ('Earrings on the Table', 'Daughter Of Zion'),
#  ('Earrings on the Table', 'Woh\\xc3\\xa4r dr Wind w\\xc3\\xa4iht'),
#  ('Earrings on the Table', 'Bye Bye'),
#  ('Earrings on the Table', 'Si Tu Me Dices Ven'),
#  ('Earrings on the Table', 'Oceans Of Love (LP Version)'),
#  ('Earrings on the Table', 'Only If You Live There'),
#  ('Earrings on the Table', 'Bateu No Paladar'),
#  ('Earrings on the Table', 'Faithkeeper_ Part 1'),
#  ('Earrings on the Table', 'El Arte De Amar'),
#  ('Earrings on the Table', 'Des Helden Widersacher'),
#  ('Earrings on the Table', 'Everybody Loves You'),
#  ('Earrings on the Table', 'Star'),
#  ('Earrings on the Table', 'With Tears In My Eyes'),
#  ('Earrings on the Table', 'Shoulda Did'),
#  ('Earrings on the Table', 'Turn It Up'),
#  ('Earrings on the Table', "Bartholdi's Dream"),
#  ('Earrings on the Table', 'Perdido (1999 Digital Remaster)'),
#  ('Earrings on the Table',
#   'Dale Darrell Waltrip Richard Petty Rusty Awesome Bill Irvin Gordon Earnhardt Smith...Johnson_ Jr. (Live)'),
#  ('Earrings on the Table', '\\xc3\\x98mhet'),
#  ('Earrings on the Table', 'Communication (More Mix)'),
#  ('Earrings on the Table', 'Encouraged'),
#  ('Earrings on the Table', 'The Luck You Got'),
#  ('Earrings on the Table', 'Your Love Takes Good Care Of Me'),
#  ('Earrings on the Table', 'Nina Nina'),
#  ('Earrings on the Table', 'Die Romantic [Live]'),
#  ('Earrings on the Table', "What'll I Do For Satisfaction (LP Version)"),
#  ('Earrings on the Table', 'Banana Split Republic'),
#  ('Earrings on the Table', 'My Tribute (to God Be The Glory)'),
#  ('Earrings on the Table', 'Ethiopian Anthem'),
#  ('Earrings on the Table', "Don't Knock Love"),
#  ('Earrings on the Table', 'MVP'),
#  ('Earrings on the Table', 'Allein'),
#  ('Earrings on the Table', 'Take The Wheel'),
#  ('Earrings on the Table', 'Grow Proper'),
#  ('Earrings on the Table', "Love Is Gone (Eddie Thoneick's Liberte Mix)"),
#  ('Earrings on the Table', 'On Independence Day'),
#  ('Earrings on the Table', 'Beyond The Reef'),
#  ('Earrings on the Table', 'Meteorito'),
#  ('Earrings on the Table', 'Cable'),
#  ('Earrings on the Table', 'C\\xc3\\xa9u do Brasil'),
#  ('Earrings on the Table', 'Menuet in the Name of Haydn'),
#  ('Earrings on the Table', 'Rollercoasting'),
#  ('Earrings on the Table', 'The Marquis and the Scaffold (From "Quills")'),
#  ('Earrings on the Table', 'Insatiable (Instrumental Version)'),
#  ('Earrings on the Table', 'Midnight Hour'),
#  ('Earrings on the Table', 'Forr\\xc3\\xb3 Praieiro'),
#  ('Earrings on the Table', 'Ghetto'),
#  ('Earrings on the Table', 'part 2 - Winterlight'),
#  ('Earrings on the Table', 'Kenourgia Fotia'),
#  ('Earrings on the Table', 'Sex'),
#  ('Earrings on the Table', 'Idaho Red'),
#  ('Earrings on the Table', 'Mopao'),
#  ('Earrings on the Table', 'Betrayal Is A Symptom'),
#  ('Earrings on the Table', 'Seuraavassa el\\xc3\\xa4m\\xc3\\xa4ss\\xc3\\xa4'),
#  ('Earrings on the Table', 'Wo Ai Ni_ Zai Jian!'),
#  ('Earrings on the Table', 'September Song'),
#  ('Earrings on the Table', 'Say What!?!'),
#  ('Earrings on the Table', 'Head Over Heels'),
#  ('Earrings on the Table', 'Monologue With the Sky'),
#  ('Earrings on the Table', 'Pray On'),
#  ('Earrings on the Table', 'Ter\\xc3\\xa4slintu'),
#  ('Earrings on the Table', 'Gamble Calypso'),
#  ('Earrings on the Table', 'Your Touch Versus Death'),
#  ('Earrings on the Table', 'Main Theme from Jaws'),
#  ('Earrings on the Table', 'Guardians Of The Forest'),
#  ('Earrings on the Table', 'Skyline'),
#  ('Earrings on the Table', 'Sheng Li Hu Huan'),
#  ('Earrings on the Table', 'Whispering Grass'),
#  ('Earrings on the Table', 'Tonight Will Be Alright'),
#  ('Earrings on the Table', 'Break My Mind'),
#  ('Earrings on the Table', 'Yesterdays'),
#  ('Earrings on the Table', 'Mi Morena (Revised Live Version)'),
#  ('Earrings on the Table',
#   'Concerto For Saxophone (Quartet Version): Movement IV'),
#  ('Earrings on the Table', 'We Do It For the Money_ OBVIOUSLY! (Demo)'),
#  ('Earrings on the Table', 'Give Me That Touch (The Touch Up Mix)'),
#  ('Earrings on the Table', 'Another Djemba Djemba'),
#  ('Larger Than Life', 'Jesus'),
#  ('Larger Than Life', 'Tides Of Time'),
#  ('Larger Than Life', '18 De Noviembre'),
#  ('Larger Than Life', 'Big Woman'),
#  ('Larger Than Life',
#   'Oedipus Rex_ Atto Primo: Liberi_ Vos Liberabo (Oedipus) (Stravinsky)'),
#  ('Larger Than Life', 'Thank You Mama'),
#  ('Larger Than Life', 'Studen plamuk'),
#  ('Larger Than Life', 'Intro'),
#  ('Larger Than Life', 'Te Parto el Alma (inter. El Tariacuri)'),
#  ('Larger Than Life', 'El Aranero'),
#  ('Larger Than Life', 'Posledny Buntar`'),
#  ('Larger Than Life', 'No Pienses Asi'),
#  ('Larger Than Life', 'Old Memory'),
#  ('Larger Than Life', 'No. 284'),
#  ('Larger Than Life', 'Kids Now'),
#  ('Larger Than Life', 'Contessa Entellina'),
#  ('Larger Than Life', "Il a suffit d'une chanson d'amour"),
#  ('Larger Than Life', 'Vollmond'),
#  ('Larger Than Life', 'Petticoat'),
#  ('Larger Than Life', 'Noises'),
#  ('Larger Than Life', 'Blaue Matrosen (live)'),
#  ('Larger Than Life', 'Loud And Clear'),
#  ('Larger Than Life', 'Straight Coats'),
#  ('Larger Than Life', 'Tracy'),
#  ('Larger Than Life', 'Never Alone'),
#  ('Larger Than Life', 'Close Up'),
#  ('Larger Than Life', 'Andra sidan'),
#  ('Larger Than Life', 'By Faith I Can Touch Him Now'),
#  ('Larger Than Life', 'Have It Your Way'),
#  ('Larger Than Life', 'All Rise'),
#  ('Larger Than Life',
#   'Stereophonic Presentation - Process And Passion_ Pt. 4'),
#  ('Larger Than Life', 'Seni Unuturum'),
#  ('Larger Than Life', 'Sou Vazo Diskola'),
#  ('Larger Than Life', 'Sabor Guajiro'),
#  ('Larger Than Life', "Don't Cry_ Joe"),
#  ('Larger Than Life', 'Sinnloz/ Anakonda (live)'),
#  ('Larger Than Life', 'Amor Bonito'),
#  ('Larger Than Life', 'Cry_ Cry_ Cry'),
#  ('Larger Than Life', "Can't Break This Man"),
#  ('Larger Than Life', 'Scrimmage'),
#  ('Larger Than Life', 'Church Hangover'),
#  ('Larger Than Life', 'Happy To Meet & Sorry To Part'),
#  ('Larger Than Life', 'Los De Arag\\xc3\\xb3n: "Los De Arag\\xc3\\xb3n'),
#  ('Larger Than Life', 'In The Name Of God (Gentle Revolution Album Version)'),
#  ('Larger Than Life', 'Bateu No Paladar'),
#  ('Larger Than Life', 'Faithkeeper_ Part 1'),
#  ('Larger Than Life', 'White Winter Hymnal'),
#  ('Larger Than Life', 'With Tears In My Eyes'),
#  ('Larger Than Life', 'Shoulda Did'),
#  ('Larger Than Life', 'Turn It Up'),
#  ('Larger Than Life', "Bartholdi's Dream"),
#  ('Larger Than Life',
#   'Dale Darrell Waltrip Richard Petty Rusty Awesome Bill Irvin Gordon Earnhardt Smith...Johnson_ Jr. (Live)'),
#  ('Larger Than Life', 'Coma'),
#  ('Larger Than Life', 'El Te Daba Mala Vida'),
#  ('Larger Than Life', 'Daughter Of Zion'),
#  ('Larger Than Life', 'Hai Shava'),
#  ('Larger Than Life', "Gangsta's Fairytale 2 (Explicit)"),
#  ('Larger Than Life', 'Encouraged'),
#  ('Larger Than Life', 'Gaita Pueblera'),
#  ('Larger Than Life', 'Frente A Tu Altar'),
#  ('Larger Than Life', "I Don't Like You"),
#  ('Larger Than Life', 'Ida Red'),
#  ('Larger Than Life', 'My Tribute (to God Be The Glory)'),
#  ('Larger Than Life', 'Chitlins Con Carne'),
#  ('Larger Than Life', "Don't Knock Love"),
#  ('Larger Than Life', 'MVP'),
#  ('Larger Than Life', 'Wasted Love'),
#  ('Larger Than Life', 'Pork Chop Sandwich'),
#  ('Larger Than Life', 'Pus-Filled Carcass'),
#  ('Larger Than Life', "Sur L'autre rive"),
#  ('Larger Than Life', 'Meteorito'),
#  ('Larger Than Life', 'Menuet in the Name of Haydn'),
#  ('Larger Than Life', 'Nuovi Re pt. I I (feat. Tek money - Lady Tambler)'),
#  ('Larger Than Life', 'Insatiable (Instrumental Version)'),
#  ('Larger Than Life', 'En La Soledad'),
#  ('Larger Than Life', 'Forr\\xc3\\xb3 Praieiro'),
#  ('Larger Than Life', 'part 2 - Winterlight'),
#  ('Larger Than Life', 'Peyte Pivo Pennoe (present for A. Trofimov)'),
#  ('Larger Than Life', 'Sometimes I'),
#  ('Larger Than Life', 'Idaho Red'),
#  ('Larger Than Life', 'Wo Ai Ni_ Zai Jian!'),
#  ('Larger Than Life', 'Iron-head: Palestine'),
#  ('Larger Than Life', 'Cuando Calienta El Sol'),
#  ('Larger Than Life', 'Say What!?!'),
#  ('Larger Than Life', 'El Jamaiquino'),
#  ('Larger Than Life', 'A Night in Tunisia'),
#  ('Larger Than Life', 'Your Touch Versus Death'),
#  ('Larger Than Life', 'Main Theme from Jaws'),
#  ('Larger Than Life', 'The Bravest Kids (Acoustic)'),
#  ('Larger Than Life', 'Be Aware'),
#  ('Larger Than Life', 'African Typic Collection'),
#  ('Larger Than Life', 'Sheng Li Hu Huan'),
#  ('Larger Than Life', 'Ai Ji Mei Gui 1000 Da'),
#  ('Larger Than Life', "I Can't Wait 'Til Christmas (LP Version)"),
#  ('Larger Than Life', 'Yesterdays'),
#  ('Larger Than Life', 'Ooh Wee Baby'),
#  ('Spotlight', 'Wo Ai Ni_ Zai Jian!'),
#  ('Spotlight', 'Somewhere'),
#  ('Spotlight', 'Wishy Washy Woman'),
#  ('Spotlight', 'Hiekkaa (polvere)'),
#  ('Spotlight', 'Big Woman'),
#  ('Spotlight', "Il a suffit d'une chanson d'amour"),
#  ('Spotlight',
#   'Oedipus Rex_ Atto Primo: Liberi_ Vos Liberabo (Oedipus) (Stravinsky)'),
#  ('Spotlight', 'Intro'),
#  ('Spotlight', 'Te Parto el Alma (inter. El Tariacuri)'),
#  ('Spotlight', 'Nada De Ti'),
#  ('Spotlight', 'Packing Up'),
#  ('Spotlight', 'Everything Has Changed'),
#  ('Spotlight', 'Distancia'),
#  ('Spotlight', 'No. 284'),
#  ('Spotlight', 'New Love'),
#  ('Spotlight', 'Studen plamuk'),
#  ('Spotlight', 'Quand on est amoureux'),
#  ('Spotlight', 'I Feel So Good'),
#  ('Spotlight', 'The 23rd Psalm'),
#  ('Spotlight', 'Petticoat'),
#  ('Spotlight', 'Ego is the drug/3am'),
#  ('Spotlight', 'Loud And Clear'),
#  ('Spotlight', 'I Wonder Where You Are Tonight'),
#  ('Spotlight', 'For Me And My Gal'),
#  ('Spotlight', 'Tracy'),
#  ('Spotlight', 'Here Comes The Big Parade'),
#  ('Spotlight', 'When He Was On The Cross [I Was On His Mind]'),
#  ('Spotlight', 'The Lakes Of Pontchartrain'),
#  ('Spotlight', 'Seni Unuturum'),
#  ('Spotlight', 'Sou Vazo Diskola'),
#  ('Spotlight', 'Let It All Go'),
#  ('Spotlight', 'Maracaia'),
#  ('Spotlight', "Sho' Enough"),
#  ('Spotlight', 'Scrimmage'),
#  ('Spotlight', 'Sentimental Journey'),
#  ('Spotlight', 'Main Title / The Searchers'),
#  ('Spotlight', "I'm Thinking Tonight Of My Blue Eyes"),
#  ('Spotlight', 'Twerk (feat. Yo Majesty)'),
#  ('Spotlight', 'Si Tu Me Dices Ven'),
#  ('Spotlight', 'Oceans Of Love (LP Version)'),
#  ('Spotlight', 'Bateu No Paladar'),
#  ('Spotlight', 'Up Jumped The Devil'),
#  ('Spotlight', 'Faithkeeper_ Part 1'),
#  ('Spotlight', 'Same Man'),
#  ('Spotlight', 'Murder One'),
#  ('Spotlight', "Don't You Think It's Time To Go"),
#  ('Spotlight', "It's You"),
#  ('Spotlight', 'Stack and Pile'),
#  ('Spotlight', 'El Te Daba Mala Vida'),
#  ('Spotlight', 'Daughter Of Zion'),
#  ('Spotlight', 'Moon Going Down'),
#  ('Spotlight', 'Encouraged'),
#  ('Spotlight', "She's About A Mover"),
#  ('Spotlight', 'El Aranero'),
#  ('Spotlight', 'Love Me Now (Rockwilder Remix) (Feat. Wyclef And Redman)'),
#  ('Spotlight', '(I Wanna) Play A Little While'),
#  ('Spotlight', 'Banana Split Republic'),
#  ('Spotlight', 'Ghetto'),
#  ('Spotlight', 'Chitlins Con Carne'),
#  ('Spotlight', 'MVP'),
#  ('Spotlight', 'El Termometro'),
#  ('Spotlight', 'Baiao Malandro'),
#  ('Spotlight', 'Chanson sous la pluie'),
#  ('Spotlight', 'Street Sh***'),
#  ('Spotlight', 'Hear Me Talking To You'),
#  ('Spotlight', 'Blue Yodel No. 1(T For Texas)'),
#  ('Spotlight', 'The Blinding Sun'),
#  ('Spotlight', 'One Scotch_ One Bourbon_ One Beer'),
#  ('Spotlight', 'Menuet in the Name of Haydn'),
#  ('Spotlight', 'Love The Feeling - Original'),
#  ('Spotlight', 'Insatiable (Instrumental Version)'),
#  ('Spotlight', 'Beneath an Evening Sky'),
#  ('Spotlight', "Breezin' Along With the Breeze"),
#  ('Spotlight', 'Shi Shang Zui Qiang Man Hua Wang Da Luan Dou'),
#  ('Spotlight', 'Monologue With the Sky'),
#  ('Spotlight', 'The Bravest Kids (Acoustic)'),
#  ('Spotlight', 'Be Aware'),
#  ('Spotlight', 'Sheng Li Hu Huan'),
#  ('Spotlight', 'Whispering Grass'),
#  ('Spotlight', 'Gonna Take a Miracle'),
#  ('Spotlight', 'Ai Ji Mei Gui 1000 Da'),
#  ('Spotlight', 'Tonight Will Be Alright'),
#  ('Spotlight', 'Faithful and True (Collectors Version)'),
#  ('Spotlight', 'Stereophonic Presentation - Process And Passion_ Pt. 4'),
#  ('Spotlight', 'Need More Blues'),
#  ('Spotlight', 'Meditacao'),
#  ('Spotlight', 'Yesterdays'),
#  ('Spotlight', 'Concerto For Saxophone (Quartet Version): Movement IV'),
#  ('Spotlight', 'In The Name Of God (Gentle Revolution Album Version)'),
#  ('Spotlight', 'We Do It For the Money_ OBVIOUSLY! (Demo)'),
#  ('Spotlight', 'Laying Down My Will (The Plan Album Version)'),
#  ('Spotlight', 'Choro II'),
#  ('Spotlight', 'Ooh Wee Baby'),
#  ('Spotlight', 'Meteores mouvement de Chroniques de la lumier'),
#  ('Spotlight', 'All I Want'),
#  ('Rescue Me', 'Tides Of Time'),
#  ('Rescue Me', 'El Aranero'),
#  ('Rescue Me', "Like It's Hot"),
#  ('Rescue Me', "Il a suffit d'une chanson d'amour"),
#  ('Rescue Me', 'Quand on est amoureux'),
#  ('Rescue Me', 'Petticoat'),
#  ('Rescue Me', 'Loud And Clear'),
#  ('Rescue Me', 'Jokers and Thieves'),
#  ('Rescue Me', 'Daughter Of Zion'),
#  ('Rescue Me', 'Banana Split Republic'),
#  ('Rescue Me', 'Cry_ Cry_ Cry'),
#  ('Rescue Me', 'As The Terror Dances Your Way'),
#  ('Rescue Me', 'Prospection'),
#  ('Rescue Me', 'Oceans Of Love (LP Version)'),
#  ('Rescue Me', 'Ice Cream Cone'),
#  ('Rescue Me', 'Burbullas A Grella'),
#  ('Rescue Me', "Let's Have Some Fun"),
#  ('Rescue Me', 'No La Dejes Sola'),
#  ('Rescue Me', 'With Tears In My Eyes'),
#  ('Rescue Me',
#   'Dale Darrell Waltrip Richard Petty Rusty Awesome Bill Irvin Gordon Earnhardt Smith...Johnson_ Jr. (Live)'),
#  ('Rescue Me', '\\xc3\\x98mhet'),
#  ('Rescue Me', 'Hispaniola A'),
#  ('Rescue Me', 'Gonna Take a Miracle'),
#  ('Rescue Me', 'Primordial Breath'),
#  ('Rescue Me', 'Herval na percaria'),
#  ('Rescue Me', 'Belle Isle Players'),
#  ('Rescue Me', 'Grow Proper'),
#  ('Rescue Me', 'A Girls Oath'),
#  ('Rescue Me', 'Nuovi Re pt. I I (feat. Tek money - Lady Tambler)'),
#  ('Rescue Me', 'Solemn'),
#  ('Rescue Me', 'Meteorito'),
#  ('Rescue Me', 'Naked Albino'),
#  ('Rescue Me', 'Idaho Red'),
#  ('Rescue Me', 'Iron-head: Palestine'),
#  ('Rescue Me', 'Never After'),
#  ('Rescue Me', 'Ter\\xc3\\xa4slintu'),
#  ('Rescue Me', 'Your Touch Versus Death'),
#  ('Rescue Me', 'By Faith I Can Touch Him Now'),
#  ('Rescue Me', 'Guardians Of The Forest'),
#  ('Rescue Me', 'Cavaleiro De Aruanda'),
#  ('Rescue Me', 'Missing You'),
#  ('Rescue Me', 'Give Me That Touch (The Touch Up Mix)'),
#  ('Rescue Me', 'Another Djemba Djemba'),
#  ('Wo Ai Ni_ Zai Jian!', 'Somewhere'),
#  ('Wo Ai Ni_ Zai Jian!', 'Ask The Angels'),
#  ('Wo Ai Ni_ Zai Jian!', "Hang 'm High"),
#  ('Wo Ai Ni_ Zai Jian!', 'Iron-head: Palestine'),
#  ('Wo Ai Ni_ Zai Jian!', 'The Marquis and the Scaffold (From "Quills")'),
#  ('Wo Ai Ni_ Zai Jian!', 'Thrill Pistol'),
#  ('Wo Ai Ni_ Zai Jian!',
#   'Oedipus Rex_ Atto Primo: Liberi_ Vos Liberabo (Oedipus) (Stravinsky)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Pu**y Pop'),
#  ('Wo Ai Ni_ Zai Jian!', 'I.A.I'),
#  ('Wo Ai Ni_ Zai Jian!', 'No La Dejes Sola'),
#  ('Wo Ai Ni_ Zai Jian!', 'Directions to my special place'),
#  ('Wo Ai Ni_ Zai Jian!', 'What Is This'),
#  ('Wo Ai Ni_ Zai Jian!', 'Posledny Buntar`'),
#  ('Wo Ai Ni_ Zai Jian!', 'No Pienses Asi'),
#  ('Wo Ai Ni_ Zai Jian!', 'Ojos Gitanos'),
#  ('Wo Ai Ni_ Zai Jian!', 'Revolution'),
#  ('Wo Ai Ni_ Zai Jian!', 'Packing Up'),
#  ('Wo Ai Ni_ Zai Jian!', "Don't Let Go"),
#  ('Wo Ai Ni_ Zai Jian!', 'Distancia'),
#  ('Wo Ai Ni_ Zai Jian!', 'Georgia'),
#  ('Wo Ai Ni_ Zai Jian!', "Like It's Hot"),
#  ('Wo Ai Ni_ Zai Jian!', 'Just A Phase'),
#  ('Wo Ai Ni_ Zai Jian!', 'New Love'),
#  ('Wo Ai Ni_ Zai Jian!', 'Flipside'),
#  ('Wo Ai Ni_ Zai Jian!', 'Try'),
#  ('Wo Ai Ni_ Zai Jian!', 'Them No Care'),
#  ('Wo Ai Ni_ Zai Jian!', 'Contessa Entellina'),
#  ('Wo Ai Ni_ Zai Jian!', "Il a suffit d'une chanson d'amour"),
#  ('Wo Ai Ni_ Zai Jian!', 'Turn It Up'),
#  ('Wo Ai Ni_ Zai Jian!', 'The 23rd Psalm'),
#  ('Wo Ai Ni_ Zai Jian!', 'Sleeping My Day Away [Live]'),
#  ('Wo Ai Ni_ Zai Jian!', 'Ability To Create A War'),
#  ('Wo Ai Ni_ Zai Jian!', 'Loud And Clear'),
#  ('Wo Ai Ni_ Zai Jian!', 'The Blinding Sun'),
#  ('Wo Ai Ni_ Zai Jian!', '2HB (1999 Digital Remaster)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Streets On Fire (Explicit Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Straight Coats'),
#  ('Wo Ai Ni_ Zai Jian!', 'Les Trois Orf\\xc3\\xa8vres'),
#  ('Wo Ai Ni_ Zai Jian!', "I've Been Trying"),
#  ('Wo Ai Ni_ Zai Jian!', 'Have It Your Way'),
#  ('Wo Ai Ni_ Zai Jian!', 'Cuore Appassionato'),
#  ('Wo Ai Ni_ Zai Jian!', 'When He Was On The Cross [I Was On His Mind]'),
#  ('Wo Ai Ni_ Zai Jian!', 'Test 72'),
#  ('Wo Ai Ni_ Zai Jian!', 'Te Fuiste En Abril'),
#  ('Wo Ai Ni_ Zai Jian!', 'Machuca'),
#  ('Wo Ai Ni_ Zai Jian!', 'Pinini Reggae'),
#  ('Wo Ai Ni_ Zai Jian!', 'The Plot To Bomb The Panhandle (Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', "It Has Been A Long Time_ Hasn't It"),
#  ('Wo Ai Ni_ Zai Jian!', 'Let It All Go'),
#  ('Wo Ai Ni_ Zai Jian!', 'Sabor Guajiro'),
#  ('Wo Ai Ni_ Zai Jian!', 'Big Woman'),
#  ('Wo Ai Ni_ Zai Jian!', 'This Christmas (LP Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Scrimmage'),
#  ('Wo Ai Ni_ Zai Jian!', 'Skyline'),
#  ('Wo Ai Ni_ Zai Jian!', 'Two Elegiac Melodies Op. 34: 2. The Last Spring'),
#  ('Wo Ai Ni_ Zai Jian!', 'La Bambola'),
#  ('Wo Ai Ni_ Zai Jian!', 'Seventy Times Seven (LP Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Sunset Manifesto'),
#  ('Wo Ai Ni_ Zai Jian!', 'The Lakes Of Pontchartrain'),
#  ('Wo Ai Ni_ Zai Jian!', 'Happy To Meet & Sorry To Part'),
#  ('Wo Ai Ni_ Zai Jian!', 'Woh\\xc3\\xa4r dr Wind w\\xc3\\xa4iht'),
#  ('Wo Ai Ni_ Zai Jian!', 'Only If You Live There'),
#  ('Wo Ai Ni_ Zai Jian!', 'Ice Cream Cone'),
#  ('Wo Ai Ni_ Zai Jian!', 'Bateu No Paladar'),
#  ('Wo Ai Ni_ Zai Jian!', 'the tales of King Solitude 1:3'),
#  ('Wo Ai Ni_ Zai Jian!',
#   'Concerto For Saxophone (Quartet Version): Movement IV'),
#  ('Wo Ai Ni_ Zai Jian!', 'Same Man'),
#  ('Wo Ai Ni_ Zai Jian!', 'All Burned Out'),
#  ('Wo Ai Ni_ Zai Jian!', 'Everybody Loves You'),
#  ('Wo Ai Ni_ Zai Jian!', 'Noises'),
#  ('Wo Ai Ni_ Zai Jian!', "Bartholdi's Dream"),
#  ('Wo Ai Ni_ Zai Jian!', "It's You"),
#  ('Wo Ai Ni_ Zai Jian!', 'Bumbling Along'),
#  ('Wo Ai Ni_ Zai Jian!', 'Perdido (1999 Digital Remaster)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Cancion Para Mi Muerte'),
#  ('Wo Ai Ni_ Zai Jian!', 'The Jezebel Spirit'),
#  ('Wo Ai Ni_ Zai Jian!', 'Coma'),
#  ('Wo Ai Ni_ Zai Jian!', 'Daughter Of Zion'),
#  ('Wo Ai Ni_ Zai Jian!', 'Hai Shava'),
#  ('Wo Ai Ni_ Zai Jian!', 'Moon Going Down'),
#  ('Wo Ai Ni_ Zai Jian!', 'The One I Got'),
#  ('Wo Ai Ni_ Zai Jian!', 'Monsters In Tinsel Town'),
#  ('Wo Ai Ni_ Zai Jian!', "Gangsta's Fairytale 2 (Explicit)"),
#  ('Wo Ai Ni_ Zai Jian!', 'The Luck You Got'),
#  ('Wo Ai Ni_ Zai Jian!', 'Hum Drum'),
#  ('Wo Ai Ni_ Zai Jian!', 'Mark Practices'),
#  ('Wo Ai Ni_ Zai Jian!', 'Rakkahin -Be My Love-'),
#  ('Wo Ai Ni_ Zai Jian!', 'Your Love Takes Good Care Of Me'),
#  ('Wo Ai Ni_ Zai Jian!', "What'll I Do For Satisfaction (LP Version)"),
#  ('Wo Ai Ni_ Zai Jian!', "I Don't Like You"),
#  ('Wo Ai Ni_ Zai Jian!', 'Courtyard'),
#  ('Wo Ai Ni_ Zai Jian!', 'Ida Red'),
#  ('Wo Ai Ni_ Zai Jian!', 'Ghetto'),
#  ('Wo Ai Ni_ Zai Jian!', "It's Too Late"),
#  ('Wo Ai Ni_ Zai Jian!', 'Woo Hoo'),
#  ('Wo Ai Ni_ Zai Jian!', 'If Money Talks'),
#  ('Wo Ai Ni_ Zai Jian!', 'Ethiopian Anthem'),
#  ('Wo Ai Ni_ Zai Jian!', 'So Jah Seh'),
#  ('Wo Ai Ni_ Zai Jian!', "Don't Knock Love"),
#  ('Wo Ai Ni_ Zai Jian!', 'Sick 2 Think'),
#  ('Wo Ai Ni_ Zai Jian!', 'MVP'),
#  ('Wo Ai Ni_ Zai Jian!', 'Communication (More Mix)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Round 7:  2138'),
#  ('Wo Ai Ni_ Zai Jian!', 'Adios Pampa Mia'),
#  ('Wo Ai Ni_ Zai Jian!', 'El Termometro'),
#  ('Wo Ai Ni_ Zai Jian!', 'Allein'),
#  ('Wo Ai Ni_ Zai Jian!', 'Faithkeeper_ Part 1'),
#  ('Wo Ai Ni_ Zai Jian!', 'Dancing The Night Away'),
#  ('Wo Ai Ni_ Zai Jian!', 'People = Sh*t (live) (Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Use Me'),
#  ('Wo Ai Ni_ Zai Jian!', 'Blue Yodel No. 1(T For Texas)'),
#  ('Wo Ai Ni_ Zai Jian!', 'On Independence Day'),
#  ('Wo Ai Ni_ Zai Jian!', 'Beyond The Reef'),
#  ('Wo Ai Ni_ Zai Jian!', 'Cable'),
#  ('Wo Ai Ni_ Zai Jian!', 'C\\xc3\\xa9u do Brasil'),
#  ('Wo Ai Ni_ Zai Jian!', 'Menuet in the Name of Haydn'),
#  ('Wo Ai Ni_ Zai Jian!', 'Eyes Of A Stranger (Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Fortress'),
#  ('Wo Ai Ni_ Zai Jian!', 'Transmission (Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'So Still (Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Forr\\xc3\\xb3 Praieiro'),
#  ('Wo Ai Ni_ Zai Jian!', 'Enclosed_ One Broken Heart'),
#  ('Wo Ai Ni_ Zai Jian!', 'part 2 - Winterlight'),
#  ('Wo Ai Ni_ Zai Jian!', 'The Harbour'),
#  ('Wo Ai Ni_ Zai Jian!', 'Peyte Pivo Pennoe (present for A. Trofimov)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Apoliome Re Giorgi (Feat. Etsi De)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Kenourgia Fotia'),
#  ('Wo Ai Ni_ Zai Jian!', 'El Arte De Amar'),
#  ('Wo Ai Ni_ Zai Jian!', 'Sometimes I'),
#  ('Wo Ai Ni_ Zai Jian!', 'Beneath an Evening Sky'),
#  ('Wo Ai Ni_ Zai Jian!', 'Idaho Red'),
#  ('Wo Ai Ni_ Zai Jian!', 'Undertow'),
#  ('Wo Ai Ni_ Zai Jian!', 'Betrayal Is A Symptom'),
#  ('Wo Ai Ni_ Zai Jian!', 'Have U Own Things'),
#  ('Wo Ai Ni_ Zai Jian!', 'Till The End Of The Day (Alternate Mix)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Dark As A Dungeon (LP Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Pray On'),
#  ('Wo Ai Ni_ Zai Jian!', 'Son of Jack the Ripper'),
#  ('Wo Ai Ni_ Zai Jian!', 'Peace Prayer'),
#  ('Wo Ai Ni_ Zai Jian!', 'By Faith I Can Touch Him Now'),
#  ('Wo Ai Ni_ Zai Jian!', 'The Bravest Kids (Acoustic)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Be Aware'),
#  ('Wo Ai Ni_ Zai Jian!', 'What Would You Do'),
#  ('Wo Ai Ni_ Zai Jian!', 'African Typic Collection'),
#  ('Wo Ai Ni_ Zai Jian!', 'Whispering Grass'),
#  ('Wo Ai Ni_ Zai Jian!', 'Gonna Take a Miracle'),
#  ('Wo Ai Ni_ Zai Jian!',
#   'In The Name Of God (Gentle Revolution Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Break My Mind'),
#  ('Wo Ai Ni_ Zai Jian!',
#   'Stereophonic Presentation - Process And Passion_ Pt. 4'),
#  ('Wo Ai Ni_ Zai Jian!', 'Need More Blues'),
#  ('Wo Ai Ni_ Zai Jian!', 'Meditacao'),
#  ('Wo Ai Ni_ Zai Jian!', 'Yesterdays'),
#  ('Wo Ai Ni_ Zai Jian!', 'Solemn'),
#  ('Wo Ai Ni_ Zai Jian!', '2StepN'),
#  ('Wo Ai Ni_ Zai Jian!', 'Duck And Run'),
#  ('Wo Ai Ni_ Zai Jian!', 'Skin Ticket (Live version) (Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Naked Albino'),
#  ('Wo Ai Ni_ Zai Jian!', 'Yesss Lord...'),
#  ('Wo Ai Ni_ Zai Jian!', 'San Cristobal'),
#  ('Wo Ai Ni_ Zai Jian!', "Widow's Walk"),
#  ('Wo Ai Ni_ Zai Jian!',
#   'What Is Light? Where Is Laughter? (Acoustic Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'The Attitude Song'),
#  ('Wo Ai Ni_ Zai Jian!', 'Lil Brother (LP Version)'),
#  ('Somewhere', 'Have U Own Things'),
#  ('Somewhere', '18 De Noviembre'),
#  ('Somewhere', 'D\\xc3\\xa5 \\xc3\\xa4r det jul'),
#  ('Somewhere', 'Far Beyond The Endless'),
#  ('Somewhere',
#   'Oedipus Rex_ Atto Primo: Liberi_ Vos Liberabo (Oedipus) (Stravinsky)'),
#  ('Somewhere', 'Un Tipo Como Yo'),
#  ('Somewhere', 'Bigbigkiss'),
#  ('Somewhere', 'Die Romantic [Live]'),
#  ('Somewhere', 'Ojos Gitanos'),
#  ('Somewhere', 'Old Memory'),
#  ('Somewhere', 'No. 284'),
#  ('Somewhere', 'Georgia'),
#  ('Somewhere', 'Just A Phase'),
#  ('Somewhere', 'New Love'),
#  ('Somewhere', 'Studen plamuk'),
#  ('Somewhere', 'Quand on est amoureux'),
#  ('Somewhere', 'She Will Love You (Album Version)'),
#  ('Somewhere', 'Ability To Create A War'),
#  ('Somewhere', 'Ego is the drug/3am'),
#  ('Somewhere', 'Noises'),
#  ('Somewhere', 'Loud And Clear'),
#  ('Somewhere', 'Arabian Night'),
#  ('Somewhere', 'Straight Coats'),
#  ('Somewhere', 'Tracy'),
#  ('Somewhere', 'Les Trois Orf\\xc3\\xa8vres'),
#  ('Somewhere', 'White Winter Hymnal'),
#  ('Somewhere', 'Andra sidan'),
#  ('Somewhere', 'Test 72'),
#  ('Somewhere', 'Them No Care'),
#  ('Somewhere', 'Seni Unuturum'),
#  ('Somewhere', 'Be Stiff (Live)'),
#  ('Somewhere', 'Te Fuiste En Abril'),
#  ('Somewhere', 'Next Time'),
#  ('Somewhere', "It Has Been A Long Time_ Hasn't It"),
#  ('Somewhere', 'Sou Vazo Diskola'),
#  ('Somewhere', 'Procession'),
#  ('Somewhere', 'Nothing To Hold Me'),
#  ('Somewhere', 'Cry_ Cry_ Cry'),
#  ('Somewhere', 'Anfang Vom Ende'),
#  ('Somewhere', 'Heal (The Separation) [PM Dawn Alt. Lead Mix]'),
#  ('Somewhere', 'Sunset Manifesto'),
#  ('Somewhere', 'Only If You Live There'),
#  ('Somewhere', 'Oceans Of Love (LP Version)'),
#  ('Somewhere', 'Travel Song (Reprise)'),
#  ('Somewhere', 'the tales of King Solitude 1:3'),
#  ('Somewhere', 'Concerto For Saxophone (Quartet Version): Movement IV'),
#  ('Somewhere', 'Rollercoasting'),
#  ('Somewhere', 'Everybody Loves You'),
#  ('Somewhere', 'No La Dejes Sola'),
#  ('Somewhere', 'With Tears In My Eyes'),
#  ('Somewhere', 'Shoulda Did'),
#  ('Somewhere', 'Turn It Up'),
#  ('Somewhere', 'Cancion Para Mi Muerte'),
#  ('Somewhere', 'El Te Daba Mala Vida'),
#  ('Somewhere', 'Floating'),
#  ('Somewhere', 'Hai Shava'),
#  ('Somewhere', 'Monsters In Tinsel Town'),
#  ('Somewhere', 'Gallows (Album Version)'),
#  ('Somewhere', "Gangsta's Fairytale 2 (Explicit)"),
#  ('Somewhere', 'The Luck You Got'),
#  ('Somewhere', 'Mark Practices'),
#  ('Somewhere', "What'll I Do For Satisfaction (LP Version)"),
#  ('Somewhere', 'Herval na percaria'),
#  ('Somewhere', 'Ghetto'),
#  ('Somewhere', 'Tango de la Flor (Album Version)'),
#  ('Somewhere', 'Das Geheimrezept'),
#  ('Somewhere', 'Chitlins Con Carne'),
#  ('Somewhere', 'Sick 2 Think'),
#  ('Somewhere', "Since I've Been Loving You"),
#  ('Somewhere', 'Adios Pampa Mia'),
#  ('Somewhere', 'Allein'),
#  ('Somewhere', 'Wasted Love'),
#  ('Somewhere', 'Valokeilojen vampyyri'),
#  ('Somewhere', "I Don't Like You"),
#  ('Somewhere', 'People = Sh*t (live) (Album Version)'),
#  ('Somewhere', 'Grow Proper'),
#  ('Somewhere', 'On Independence Day'),
#  ('Somewhere', "Sur L'autre rive"),
#  ('Somewhere', 'Meteorito'),
#  ('Somewhere', 'Cable'),
#  ('Somewhere', 'C\\xc3\\xa9u do Brasil'),
#  ('Somewhere', 'Tiempos Dificiles'),
#  ('Somewhere', "Class Compromise (&History's Glory)"),
#  ('Somewhere', 'Revolution'),
#  ('Somewhere', 'Bye Bye'),
#  ('Somewhere', 'Hispaniola A'),
#  ('Somewhere', 'Bateu No Paladar'),
#  ('Somewhere', 'En La Soledad'),
#  ('Somewhere', 'Digital [Live at Birmingham University] [2007 Re-mastered]'),
#  ('Somewhere', 'Apoliome Re Giorgi (Feat. Etsi De)'),
#  ('Somewhere', 'El Arte De Amar'),
#  ('Somewhere', 'Sex'),
#  ('Somewhere', 'Beneath an Evening Sky'),
#  ('Somewhere', 'Idaho Red'),
#  ('Somewhere', "Il a suffit d'une chanson d'amour"),
#  ('Somewhere', 'Seuraavassa el\\xc3\\xa4m\\xc3\\xa4ss\\xc3\\xa4'),
#  ('Somewhere', 'Iron-head: Palestine'),
#  ('Somewhere', 'September Song'),
#  ('Somewhere', 'Gamble Calypso'),
#  ('Somewhere', 'Main Theme from Jaws'),
#  ('Somewhere', 'Jokers and Thieves'),
#  ('Somewhere', 'Guardians Of The Forest'),
#  ('Somewhere', 'The Bravest Kids (Acoustic)'),
#  ('Somewhere', 'African Typic Collection'),
#  ('Somewhere', 'Ai Ji Mei Gui 1000 Da'),
#  ('Somewhere', 'La Bambola'),
#  ('Somewhere', 'The 23rd Psalm'),
#  ('Somewhere', 'Cavaleiro De Aruanda'),
#  ('Somewhere', 'The World In My Hands (We Are One)'),
#  ('Somewhere', 'That you fool ed me'),
#  ('Somewhere', 'I Want What I Want'),
#  ('Somewhere', 'Skin Ticket (Live version) (Album Version)'),
#  ('Somewhere', 'Slipping Away'),
#  ('Somewhere', 'San Cristobal'),
#  ('Somewhere', 'Another Djemba Djemba'),
#  ("A Poor Man's Roses", 'Thank You Mama'),
#  ("A Poor Man's Roses", 'Big Guys Throw Cones'),
#  ("A Poor Man's Roses", "Il a suffit d'une chanson d'amour"),
#  ("A Poor Man's Roses", 'Petticoat'),
#  ("A Poor Man's Roses", 'Red is the Rose'),
#  ("A Poor Man's Roses", 'All Rise'),
#  ("A Poor Man's Roses", 'Amor Bonito'),
#  ("A Poor Man's Roses", 'Cry_ Cry_ Cry'),
#  ("A Poor Man's Roses", 'Two Elegiac Melodies Op. 34: 2. The Last Spring'),
#  ("A Poor Man's Roses", 'Prospection'),
#  ("A Poor Man's Roses", 'Caricia Y Herida'),
#  ("A Poor Man's Roses", 'Communication (More Mix)'),
#  ("A Poor Man's Roses", 'Herval na percaria'),
#  ("A Poor Man's Roses", 'Belle Isle Players'),
#  ("A Poor Man's Roses", 'Mothers Rastas'),
#  ("A Poor Man's Roses", "Sur L'autre rive"),
#  ("A Poor Man's Roses", 'Wisdom'),
#  ("A Poor Man's Roses", 'Solemn'),
#  ("A Poor Man's Roses", 'Pray On'),
#  ("A Poor Man's Roses", 'En La Soledad'),
#  ("A Poor Man's Roses", 'Cuando Calienta El Sol'),
#  ("A Poor Man's Roses", 'Never After'),
#  ("A Poor Man's Roses", 'Your Touch Versus Death'),
#  ("A Poor Man's Roses", 'Skyline'),
#  ("A Poor Man's Roses", 'Joaquin Torres Jr.'),
#  ("A Poor Man's Roses", 'Banana Split Republic'),
#  ("A Poor Man's Roses", 'Antes Que Seja Tarde'),
#  ('Ask The Angels', "Hang 'm High"),
#  ('Ask The Angels', 'The Marquis and the Scaffold (From "Quills")'),
#  ('Ask The Angels', 'Them No Care'),
#  ('Ask The Angels', 'Tides Of Time'),
#  ('Ask The Angels', 'Cuore Appassionato'),
#  ('Ask The Angels', 'D\\xc3\\xa5 \\xc3\\xa4r det jul'),
#  ('Ask The Angels', 'Heart Of Dixie'),
#  ('Ask The Angels', 'Big Woman'),
#  ('Ask The Angels', 'Intro'),
#  ('Ask The Angels', 'Anyone Who Had A Heart'),
#  ('Ask The Angels', 'No Pienses Asi'),
#  ('Ask The Angels', 'I WANNA HEAR IT FROM YOU'),
#  ('Ask The Angels', 'Old Memory'),
#  ('Ask The Angels', 'An Old Fashioned Christmas'),
#  ('Ask The Angels', "Like It's Hot"),
#  ('Ask The Angels', 'Rossignol Montmartrois (Polka)'),
#  ('Ask The Angels', 'New Love'),
#  ('Ask The Angels', 'Studen plamuk'),
#  ('Ask The Angels', 'Amigo m\\xc3\\xado'),
#  ('Ask The Angels', 'Quand on est amoureux'),
#  ('Ask The Angels', 'The Kangaroo Theory'),
#  ('Ask The Angels', 'Ego is the drug/3am'),
#  ('Ask The Angels', 'Susan Said'),
#  ('Ask The Angels', 'Streets On Fire (Explicit Album Version)'),
#  ('Ask The Angels', 'Straight Coats'),
#  ('Ask The Angels', 'Here Comes The Big Parade'),
#  ('Ask The Angels', 'Les Trois Orf\\xc3\\xa8vres'),
#  ('Ask The Angels', 'Never Alone'),
#  ('Ask The Angels', 'You Feel Good All Over'),
#  ('Ask The Angels', 'Andra sidan'),
#  ('Ask The Angels', 'Bahama Lullaby'),
#  ('Ask The Angels', 'Let It All Go'),
#  ('Ask The Angels', 'The One Who Lives Inside Your Heart'),
#  ('Ask The Angels', 'Procession'),
#  ('Ask The Angels', 'Rant Kanaria'),
#  ('Ask The Angels', 'This Christmas (LP Version)'),
#  ('Ask The Angels', 'La cl\\xc3\\xa9 parfum\\xc3\\xa9e'),
#  ('Ask The Angels', 'Sentimental Journey'),
#  ('Ask The Angels', 'Two Elegiac Melodies Op. 34: 2. The Last Spring'),
#  ('Ask The Angels', 'Fly Again (The Scumfrog Radio Edit)'),
#  ('Ask The Angels', 'La Bambola'),
#  ('Ask The Angels', 'Seventy Times Seven (LP Version)'),
#  ('Ask The Angels', 'Campeones De La Vida'),
#  ('Ask The Angels', 'Heart Of The City (Soul and R&B)'),
#  ('Ask The Angels', "I Can't"),
#  ('Ask The Angels', 'Woh\\xc3\\xa4r dr Wind w\\xc3\\xa4iht'),
#  ('Ask The Angels', 'Oceans Of Love (LP Version)'),
#  ('Ask The Angels', 'Only If You Live There'),
#  ('Ask The Angels', 'Ice Cream Cone'),
#  ('Ask The Angels', 'Bateu No Paladar'),
#  ('Ask The Angels', 'Una dolce melodia'),
#  ('Ask The Angels', 'Vollmond'),
#  ('Ask The Angels', 'Concerto For Saxophone (Quartet Version): Movement IV'),
#  ('Ask The Angels', 'El Arte De Amar'),
#  ('Ask The Angels', 'Otra Parte De Mi (1997 Digital Remaster)'),
#  ('Ask The Angels', 'Chasing Windmills'),
#  ('Ask The Angels', 'With Tears In My Eyes'),
#  ('Ask The Angels', 'Noises'),
#  ('Ask The Angels', "It's You"),
#  ('Ask The Angels', 'Bumbling Along'),
#  ('Ask The Angels', 'Cancion Para Mi Muerte'),
#  ('Ask The Angels', 'El Te Daba Mala Vida'),
#  ('Ask The Angels', 'Daughter Of Zion'),
#  ('Ask The Angels', "Gangsta's Fairytale 2 (Explicit)"),
#  ('Ask The Angels', 'Encouraged'),
#  ('Ask The Angels', 'Your Love Takes Good Care Of Me'),
#  ('Ask The Angels', 'Nina Nina'),
#  ('Ask The Angels', 'Thrill Pistol'),
#  ('Ask The Angels', 'Courtyard'),
#  ('Ask The Angels',
#   'Love Me Now (Rockwilder Remix) (Feat. Wyclef And Redman)'),
#  ('Ask The Angels', 'My Tribute (to God Be The Glory)'),
#  ('Ask The Angels', 'Tango de la Flor (Album Version)'),
#  ('Ask The Angels', 'So Jah Seh'),
#  ('Ask The Angels', 'I Hate to Be the One to Say'),
#  ('Ask The Angels', 'MVP'),
#  ('Ask The Angels', 'Round 7:  2138'),
#  ('Ask The Angels', "Since I've Been Loving You"),
#  ('Ask The Angels', 'Adios Pampa Mia'),
#  ('Ask The Angels', 'El Termometro'),
#  ('Ask The Angels', 'Allein'),
#  ('Ask The Angels', 'A Little Tear'),
#  ('Ask The Angels', 'Wasted Love'),
#  ('Ask The Angels', 'Shame'),
#  ('Ask The Angels', 'I Got My Discharge Papers'),
#  ('Ask The Angels', 'Blue Yodel No. 1(T For Texas)'),
#  ('Ask The Angels', "Maybe You'll Love Me Too"),
#  ('Ask The Angels', 'Meteorito'),
#  ('Ask The Angels', 'One Scotch_ One Bourbon_ One Beer'),
#  ('Ask The Angels', 'A True'),
#  ('Ask The Angels', 'Cable'),
#  ('Ask The Angels', 'Tiempos Dificiles'),
#  ('Ask The Angels', 'You Make Me Feel So Good'),
#  ('Ask The Angels', 'The Christmas Song  (LP Version)'),
#  ('Ask The Angels', 'Love The Feeling - Original'),
#  ('Ask The Angels', 'Fortress'),
#  ('Ask The Angels', 'Solemn'),
#  ('Ask The Angels', "Dialogue et final si j'avais su"),
#  ('Ask The Angels', 'Insatiable (Instrumental Version)'),
#  ('Ask The Angels', "Wish I Hadn't Called Home"),
#  ('Ask The Angels', 'Arabian Night'),
#  ('Ask The Angels', 'That Old Gang Of Mine'),
#  ('Ask The Angels', 'Apoliome Re Giorgi (Feat. Etsi De)'),
#  ('Ask The Angels', 'Kenourgia Fotia'),
#  ('Ask The Angels', 'Beneath an Evening Sky'),
#  ('Ask The Angels', 'Mopao'),
#  ('Ask The Angels', "Breezin' Along With the Breeze"),
#  ('Ask The Angels', 'Shi Shang Zui Qiang Man Hua Wang Da Luan Dou'),
#  ('Ask The Angels', 'September Song'),
#  ('Ask The Angels', 'Say What!?!'),
#  ('Ask The Angels', 'La Mam\\xc3\\xa1 De Jimmy'),
#  ('Ask The Angels', 'Head Over Heels'),
#  ('Ask The Angels', 'A Night in Tunisia'),
#  ('Ask The Angels', 'Gamble Calypso'),
#  ('Ask The Angels', 'Peace Prayer'),
#  ('Ask The Angels', 'By Faith I Can Touch Him Now'),
#  ('Ask The Angels', 'Guardians Of The Forest'),
#  ('Ask The Angels', 'Be Aware'),
#  ('Ask The Angels', 'What Would You Do'),
#  ('Ask The Angels', 'Whispering Grass'),
#  ('Ask The Angels', 'Ai Ji Mei Gui 1000 Da'),
#  ('Ask The Angels', 'Break My Mind'),
#  ('Ask The Angels', 'Phillippe'),
#  ('Ask The Angels', 'Faithful and True (Collectors Version)'),
#  ('Ask The Angels', 'Incide'),
#  ('Ask The Angels', 'Das Geheimrezept'),
#  ('Ask The Angels', 'Who Cares'),
#  ('Ask The Angels', 'Wasted Days And Wasted Nights'),
#  ('Ask The Angels', 'Choro II'),
#  ('Ask The Angels', 'Ooh Wee Baby'),
#  ('Ask The Angels', 'Stack and Pile'),
#  ('Ask The Angels', 'I Know That Car'),
#  ('Ask The Angels', 'Another Djemba Djemba'),
#  ('Ask The Angels', 'Chinz Ninja (Rui Da Silva mix)'),
#  ('Ask The Angels', 'All I Want'),
#  ('Ask The Angels', 'Lil Brother (LP Version)'),
#  ('Jesus', 'Fortress'),
#  ('Jesus', 'Forr\\xc3\\xb3 Praieiro'),
#  ('Jesus', 'Hear Me Lord (2001 Digital Remaster)'),
#  ('Jesus', 'Cancion Para Mi Muerte'),
#  ('Jesus', "She's About A Mover"),
#  ('Jesus', 'Till The End Of The Day (Alternate Mix)'),
#  ('Jesus', 'Anyone Who Had A Heart'),
#  ('Jesus', 'El Te Daba Mala Vida'),
#  ('Jesus', 'Choro II'),
#  ('Jesus', 'Floating'),
#  ('Jesus', 'Hai Shava'),
#  ('Jesus', 'Use Me'),
#  ('Jesus', 'Machuca'),
#  ('Jesus', 'Quand on est amoureux'),
#  ('Jesus', 'En La Soledad'),
#  ('Jesus', 'Pinini Reggae'),
#  ('Jesus', 'Saca La Botella'),
#  ('Jesus', "Wish I Hadn't Called Home"),
#  ('Jesus', 'Next Time'),
#  ('Jesus', "Breezin' Along With the Breeze"),
#  ('Jesus', 'Yesterdays'),
#  ('Jesus', 'Again'),
#  ('Jesus', 'D\\xc3\\xa5 \\xc3\\xa4r det jul'),
#  ('Jesus', 'Heart Of Dixie'),
#  ('Jesus', 'Arabian Night'),
#  ('Jesus', 'Far Beyond The Endless'),
#  ('Jesus', 'That Old Gang Of Mine'),
#  ('Jesus', 'Rakkahin -Be My Love-'),
#  ('Jesus', 'El Arte De Amar'),
#  ('Jesus', 'Hear Me Talking To You'),
#  ('Jesus', 'Nina Nina'),
#  ('Jesus', 'Movement 4 [from Kiss] (Album Version)'),
#  ('Jesus', 'Sabor Guajiro'),
#  ('Jesus', 'Shame'),
#  ('Jesus', 'Mopao'),
#  ('Jesus', 'I Know That Car'),
#  ('Jesus', 'Amor Bonito'),
#  ('Jesus', "What'll I Do For Satisfaction (LP Version)"),
#  ('Jesus', 'When A Man Loves A Woman'),
#  ('Jesus', 'Maracaia'),
#  ('Jesus', 'Un Tipo Como Yo'),
#  ('Jesus', 'Te Parto el Alma (inter. El Tariacuri)'),
#  ('Jesus', 'Rant Kanaria'),
#  ('Jesus', 'Punjabian Di Chale Glassi'),
#  ('Jesus', 'Dark As A Dungeon (LP Version)'),
#  ('Jesus', 'El Perro'),
#  ('Jesus', 'Scrimmage'),
#  ('Jesus', 'Cuando Calienta El Sol'),
#  ('Jesus', 'Comfortable'),
#  ('Jesus', 'El Aranero'),
#  ('Jesus', 'La Mam\\xc3\\xa1 De Jimmy'),
#  ('Jesus', 'Life Upon The Wicked Stage'),
#  ('Jesus', 'Ghetto'),
#  ('Jesus', 'La Bambola'),
#  ('Jesus', 'No Pienses Asi'),
#  ('Jesus', 'I WANNA HEAR IT FROM YOU'),
#  ('Jesus', 'Smooth Operator'),
#  ('Jesus', 'A Night in Tunisia'),
#  ('Jesus', 'Nada De Ti'),
#  ('Jesus', 'School'),
#  ('Jesus', 'Gamble Calypso'),
#  ('Jesus', 'Tango de la Flor (Album Version)'),
#  ('Jesus', 'Nuovi Re pt. I I (feat. Tek money - Lady Tambler)'),
#  ('Jesus', 'The Hammer Song (2010 Digital Remaster)'),
#  ('Jesus', 'Ethiopian Anthem'),
#  ('Jesus', 'Raining On Our Love'),
#  ('Jesus', 'Main Theme from Jaws'),
#  ('Jesus', 'Walk Away'),
#  ('Jesus', 'By Faith I Can Touch Him Now'),
#  ('Jesus', 'Les Fleurs'),
#  ('Jesus', "Heut' Nacht"),
#  ('Jesus', 'Packing Up'),
#  ('Jesus', 'But You Are'),
#  ('Jesus', 'Bitch Is Back'),
#  ('Jesus', 'Hush'),
#  ('Jesus', 'The Saga Of Rita Joe'),
#  ('Jesus', 'Afro Profondo'),
#  ('Jesus', 'Medicate Myself'),
#  ('Jesus', 'Distancia'),
#  ('Jesus', 'No. 284'),
#  ('Jesus', 'Cumayon'),
#  ('Jesus', 'El Jamaiquino'),
#  ('Jesus', 'Joaquin Torres Jr.'),
#  ('Jesus', 'Baiao Malandro'),
#  ('Jesus', 'Whispering Grass'),
#  ('Jesus', 'Ai Ji Mei Gui 1000 Da'),
#  ('Jesus', 'Rossignol Montmartrois (Polka)'),
#  ('Jesus', 'Sentimental Journey'),
#  ('Jesus', 'Tonight Will Be Alright'),
#  ('Jesus', 'Cavaleiro De Aruanda'),
#  ('Jesus', 'New Love'),
#  ('Jesus', 'It Makes No Difference Now'),
#  ('Jesus', 'A Little Tear'),
#  ('Jesus', 'Si Tu Me Dices Ven'),
#  ('Jesus', 'Adios Pampa Mia'),
#  ('Jesus', 'Wishy Washy Woman'),
#  ('Jesus', 'Sleeping Annaleah (2009 Digital Remaster)'),
#  ('Jesus', 'Valokeilojen vampyyri'),
#  ('Jesus', 'Bateu No Paladar'),
#  ('Jesus', 'Meditacao'),
#  ('Jesus', 'Take The Wheel'),
#  ('Jesus', 'Another Djemba Djemba'),
#  ('Jesus', 'Aguas Claras De Olimpos'),
#  ('Jesus', 'Mi Morena (Revised Live Version)'),
#  ('Jesus', 'Up Jumped The Devil'),
#  ('Jesus', 'It Is No Secret (What God Can Do)'),
#  ('Jesus', 'Amigo m\\xc3\\xado'),
#  ('Jesus', 'Turn It Up'),
#  ('Jesus', 'Antes Que Seja Tarde'),
#  ('Jesus', 'Bye Bye'),
#  ('Jesus', 'Watermelon Man'),
#  ('Jesus', 'I Got My Discharge Papers'),
#  ('Jesus', 'What If I Forget The Champagne'),
#  ('Jesus', 'Chinz Ninja (Rui Da Silva mix)'),
#  ('Jesus', 'Who Cares'),
#  ('Jesus', 'I Want What I Want'),
#  ('Jesus', "Sur L'autre rive"),
#  ('Jesus', 'Otra Parte De Mi (1997 Digital Remaster)'),
#  ('Jesus', 'Missing You'),
#  ('Jesus', 'I Wonder Where You Are Tonight'),
#  ('Jesus', 'Meteorito'),
#  ('Jesus', 'You Make Me Feel So Good'),
#  ('Jesus', 'Susan Said'),
#  ('Jesus', 'Camino'),
#  ('Jesus', 'San Cristobal'),
#  ('Jesus', 'Cable'),
#  ('Jesus', 'Straight Coats'),
#  ('Jesus', 'Apertura in jazz'),
#  ('Jesus', 'Star'),
#  ('Jesus', 'Here Comes The Big Parade'),
#  ('Jesus', 'Tiempos Dificiles'),
#  ('Jesus', 'No La Dejes Sola'),
#  ('Jesus', 'Cai dentro'),
#  ('Jesus', 'U Not Like Me'),
#  ('Jesus', 'Love That Jazz (Basements Boys Album Vers)'),
#  ('Jesus', 'Autobahn (Live)'),
#  ('Jesus', 'Menuet in the Name of Haydn'),
#  ('Jesus', "It's You"),
#  ('Jesus', 'Burbullas A Grella'),
#  ('Jesus', 'Los De Arag\\xc3\\xb3n: "Los De Arag\\xc3\\xb3n'),
#  ('Jesus', 'Love The Feeling - Original'),
#  ('Jesus', 'Bumbling Along'),
#  ('Jesus', "Like It's Hot"),
#  ('Jesus', 'Polly'),
#  ('Iron-head: Palestine',
#   'Speed Of Sound (Emergency Broadcast Album Version)'),
#  ('Iron-head: Palestine',
#   'Edge Of The Dream (Emergency Broadcast Album Version)'),
#  ('Iron-head: Palestine', 'Tides Of Time'),
#  ('Iron-head: Palestine', "Freezin' From The Inside Out"),
#  ('Iron-head: Palestine', 'Packed Up And Took My Mind'),
#  ('Iron-head: Palestine', 'Heart Of Dixie'),
#  ('Iron-head: Palestine', "Il a suffit d'une chanson d'amour"),
#  ('Iron-head: Palestine',
#   'Soldiers At War feat. Kon Juan_ Big Scoob_ Short Nutty_ L.V.'),
#  ('Iron-head: Palestine', 'I WANNA HEAR IT FROM YOU'),
#  ('Iron-head: Palestine', 'Ojos Gitanos'),
#  ('Iron-head: Palestine', 'Nada De Ti'),
#  ('Iron-head: Palestine', 'Raining On Our Love'),
#  ('Iron-head: Palestine', 'An Old Fashioned Christmas'),
#  ('Iron-head: Palestine', 'Watermelon Man'),
#  ('Iron-head: Palestine', 'The Saga Of Rita Joe'),
#  ('Iron-head: Palestine', 'Distancia'),
#  ('Iron-head: Palestine', 'Nothing But The Best'),
#  ('Iron-head: Palestine',
#   'Stereophonic Presentation - Process And Passion_ Pt. 4'),
#  ('Iron-head: Palestine', 'Rossignol Montmartrois (Polka)'),
#  ('Iron-head: Palestine', 'New Love'),
#  ('Iron-head: Palestine', 'Please Love Me'),
#  ('Iron-head: Palestine', 'Quiet Time'),
#  ('Iron-head: Palestine', 'Contessa Entellina'),
#  ('Iron-head: Palestine', "Job's Defiance"),
#  ('Iron-head: Palestine', 'Amigo m\\xc3\\xado'),
#  ('Iron-head: Palestine', 'Petticoat'),
#  ('Iron-head: Palestine', 'Loud And Clear'),
#  ('Iron-head: Palestine', 'I Wonder Where You Are Tonight'),
#  ('Iron-head: Palestine', '2HB (1999 Digital Remaster)'),
#  ('Iron-head: Palestine', 'Streets On Fire (Explicit Album Version)'),
#  ('Iron-head: Palestine', 'Tracy'),
#  ('Iron-head: Palestine', 'Here Comes The Big Parade'),
#  ('Iron-head: Palestine', 'Close Up'),
#  ('Iron-head: Palestine', 'You Feel Good All Over'),
#  ('Iron-head: Palestine', 'Cuore Appassionato'),
#  ('Iron-head: Palestine', 'When He Was On The Cross [I Was On His Mind]'),
#  ('Iron-head: Palestine', 'Susan Said'),
#  ('Iron-head: Palestine', 'Seni Unuturum'),
#  ('Iron-head: Palestine', "It Has Been A Long Time_ Hasn't It"),
#  ('Iron-head: Palestine', 'Sou Vazo Diskola'),
#  ('Iron-head: Palestine', 'Apoliome Re Giorgi (Feat. Etsi De)'),
#  ('Iron-head: Palestine', 'Amor Bonito'),
#  ('Iron-head: Palestine', 'Rant Kanaria'),
#  ('Iron-head: Palestine', 'This Christmas (LP Version)'),
#  ('Iron-head: Palestine', 'Scrimmage'),
#  ('Iron-head: Palestine', 'La cl\\xc3\\xa9 parfum\\xc3\\xa9e'),
#  ('Iron-head: Palestine', 'Sentimental Journey'),
#  ('Iron-head: Palestine', 'For Me And My Gal'),
#  ('Iron-head: Palestine', "Don't Let Go"),
#  ('Iron-head: Palestine', "I'm Thinking Tonight Of My Blue Eyes"),
#  ('Iron-head: Palestine', 'Seventy Times Seven (LP Version)'),
#  ('Iron-head: Palestine', 'As The Terror Dances Your Way'),
#  ('Iron-head: Palestine', 'But You Are'),
#  ('Iron-head: Palestine', 'Heart Of The City (Soul and R&B)'),
#  ('Iron-head: Palestine',
#   'In The Name Of God (Gentle Revolution Album Version)'),
#  ('Iron-head: Palestine', 'Special'),
#  ('Iron-head: Palestine', "I Can't"),
#  ('Iron-head: Palestine', 'Cumayon'),
#  ...]

# %% [markdown]
# There are 24,852 edges that will be removed from the 99,420 edges.

# %%
G_2_25 = G_2

# Remove the edges in remove_edge_list
G_2_25.remove_edges_from(remove_edge_list)
print(G_2_25.number_of_edges())

# Draw the network graph
nx.draw(G_2_25,
        pos=nx.spring_layout(G_2_25), # Or spectral_layout, random_layout, shell_layout , spring_layout     
        with_labels = False,
        node_size=100, 
        alpha=0.8, 
        node_color = [G_2_25.node[node]['color'] for node in G_2_25],#node_color_values['color'],
        font_size = 7,
        font_color = 'black',
        font_family = 'arial',
        edge_color = 'gray',
        width = [0.1*edge[2]['weight'] for edge in G_2_25.edges(data=True)])
        
pyplot.show()
# Out:
# 74567

# %% [markdown]
# The graph now looks a little better but still there is one single cluster.
#
# #### Remove edges with weights less than Q2 and draw
#
# If we were to drop all edges that have weights less than the second quartile of 3.82, then we would be reducing the number of edges by 50%.

# %%
remove_edge_list = [] #define empty list
for edge in G_2.edges_iter(data = True):
    if edge[2]['weight'] < 3.82:
        # append edge to list
        remove_edge_list.append((edge[0],edge[1]))

print(len(remove_edge_list))
remove_edge_list
# Out:
# 24814
# [('Earrings on the Table', 'Larger Than Life'),
#  ('Earrings on the Table', 'Spotlight'),
#  ('Earrings on the Table', 'Somewhere'),
#  ('Earrings on the Table', 'Ask The Angels'),
#  ('Earrings on the Table', 'Tides Of Time'),
#  ('Earrings on the Table', 'Cuore Appassionato'),
#  ('Earrings on the Table', 'D\\xc3\\xa5 \\xc3\\xa4r det jul'),
#  ('Earrings on the Table', 'Into A Swan'),
#  ('Earrings on the Table', 'Intro'),
#  ('Earrings on the Table', 'Under Attack'),
#  ('Earrings on the Table', 'Punjabian Di Chale Glassi'),
#  ('Earrings on the Table', 'Posledny Buntar`'),
#  ('Earrings on the Table', 'I WANNA HEAR IT FROM YOU'),
#  ('Earrings on the Table', 'Nada De Ti'),
#  ('Earrings on the Table', 'An Old Fashioned Christmas'),
#  ('Earrings on the Table', 'Watermelon Man'),
#  ('Earrings on the Table', 'Georgia'),
#  ('Earrings on the Table', 'Nothing But The Best'),
#  ('Earrings on the Table', 'Enclosed_ One Broken Heart'),
#  ('Earrings on the Table', 'New Love'),
#  ('Earrings on the Table', 'Kids Now'),
#  ('Earrings on the Table',
#   'Speed Of Sound (Emergency Broadcast Album Version)'),
#  ('Earrings on the Table',
#   'Edge Of The Dream (Emergency Broadcast Album Version)'),
#  ('Earrings on the Table', 'Kuolema Tekee Taiteilijan'),
#  ('Earrings on the Table', 'The Kangaroo Theory'),
#  ('Earrings on the Table', 'The Blinding Sun'),
#  ('Earrings on the Table', 'Streets On Fire (Explicit Album Version)'),
#  ('Earrings on the Table', 'Straight Coats'),
#  ('Earrings on the Table', 'Tracy'),
#  ('Earrings on the Table', 'Here Comes The Big Parade'),
#  ('Earrings on the Table', 'You Feel Good All Over'),
#  ('Earrings on the Table', 'Test 72'),
#  ('Earrings on the Table', 'Be Stiff (Live)'),
#  ('Earrings on the Table', 'People = Sh*t (live) (Album Version)'),
#  ('Earrings on the Table', 'Pinini Reggae'),
#  ('Earrings on the Table', 'Next Time'),
#  ('Earrings on the Table', 'The One Who Lives Inside Your Heart'),
#  ('Earrings on the Table', 'Wow'),
#  ('Earrings on the Table', 'Procession'),
#  ('Earrings on the Table', 'Nothing To Hold Me'),
#  ('Earrings on the Table', "Don't Cry_ Joe"),
#  ('Earrings on the Table', 'Just Say Yes'),
#  ('Earrings on the Table', "Can't Break This Man"),
#  ('Earrings on the Table', 'Kiss the Sky'),
#  ('Earrings on the Table', 'Anfang Vom Ende'),
#  ('Earrings on the Table', 'Sentimental Journey'),
#  ('Earrings on the Table', 'Church Hangover'),
#  ('Earrings on the Table', 'Seventy Times Seven (LP Version)'),
#  ('Earrings on the Table', 'Campeones De La Vida'),
#  ('Earrings on the Table', 'But You Are'),
#  ('Earrings on the Table', 'Camino'),
#  ('Earrings on the Table', 'Gemini'),
#  ('Earrings on the Table', 'Travel Song (Reprise)'),
#  ('Earrings on the Table', 'S.O.S.'),
#  ('Earrings on the Table', 'the tales of King Solitude 1:3'),
#  ('Earrings on the Table', 'It Makes No Difference Now'),
#  ('Earrings on the Table', 'Pus-Filled Carcass'),
#  ('Earrings on the Table', 'Otra Parte De Mi (1997 Digital Remaster)'),
#  ('Earrings on the Table', "Don't You Think It's Time To Go"),
#  ('Earrings on the Table', "It's You"),
#  ('Earrings on the Table', 'Bumbling Along'),
#  ('Earrings on the Table', 'Les D\\xc3\\xa9penaill\\xc3\\xa9s'),
#  ('Earrings on the Table', 'Did You Get My Message?  (Live From Shubas)'),
#  ('Earrings on the Table', 'Gallows (Album Version)'),
#  ('Earrings on the Table', 'La Bambola'),
#  ('Earrings on the Table', 'Primordial Breath'),
#  ('Earrings on the Table', "I Don't Like You"),
#  ('Earrings on the Table', 'Ida Red'),
#  ('Earrings on the Table', 'Tango de la Flor (Album Version)'),
#  ('Earrings on the Table', 'Das Geheimrezept'),
#  ('Earrings on the Table', 'Sick 2 Think'),
#  ('Earrings on the Table', 'Adios Pampa Mia'),
#  ('Earrings on the Table', 'El Termometro'),
#  ('Earrings on the Table', 'Baiao Malandro'),
#  ('Earrings on the Table', 'A Little Tear'),
#  ('Earrings on the Table', 'Pork Chop Sandwich'),
#  ('Earrings on the Table', 'Shame'),
#  ('Earrings on the Table', 'Dancing The Night Away'),
#  ('Earrings on the Table', 'Machuca'),
#  ('Earrings on the Table', '317 East 32nd'),
#  ('Earrings on the Table', 'Tiempos Dificiles'),
#  ('Earrings on the Table', 'Revolution'),
#  ('Earrings on the Table', 'Fortress'),
#  ('Earrings on the Table', 'Transmission (Album Version)'),
#  ('Earrings on the Table', 'I Remember/Great Is Thy Faithfulness'),
#  ('Earrings on the Table', 'Execution'),
#  ('Earrings on the Table',
#   'Digital [Live at Birmingham University] [2007 Re-mastered]'),
#  ('Earrings on the Table', 'Naked Albino'),
#  ('Earrings on the Table', 'Arabian Night'),
#  ('Earrings on the Table', 'Peyte Pivo Pennoe (present for A. Trofimov)'),
#  ('Earrings on the Table', 'Undertow'),
#  ('Earrings on the Table', 'How It Begins'),
#  ('Earrings on the Table', "Breezin' Along With the Breeze"),
#  ('Earrings on the Table', 'Dark As A Dungeon (LP Version)'),
#  ('Earrings on the Table', 'Shi Shang Zui Qiang Man Hua Wang Da Luan Dou'),
#  ('Earrings on the Table', 'Olivia'),
#  ('Earrings on the Table', 'Smooth Operator'),
#  ('Earrings on the Table', 'A Night in Tunisia'),
#  ('Earrings on the Table', "Heut' Nacht"),
#  ('Earrings on the Table', 'Say How I Feel'),
#  ('Earrings on the Table', 'Hush'),
#  ('Earrings on the Table', 'Be Aware'),
#  ('Earrings on the Table', 'Gonna Take a Miracle'),
#  ('Earrings on the Table', 'Ai Ji Mei Gui 1000 Da'),
#  ('Earrings on the Table', "Widow's Walk"),
#  ('Earrings on the Table', 'The 23rd Psalm'),
#  ('Earrings on the Table',
#   'Stereophonic Presentation - Process And Passion_ Pt. 4'),
#  ('Earrings on the Table', 'Meditacao'),
#  ('Earrings on the Table', 'Incide'),
#  ('Earrings on the Table', 'Nerio Compra Una Contestadora'),
#  ('Earrings on the Table', 'A Girls Oath'),
#  ('Earrings on the Table', 'Duck And Run'),
#  ('Earrings on the Table', 'Missing You'),
#  ('Earrings on the Table', 'Skin Ticket (Live version) (Album Version)'),
#  ('Earrings on the Table', 'San Cristobal'),
#  ('Earrings on the Table', 'Wasted Days And Wasted Nights'),
#  ('Earrings on the Table', 'Laying Down My Will (The Plan Album Version)'),
#  ('Earrings on the Table', 'Choro II'),
#  ('Earrings on the Table', 'I Know That Car'),
#  ('Earrings on the Table',
#   'What Is Light? Where Is Laughter? (Acoustic Version)'),
#  ('Earrings on the Table', 'Chinz Ninja (Rui Da Silva mix)'),
#  ('Earrings on the Table', 'Jetstream - Arthur Baker Remix'),
#  ('Earrings on the Table', '22 (Vingt Deux) (Feat. Ours)'),
#  ('Larger Than Life', 'Have U Own Things'),
#  ('Larger Than Life', 'Spotlight'),
#  ('Larger Than Life', 'Ask The Angels'),
#  ('Larger Than Life', 'Dark As A Dungeon (LP Version)'),
#  ('Larger Than Life', 'Speed Of Sound (Emergency Broadcast Album Version)'),
#  ('Larger Than Life', 'Edge Of The Dream (Emergency Broadcast Album Version)'),
#  ('Larger Than Life', "Freezin' From The Inside Out"),
#  ('Larger Than Life', 'Far Beyond The Endless'),
#  ('Larger Than Life', "Job's Defiance"),
#  ('Larger Than Life', 'The Name Is...'),
#  ('Larger Than Life', 'Under Attack'),
#  ('Larger Than Life', 'Bigbigkiss'),
#  ('Larger Than Life', 'WHEN I AM YOU'),
#  ('Larger Than Life', 'Anyone Who Had A Heart'),
#  ('Larger Than Life', 'Ojos Gitanos'),
#  ('Larger Than Life', 'Nada De Ti'),
#  ('Larger Than Life', 'Watermelon Man'),
#  ('Larger Than Life', 'Distancia'),
#  ('Larger Than Life', 'Nothing But The Best'),
#  ('Larger Than Life', 'New Love'),
#  ('Larger Than Life', 'Try'),
#  ('Larger Than Life', 'Them No Care'),
#  ('Larger Than Life', 'Amigo m\\xc3\\xado'),
#  ('Larger Than Life', 'Quand on est amoureux'),
#  ('Larger Than Life', 'She Will Love You (Album Version)'),
#  ('Larger Than Life', 'I Feel So Good'),
#  ('Larger Than Life', 'Main Title / The Searchers'),
#  ('Larger Than Life', 'Les Trois Orf\\xc3\\xa8vres'),
#  ('Larger Than Life', 'When He Was On The Cross [I Was On His Mind]'),
#  ('Larger Than Life', 'Test 72'),
#  ('Larger Than Life', 'The Lakes Of Pontchartrain'),
#  ('Larger Than Life', "Pop A Cap In Yo' Ass"),
#  ('Larger Than Life', 'Pinini Reggae'),
#  ('Larger Than Life', 'Next Time'),
#  ('Larger Than Life', "It Has Been A Long Time_ Hasn't It"),
#  ('Larger Than Life', 'Let It All Go'),
#  ('Larger Than Life', 'The One Who Lives Inside Your Heart'),
#  ('Larger Than Life', 'Procession'),
#  ('Larger Than Life', 'Nothing To Hold Me'),
#  ('Larger Than Life', 'Maracaia'),
#  ('Larger Than Life', "Sho' Enough"),
#  ('Larger Than Life', 'Kiss the Sky'),
#  ('Larger Than Life', 'La cl\\xc3\\xa9 parfum\\xc3\\xa9e'),
#  ('Larger Than Life', 'I Want What I Want'),
#  ('Larger Than Life', "Don't Let Go"),
#  ('Larger Than Life', 'Outside The Law'),
#  ('Larger Than Life', "I'm Thinking Tonight Of My Blue Eyes"),
#  ('Larger Than Life', 'Twerk (feat. Yo Majesty)'),
#  ('Larger Than Life', 'Sunset Manifesto'),
#  ('Larger Than Life', 'As The Terror Dances Your Way'),
#  ('Larger Than Life', 'Te Fuiste En Abril'),
#  ('Larger Than Life', 'Heart Of The City (Soul and R&B)'),
#  ('Larger Than Life', 'Special'),
#  ('Larger Than Life', 'Si Tu Me Dices Ven'),
#  ('Larger Than Life', 'Travel Song (Reprise)'),
#  ('Larger Than Life', 'S.O.S.'),
#  ('Larger Than Life', 'the tales of King Solitude 1:3'),
#  ('Larger Than Life', 'Same Man'),
#  ('Larger Than Life', 'El Arte De Amar'),
#  ('Larger Than Life', 'Murder One'),
#  ('Larger Than Life', 'Des Helden Widersacher'),
#  ('Larger Than Life', 'Everybody Loves You'),
#  ('Larger Than Life', "Don't You Think It's Time To Go"),
#  ('Larger Than Life', 'Take The Veil Cerpin Taxt'),
#  ('Larger Than Life', "It's You"),
#  ('Larger Than Life', 'Stack and Pile'),
#  ('Larger Than Life', 'Cancion Para Mi Muerte'),
#  ('Larger Than Life', 'The Jezebel Spirit'),
#  ('Larger Than Life', 'Writes Of Winter'),
#  ('Larger Than Life', 'Floating'),
#  ('Larger Than Life', 'Moon Going Down'),
#  ('Larger Than Life', 'Monsters In Tinsel Town'),
#  ('Larger Than Life', 'Gallows (Album Version)'),
#  ('Larger Than Life', 'The Luck You Got'),
#  ('Larger Than Life', 'Primordial Breath'),
#  ('Larger Than Life', 'Die Romantic [Live]'),
#  ('Larger Than Life', "What'll I Do For Satisfaction (LP Version)"),
#  ('Larger Than Life', 'What Is This'),
#  ('Larger Than Life', 'Thrill Pistol'),
#  ('Larger Than Life',
#   'Love Me Now (Rockwilder Remix) (Feat. Wyclef And Redman)'),
#  ('Larger Than Life', 'Ghetto'),
#  ('Larger Than Life', 'Tango de la Flor (Album Version)'),
#  ('Larger Than Life', 'One Scotch_ One Bourbon_ One Beer'),
#  ('Larger Than Life', 'Das Geheimrezept'),
#  ('Larger Than Life', 'Ethiopian Anthem'),
#  ('Larger Than Life', 'Aguas Claras De Olimpos'),
#  ('Larger Than Life', "Since I've Been Loving You"),
#  ('Larger Than Life', 'El Termometro'),
#  ('Larger Than Life', 'Allein'),
#  ('Larger Than Life', 'Waiting For A Train [Live]'),
#  ('Larger Than Life', 'Chanson sous la pluie'),
#  ('Larger Than Life', 'Dancing The Night Away'),
#  ('Larger Than Life', 'Street Sh***'),
#  ('Larger Than Life', 'Machuca'),
#  ('Larger Than Life', 'Hear Me Talking To You'),
#  ('Larger Than Life', 'Liquid Time (composition by John Goodsall)'),
#  ('Larger Than Life', "Love Is Gone (Eddie Thoneick's Liberte Mix)"),
#  ('Larger Than Life', 'Blue Yodel No. 1(T For Texas)'),
#  ('Larger Than Life', 'On Independence Day'),
#  ('Larger Than Life', "Don't Mess With Cupid (1972 demo)"),
#  ('Larger Than Life', 'The Blinding Sun'),
#  ('Larger Than Life', 'Cable'),
#  ('Larger Than Life', 'Tiempos Dificiles'),
#  ('Larger Than Life', "Class Compromise (&History's Glory)"),
#  ('Larger Than Life', 'Eyes Of A Stranger (Album Version)'),
#  ('Larger Than Life', 'Love The Feeling - Original'),
#  ('Larger Than Life', 'Rollercoasting'),
#  ('Larger Than Life', 'Fortress'),
#  ('Larger Than Life', 'The Marquis and the Scaffold (From "Quills")'),
#  ('Larger Than Life', 'You Were There'),
#  ('Larger Than Life', 'Transmission (Album Version)'),
#  ('Larger Than Life', 'Execution'),
#  ('Larger Than Life',
#   'Digital [Live at Birmingham University] [2007 Re-mastered]'),
#  ('Larger Than Life', 'Naked Albino'),
#  ('Larger Than Life', '(I Wanna) Play A Little While'),
#  ('Larger Than Life', 'Apoliome Re Giorgi (Feat. Etsi De)'),
#  ('Larger Than Life', 'Kenourgia Fotia'),
#  ('Larger Than Life', 'Sex'),
#  ('Larger Than Life', 'Undertow'),
#  ('Larger Than Life', 'Seuraavassa el\\xc3\\xa4m\\xc3\\xa4ss\\xc3\\xa4'),
#  ('Larger Than Life', 'Olivia'),
#  ('Larger Than Life', 'La Mam\\xc3\\xa1 De Jimmy'),
#  ('Larger Than Life', 'Son of Jack the Ripper'),
#  ('Larger Than Life', 'Ter\\xc3\\xa4slintu'),
#  ('Larger Than Life', 'Gamble Calypso'),
#  ('Larger Than Life', 'Say How I Feel'),
#  ('Larger Than Life', 'Hush'),
#  ('Larger Than Life', 'Guardians Of The Forest'),
#  ('Larger Than Life', "Widow's Walk"),
#  ('Larger Than Life', 'The 23rd Psalm'),
#  ('Larger Than Life', 'Rewind'),
#  ('Larger Than Life', 'Wishy Washy Woman'),
#  ('Larger Than Life', 'Need More Blues'),
#  ('Larger Than Life', 'Concerto For Saxophone (Quartet Version): Movement IV'),
#  ('Larger Than Life', 'Incide'),
#  ('Larger Than Life', 'Peaches (Fear of Theydon remix)'),
#  ('Larger Than Life', 'We Do It For the Money_ OBVIOUSLY! (Demo)'),
#  ('Larger Than Life', 'A Girls Oath'),
#  ('Larger Than Life', 'How It Begins'),
#  ('Larger Than Life', 'Slipping Away'),
#  ('Larger Than Life', 'Yesss Lord...'),
#  ('Larger Than Life', 'San Cristobal'),
#  ('Larger Than Life', 'Shi Shang Zui Qiang Man Hua Wang Da Luan Dou'),
#  ('Larger Than Life', 'Laying Down My Will (The Plan Album Version)'),
#  ('Larger Than Life', 'Choro II'),
#  ('Larger Than Life', 'All I Want'),
#  ('Spotlight', 'Rescue Me'),
#  ('Spotlight', 'Iron-head: Palestine'),
#  ('Spotlight', 'The Marquis and the Scaffold (From "Quills")'),
#  ('Spotlight', 'Tides Of Time'),
#  ('Spotlight', 'What If I Forget The Champagne'),
#  ('Spotlight', "Freezin' From The Inside Out"),
#  ('Spotlight', 'Packed Up And Took My Mind'),
#  ('Spotlight', 'Cuore Appassionato'),
#  ('Spotlight', 'D\\xc3\\xa5 \\xc3\\xa4r det jul'),
#  ('Spotlight', 'Heart Of Dixie'),
#  ('Spotlight', 'Anyone Who Had A Heart'),
#  ('Spotlight', 'No Pienses Asi'),
#  ('Spotlight', 'I WANNA HEAR IT FROM YOU'),
#  ('Spotlight', 'Ojos Gitanos'),
#  ('Spotlight', 'An Old Fashioned Christmas'),
#  ('Spotlight', 'Watermelon Man'),
#  ('Spotlight', 'La Bambola'),
#  ('Spotlight', 'Long Summer Days'),
#  ('Spotlight', 'Georgia'),
#  ('Spotlight', 'Rossignol Montmartrois (Polka)'),
#  ('Spotlight', 'Enclosed_ One Broken Heart'),
#  ('Spotlight', 'Flipside'),
#  ('Spotlight', 'Please Love Me'),
#  ('Spotlight', "Job's Defiance"),
#  ('Spotlight', 'Amigo m\\xc3\\xado'),
#  ('Spotlight', 'Blaue Matrosen (live)'),
#  ('Spotlight', '2HB (1999 Digital Remaster)'),
#  ('Spotlight', 'Streets On Fire (Explicit Album Version)'),
#  ('Spotlight', 'Apertura in jazz'),
#  ('Spotlight', 'Close Up'),
#  ('Spotlight', 'White Winter Hymnal'),
#  ('Spotlight', 'Test 72'),
#  ('Spotlight', 'Next Time'),
#  ('Spotlight', "It Has Been A Long Time_ Hasn't It"),
#  ('Spotlight', 'Procession'),
#  ('Spotlight', 'Quiet Time'),
#  ('Spotlight', 'Sinnloz/ Anakonda (live)'),
#  ('Spotlight', 'Kiss the Sky'),
#  ('Spotlight', 'La cl\\xc3\\xa9 parfum\\xc3\\xa9e'),
#  ('Spotlight', 'Seventy Times Seven (LP Version)'),
#  ('Spotlight', 'As The Terror Dances Your Way'),
#  ('Spotlight', 'Te Fuiste En Abril'),
#  ('Spotlight', 'Heart Of The City (Soul and R&B)'),
#  ('Spotlight', 'Special'),
#  ('Spotlight', 'Cumayon'),
#  ('Spotlight', 'Camino'),
#  ('Spotlight', 'Woh\\xc3\\xa4r dr Wind w\\xc3\\xa4iht'),
#  ('Spotlight', 'S.O.S.'),
#  ('Spotlight', 'It Is No Secret (What God Can Do)'),
#  ('Spotlight', 'It Makes No Difference Now'),
#  ('Spotlight', 'Big Guys Throw Cones'),
#  ('Spotlight', 'Life Upon The Wicked Stage'),
#  ('Spotlight', 'Otra Parte De Mi (1997 Digital Remaster)'),
#  ('Spotlight', 'Chasing Windmills'),
#  ('Spotlight', 'Des Helden Widersacher'),
#  ('Spotlight', 'I Need You'),
#  ('Spotlight', 'Noises'),
#  ('Spotlight', 'Bumbling Along'),
#  ('Spotlight', 'Perdido (1999 Digital Remaster)'),
#  ('Spotlight', 'Coma'),
#  ('Spotlight', 'The One I Got'),
#  ('Spotlight', "Gangsta's Fairytale 2 (Explicit)"),
#  ('Spotlight', 'Your Love Takes Good Care Of Me'),
#  ('Spotlight', 'All Rise'),
#  ('Spotlight', 'Tango de la Flor (Album Version)'),
#  ('Spotlight', 'Das Geheimrezept'),
#  ('Spotlight', 'So Jah Seh'),
#  ('Spotlight', 'Round 7:  2138'),
#  ('Spotlight', 'Adios Pampa Mia'),
#  ('Spotlight', 'Allein'),
#  ('Spotlight', 'Waiting For A Train [Live]'),
#  ('Spotlight', 'A Little Tear'),
#  ('Spotlight', 'Shame'),
#  ('Spotlight', 'It Was Only A Heart'),
#  ('Spotlight', 'I Got My Discharge Papers'),
#  ('Spotlight', 'Dedicated To The One I Love'),
#  ('Spotlight', 'Again'),
#  ('Spotlight', 'Meteorito'),
#  ('Spotlight', 'A True'),
#  ('Spotlight', 'Cable'),
#  ('Spotlight', 'Tiempos Dificiles'),
#  ('Spotlight', 'You Make Me Feel So Good'),
#  ('Spotlight', 'Fortress'),
#  ('Spotlight', 'A Man Can Only Stand Just So Much Pain (Bonus Track)'),
#  ('Spotlight', 'So Still (Album Version)'),
#  ('Spotlight', "Dialogue et final si j'avais su"),
#  ('Spotlight', 'Execution'),
#  ('Spotlight', 'Love That Jazz (Basements Boys Album Vers)'),
#  ('Spotlight', 'That Old Gang Of Mine'),
#  ('Spotlight', 'Apoliome Re Giorgi (Feat. Etsi De)'),
#  ('Spotlight', 'Kenourgia Fotia'),
#  ('Spotlight', 'El Arte De Amar'),
#  ('Spotlight', 'When A Man Loves A Woman'),
#  ('Spotlight', 'Dark As A Dungeon (LP Version)'),
#  ('Spotlight', 'Olivia'),
#  ('Spotlight', 'La Mam\\xc3\\xa1 De Jimmy'),
#  ('Spotlight', 'Will You Love Me Tomorrow'),
#  ('Spotlight', 'Ter\\xc3\\xa4slintu'),
#  ('Spotlight', 'Gamble Calypso'),
#  ('Spotlight', 'Les Fleurs'),
#  ('Spotlight', 'Say How I Feel'),
#  ('Spotlight', 'Hush'),
#  ('Spotlight', 'What Would You Do'),
#  ('Spotlight', 'Break My Mind'),
#  ('Spotlight', 'I Know That Car'),
#  ('Spotlight', 'Phillippe'),
#  ('Spotlight', 'Incide'),
#  ('Spotlight', '2StepN'),
#  ('Spotlight', 'Who Cares'),
#  ('Spotlight', 'Wasted Days And Wasted Nights'),
#  ('Spotlight', "She's All I Ever Had"),
#  ('Spotlight', 'I Hate to Be the One to Say'),
#  ('Rescue Me', 'Have U Own Things'),
#  ('Rescue Me', 'Ask The Angels'),
#  ('Rescue Me', "Hang 'm High"),
#  ('Rescue Me', 'Speed Of Sound (Emergency Broadcast Album Version)'),
#  ('Rescue Me', 'Edge Of The Dream (Emergency Broadcast Album Version)'),
#  ('Rescue Me', '18 De Noviembre'),
#  ('Rescue Me',
#   'Oedipus Rex_ Atto Primo: Liberi_ Vos Liberabo (Oedipus) (Stravinsky)'),
#  ('Rescue Me', 'Pu**y Pop'),
#  ('Rescue Me', 'Thank You Mama'),
#  ('Rescue Me', 'Studen plamuk'),
#  ('Rescue Me', 'Un Tipo Como Yo'),
#  ('Rescue Me', 'Posledny Buntar`'),
#  ('Rescue Me', 'Ojos Gitanos'),
#  ('Rescue Me', 'Everything Has Changed'),
#  ('Rescue Me', 'Distancia'),
#  ('Rescue Me', 'Georgia'),
#  ('Rescue Me', 'Nothing But The Best'),
#  ('Rescue Me', 'Rossignol Montmartrois (Polka)'),
#  ('Rescue Me', 'New Love'),
#  ('Rescue Me', 'Flipside'),
#  ('Rescue Me', 'September Song'),
#  ('Rescue Me', "I'm Thinking Tonight Of My Blue Eyes"),
#  ('Rescue Me', 'Them No Care'),
#  ('Rescue Me', 'Kids Now'),
#  ('Rescue Me', 'Vollmond'),
#  ('Rescue Me', 'Ability To Create A War'),
#  ('Rescue Me', 'Ego is the drug/3am'),
#  ('Rescue Me', 'Blaue Matrosen (live)'),
#  ('Rescue Me', 'All Rise'),
#  ('Rescue Me', 'When He Was On The Cross [I Was On His Mind]'),
#  ('Rescue Me', 'Test 72'),
#  ('Rescue Me', 'Seni Unuturum'),
#  ('Rescue Me', "It Has Been A Long Time_ Hasn't It"),
#  ('Rescue Me', 'Sou Vazo Diskola'),
#  ('Rescue Me', 'Let It All Go'),
#  ('Rescue Me', 'Sabor Guajiro'),
#  ('Rescue Me', "Don't Cry_ Joe"),
#  ('Rescue Me', 'Sinnloz/ Anakonda (live)'),
#  ('Rescue Me', 'Maracaia'),
#  ('Rescue Me', 'Rant Kanaria'),
#  ('Rescue Me', 'Church Hangover'),
#  ('Rescue Me', 'Two Elegiac Melodies Op. 34: 2. The Last Spring'),
#  ('Rescue Me', 'Sunset Manifesto'),
#  ('Rescue Me', 'Campeones De La Vida'),
#  ('Rescue Me', 'Te Fuiste En Abril'),
#  ('Rescue Me', 'Apoliome Re Giorgi (Feat. Etsi De)'),
#  ('Rescue Me', 'Los De Arag\\xc3\\xb3n: "Los De Arag\\xc3\\xb3n'),
#  ('Rescue Me', 'Special'),
#  ('Rescue Me', 'Woh\\xc3\\xa4r dr Wind w\\xc3\\xa4iht'),
#  ('Rescue Me', 'the tales of King Solitude 1:3'),
#  ('Rescue Me', 'Same Man'),
#  ('Rescue Me', 'El Arte De Amar'),
#  ('Rescue Me', 'Everybody Loves You'),
#  ('Rescue Me', 'White Winter Hymnal'),
#  ('Rescue Me', 'Noises'),
#  ('Rescue Me', 'Only If You Live There'),
#  ('Rescue Me', 'Communication (More Mix)'),
#  ('Rescue Me', 'Hai Shava'),
#  ('Rescue Me', "Gangsta's Fairytale 2 (Explicit)"),
#  ('Rescue Me', 'The Luck You Got'),
#  ('Rescue Me', 'Mark Practices'),
#  ('Rescue Me', "What'll I Do For Satisfaction (LP Version)"),
#  ('Rescue Me', 'Ida Red'),
#  ('Rescue Me', 'Love Me Now (Rockwilder Remix) (Feat. Wyclef And Redman)'),
#  ('Rescue Me', 'Ghetto'),
#  ('Rescue Me', 'Adios Pampa Mia'),
#  ('Rescue Me', 'Allein'),
#  ('Rescue Me', 'Pork Chop Sandwich'),
#  ('Rescue Me', 'Chanson sous la pluie'),
#  ('Rescue Me', 'Dancing The Night Away'),
#  ('Rescue Me', 'Street Sh***'),
#  ('Rescue Me', 'Machuca'),
#  ('Rescue Me', 'On Independence Day'),
#  ('Rescue Me', 'Beyond The Reef'),
#  ('Rescue Me', 'Pus-Filled Carcass'),
#  ('Rescue Me', 'C\\xc3\\xa9u do Brasil'),
#  ('Rescue Me', 'Tiempos Dificiles'),
#  ('Rescue Me', 'Pray On'),
#  ('Rescue Me', 'Insatiable (Instrumental Version)'),
#  ('Rescue Me', 'Midnight Hour'),
#  ('Rescue Me', 'Peyte Pivo Pennoe (present for A. Trofimov)'),
#  ('Rescue Me', 'Kenourgia Fotia'),
#  ('Rescue Me', 'Gamble Calypso'),
#  ('Rescue Me', 'Main Theme from Jaws'),
#  ('Rescue Me', 'The Bravest Kids (Acoustic)'),
#  ('Rescue Me', 'Be Aware'),
#  ('Rescue Me', 'Sheng Li Hu Huan'),
#  ('Rescue Me', 'La Bambola'),
#  ('Rescue Me', 'Incide'),
#  ('Rescue Me', 'That you fool ed me'),
#  ('Rescue Me', 'We Do It For the Money_ OBVIOUSLY! (Demo)'),
#  ('Rescue Me', 'Stack and Pile'),
#  ('Rescue Me', 'San Cristobal'),
#  ('Rescue Me', 'Wasted Days And Wasted Nights'),
#  ('Rescue Me', "She's All I Ever Had"),
#  ('Rescue Me', 'What Is Light? Where Is Laughter? (Acoustic Version)'),
#  ('Rescue Me', 'All I Want'),
#  ('Wo Ai Ni_ Zai Jian!', 'Speed Of Sound (Emergency Broadcast Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'What If I Forget The Champagne'),
#  ('Wo Ai Ni_ Zai Jian!', 'Immigrant Song (Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Packed Up And Took My Mind'),
#  ('Wo Ai Ni_ Zai Jian!',
#   'Edge Of The Dream (Emergency Broadcast Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'D\\xc3\\xa5 \\xc3\\xa4r det jul'),
#  ('Wo Ai Ni_ Zai Jian!', 'Heart Of Dixie'),
#  ('Wo Ai Ni_ Zai Jian!', 'Far Beyond The Endless'),
#  ('Wo Ai Ni_ Zai Jian!', 'Movement 4 [from Kiss] (Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Onni'),
#  ('Wo Ai Ni_ Zai Jian!', 'The Name Is...'),
#  ('Wo Ai Ni_ Zai Jian!', 'Intro'),
#  ('Wo Ai Ni_ Zai Jian!', 'The Hammer Song (2010 Digital Remaster)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Anyone Who Had A Heart'),
#  ('Wo Ai Ni_ Zai Jian!', 'I WANNA HEAR IT FROM YOU'),
#  ('Wo Ai Ni_ Zai Jian!', 'Nada De Ti'),
#  ('Wo Ai Ni_ Zai Jian!', 'An Old Fashioned Christmas'),
#  ('Wo Ai Ni_ Zai Jian!', 'Watermelon Man'),
#  ('Wo Ai Ni_ Zai Jian!', 'Bitch Is Back'),
#  ('Wo Ai Ni_ Zai Jian!', 'Long Summer Days'),
#  ('Wo Ai Ni_ Zai Jian!', 'Everything Has Changed'),
#  ('Wo Ai Ni_ Zai Jian!', 'Nothing But The Best'),
#  ('Wo Ai Ni_ Zai Jian!', 'Rossignol Montmartrois (Polka)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Please Love Me'),
#  ('Wo Ai Ni_ Zai Jian!', 'Amigo m\\xc3\\xado'),
#  ('Wo Ai Ni_ Zai Jian!', 'Arabian Night'),
#  ('Wo Ai Ni_ Zai Jian!', 'I Wonder Where You Are Tonight'),
#  ('Wo Ai Ni_ Zai Jian!', 'For Me And My Gal'),
#  ('Wo Ai Ni_ Zai Jian!', 'Tracy'),
#  ('Wo Ai Ni_ Zai Jian!', 'Here Comes The Big Parade'),
#  ('Wo Ai Ni_ Zai Jian!', 'Gemini'),
#  ('Wo Ai Ni_ Zai Jian!', 'Close Up'),
#  ('Wo Ai Ni_ Zai Jian!', 'You Feel Good All Over'),
#  ('Wo Ai Ni_ Zai Jian!', 'As You Take A  Walk Through My Mind'),
#  ('Wo Ai Ni_ Zai Jian!', 'Seni Unuturum'),
#  ('Wo Ai Ni_ Zai Jian!', "Pop A Cap In Yo' Ass"),
#  ('Wo Ai Ni_ Zai Jian!', 'Sou Vazo Diskola'),
#  ('Wo Ai Ni_ Zai Jian!', 'Wow'),
#  ('Wo Ai Ni_ Zai Jian!', 'Procession'),
#  ('Wo Ai Ni_ Zai Jian!', 'Nothing To Hold Me'),
#  ('Wo Ai Ni_ Zai Jian!', 'Just Say Yes'),
#  ('Wo Ai Ni_ Zai Jian!', "Sho' Enough"),
#  ('Wo Ai Ni_ Zai Jian!', 'Rant Kanaria'),
#  ('Wo Ai Ni_ Zai Jian!', 'Heal (The Separation) [PM Dawn Alt. Lead Mix]'),
#  ('Wo Ai Ni_ Zai Jian!', 'Fly Again (The Scumfrog Radio Edit)'),
#  ('Wo Ai Ni_ Zai Jian!', "I'm Thinking Tonight Of My Blue Eyes"),
#  ('Wo Ai Ni_ Zai Jian!', 'Campeones De La Vida'),
#  ('Wo Ai Ni_ Zai Jian!', 'Carry The Light'),
#  ('Wo Ai Ni_ Zai Jian!', "I Can't"),
#  ('Wo Ai Ni_ Zai Jian!', 'Cumayon'),
#  ('Wo Ai Ni_ Zai Jian!', 'Si Tu Me Dices Ven'),
#  ('Wo Ai Ni_ Zai Jian!', 'U Not Like Me'),
#  ('Wo Ai Ni_ Zai Jian!', 'Camino'),
#  ('Wo Ai Ni_ Zai Jian!', 'Damn those eyes'),
#  ('Wo Ai Ni_ Zai Jian!', 'Travel Song (Reprise)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Una dolce melodia'),
#  ('Wo Ai Ni_ Zai Jian!', 'Otra Parte De Mi (1997 Digital Remaster)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Murder One'),
#  ('Wo Ai Ni_ Zai Jian!', 'Chasing Windmills'),
#  ('Wo Ai Ni_ Zai Jian!', 'Des Helden Widersacher'),
#  ('Wo Ai Ni_ Zai Jian!', 'White Winter Hymnal'),
#  ('Wo Ai Ni_ Zai Jian!', 'Star'),
#  ('Wo Ai Ni_ Zai Jian!', 'Say How I Feel'),
#  ('Wo Ai Ni_ Zai Jian!', "What's In You?"),
#  ('Wo Ai Ni_ Zai Jian!', 'Les D\\xc3\\xa9penaill\\xc3\\xa9s'),
#  ('Wo Ai Ni_ Zai Jian!', 'Fall in Philadelphia'),
#  ('Wo Ai Ni_ Zai Jian!', 'El Te Daba Mala Vida'),
#  ('Wo Ai Ni_ Zai Jian!', 'Floating'),
#  ('Wo Ai Ni_ Zai Jian!', 'Did You Get My Message?  (Live From Shubas)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Gallows (Album Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Nina Nina'),
#  ('Wo Ai Ni_ Zai Jian!', 'Blues As Blues Can Get'),
#  ('Wo Ai Ni_ Zai Jian!', 'The World In My Hands (We Are One)'),
#  ('Wo Ai Ni_ Zai Jian!',
#   'Love Me Now (Rockwilder Remix) (Feat. Wyclef And Redman)'),
#  ('Wo Ai Ni_ Zai Jian!', "Please Don't Lie To Me"),
#  ('Wo Ai Ni_ Zai Jian!', 'Das Geheimrezept'),
#  ('Wo Ai Ni_ Zai Jian!', 'Baiao Malandro'),
#  ('Wo Ai Ni_ Zai Jian!', 'A Little Tear'),
#  ('Wo Ai Ni_ Zai Jian!', 'Sleeping Annaleah (2009 Digital Remaster)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Chanson sous la pluie'),
#  ('Wo Ai Ni_ Zai Jian!', 'Hear Me Talking To You'),
#  ('Wo Ai Ni_ Zai Jian!', 'Liquid Time (composition by John Goodsall)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Sweet And Lovely'),
#  ('Wo Ai Ni_ Zai Jian!', 'Angie (1993 Digital Remaster)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Meteorito'),
#  ('Wo Ai Ni_ Zai Jian!', 'You Make Me Feel So Good'),
#  ('Wo Ai Ni_ Zai Jian!', 'The Christmas Song  (LP Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'All I Can Do'),
#  ('Wo Ai Ni_ Zai Jian!', 'El Jamaiquino'),
#  ('Wo Ai Ni_ Zai Jian!',
#   'A Man Can Only Stand Just So Much Pain (Bonus Track)'),
#  ('Wo Ai Ni_ Zai Jian!', 'You Were There'),
#  ('Wo Ai Ni_ Zai Jian!', "Wish I Hadn't Called Home"),
#  ('Wo Ai Ni_ Zai Jian!', 'Slipping Away'),
#  ('Wo Ai Ni_ Zai Jian!', 'Mopao'),
#  ('Wo Ai Ni_ Zai Jian!', 'Laakista humppa'),
#  ('Wo Ai Ni_ Zai Jian!', 'La Mam\\xc3\\xa1 De Jimmy'),
#  ('Wo Ai Ni_ Zai Jian!', 'Head Over Heels'),
#  ('Wo Ai Ni_ Zai Jian!', 'Ter\\xc3\\xa4slintu'),
#  ('Wo Ai Ni_ Zai Jian!', 'Gamble Calypso'),
#  ('Wo Ai Ni_ Zai Jian!', 'Main Theme from Jaws'),
#  ('Wo Ai Ni_ Zai Jian!', "Heut' Nacht"),
#  ('Wo Ai Ni_ Zai Jian!', 'Hush'),
#  ('Wo Ai Ni_ Zai Jian!', 'Tonight Will Be Alright'),
#  ('Wo Ai Ni_ Zai Jian!', 'I Know That Car'),
#  ('Wo Ai Ni_ Zai Jian!', 'Mi Morena (Revised Live Version)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Hear Me Lord (2001 Digital Remaster)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Nerio Compra Una Contestadora'),
#  ('Wo Ai Ni_ Zai Jian!', 'Street Sh***'),
#  ('Wo Ai Ni_ Zai Jian!', '22 (Vingt Deux) (Feat. Ours)'),
#  ('Wo Ai Ni_ Zai Jian!', 'Wasted Days And Wasted Nights'),
#  ('Wo Ai Ni_ Zai Jian!', 'Choro II'),
#  ('Wo Ai Ni_ Zai Jian!', 'Stack and Pile'),
#  ('Wo Ai Ni_ Zai Jian!', 'I Hate to Be the One to Say'),
#  ('Wo Ai Ni_ Zai Jian!', 'Another Djemba Djemba'),
#  ('Wo Ai Ni_ Zai Jian!', 'All I Want'),
#  ('Wo Ai Ni_ Zai Jian!', 'Jetstream - Arthur Baker Remix'),
#  ('Somewhere', 'Till The End Of The Day (Alternate Mix)'),
#  ('Somewhere', 'Thank You Mama'),
#  ('Somewhere', 'Wishy Washy Woman'),
#  ('Somewhere', 'Dark As A Dungeon (LP Version)'),
#  ('Somewhere', 'Heart Of Dixie'),
#  ('Somewhere', 'Big Woman'),
#  ('Somewhere', 'Into A Swan'),
#  ('Somewhere', 'So Many Reasons'),
#  ('Somewhere', 'La Mam\\xc3\\xa1 De Jimmy'),
#  ('Somewhere', 'Te Parto el Alma (inter. El Tariacuri)'),
#  ('Somewhere', 'Under Attack'),
#  ('Somewhere', 'What Is This'),
#  ('Somewhere', 'No Pienses Asi'),
#  ('Somewhere', 'I WANNA HEAR IT FROM YOU'),
#  ('Somewhere', 'Nada De Ti'),
#  ('Somewhere', 'An Old Fashioned Christmas'),
#  ('Somewhere', 'Bitch Is Back'),
#  ('Somewhere', 'The Saga Of Rita Joe'),
#  ('Somewhere', 'Distancia'),
#  ('Somewhere', 'Rossignol Montmartrois (Polka)'),
#  ('Somewhere', 'Flipside'),
#  ('Somewhere', 'Kids Now'),
#  ('Somewhere', 'Contessa Entellina'),
#  ('Somewhere', 'Kuolema Tekee Taiteilijan'),
#  ('Somewhere', 'The Hammer Song (2010 Digital Remaster)'),
#  ('Somewhere', 'S.O.S.'),
#  ('Somewhere', 'Sleeping My Day Away [Live]'),
#  ('Somewhere', 'The Kangaroo Theory'),
#  ('Somewhere', '2HB (1999 Digital Remaster)'),
#  ('Somewhere', 'Peaches (Fear of Theydon remix)'),
#  ('Somewhere', 'Main Title / The Searchers'),
#  ('Somewhere', 'Close Up'),
#  ('Somewhere', 'Machuca'),
#  ('Somewhere', 'Pinini Reggae'),
#  ('Somewhere', 'The Plot To Bomb The Panhandle (Album Version)'),
#  ('Somewhere', 'Let It All Go'),
#  ('Somewhere', 'The One Who Lives Inside Your Heart'),
#  ('Somewhere', 'Wow'),
#  ('Somewhere', 'Sabor Guajiro'),
#  ('Somewhere', "Don't Cry_ Joe"),
#  ('Somewhere', 'Amor Bonito'),
#  ('Somewhere', 'Just Say Yes'),
#  ('Somewhere', 'Maracaia'),
#  ('Somewhere', 'Rant Kanaria'),
#  ('Somewhere', "Can't Break This Man"),
#  ('Somewhere', 'Kiss the Sky'),
#  ('Somewhere', 'El Perro'),
#  ('Somewhere', 'Scrimmage'),
#  ('Somewhere', 'Movement 4 [from Kiss] (Album Version)'),
#  ('Somewhere', 'Sentimental Journey'),
#  ('Somewhere', 'Church Hangover'),
#  ('Somewhere', 'Fly Again (The Scumfrog Radio Edit)'),
#  ('Somewhere', "I'm Thinking Tonight Of My Blue Eyes"),
#  ('Somewhere', 'School'),
#  ('Somewhere', 'Happy To Meet & Sorry To Part'),
#  ('Somewhere', 'Los De Arag\\xc3\\xb3n: "Los De Arag\\xc3\\xb3n'),
#  ('Somewhere', 'Si Tu Me Dices Ven'),
#  ('Somewhere', 'Woh\\xc3\\xa4r dr Wind w\\xc3\\xa4iht'),
#  ('Somewhere', "Don't Let Go"),
#  ('Somewhere', 'Camino'),
#  ('Somewhere', 'Gemini'),
#  ('Somewhere', 'The Marquis and the Scaffold (From "Quills")'),
#  ('Somewhere', 'Polly'),
#  ('Somewhere', 'Same Man'),
#  ('Somewhere', 'Murder One'),
#  ('Somewhere', 'Des Helden Widersacher'),
#  ('Somewhere', 'Star'),
#  ('Somewhere', 'Take The Veil Cerpin Taxt'),
#  ('Somewhere', "Bartholdi's Dream"),
#  ('Somewhere', "It's You"),
#  ('Somewhere', 'Bumbling Along'),
#  ('Somewhere', 'Stack and Pile'),
#  ('Somewhere', 'Perdido (1999 Digital Remaster)'),
#  ('Somewhere', 'Les D\\xc3\\xa9penaill\\xc3\\xa9s'),
#  ('Somewhere',
#   'Dale Darrell Waltrip Richard Petty Rusty Awesome Bill Irvin Gordon Earnhardt Smith...Johnson_ Jr. (Live)'),
#  ('Somewhere', '\\xc3\\x98mhet'),
#  ('Somewhere', 'Coma'),
#  ('Somewhere', 'Fall in Philadelphia'),
#  ('Somewhere', 'Hum Drum'),
#  ('Somewhere', 'Your Love Takes Good Care Of Me'),
#  ('Somewhere', 'Love Me Now (Rockwilder Remix) (Feat. Wyclef And Redman)'),
#  ('Somewhere', 'Ida Red'),
#  ('Somewhere', 'If Money Talks'),
#  ('Somewhere', 'Ethiopian Anthem'),
#  ('Somewhere', 'Aguas Claras De Olimpos'),
#  ('Somewhere', "Don't Knock Love"),
#  ('Somewhere', 'MVP'),
#  ('Somewhere', 'El Termometro'),
#  ('Somewhere', 'Sleeping Annaleah (2009 Digital Remaster)'),
#  ('Somewhere', 'Chanson sous la pluie'),
#  ('Somewhere', 'The Attitude Song'),
#  ('Somewhere', 'Dancing The Night Away'),
#  ('Somewhere', 'Liquid Time (composition by John Goodsall)'),
#  ('Somewhere', 'Use Me'),
#  ('Somewhere', "Love Is Gone (Eddie Thoneick's Liberte Mix)"),
#  ('Somewhere', 'Blue Yodel No. 1(T For Texas)'),
#  ('Somewhere', '317 East 32nd'),
#  ('Somewhere', 'Beyond The Reef'),
#  ('Somewhere', "Maybe You'll Love Me Too"),
#  ('Somewhere', 'Autobahn (Live)'),
#  ('Somewhere', 'Menuet in the Name of Haydn'),
#  ('Somewhere', 'Nuovi Re pt. I I (feat. Tek money - Lady Tambler)'),
#  ('Somewhere', 'Eyes Of A Stranger (Album Version)'),
#  ('Somewhere', 'Fortress'),
#  ('Somewhere', 'El Jamaiquino'),
#  ('Somewhere', 'Execution'),
#  ('Somewhere', 'Love That Jazz (Basements Boys Album Vers)'),
#  ('Somewhere', 'Naked Albino'),
#  ('Somewhere', 'Forr\\xc3\\xb3 Praieiro'),
#  ('Somewhere', "I Can't Wait 'Til Christmas (LP Version)"),
#  ('Somewhere', 'part 2 - Winterlight'),
#  ('Somewhere', 'The Harbour'),
#  ('Somewhere', 'Kenourgia Fotia'),
#  ('Somewhere', 'Sometimes I'),
#  ('Somewhere', 'Undertow'),
#  ('Somewhere', 'How It Begins'),
#  ('Somewhere', "Breezin' Along With the Breeze"),
#  ('Somewhere', 'Betrayal Is A Symptom'),
#  ('Somewhere', 'Wasted Days And Wasted Nights'),
#  ('Somewhere', 'Olivia'),
#  ('Somewhere', 'Say What!?!'),
#  ('Somewhere', 'Head Over Heels'),
#  ('Somewhere', 'Ter\\xc3\\xa4slintu'),
#  ('Somewhere', 'Cuando Calienta El Sol'),
#  ('Somewhere', 'Sheng Li Hu Huan'),
#  ('Somewhere', 'Whispering Grass'),
#  ('Somewhere', 'Break My Mind'),
#  ('Somewhere', 'Rewind'),
#  ('Somewhere', 'Stereophonic Presentation - Process And Passion_ Pt. 4'),
#  ('Somewhere', 'Yesterdays'),
#  ('Somewhere', 'Hear Me Lord (2001 Digital Remaster)'),
#  ('Somewhere', 'Street Sh***'),
#  ('Somewhere', 'Duck And Run'),
#  ('Somewhere', 'Yesss Lord...'),
#  ('Somewhere', 'Shi Shang Zui Qiang Man Hua Wang Da Luan Dou'),
#  ('Somewhere', "She's All I Ever Had"),
#  ('Somewhere', 'Ooh Wee Baby'),
#  ('Somewhere', 'I Know That Car'),
#  ('Somewhere', 'What Is Light? Where Is Laughter? (Acoustic Version)'),
#  ('Somewhere', 'All I Want'),
#  ('Somewhere', 'Jetstream - Arthur Baker Remix'),
#  ("A Poor Man's Roses", 'Ask The Angels'),
#  ("A Poor Man's Roses", '18 De Noviembre'),
#  ("A Poor Man's Roses",
#   'Oedipus Rex_ Atto Primo: Liberi_ Vos Liberabo (Oedipus) (Stravinsky)'),
#  ("A Poor Man's Roses", 'El Aranero'),
#  ("A Poor Man's Roses", 'The Saga Of Rita Joe'),
#  ("A Poor Man's Roses", 'Everything Has Changed'),
#  ("A Poor Man's Roses", "Like It's Hot"),
#  ("A Poor Man's Roses", 'Ability To Create A War'),
#  ("A Poor Man's Roses", 'Ego is the drug/3am'),
#  ("A Poor Man's Roses", 'So Many Reasons'),
#  ("A Poor Man's Roses", 'Jokers and Thieves'),
#  ("A Poor Man's Roses", 'When He Was On The Cross [I Was On His Mind]'),
#  ("A Poor Man's Roses", 'Seni Unuturum'),
#  ("A Poor Man's Roses", 'Sou Vazo Diskola'),
#  ("A Poor Man's Roses", 'Meteores mouvement de Chroniques de la lumier'),
#  ("A Poor Man's Roses", 'Los De Arag\\xc3\\xb3n: "Los De Arag\\xc3\\xb3n'),
#  ("A Poor Man's Roses", 'Oceans Of Love (LP Version)'),
#  ("A Poor Man's Roses", 'Only If You Live There'),
#  ("A Poor Man's Roses", 'Vollmond'),
#  ("A Poor Man's Roses", 'Faithkeeper_ Part 1'),
#  ("A Poor Man's Roses", 'No La Dejes Sola'),
#  ("A Poor Man's Roses", 'With Tears In My Eyes'),
#  ("A Poor Man's Roses",
#   'Dale Darrell Waltrip Richard Petty Rusty Awesome Bill Irvin Gordon Earnhardt Smith...Johnson_ Jr. (Live)'),
#  ("A Poor Man's Roses", 'Georgia'),
#  ("A Poor Man's Roses", '\\xc3\\x98mhet'),
#  ("A Poor Man's Roses", 'Encouraged'),
#  ("A Poor Man's Roses", 'Hispaniola A'),
#  ("A Poor Man's Roses", 'On Independence Day'),
#  ("A Poor Man's Roses", 'C\\xc3\\xa9u do Brasil'),
#  ("A Poor Man's Roses", 'Burbullas A Grella'),
#  ("A Poor Man's Roses", 'Iron-head: Palestine'),
#  ("A Poor Man's Roses", 'Monologue With the Sky'),
#  ("A Poor Man's Roses", 'Main Theme from Jaws'),
#  ("A Poor Man's Roses", 'Sheng Li Hu Huan'),
#  ("A Poor Man's Roses", "I Can't Wait 'Til Christmas (LP Version)"),
#  ("A Poor Man's Roses", 'Cavaleiro De Aruanda'),
#  ("A Poor Man's Roses", 'Incide'),
#  ("A Poor Man's Roses", 'We Do It For the Money_ OBVIOUSLY! (Demo)'),
#  ("A Poor Man's Roses", 'Quand on est amoureux'),
#  ("A Poor Man's Roses", 'Peace Prayer'),
#  ("A Poor Man's Roses", 'Another Djemba Djemba'),
#  ('Ask The Angels', 'Wishy Washy Woman'),
#  ('Ask The Angels', 'Iron-head: Palestine'),
#  ('Ask The Angels', 'Speed Of Sound (Emergency Broadcast Album Version)'),
#  ('Ask The Angels', 'What If I Forget The Champagne'),
#  ('Ask The Angels', 'Packed Up And Took My Mind'),
#  ('Ask The Angels', 'All Rise'),
#  ('Ask The Angels', 'Onni'),
#  ('Ask The Angels', 'Punjabian Di Chale Glassi'),
#  ('Ask The Angels', 'El Aranero'),
#  ('Ask The Angels', 'WHEN I AM YOU'),
#  ('Ask The Angels', 'Ojos Gitanos'),
#  ('Ask The Angels', 'Raining On Our Love'),
#  ('Ask The Angels', 'Packing Up'),
#  ('Ask The Angels', 'Watermelon Man'),
#  ('Ask The Angels', 'Long Summer Days'),
#  ('Ask The Angels', 'Everything Has Changed'),
#  ('Ask The Angels', 'Nothing But The Best'),
#  ('Ask The Angels', 'Enclosed_ One Broken Heart'),
#  ('Ask The Angels', 'Flipside'),
#  ('Ask The Angels', 'Please Love Me'),
#  ('Ask The Angels', 'Kids Now'),
#  ('Ask The Angels', 'Edge Of The Dream (Emergency Broadcast Album Version)'),
#  ('Ask The Angels', 'Only Lonely'),
#  ('Ask The Angels', "Job's Defiance"),
#  ('Ask The Angels', 'I Feel So Good'),
#  ('Ask The Angels', 'Petticoat'),
#  ('Ask The Angels', 'Blaue Matrosen (live)'),
#  ('Ask The Angels', '2HB (1999 Digital Remaster)'),
#  ('Ask The Angels', 'Apertura in jazz'),
#  ('Ask The Angels', 'Tracy'),
#  ('Ask The Angels', 'As You Take A  Walk Through My Mind'),
#  ('Ask The Angels', 'Again'),
#  ('Ask The Angels', 'Test 72'),
#  ('Ask The Angels', "Pop A Cap In Yo' Ass"),
#  ('Ask The Angels', 'Next Time'),
#  ('Ask The Angels', 'Quiet Time'),
#  ('Ask The Angels', 'Sinnloz/ Anakonda (live)'),
#  ('Ask The Angels', 'Kiss the Sky'),
#  ('Ask The Angels', 'Church Hangover'),
#  ('Ask The Angels', 'Heal (The Separation) [PM Dawn Alt. Lead Mix]'),
#  ('Ask The Angels', 'Outside The Law'),
#  ('Ask The Angels', 'Twerk (feat. Yo Majesty)'),
#  ('Ask The Angels', 'Sunset Manifesto'),
#  ('Ask The Angels', 'As The Terror Dances Your Way'),
#  ('Ask The Angels', 'Special'),
#  ('Ask The Angels', 'Carry The Light'),
#  ('Ask The Angels', 'Cumayon'),
#  ('Ask The Angels', 'Camino'),
#  ('Ask The Angels', 'Bye Bye'),
#  ('Ask The Angels', 'Gemini'),
#  ('Ask The Angels', 'S.O.S.'),
#  ('Ask The Angels', 'Up Jumped The Devil'),
#  ('Ask The Angels', 'It Is No Secret (What God Can Do)'),
#  ('Ask The Angels', 'It Makes No Difference Now'),
#  ('Ask The Angels', 'Life Upon The Wicked Stage'),
#  ('Ask The Angels', "Let's Have Some Fun"),
#  ('Ask The Angels', 'Des Helden Widersacher'),
#  ('Ask The Angels', "Don't You Think It's Time To Go"),
#  ('Ask The Angels', 'Star'),
#  ('Ask The Angels', 'Say How I Feel'),
#  ('Ask The Angels', "What's In You?"),
#  ('Ask The Angels', 'Perdido (1999 Digital Remaster)'),
#  ('Ask The Angels', 'Coma'),
#  ('Ask The Angels', 'Writes Of Winter'),
#  ('Ask The Angels', 'Fall in Philadelphia'),
#  ('Ask The Angels', 'Moon Going Down'),
#  ('Ask The Angels', 'The One I Got'),
#  ('Ask The Angels', 'Monsters In Tinsel Town'),
#  ('Ask The Angels', 'Did You Get My Message?  (Live From Shubas)'),
#  ('Ask The Angels', 'We Blame Love'),
#  ('Ask The Angels', 'The Luck You Got'),
#  ('Ask The Angels', 'Hum Drum'),
#  ('Ask The Angels', "She's About A Mover"),
#  ('Ask The Angels', 'Blues As Blues Can Get'),
#  ('Ask The Angels', 'Primordial Breath'),
#  ('Ask The Angels', 'What Is This'),
#  ('Ask The Angels', "Please Don't Lie To Me"),
#  ('Ask The Angels', 'Faithkeeper_ Part 1'),
#  ('Ask The Angels', 'If Money Talks'),
#  ('Ask The Angels', 'Seuraavassa el\\xc3\\xa4m\\xc3\\xa4ss\\xc3\\xa4'),
#  ('Ask The Angels', 'Nerio Compra Una Contestadora'),
#  ('Ask The Angels', 'Aguas Claras De Olimpos'),
#  ('Ask The Angels', 'Chitlins Con Carne'),
#  ('Ask The Angels', 'Baiao Malandro'),
#  ('Ask The Angels', 'Pork Chop Sandwich'),
#  ('Ask The Angels', 'Hear Me Talking To You'),
#  ('Ask The Angels', 'It Was Only A Heart'),
#  ('Ask The Angels', "Love Is Gone (Eddie Thoneick's Liberte Mix)"),
#  ('Ask The Angels', 'Dedicated To The One I Love'),
#  ('Ask The Angels', 'Sweet And Lovely'),
#  ('Ask The Angels', 'A Man Can Only Stand Just So Much Pain (Bonus Track)'),
#  ('Ask The Angels', 'So Still (Album Version)'),
#  ('Ask The Angels', 'I Remember/Great Is Thy Faithfulness'),
#  ('Ask The Angels', 'Love That Jazz (Basements Boys Album Vers)'),
#  ('Ask The Angels', 'Naked Albino'),
#  ('Ask The Angels', '(I Wanna) Play A Little While'),
#  ('Ask The Angels', 'I Need You'),
#  ('Ask The Angels', 'When A Man Loves A Woman'),
#  ('Ask The Angels', 'Have U Own Things'),
#  ('Ask The Angels', 'Till The End Of The Day (Alternate Mix)'),
#  ('Ask The Angels', 'Dark As A Dungeon (LP Version)'),
#  ('Ask The Angels', 'Olivia'),
#  ('Ask The Angels', 'Will You Love Me Tomorrow'),
#  ('Ask The Angels', "She's All I Ever Had"),
#  ('Ask The Angels', 'Hush'),
#  ('Ask The Angels', 'The 23rd Psalm'),
#  ('Ask The Angels', 'Need More Blues'),
#  ('Ask The Angels', 'Meditacao'),
#  ('Ask The Angels', 'Mi Morena (Revised Live Version)'),
#  ('Ask The Angels', 'Peaches (Fear of Theydon remix)'),
#  ('Ask The Angels', '2StepN'),
#  ('Ask The Angels', 'A Girls Oath'),
#  ('Ask The Angels', 'Loving You'),
#  ('Ask The Angels', 'Slipping Away'),
#  ('Ask The Angels', 'Yesss Lord...'),
#  ('Ask The Angels', 'The Attitude Song'),
#  ('Jesus', 'Campeones De La Vida'),
#  ('Jesus', 'A Man Can Only Stand Just So Much Pain (Bonus Track)'),
#  ('Jesus', 'Church Hangover'),
#  ('Jesus', 'One Scotch_ One Bourbon_ One Beer'),
#  ('Jesus', 'El Termometro'),
#  ('Jesus', 'Te Fuiste En Abril'),
#  ('Jesus', 'Nerio Compra Una Contestadora'),
#  ('Jesus', 'Era um dia desses'),
#  ('Jesus', 'Caricia Y Herida'),
#  ('Jesus', "She's All I Ever Had"),
#  ('Jesus', 'Kids Now'),
#  ('Iron-head: Palestine', 'What If I Forget The Champagne'),
#  ('Iron-head: Palestine', 'Hold On (LP Version)'),
#  ('Iron-head: Palestine', 'Far Beyond The Endless'),
#  ('Iron-head: Palestine', 'Thrill Pistol'),
#  ('Iron-head: Palestine',
#   'Oedipus Rex_ Atto Primo: Liberi_ Vos Liberabo (Oedipus) (Stravinsky)'),
#  ('Iron-head: Palestine', 'I.A.I'),
#  ('Iron-head: Palestine', 'Intro'),
#  ('Iron-head: Palestine', 'Punjabian Di Chale Glassi'),
#  ('Iron-head: Palestine', 'WHEN I AM YOU'),
#  ('Iron-head: Palestine', 'Anyone Who Had A Heart'),
#  ('Iron-head: Palestine', 'Careless Talk'),
#  ('Iron-head: Palestine', "Dialogue et final si j'avais su"),
#  ('Iron-head: Palestine', 'Long Summer Days'),
#  ('Iron-head: Palestine', 'No. 284'),
#  ('Iron-head: Palestine', 'Georgia'),
#  ('Iron-head: Palestine', 'Just A Phase'),
#  ('Iron-head: Palestine', 'Flipside'),
#  ('Iron-head: Palestine', 'Kuolema Tekee Taiteilijan'),
#  ('Iron-head: Palestine', 'Studen plamuk'),
#  ('Iron-head: Palestine', 'The Hammer Song (2010 Digital Remaster)'),
#  ('Iron-head: Palestine', 'The Kangaroo Theory'),
#  ('Iron-head: Palestine', 'Loving You'),
#  ('Iron-head: Palestine', 'Ability To Create A War'),
#  ('Iron-head: Palestine', 'Ego is the drug/3am'),
#  ('Iron-head: Palestine', 'Blaue Matrosen (live)'),
#  ('Iron-head: Palestine', 'Main Title / The Searchers'),
#  ('Iron-head: Palestine', 'Apertura in jazz'),
#  ('Iron-head: Palestine', 'As You Take A  Walk Through My Mind'),
#  ('Iron-head: Palestine', 'Andra sidan'),
#  ('Iron-head: Palestine', 'Them No Care'),
#  ('Iron-head: Palestine', 'Te Fuiste En Abril'),
#  ('Iron-head: Palestine', "Pop A Cap In Yo' Ass"),
#  ('Iron-head: Palestine', 'Next Time'),
#  ('Iron-head: Palestine', 'Wow'),
#  ('Iron-head: Palestine', 'Procession'),
#  ('Iron-head: Palestine', 'Sinnloz/ Anakonda (live)'),
#  ('Iron-head: Palestine', 'Just Say Yes'),
#  ('Iron-head: Palestine', 'Maracaia'),
#  ('Iron-head: Palestine', 'Meteores mouvement de Chroniques de la lumier'),
#  ('Iron-head: Palestine', "Can't Break This Man"),
#  ('Iron-head: Palestine', 'Kiss the Sky'),
#  ('Iron-head: Palestine', 'Anfang Vom Ende'),
#  ('Iron-head: Palestine', 'Comfortable'),
#  ('Iron-head: Palestine', 'Twerk (feat. Yo Majesty)'),
#  ('Iron-head: Palestine', 'Sunset Manifesto'),
#  ('Iron-head: Palestine', 'Campeones De La Vida'),
#  ('Iron-head: Palestine', 'Prospection'),
#  ('Iron-head: Palestine', 'Woh\\xc3\\xa4r dr Wind w\\xc3\\xa4iht'),
#  ('Iron-head: Palestine', 'Bye Bye'),
#  ('Iron-head: Palestine', "Hey Daddy (Daddy's Home)"),
#  ('Iron-head: Palestine', 'Damn those eyes'),
#  ('Iron-head: Palestine', "What's In You?"),
#  ('Iron-head: Palestine', 'The Marquis and the Scaffold (From "Quills")'),
#  ('Iron-head: Palestine', 'Otra Parte De Mi (1997 Digital Remaster)'),
#  ('Iron-head: Palestine', 'Angie (1993 Digital Remaster)'),
#  ('Iron-head: Palestine', 'Chasing Windmills'),
#  ('Iron-head: Palestine', 'Des Helden Widersacher'),
#  ('Iron-head: Palestine', 'Everybody Loves You'),
#  ('Iron-head: Palestine', 'Mein Herz kann man nicht kaufen'),
#  ('Iron-head: Palestine', 'Noises'),
#  ('Iron-head: Palestine', 'Bumbling Along'),
#  ('Iron-head: Palestine', 'Stack and Pile'),
#  ('Iron-head: Palestine', 'Perdido (1999 Digital Remaster)'),
#  ('Iron-head: Palestine', 'Writes Of Winter'),
#  ('Iron-head: Palestine', 'Floating'),
#  ('Iron-head: Palestine', 'Did You Get My Message?  (Live From Shubas)'),
#  ('Iron-head: Palestine', "Gangsta's Fairytale 2 (Explicit)"),
#  ('Iron-head: Palestine', 'We Blame Love'),
#  ('Iron-head: Palestine', 'Rakkahin -Be My Love-'),
#  ('Iron-head: Palestine', 'Blues As Blues Can Get'),
#  ('Iron-head: Palestine', 'What Is This'),
#  ('Iron-head: Palestine',
#   'Love Me Now (Rockwilder Remix) (Feat. Wyclef And Redman)'),
#  ('Iron-head: Palestine', 'Banana Split Republic'),
#  ('Iron-head: Palestine', 'Ghetto'),
#  ('Iron-head: Palestine', "It's Too Late"),
#  ('Iron-head: Palestine', 'If Money Talks'),
#  ('Iron-head: Palestine', "Since I've Been Loving You"),
#  ('Iron-head: Palestine', 'Baiao Malandro'),
#  ('Iron-head: Palestine', 'A Little Tear'),
#  ('Iron-head: Palestine', 'Pork Chop Sandwich'),
#  ('Iron-head: Palestine', 'Sleeping Annaleah (2009 Digital Remaster)'),
#  ('Iron-head: Palestine', 'Dancing The Night Away'),
#  ('Iron-head: Palestine', 'Liquid Time (composition by John Goodsall)'),
#  ('Iron-head: Palestine', 'Use Me'),
#  ('Iron-head: Palestine', 'It Was Only A Heart'),
#  ('Iron-head: Palestine', 'On Independence Day'),
#  ('Iron-head: Palestine', 'The Christmas Song  (LP Version)'),
#  ('Iron-head: Palestine', 'All I Can Do'),
#  ('Iron-head: Palestine', 'Menuet in the Name of Haydn'),
#  ('Iron-head: Palestine', 'Eyes Of A Stranger (Album Version)'),
#  ('Iron-head: Palestine', 'Transmission (Album Version)'),
#  ('Iron-head: Palestine', 'Insatiable (Instrumental Version)'),
#  ('Iron-head: Palestine', 'I Remember/Great Is Thy Faithfulness'),
#  ('Iron-head: Palestine', 'Arabian Night'),
#  ('Iron-head: Palestine', 'I Need You'),
#  ('Iron-head: Palestine', 'Sex'),
#  ('Iron-head: Palestine', 'Zig-Zag Walk'),
#  ...]

# %%
G_2_50 = G_2

# Remove the edges in remove_edge_list
G_2_50.remove_edges_from(remove_edge_list)
print(G_2_50.number_of_edges())

# Draw the network graph
nx.draw(G_2_50,
        pos=nx.spring_layout(G_2_50), # Or spectral_layout, random_layout, shell_layout , spring_layout     
        with_labels = False,
        node_size=100, 
        alpha=0.8, 
        node_color = [G_2_50.node[node]['color'] for node in G_2_50],#node_color_values['color'],
        font_size = 7,
        font_color = 'black',
        font_family = 'arial',
        edge_color = 'gray',
        width = [0.1*edge[2]['weight'] for edge in G_2_50.edges(data=True)])
        
pyplot.show()
# Out:
# 49753

# %% [markdown]
# The nodes in the network graph spreads out even further. But still no clear multiple clusters.
#
# #### Subgraph of the single track with all its neighbors
#
# Let us look at the subgraph of the track titled _Thank You Mama_.

# %%
neighbors = nx.neighbors(G_2_50,'Thank You Mama')
neighbors.append('Thank You Mama')

G_2_sub = nx.subgraph(G_2_25,neighbors)

nx.draw(G_2_sub,
        pos=nx.spring_layout(G_2_sub), # Or spectral_layout, random_layout, shell_layout , spring_layout     
        with_labels = True,
        node_size=140, 
        alpha=0.8, 
        node_color = [G_2_sub.node[node]['color'] for node in G_2_sub],#node_color_values['color'],
        font_size = 11,
        font_color = 'black',
        font_family = 'arial',
        edge_color = 'gray',
        width = [0.2*edge[2]['weight'] for edge in G_2_sub.edges(data=True)])
        
pyplot.show()

# %% [markdown]
# The `ego_graph` module of `networkx` library also helps generate a sub graph, as shown below.

# %%
G_ego = nx.ego_graph(G_2_25, 'Thank You Mama', radius=1, center=True, undirected=False, distance=None)
# radius is the number defining the no. of edges within which the neighbors need to be identified

nx.draw(G_ego,
        with_labels = True,
        pos=nx.spring_layout(G_ego), # Or spectral_layout, random_layout, shell_layout , spring_layout     
        node_size=150, 
        alpha=0.8, 
        font_size = 11,
        font_color = 'black',
        font_family = 'arial',
        edge_color = 'gray',
        edge_labels = nx.get_edge_attributes(G_ego,'weight'),
        width = [0.1*edge[2]['weight'] for edge in G_ego.edges(data=True)]) # not working

#nx.draw_networkx_edge_labels(G_ego, nx.spring_layout(G_ego), labels = nx.get_edge_attributes(G_ego,'weight'), font_size = 1)

pyplot.show()

# %% [markdown]
# ### Recommendation using Dijkstra's Algorithm
#
# In this section, given a `track`, the 10 nearest songs are recommended using the __Dijkstra's__ algorithm. It is an algorithm for finding the shortest paths between nodes in a graph, which may represent, for example, road networks. More information on the algorithm can be found at https://en.wikipedia.org/wiki/Dijkstra%27s_algorithm.
#
# For our recommendation, in addition to looking at the nearest directly connected neighbors, the nodes or the series of nodes that end up leading to the top 10 shortest paths will be looked at. The module `dijkstra_predecessor_and_distance` does this. Given an input node, it provides us with all the shortest path lengths and predecessors on these shortest paths.
#
# #### Recommendation for the track _Thank You Mama_
#
# The __Dijkstra's__ algorithm is used to recommend the 10 closest songs based on the shortest paths for the track __Thank You Mama__.

# %%
# For recommendations
short_path = nx.dijkstra_predecessor_and_distance(G_2_25, 'Thank You Mama', cutoff=0.2, weight='inv_weight')
# Returns two dictionaries, one containing the path traversed and the other containing the path distances.
print(type(short_path))
print(type(short_path[1]))
short_path
# Out:
# <class 'tuple'>
# <class 'dict'>
# ({'By Faith I Can Touch Him Now': ['Thank You Mama'],
#   'Encouraged': ['Thank You Mama'],
#   "Job's Defiance": ['Thank You Mama'],
#   'Never Alone': ['Thank You Mama'],
#   'Packing Up': ['Thank You Mama'],
#   'Pray On': ['Thank You Mama'],
#   'So Many Reasons': ['Thank You Mama'],
#   'Thank You Mama': [],
#   'The Christmas Song  (LP Version)': ['Thank You Mama']},
#  {'By Faith I Can Touch Him Now': 0.17351011923680854,
#   'Encouraged': 0.1629578055774056,
#   "Job's Defiance": 0.19294197292733542,
#   'Never Alone': 0.1952223990227066,
#   'Packing Up': 0.15996397932036563,
#   'Pray On': 0.16767385166201704,
#   'So Many Reasons': 0.19647779212008937,
#   'Thank You Mama': 0,
#   'The Christmas Song  (LP Version)': 0.18306110744959686})

# %% [markdown]
# The module `dijkstra_predecessor_and_distance` returns two dictionaries, one containing the path traversed and the other containing the path distance. The `value` in the first dictionary above is the source of the last edge of the path, while the `key` is the end node. The second dictionary will have the same end node as the `key` while the `value` will be the distance of the total path.
#
# The key point to be understood here is that, in the case of a multi-edge path traversal, only the last edge of path is in the first dictionary. However, all the prior edges in the path would have already been traversed by the algorithm and those intermediate nodes will be included in the dictionary `key` as an end node with a lesser path distance than the last node of the multi-edge path.
#
# A comprehensive understanding of how the __Dijkstra's__ algorithm works, will make it very clear.
#
# Therefore, if one converts the second dictionary into a dataframe and ranks them in ascending order based on the distances, the song recommendation is complete.
#
# #### Convert the second dictionary into a dataframe

# %%
# Convert the path distances dictionary into a list
short_path_end_node_list = []
for key, value in short_path[1].items():
    temp = [key,value]
    short_path_end_node_list.append(temp)

short_path_end_node_list
#short_path_end_node_list[1]   
#short_path_end_node_list[1][1]
#short_path_end_node_list[1][1][0]
# Out:
# [['By Faith I Can Touch Him Now', 0.17351011923680854],
#  ['Packing Up', 0.15996397932036563],
#  ['Encouraged', 0.1629578055774056],
#  ['The Christmas Song  (LP Version)', 0.18306110744959686],
#  ["Job's Defiance", 0.19294197292733542],
#  ['Never Alone', 0.1952223990227066],
#  ['Thank You Mama', 0],
#  ['Pray On', 0.16767385166201704],
#  ['So Many Reasons', 0.19647779212008937]]

# %%
# Convert the list into a dataframe 
short_path_df = pd.DataFrame(np.nan, index=[i for i in range(0,len(short_path_end_node_list))], columns=['dist','end_node'])

for i in range(0,len(short_path_end_node_list)):
    short_path_df.loc[i,['end_node']] = short_path_end_node_list[i][0]
    short_path_df.loc[i,['dist']] = short_path_end_node_list[i][1]

# remove the song with dist = 0, which is the same song
short_path_df = short_path_df[short_path_df.dist > 0]

# Rank and sort in ascending order based on the distance
short_path_df['rank'] = short_path_df['dist'].rank(axis=0, method='min', ascending=True, pct=False)

# sort ths recommendations in ascending order based on the rank
recommendation_df = short_path_df.sort_index(by='rank', ascending=1) # sort in ascending order
recommendation_df.rename(columns={'dist': 'Distance', 'end_node': 'Recommended Track', 'rank' : 'Rank'}, inplace=True)

# List out only a maximum of 10 closet songs.
if len(recommendation_df) >= 10:
    print('The top 10 recommendations are:\n', '--------------------------- \n', recommendation_df.iloc[10,:])
else:
    print('The top recommendations are:\n', '--------------------------- \n', recommendation_df)
# Out:
# The top recommendations are:
#  ---------------------------
#     Distance                 Recommended Track  Rank
# 1  0.159964                        Packing Up   1.0
# 2  0.162958                        Encouraged   2.0
# 7  0.167674                           Pray On   3.0
# 0  0.173510      By Faith I Can Touch Him Now   4.0
# 3  0.183061  The Christmas Song  (LP Version)   5.0
# 4  0.192942                    Job's Defiance   6.0
# 5  0.195222                       Never Alone   7.0
# 8  0.196478                   So Many Reasons   8.0
# C:\Users\ganes_000\Anaconda3\envs\python3.5\lib\site-packages\ipykernel\__main__.py:15: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)

# %% [markdown]
# #### Pickle the graph objects

# %%
# Pickle the graph objects
path = "C:/Users/ganes_000/Documents/MSBA/Spring 2016/MA 755/Pickle Files"
nx.write_gpickle(G_2,path+"/Track_Track_Graph_500_edit.pkl")
nx.write_gpickle(G_1,path+"/Track_Artist_Artist_Terms_Graph_500_edit.pkl")

# %% [markdown]
# ### Conclusion and Further Scope
#
# + Given a song from the dataset, the weighted network graphs have been successfully applied to recommend songs. As a technique, it appears to be robust and most importantly the rationale behind the recommendations are apparent unlike other techniques.
#
# + The recommendations have not been validated yet since the primary goal was to demonstrate the approach.
#
# + Only the metadata were used. Even with metadata, tweaking of the weight computation logic for the `track`-`track` relationships might provide improved results.
#
# + If other data like the analysis data were to be used and if some kind of a distance or similarity measure is established between the different `track`, such relationships can also be added to the existing graph as a `MultiGraph` edge and song recommendations can be made.
#
# + Any other set of data fields like _user history_, if available, can also be intelligently incorporated into the graphs which will help imporve the recommendations.
