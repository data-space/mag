# %% [markdown]
# # About the Notebook
#
# This notebook describes the steps to create row-wise dataframes as well as column-wise dataframes for the Million Songs Subset data.

# %% [markdown]
# ## Import the libraries

# %%
import os
import re
import itertools as it
import pandas as pd
import numpy as np
import operator 
import functools
import pickle as pk
import networkx as nx
import matplotlib as mplot
import matplotlib.colors as colors
import matplotlib.pyplot as pyplot
import random

# %% [markdown]
# ### Set random generator seed
#
# For some analysis, a subset of the __Million Songs Subset__, referred henceforth as MSS, will be used. To be able to pick the same random set at all times and across all notebooks, the set is set to a number (4 in this case) consistently across all notebooks used for this analysis.

# %%
# Set the seed for the random number generator - to be consistent in different notebooks
a = random.randint(0,9)
random.seed(4)
a
# Out:
# 3

# %% [markdown]
# # Create a Dataframe with the Metadata
#
# To assist in our goal of creating a network graph using the metadata, the data from the `HDF5` files are read row-wise for multiple values for the fields `artist_terms`, `artist_term_wt` and `artist_terms_freq`. This approach makes it easier for analysing the MSS using network graphs.

# %% [markdown]
# ### Utility Functions
#
# The `get_filenames` function recursively gets the names of all files in a given directory path and all of its subdirectories.The function returns a multi-level list if path contains subdirectories.
#
# The `unlist` function flattens the list by removing one level.
#
# While the `h1d_array` function creates a single row array, the function `h2d_array` creates a single column array.

# %%
# The functions to be used
def get_filenames(path):
    return([get_filenames(path+"/"+entry.name)
            if entry.is_dir() 
            else path+"/"+entry.name 
            for entry 
            in os.scandir(path)
           ])

def unlist(alist):
    return(list(it.chain.from_iterable(alist)
               )
          )

def var_list(base,numof):
    return([base+str(ndx) for ndx in range(numof)]
          )

def h1d_array(in_array,n): 
    # n1d is the number of elements in `in_array`
    n1d = functools.reduce(operator.mul,
                           list(in_array.shape))
    # return a 1 row 2D array with `n` columns
    b = np.ndarray(shape=(1,n1d),
                   buffer=in_array,
                   dtype=in_array.dtype
                  )[0:1,0:n]
    return(b)

def h2d_array(in_array,n): 
    # n2d is the number of elements in `in_array`
    n2d = functools.reduce(operator.mul,
                           list(in_array.shape))
    # return a 1 row 2D array with `n` columns
    b = np.ndarray(shape=(n2d,1),
                   buffer=in_array,
                   dtype=in_array.dtype
                  )[0:n2d,0:1]
    return(b)

# %% [markdown]
# The `fill_track_artist_mul_col` function basically uses the value in the first row and fills all the other rows in the column with the same value. The input to the function is a dataframe and the list of column numbers for which the filling has to be done.
#
# The `remove_b_mul_col` function takes a dataframe and column numbers list as the input and returns another dataframe by removing the __b'__ and the __'__ from the begining and end of the string values in the respective columns.
#
# The `bytes_to_string_artist_terms` function does the same function as the `remove_b_mul_col`, explained before. The former is used when the datatype of the column is `S256`, wherein a decoding algorithm is used. The latter function does not work for the particular datatype.
#
# The reason behind using this function will be explained a little later.

# %%
# Second set of functions

def fill_track_artist_mul_col(df,col = []):
    for j in range(0,len(col)):
        for i in range(0,len(df)):
            df.iloc[i,col[j]] = df.iloc[0,col[j]]
            #df.iloc[i,1] = df.iloc[0,1]
    return(df)


def bytes_to_string_artist_terms(df,n):
    #for i in range(0,df.shape[1]):
    b = pd.DataFrame(df[df.columns[n-1]])
    b.columns = ['artist_terms']
    for i in range(0,len(df)):
        #if df.dtypes[i] == 'S256':
        b.iloc[i,0] = df.iloc[i,n].decode("utf-8")
    df = pd.concat([df,b], axis = 1)
    return(df)
        
def remove_b_mul_col(df, col = []):
    for j in range(0,len(col)):
        for i in range(0,len(df)):  
                df.iloc[i,col[j]]=str(df.iloc[i,col[j]])[2:-1]
    return(df)

# %% [markdown]
# The `make_rows_df` function returns a multiple rows dataframe and takes the following input:
# + `filename`: full path file name of an MSD HDF5 file containing data for a single song
# + `metadata_vars`: list of variable names from `/metadata/songs`
# + `analysis_vars`: list of variable names from `/analysis/songs`
# + `musicbrainz_vars`: list of variable names from `/musicbrainz/songs`
# + `remove`:
#     - if `False` the variables listed in the last two parameters are retrieved from the input file
#     - if `True` all variables except those listed are retrieved from the input file
#
# When a single track filename is read, and say for example the track has an artist with 10 artist terms, then only the artist terms column will have 10 values (in 10 rows). The other variables (from the variable list) will only be read once and populated in the first row. So, in order to fill them up for all rows, the function `fill_track_artist_mul_col` is used within the `make_rows_df` function. Similarly, to remove the __b'__ and __'__ from some columns, the `remove_b_mul_col` function is used within. Since the column numbers that need to be filled and fixed are known, these functions are embedded within `make_rows_df`.

# %%
def make_rows_df(filename='', metadata_vars=[], analysis_vars=[], musicbrainz_vars = [], remove=False):
    # open `filename` as a HDF5 file
    store = pd.HDFStore(filename,"r")
    if remove==True:
        # `metadata_vars` and `analysis_vars` contain the variables to remove
        metadata_vars = list({item for item 
                                  in list(store.root.metadata.songs.read().dtype.names) 
                                  if item not in metadata_vars})
        analysis_vars = list({item for item 
                                  in list(store.root.analysis.songs.read().dtype.names) 
                                  if item not in analysis_vars})
        musicbrainz_vars = list({item for item 
                                  in list(store.root.musicbrainz.songs.read().dtype.names) 
                                  if item not in musicbrainz_vars})
    # else: `metadata_vars` and `analysis_vars` contain the variables to keep
    
    # retrieve the first `n` values as a vertical array of 1 dimension
    #artist_name = h2d_array(store.root.metadata.artist_name.read(),1)
    artist_terms     = h2d_array(store.root.metadata.artist_terms.read(),37)
    artist_terms_freq  = h2d_array(store.root.metadata.artist_terms_freq.read(),37)
    artist_terms_weight = h2d_array(store.root.metadata.artist_terms_weight.read(),37)
    
    # store these values as variables in single dataframes
    #s_art_df = pd.DataFrame(similar_artists ,columns=var_list('sart_',bars_confidence .shape[1]))
    at_df = pd.DataFrame(artist_terms,columns=['at'])
    atf_df = pd.DataFrame(artist_terms_freq,columns=['at_freq'])
    atw_df = pd.DataFrame(artist_terms_weight ,columns=['at_wt'])
    
    # get track from filename
    match = re.split('\/',filename)
    match[-1]
    match = re.split('\.',match[-1])
    
    # merge these single dataframes into one single row dataframe
    ret = pd.concat([
            # make single row dataframe from track
            pd.DataFrame([match[0]], columns=['track']),
            # retrieve a single row dataframe from `/metadata/songs`
            pd.DataFrame(store.root.metadata.songs.read(), 
                         columns=metadata_vars),
            # retrieve a single row dataframe from `/analysis/songs`
            pd.DataFrame(store.root.analysis.songs.read(), 
                         columns=analysis_vars),
            # retrieve a single row dataframe from `/musicbrainz/songs`
            pd.DataFrame(store.root.musicbrainz.songs.read(), 
                         columns=musicbrainz_vars),
            at_df, 
            atf_df,
            atw_df],
            #bc_df, 
            #sp_df,
            #st_df],
            #s_art_df,
            axis=1) # `axes=1` means stack the dataframes horizontally 
    # close the HDF5 file
    store.close()
    # fill
    aa = fill_track_artist_mul_col(ret,col = [0,1,2,3,4,5,6,7,8])
    # remove b
    bb = remove_b_mul_col(aa, col = [1,2,3,4])
    ##cc = bytes_to_string_artist_terms(bb,6)
    # drop artist_terms with b (since it is a S256 dtype)
    #dd = cc.drop('at',axis = 1)
    # return the merged dataframe
    return(bb)

# %% [markdown]
# ### Get the list of (10,000) HDF5 (.h5) files
#
# The `path` variable stores the root of the directory tree containing all of the song files. The function `get_filenames` returns a multi-level list, which is flattened using `unlist` and stored in variable `filenames` as a list of full-path filenames.

# %%
path = "C:/Users/ganes_000/Documents/MSBA/Spring 2016/MA 755/millionsongsubset_full/MillionSongSubset/data"
filenames = unlist(unlist(unlist(get_filenames(path))))
filenames[0:2]
# Out:
# ['C:/Users/ganes_000/Documents/MSBA/Spring 2016/MA 755/millionsongsubset_full/MillionSongSubset/data/A/A/A/TRAAAAW128F429D538.h5',
#  'C:/Users/ganes_000/Documents/MSBA/Spring 2016/MA 755/millionsongsubset_full/MillionSongSubset/data/A/A/A/TRAAABD128F429CF47.h5']

# %% [markdown]
# ### Store in the filenames variable only the files with extension .h5¶

# %%
p = re.compile("\.h5$")
filenames = [filename for filename 
             in filenames if p.search(filename)]
filenames[0:2]
len(filenames)
# Out:
# 10000

# %% [markdown]
# ### Pick a random set of the files from above (optional)
#
# For some memory intensive analysis, a subset of 500 songs from the MSS, will be used. The code chunk in the following cell helps pick a random 500 songs subset.

# %%
random_filename_ind = random.sample(range(0,10000), 500)

filenames_500 = [ filenames[i] for i in random_filename_ind]
filenames_500

filenames = filenames_500 # comment this line out, if the entire 10,000 songs are to be read

# %% [markdown]
# ### Read a single track file
#
# A single track file is read using the functions described earlier and validated.

# %%
# Read one track file and get the data - which will be a bunch of rows
f_m = make_rows_df(filename=filenames[40],
                            metadata_vars=['title','song_id','artist_id','artist_name',
                                           'artist_familiarity','artist_hotttnesss','song_hotttnesss'],
                            # Omit: genre
                            analysis_vars=[],
                             musicbrainz_vars = ['year'],
                            # Omit: danceability, energy
                            remove=False
                           )

#a.iloc[:,3:40]
print(type(f_m))
f_m
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                  track              title             song_id  \
# 0   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 1   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 2   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 3   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 4   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 5   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 6   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 7   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 8   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 9   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 10  TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
#
#              artist_id artist_name  artist_familiarity  artist_hotttnesss  \
# 0   ARZI4B31187B991125         SAF            0.467583            0.27896
# 1   ARZI4B31187B991125         SAF            0.467583            0.27896
# 2   ARZI4B31187B991125         SAF            0.467583            0.27896
# 3   ARZI4B31187B991125         SAF            0.467583            0.27896
# 4   ARZI4B31187B991125         SAF            0.467583            0.27896
# 5   ARZI4B31187B991125         SAF            0.467583            0.27896
# 6   ARZI4B31187B991125         SAF            0.467583            0.27896
# 7   ARZI4B31187B991125         SAF            0.467583            0.27896
# 8   ARZI4B31187B991125         SAF            0.467583            0.27896
# 9   ARZI4B31187B991125         SAF            0.467583            0.27896
# 10  ARZI4B31187B991125         SAF            0.467583            0.27896
#
#     song_hotttnesss  year                      at   at_freq     at_wt
# 0               0.0   0.0     b'hardcore hip hop'  0.939069  1.000000
# 1               0.0   0.0              b'musette'  0.878138  0.954661
# 2               0.0   0.0              b'chanson'  0.878138  0.937098
# 3               0.0   0.0    b'progressive house'  0.878138  0.917423
# 4               0.0   0.0              b'hip hop'  1.000000  0.883275
# 5               0.0   0.0                  b'rap'  0.974711  0.860299
# 6               0.0   0.0               b'trance'  0.878138  0.795758
# 7               0.0   0.0  b'underground hip hop'  0.670753  0.771888
# 8               0.0   0.0      b'underground rap'  0.582403  0.698710
# 9               0.0   0.0           b'electronic'  0.806153  0.653429
# 10              0.0   0.0            b'macedonia'  0.267628  0.500373

# %%
# Remove b' in artist terms as well. This was not easy since the data type was S256 and had to be decoded.
f_m = bytes_to_string_artist_terms(f_m,9)
f_m = f_m.drop(['at'],axis = 1) # axis = 1 to drop a colummn, otherwise it will look for a matching index (key)
f_m
# Out:
#                  track              title             song_id  \
# 0   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 1   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 2   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 3   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 4   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 5   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 6   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 7   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 8   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 9   TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
# 10  TRAEXAN128EF354542  Skopska situacija  SOSYNKD12A6D4F6655
#
#              artist_id artist_name  artist_familiarity  artist_hotttnesss  \
# 0   ARZI4B31187B991125         SAF            0.467583            0.27896
# 1   ARZI4B31187B991125         SAF            0.467583            0.27896
# 2   ARZI4B31187B991125         SAF            0.467583            0.27896
# 3   ARZI4B31187B991125         SAF            0.467583            0.27896
# 4   ARZI4B31187B991125         SAF            0.467583            0.27896
# 5   ARZI4B31187B991125         SAF            0.467583            0.27896
# 6   ARZI4B31187B991125         SAF            0.467583            0.27896
# 7   ARZI4B31187B991125         SAF            0.467583            0.27896
# 8   ARZI4B31187B991125         SAF            0.467583            0.27896
# 9   ARZI4B31187B991125         SAF            0.467583            0.27896
# 10  ARZI4B31187B991125         SAF            0.467583            0.27896
#
#     song_hotttnesss  year   at_freq     at_wt         artist_terms
# 0               0.0   0.0  0.939069  1.000000     hardcore hip hop
# 1               0.0   0.0  0.878138  0.954661              musette
# 2               0.0   0.0  0.878138  0.937098              chanson
# 3               0.0   0.0  0.878138  0.917423    progressive house
# 4               0.0   0.0  1.000000  0.883275              hip hop
# 5               0.0   0.0  0.974711  0.860299                  rap
# 6               0.0   0.0  0.878138  0.795758               trance
# 7               0.0   0.0  0.670753  0.771888  underground hip hop
# 8               0.0   0.0  0.582403  0.698710      underground rap
# 9               0.0   0.0  0.806153  0.653429           electronic
# 10              0.0   0.0  0.267628  0.500373            macedonia

# %% [markdown]
# ### Read all the tracks from `filenames`
#
# The result will be having more rows than the number of tracks read; more specifically the number of rows will be equal to the number of tracks (`track`) times the number of `artist_terms` associated with that track (through the `artist_id`). The number of columns will be as provided in the input list plus four additional columns for the `track`, `artist_terms`, `artist_terms_wt`(`at_wt` in the dataframe) and `artist_terms_freq` (`at_freq` in the dataframe).

# %%
# Get the dataframe for all the filenames

for i in range(0,len(filenames_500)):
    if i == 0:
        df_mss_m = make_rows_df(filename=filenames_500[i],
                            metadata_vars=['title','song_id','artist_id','artist_name',
                                           'artist_familiarity','artist_hotttnesss','song_hotttnesss'],
                            # Omit: genre
                            analysis_vars=[],
                            musicbrainz_vars = ['year'],
                            
                            # Omit: danceability, energy
                            remove=False
                           )
    else:
        df_temp = make_rows_df(filename=filenames_500[i],
                            metadata_vars=['title','song_id','artist_id','artist_name',
                                           'artist_familiarity','artist_hotttnesss','song_hotttnesss'],
                            # Omit: genre
                            analysis_vars=[],
                            musicbrainz_vars = ['year'],
                            # Omit: danceability, energy
                            remove=False
                           )
        df_mss_m = pd.concat([df_mss_m,df_temp])
        
# remove b' from artist_terms
df_mss_m = bytes_to_string_artist_terms(df_mss_m,9)
# drop the field with the b'
df_mss_m = df_mss_m.drop(['at'],axis = 1) # axis = 1 to drop a colummn, otherwise it will look for a matching index (key)

print(df_mss_m.shape)
# Out:
# (13117, 12)

# %%
# check the head of the dataframe
df_mss_m.head(50)
# Out:
#                  track                     title             song_id  \
# 0   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 1   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 2   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 3   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 4   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 5   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 6   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 7   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 8   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 9   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 10  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 11  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 12  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 13  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 14  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 15  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 16  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 17  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 18  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 19  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 20  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 21  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 22  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 23  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 24  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 25  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 26  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 27  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 28  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 29  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 30  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 31  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 32  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 33  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 34  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 35  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 36  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 37  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 38  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 39  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 40  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 41  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 42  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 43  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 44  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 0   TRAQYRR128F92F8632  Twelve Gates To The City  SOZWUGO12A6D4FDCAE
# 1   TRAQYRR128F92F8632  Twelve Gates To The City  SOZWUGO12A6D4FDCAE
# 2   TRAQYRR128F92F8632  Twelve Gates To The City  SOZWUGO12A6D4FDCAE
# 3   TRAQYRR128F92F8632  Twelve Gates To The City  SOZWUGO12A6D4FDCAE
# 4   TRAQYRR128F92F8632  Twelve Gates To The City  SOZWUGO12A6D4FDCAE
#
#              artist_id                 artist_name  artist_familiarity  \
# 0   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 1   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 2   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 3   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 4   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 5   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 6   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 7   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 8   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 9   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 10  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 11  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 12  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 13  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 14  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 15  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 16  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 17  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 18  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 19  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 20  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 21  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 22  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 23  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 24  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 25  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 26  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 27  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 28  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 29  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 30  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 31  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 32  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 33  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 34  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 35  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 36  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 37  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 38  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 39  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 40  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 41  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 42  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 43  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 44  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 0   ARPC5161187B9AF35C  John Cephas & Phil Wiggins            0.388096
# 1   ARPC5161187B9AF35C  John Cephas & Phil Wiggins            0.388096
# 2   ARPC5161187B9AF35C  John Cephas & Phil Wiggins            0.388096
# 3   ARPC5161187B9AF35C  John Cephas & Phil Wiggins            0.388096
# 4   ARPC5161187B9AF35C  John Cephas & Phil Wiggins            0.388096
#
#     artist_hotttnesss  song_hotttnesss    year   at_freq     at_wt  \
# 0            0.509879         0.707172  1997.0  1.000000  1.000000
# 1            0.509879         0.707172  1997.0  0.795196  0.831104
# 2            0.509879         0.707172  1997.0  0.761407  0.811431
# 3            0.509879         0.707172  1997.0  0.795196  0.808603
# 4            0.509879         0.707172  1997.0  0.755268  0.806579
# 5            0.509879         0.707172  1997.0  0.755268  0.806579
# 6            0.509879         0.707172  1997.0  0.907628  0.804375
# 7            0.509879         0.707172  1997.0  0.835125  0.799851
# 8            0.509879         0.707172  1997.0  0.795196  0.791244
# 9            0.509879         0.707172  1997.0  0.755268  0.787546
# 10           0.509879         0.707172  1997.0  0.755268  0.784954
# 11           0.509879         0.707172  1997.0  0.795196  0.780021
# 12           0.509879         0.707172  1997.0  0.795196  0.778252
# 13           0.509879         0.707172  1997.0  0.795196  0.778252
# 14           0.509879         0.707172  1997.0  0.818553  0.775151
# 15           0.509879         0.707172  1997.0  0.715226  0.774931
# 16           0.509879         0.707172  1997.0  0.755268  0.768206
# 17           0.509879         0.707172  1997.0  0.818553  0.761224
# 18           0.509879         0.707172  1997.0  0.755268  0.760989
# 19           0.509879         0.707172  1997.0  0.927835  0.758247
# 20           0.509879         0.707172  1997.0  0.795196  0.740374
# 21           0.509879         0.707172  1997.0  0.795196  0.738427
# 22           0.509879         0.707172  1997.0  0.795196  0.735982
# 23           0.509879         0.707172  1997.0  0.818553  0.726806
# 24           0.509879         0.707172  1997.0  0.755268  0.719468
# 25           0.509879         0.707172  1997.0  0.755268  0.705565
# 26           0.509879         0.707172  1997.0  0.755268  0.704721
# 27           0.509879         0.707172  1997.0  0.622536  0.701675
# 28           0.509879         0.707172  1997.0  0.755268  0.698236
# 29           0.509879         0.707172  1997.0  0.614395  0.695240
# 30           0.509879         0.707172  1997.0  0.650922  0.687904
# 31           0.509879         0.707172  1997.0  0.755268  0.679738
# 32           0.509879         0.707172  1997.0  0.795873  0.678492
# 33           0.509879         0.707172  1997.0  0.767852  0.671055
# 34           0.509879         0.707172  1997.0  0.785882  0.670192
# 35           0.509879         0.707172  1997.0  0.709812  0.670192
# 36           0.509879         0.707172  1997.0  0.699306  0.660033
# 37           0.509879         0.707172  1997.0  0.630177  0.628476
# 38           0.509879         0.707172  1997.0  0.748027  0.628476
# 39           0.509879         0.707172  1997.0  0.738716  0.628476
# 40           0.509879         0.707172  1997.0  0.709045  0.628476
# 41           0.509879         0.707172  1997.0  0.680236  0.628475
# 42           0.509879         0.707172  1997.0  0.646983  0.628475
# 43           0.509879         0.707172  1997.0  0.642543  0.596918
# 44           0.509879         0.707172  1997.0  0.631913  0.596918
# 0            0.314104         0.000000     0.0  1.000000  1.000000
# 1            0.314104         0.000000     0.0  0.989542  0.992175
# 2            0.314104         0.000000     0.0  0.852745  0.889826
# 3            0.314104         0.000000     0.0  0.802351  0.852121
# 4            0.314104         0.000000     0.0  0.882378  0.789661
#
#             artist_terms
# 0            post-grunge
# 1          southern rock
# 2              chill-out
# 3              soft rock
# 4      alternative dance
# 5           country rock
# 6       alternative rock
# 7               pop rock
# 8                 grunge
# 9               trip hop
# 10        christian rock
# 11             folk rock
# 12        easy listening
# 13                 disco
# 14                   ska
# 15  alternative pop rock
# 16      video game music
# 17          classic rock
# 18           stoner rock
# 19                  rock
# 20                   emo
# 21            soundtrack
# 22             indie pop
# 23            indie rock
# 24              new wave
# 25      progressive rock
# 26                 blues
# 27       christmas music
# 28                  funk
# 29    american trad rock
# 30         male vocalist
# 31     singer-songwriter
# 32                   pop
# 33                  punk
# 34           alternative
# 35                   90s
# 36              acoustic
# 37               country
# 38            electronic
# 39                 indie
# 40                  folk
# 41              american
# 42                   00s
# 43          instrumental
# 44                 house
# 0         piedmont blues
# 1       east coast blues
# 2        harmonica blues
# 3          country blues
# 4                  blues

# %% [markdown]
# From the output above, it can be seen that each `track` has as many rows as the number of `artist_terms` for the track's artist.

# %% [markdown]
# ### Reset the index, pickle and save dataframe
#
# Resetting of the index is critical in this case since the index repeats when a new track file is read. Failure to do this will lead to numerous bugs during further analysis.

# %%
# reset_index
df_mss_m = df_mss_m.reset_index()
del df_mss_m['index']
#df = df.reset_index(drop=True)
df_mss_m.head(50)
# Out:
#                  track                     title             song_id  \
# 0   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 1   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 2   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 3   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 4   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 5   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 6   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 7   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 8   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 9   TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 10  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 11  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 12  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 13  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 14  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 15  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 16  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 17  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 18  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 19  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 20  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 21  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 22  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 23  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 24  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 25  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 26  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 27  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 28  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 29  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 30  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 31  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 32  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 33  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 34  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 35  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 36  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 37  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 38  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 39  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 40  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 41  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 42  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 43  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 44  TRANGCR128F148CF28            Think About Me  SOOJCHC12A6D4F81E1
# 45  TRAQYRR128F92F8632  Twelve Gates To The City  SOZWUGO12A6D4FDCAE
# 46  TRAQYRR128F92F8632  Twelve Gates To The City  SOZWUGO12A6D4FDCAE
# 47  TRAQYRR128F92F8632  Twelve Gates To The City  SOZWUGO12A6D4FDCAE
# 48  TRAQYRR128F92F8632  Twelve Gates To The City  SOZWUGO12A6D4FDCAE
# 49  TRAQYRR128F92F8632  Twelve Gates To The City  SOZWUGO12A6D4FDCAE
#
#              artist_id                 artist_name  artist_familiarity  \
# 0   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 1   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 2   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 3   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 4   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 5   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 6   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 7   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 8   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 9   AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 10  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 11  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 12  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 13  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 14  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 15  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 16  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 17  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 18  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 19  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 20  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 21  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 22  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 23  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 24  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 25  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 26  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 27  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 28  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 29  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 30  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 31  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 32  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 33  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 34  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 35  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 36  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 37  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 38  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 39  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 40  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 41  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 42  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 43  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 44  AREPD8D1187FB3F5BC                Sister Hazel            0.731066
# 45  ARPC5161187B9AF35C  John Cephas & Phil Wiggins            0.388096
# 46  ARPC5161187B9AF35C  John Cephas & Phil Wiggins            0.388096
# 47  ARPC5161187B9AF35C  John Cephas & Phil Wiggins            0.388096
# 48  ARPC5161187B9AF35C  John Cephas & Phil Wiggins            0.388096
# 49  ARPC5161187B9AF35C  John Cephas & Phil Wiggins            0.388096
#
#     artist_hotttnesss  song_hotttnesss    year   at_freq     at_wt  \
# 0            0.509879         0.707172  1997.0  1.000000  1.000000
# 1            0.509879         0.707172  1997.0  0.795196  0.831104
# 2            0.509879         0.707172  1997.0  0.761407  0.811431
# 3            0.509879         0.707172  1997.0  0.795196  0.808603
# 4            0.509879         0.707172  1997.0  0.755268  0.806579
# 5            0.509879         0.707172  1997.0  0.755268  0.806579
# 6            0.509879         0.707172  1997.0  0.907628  0.804375
# 7            0.509879         0.707172  1997.0  0.835125  0.799851
# 8            0.509879         0.707172  1997.0  0.795196  0.791244
# 9            0.509879         0.707172  1997.0  0.755268  0.787546
# 10           0.509879         0.707172  1997.0  0.755268  0.784954
# 11           0.509879         0.707172  1997.0  0.795196  0.780021
# 12           0.509879         0.707172  1997.0  0.795196  0.778252
# 13           0.509879         0.707172  1997.0  0.795196  0.778252
# 14           0.509879         0.707172  1997.0  0.818553  0.775151
# 15           0.509879         0.707172  1997.0  0.715226  0.774931
# 16           0.509879         0.707172  1997.0  0.755268  0.768206
# 17           0.509879         0.707172  1997.0  0.818553  0.761224
# 18           0.509879         0.707172  1997.0  0.755268  0.760989
# 19           0.509879         0.707172  1997.0  0.927835  0.758247
# 20           0.509879         0.707172  1997.0  0.795196  0.740374
# 21           0.509879         0.707172  1997.0  0.795196  0.738427
# 22           0.509879         0.707172  1997.0  0.795196  0.735982
# 23           0.509879         0.707172  1997.0  0.818553  0.726806
# 24           0.509879         0.707172  1997.0  0.755268  0.719468
# 25           0.509879         0.707172  1997.0  0.755268  0.705565
# 26           0.509879         0.707172  1997.0  0.755268  0.704721
# 27           0.509879         0.707172  1997.0  0.622536  0.701675
# 28           0.509879         0.707172  1997.0  0.755268  0.698236
# 29           0.509879         0.707172  1997.0  0.614395  0.695240
# 30           0.509879         0.707172  1997.0  0.650922  0.687904
# 31           0.509879         0.707172  1997.0  0.755268  0.679738
# 32           0.509879         0.707172  1997.0  0.795873  0.678492
# 33           0.509879         0.707172  1997.0  0.767852  0.671055
# 34           0.509879         0.707172  1997.0  0.785882  0.670192
# 35           0.509879         0.707172  1997.0  0.709812  0.670192
# 36           0.509879         0.707172  1997.0  0.699306  0.660033
# 37           0.509879         0.707172  1997.0  0.630177  0.628476
# 38           0.509879         0.707172  1997.0  0.748027  0.628476
# 39           0.509879         0.707172  1997.0  0.738716  0.628476
# 40           0.509879         0.707172  1997.0  0.709045  0.628476
# 41           0.509879         0.707172  1997.0  0.680236  0.628475
# 42           0.509879         0.707172  1997.0  0.646983  0.628475
# 43           0.509879         0.707172  1997.0  0.642543  0.596918
# 44           0.509879         0.707172  1997.0  0.631913  0.596918
# 45           0.314104         0.000000     0.0  1.000000  1.000000
# 46           0.314104         0.000000     0.0  0.989542  0.992175
# 47           0.314104         0.000000     0.0  0.852745  0.889826
# 48           0.314104         0.000000     0.0  0.802351  0.852121
# 49           0.314104         0.000000     0.0  0.882378  0.789661
#
#             artist_terms
# 0            post-grunge
# 1          southern rock
# 2              chill-out
# 3              soft rock
# 4      alternative dance
# 5           country rock
# 6       alternative rock
# 7               pop rock
# 8                 grunge
# 9               trip hop
# 10        christian rock
# 11             folk rock
# 12        easy listening
# 13                 disco
# 14                   ska
# 15  alternative pop rock
# 16      video game music
# 17          classic rock
# 18           stoner rock
# 19                  rock
# 20                   emo
# 21            soundtrack
# 22             indie pop
# 23            indie rock
# 24              new wave
# 25      progressive rock
# 26                 blues
# 27       christmas music
# 28                  funk
# 29    american trad rock
# 30         male vocalist
# 31     singer-songwriter
# 32                   pop
# 33                  punk
# 34           alternative
# 35                   90s
# 36              acoustic
# 37               country
# 38            electronic
# 39                 indie
# 40                  folk
# 41              american
# 42                   00s
# 43          instrumental
# 44                 house
# 45        piedmont blues
# 46      east coast blues
# 47       harmonica blues
# 48         country blues
# 49                 blues

# %%
# Pickle the dataframe
path = "C:/Users/ganes_000/Documents/MSBA/Spring 2016/MA 755/Pickle Files"
df_mss_m.to_pickle(path+"/MSS_METADATA_SUBSET_500.pkl")

# %% [markdown]
# # Create Dataframe using Analysis and MusicBrainz
#
# The steps to do this are very similar to the creation of a dataframe using the metadata. The reason this is being done separately is to reduce the filesize since in this case, there will be a single row data for each track as opposed to the dataframe using metadata.
#
# The `make_1row_df` function returns a single row dataframe and takes the following input:
#
# - `filename`: full path file name of an MSD HDF5 file containing data for a single song
# - `metadata_vars`: list of variable names from `/metadata/songs`
# - `analysis_vars`: list of variable names from `/analysis/songs`
# - `musicbrainz_vars`: list of variable names from `/musicbrainz/songs`
# - `remove`:
#     - if `False` the variables listed in the last two parameters are retrieved from the input file
#     - if `True` all variables except those listed are retrieved from the input file

# %%
def make_1row_df(filename='', metadata_vars=[], analysis_vars=[], musicbrainz_vars = [], remove=False):
    # open `filename` as a HDF5 file
    store = pd.HDFStore(filename,"r")
    if remove==True:
        # `metadata_vars` and `analysis_vars` contain the variables to remove
        metadata_vars = list({item for item 
                                  in list(store.root.metadata.songs.read().dtype.names) 
                                  if item not in metadata_vars})
        analysis_vars = list({item for item 
                                  in list(store.root.analysis.songs.read().dtype.names) 
                                  if item not in analysis_vars})
        musicbrainz_vars = list({item for item 
                                  in list(store.root.musicbrainz.songs.read().dtype.names) 
                                  if item not in musicbrainz_vars})
    # else: `metadata_vars` and `analysis_vars` contain the variables to keep
    
    # retrieve the first `n` values as a horizontal array of 1 dimension
    segments_pitches = h1d_array(store.root.analysis.segments_pitches.read(),36)
    segments_timbre  = h1d_array(store.root.analysis.segments_timbre.read(),36)
    bars_confidence  = h1d_array(store.root.analysis.bars_confidence.read(),10)
    #similar_artists = h1d_array(store.root.metadata.similar_artists.read(),10)
    
    
    # store these values as variables in single dataframes
    #s_art_df = pd.DataFrame(similar_artists ,columns=var_list('sart_',bars_confidence .shape[1]))
    bc_df = pd.DataFrame(bars_confidence ,columns=var_list('bc_',bars_confidence .shape[1]))
    sp_df = pd.DataFrame(segments_pitches,columns=var_list('sp_',segments_pitches.shape[1]))
    st_df = pd.DataFrame(segments_timbre ,columns=var_list('st_',segments_timbre .shape[1]))

    # get track from filename
    match = re.split('\/',filename)
    match[-1]
    match = re.split('\.',match[-1])
    
    # merge these single dataframes into one single row dataframe
    ret = pd.concat([
            # make single row dataframe from track
            pd.DataFrame([match[0]], columns=['track']),
            # retrieve a single row dataframe from `/metadata/songs`
            pd.DataFrame(store.root.metadata.songs.read(), 
                         columns=metadata_vars),
            # retrieve a single row dataframe from `/analysis/songs`
            pd.DataFrame(store.root.analysis.songs.read(), 
                         columns=analysis_vars),
            # retrieve a single row dataframe from `/musicbrainz/songs`
            pd.DataFrame(store.root.musicbrainz.songs.read(), 
                         columns=musicbrainz_vars),
            bc_df, 
            sp_df,
            st_df],
            #s_art_df,
            axis=1) # `axes=1` means stack the dataframes horizontally 
    # close the HDF5 file
    store.close()
    # return the merged dataframe
    return(ret)

# %% [markdown]
# ### Read one track file and validate

# %%
# Read one track file and get the data - which will be a single row
f_a = make_1row_df(filename=filenames[40],
                            metadata_vars=['track_7digitalid','title','song_id','artist_id','artist_name',
                                                'release','idx_similar_artists',
                                               'artist_familiarity','artist_hotttnesss','artist_location',
                                               'artist_longitude','artist_latitude','song_hotttnesss'],
                            # Omit: genre
                            analysis_vars=['track_id','duration','key','loudness','mode',
                                           'tempo','time_signature','end_of_fade_in'],
                             musicbrainz_vars = ['year'],
                            # Omit: danceability, energy
                            remove=False
                           )

#a.iloc[:,3:40]
print(type(f_a))
f_a

# %% [markdown]
# ### Read all the tracks from `filenames`
#
# The result of this command is a list of single row dataframes with columns indicated in the variables list.

# %%
list_mss_a = [make_1row_df(filename=filename,
                           metadata_vars=['track_7digitalid','title','song_id','artist_id','artist_name',
                                                'release','idx_similar_artists',
                                               'artist_familiarity','artist_hotttnesss','artist_location',
                                               'artist_longitude','artist_latitude','song_hotttnesss'],
                            # Omit: genre
                            analysis_vars=['track_id','duration','key','loudness','mode',
                                           'tempo','time_signature','end_of_fade_in'],
                             musicbrainz_vars = ['year'],
                            # Omit: danceability, energy
                            remove=False
                           )
                for filename in filenames[0:len(filenames)] # get data from all the files
              ]
len(list_mss_a), list_mss_a[0].shape

# %% [markdown]
# ### Merge all dataframes of list_mss_a into a single dataframe stored in df_mss_a

# %%
df_mss_a = pd.concat(list_mss_a,axis=0).reset_index(drop=True)

# %% [markdown]
# ### Remove "b ' " from relevant columns

# %%
#df_mss_a.dtypes
# remove b' from the requisite columns
df_mss_a = remove_b_mul_col(df_mss_a, col = [2,4,6,100,103])
df_mss_a

# %% [markdown]
# ### Pickle and save the dataframe object

# %%
# Pickle the dataframe
path = "C:/Users/ganes_000/Documents/MSBA/Spring 2016/MA 755/Pickle Files"
df_mss_a.to_pickle(path+"/MSS_ANALYSIS_DATA_SUBSET_500.pkl")
