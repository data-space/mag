# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ganes_000\\Dropbox\\MA755 Public\\pynotes'

# %%
path = "C:\\Users\\ganes_000\\Documents\\MSBA\\Spring 2016\\MA 755\\networkx-1.11\\networkx-1.11"
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ganes_000\\Documents\\MSBA\\Spring 2016\\MA 755\\networkx-1.11\\networkx-1.11'

# %%
import networkx as nx
nx.__version__
# Out:
# '1.11'

# %%
import pandas as pd
pd.__version__
# Out:
# '0.16.2'

# %%
file_path = "C:\\Users\\ganes_000\\Documents\\MSBA\\Spring 2016\\MA 755\\Data"
os.chdir(file_path)
data_frame = pd.DataFrame(pd.read_csv('graph_25_track_track.csv'))
data_frame[["1","0"]]
# Out:
#                         1                   0
# 0      ARNTLGG11E2835DDB9  ARNTLGG11E2835DDB9
# 1      ARBJSO81187B9BA09B  ARBJSO81187B9BA09B
# 2      AR3WMW01187B9921F7  AR3WMW01187B9921F7
# 3      AR89DTT1187B9A7ED5  AR89DTT1187B9A7ED5
# 4      ARK9TRQ1187B99C095  ARK9TRQ1187B99C095
# 5      ARTB56G11C8A41569D  ARTB56G11C8A41569D
# 6      ARMQHX71187B9890D3  ARMQHX71187B9890D3
# 7      ARNIFX51187FB418EA  ARNIFX51187FB418EA
# 8      ARMBTFC1187FB56343  ARMBTFC1187FB56343
# 9      AR3PN3R1187FB4CEBD  AR3PN3R1187FB4CEBD
# 10     ARQGYP71187FB44566  ARQGYP71187FB44566
# 11     AR0X3JJ1187FB3A9A7  AR0X3JJ1187FB3A9A7
# 12     AR1PCLK1187FB5BBFF  AR1PCLK1187FB5BBFF
# 13     AR10USD1187B99F3F1  AR10USD1187B99F3F1
# 14     ARD7TVE1187B99BFB1  ARD7TVE1187B99BFB1
# 15     ARGCY1Y1187B9A4FA5  ARGCY1Y1187B9A4FA5
# 16     ARU0HTX1187B98B4C6  ARU0HTX1187B98B4C6
# 17     AR1Y2PT1187FB5B9CE  AR1Y2PT1187FB5B9CE
# 18     ARQ9BO41187FB5CF1F  ARQ9BO41187FB5CF1F
# ...
